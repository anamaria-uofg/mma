# %% [markdown]
# # Load input CSV files and run them through PALS

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle
import pandas as pd

sys.path.append('/Users/anamaria/git/PALS/')

# %%
WIN = 'D:/'
MAC = '/Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/'

osp = MAC

# %%
from pals.pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, download_from_pimp
from pals.feature_extraction import DataSource
from pals.PLAGE import PLAGE
from pals.ORA import ORA
from pals.GSEA import GSEA
from pals.common import *
# Out:
# 2020-11-14 18:58:23.125 | WARNING  | pals.reactome:get_neo4j_driver:14 - Using a default neo4j server: bolt://localhost:7687
# 2020-11-14 18:58:23.127 | WARNING  | pals.reactome:get_neo4j_driver:19 - Using a default neo4j username or password: neo4j
# 2020-11-14 18:58:23.141 | INFO     | pals.reactome:get_neo4j_driver:24 - Created graph database driver for bolt://localhost:7687 (neo4j)

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Load data

# %%
osp = '/Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/'
intensity_csv = osp+'pals_analysis/intensity.csv'
annotation_csv =osp+'pals_analysis/annotation.csv'
sd = pd.read_csv(osp+'pals_analysis/sample_description.csv')

experimental_design =  {
    'comparisons': [{'case': 'infected', 'control': 'control', 'name':'infected/control'}],
    'groups': {'infected': [], 'control': []}
}    

for case in experimental_design['groups']:
    if case == 'infected':
        experimental_design['groups'][case] = [s for s in sd[sd['Condition'] == 'infected']['Sample Name']]
    if case == 'control':
        experimental_design['groups'][case] = [s for s in sd[sd['Condition'] == 'control']['Sample Name']]

# %%
int_df, annotation_df, groups = load_data(intensity_csv, annotation_csv)
# Out:
# 2020-11-14 18:58:33.604 | DEBUG    | pals.common:load_data:165 - Loaded 1084 x 69 peak intensities from /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pals_analysis/intensity.csv
# 2020-11-14 18:58:33.605 | DEBUG    | pals.common:load_data:166 - Loaded groups: {'control': ['KM_10.mzXML', 'KM_4.mzXML', 'KM_1.mzXML', 'KM_16.mzXML', 'KM_13.mzXML', 'KM_19.mzXML', 'KM_7.mzXML', 'C7_2.mzXML', 'C10_2.mzXML', 'C18_2.mzXML', 'C2_2.mzXML', 'C12_2.mzXML', 'C5_2.mzXML', 'C8_2.mzXML', 'C17_2.mzXML', 'C20_2.mzXML', 'C19_2.mzXML', 'C14_2.mzXML', 'C3_2.mzXML', 'C11_2.mzXML', 'C6_2.mzXML', 'C1_2.mzXML', 'C16_2.mzXML', 'C4_2.mzXML', 'C13_2.mzXML', 'C9_2.mzXML', 'C1.mzXML', 'C7.mzXML', 'C6_r.mzXML', 'C3.mzXML', 'C2.mzXML', 'C9.mzXML', 'C5.mzXML', 'C4.mzXML', 'C10.mzXML'], 'infected': ['KM_9.mzXML', 'KM_3.mzXML', 'KM_12.mzXML', 'KM_18.mzXML', 'KM_15.mzXML', 'KM_21.mzXML', 'KM_6.mzXML', 'VL7.mzXML', 'VL17.mzXML', 'VL16.mzXML', 'VL10.mzXML', 'VL11.mzXML', 'VL1.mzXML', 'VL14.mzXML', 'VL15.mzXML', 'VL5.mzXML', 'VL4.mzXML', 'VL8.mzXML', 'VL9.mzXML', 'VL3.mzXML', 'VL13.mzXML', 'VL12.mzXML', 'VL19.mzXML', 'VL18.mzXML', 'ZIK6.mzXML', 'ZIK10.mzXML', 'ZIK7.mzXML', 'ZIK1.mzXML', 'ZIK4.mzXML', 'ZIK5.mzXML', 'ZIK9.mzXML', 'ZIK8.mzXML', 'ZIK3.mzXML', 'ZIK2.mzXML']}
# 2020-11-14 18:58:33.618 | DEBUG    | pals.common:load_data:170 - Loaded 322 peak annotations from /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pals_analysis/annotation.csv

# %%
samples = np.array(int_df.columns)

# %%
annotation_df
# Out:
#         entity_id
# peak_id
# n36        C05984
# n36        C01089
# n36        C03197
# n36        C06001
# n36        C00989
# ...           ...
# p122       C05145
# p122       C01205
# p122       C03284
# p122       C01026
# p3305      C00906
#
# [322 rows x 1 columns]

# %% [markdown]
# ### PALS analysis using KEGG database exported from PiMP

# %%
ds = DataSource(int_df, annotation_df, experimental_design, DATABASE_PIMP_KEGG)
# Out:
# 2020-11-11 15:08:52.985 | DEBUG    | pals.feature_extraction:__init__:43 - Using PiMP_KEGG as database
# 2020-11-11 15:08:52.988 | DEBUG    | pals.loader:load_data:42 - Loading /Users/anamaria/git/PALS/pals/data/PiMP_KEGG.json.zip
# 2020-11-11 15:08:53.071 | DEBUG    | pals.feature_extraction:__init__:56 - Mapping pathway to unique ids
# 2020-11-11 15:08:53.096 | DEBUG    | pals.feature_extraction:__init__:70 - Creating dataset to pathway mapping
# 2020-11-11 15:08:53.208 | DEBUG    | pals.feature_extraction:__init__:98 - Computing unique id counts

# %%
ds = DataSource(int_df, annotation_df, experimental_design, DATABASE_REACTOME_KEGG, 
                reactome_species=REACTOME_SPECIES_HOMO_SAPIENS, reactome_metabolic_pathway_only=True)
# Out:
# 2020-11-14 18:58:40.333 | DEBUG    | pals.feature_extraction:__init__:43 - Using COMPOUND as database
# 2020-11-14 18:58:40.335 | DEBUG    | pals.loader:load_data:84 - Loading /Users/anamaria/git/PALS/pals/data/reactome/metabolic_pathways/COMPOUND/Homo sapiens.json.zip
# 2020-11-14 18:58:40.386 | DEBUG    | pals.feature_extraction:__init__:56 - Mapping pathway to unique ids
# 2020-11-14 18:58:40.390 | DEBUG    | pals.feature_extraction:__init__:70 - Creating dataset to pathway mapping
# 2020-11-14 18:58:40.494 | DEBUG    | pals.feature_extraction:__init__:98 - Computing unique id counts

# %%
plage = PLAGE(ds)

# %%
pathway_df = plage.get_pathway_df()
# Out:
# 2020-11-14 18:58:41.695 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:308 - Setting the zero intensity values in the dataframe
# 2020-11-14 18:58:41.715 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:310 - 0
# 2020-11-14 18:58:41.767 | DEBUG    | pals.feature_extraction:standardize_intensity_df:277 - Scaling the data across the sample: zero mean and unit variance
# 2020-11-14 18:58:41.826 | DEBUG    | pals.PLAGE:get_plage_activity_df:90 - Mean values of the rows in the DF is [ 0. -0.  0. ...  0. -0.  0.]
# 2020-11-14 18:58:41.830 | DEBUG    | pals.PLAGE:get_plage_activity_df:91 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2020-11-14 18:58:41.969 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:102 - Calculating plage p-values with resampling
# 2020-11-14 18:58:41.970 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:109 - Comparison infected/control
# 2020-11-14 18:58:41.971 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 0/1000
# 2020-11-14 18:58:42.207 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 100/1000
# 2020-11-14 18:58:42.396 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 200/1000
# 2020-11-14 18:58:42.580 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 300/1000
# 2020-11-14 18:58:42.788 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 400/1000
# 2020-11-14 18:58:42.983 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 500/1000
# 2020-11-14 18:58:43.168 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 600/1000
# 2020-11-14 18:58:43.359 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 700/1000
# 2020-11-14 18:58:43.556 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 800/1000
# 2020-11-14 18:58:43.738 | DEBUG    | pals.PLAGE:set_up_resample_plage_p_df:117 - Resampling 900/1000
# 2020-11-14 18:58:44.078 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:330 - Calculating dataset formula coverage

# %%
pd.set_option('display.max_rows', 500)
pathway_df.sort_values('infected/control p-value', ascending=True, inplace=True)
#pathway_df
pathway_df[pathway_df['tot_ds_F'] >= 10]
# Out:
#                            pw_name  infected/control p-value  unq_pw_F  \
# R-HSA-71240  Tryptophan catabolism                  0.998939        27
#
#              tot_ds_F  F_coverage        sf  exp_F  Ex_Cov  \
# R-HSA-71240        10       37.04  0.001464   3.74   13.85
#
#              COMPOUND infected/control comb_p
# R-HSA-71240                          0.998939

# %%
pname = 'R-HSA-71240'
cids = []
annot = []
logfc = []
for cid in ds.dataset_pathways_to_row_ids[pname]:
    if cid not in cids:
        
        for kegg in (get_peak_annotations(cid)):
            cids.append(cid)
            annot.append(kegg)
            logfc.append(get_logfc(cid))

# %%
df = pd.DataFrame([cids, annot, logfc], ["cid", "annot", "logfc"]).transpose().sort_values(by = 'logfc')
df.to_csv(osp+'pals_analysis/'+pname+'.csv')

# %%
group = int_df.loc[cids]

# %%
import seaborn as sns
sns.clustermap(group, center=0, cmap='vlag', col_colors=group_colours,
                       col_cluster=False, linewidths=0.75, cbar_pos=(0.1, 0.05, 0.05, 0.18))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c977885358c5> in <module>
#       1 import seaborn as sns
# ----> 2 sns.clustermap(group, center=0, cmap='vlag', col_colors=group_colours,
#       3                        col_cluster=False, linewidths=0.75, cbar_pos=(0.1, 0.05, 0.05, 0.18))
#
# NameError: name 'group_colours' is not defined

# %%
group_intensities = intensities_df.loc[members][all_samples]
group_colours = pd.Series(all_groups, index=group_intensities.columns).map(group_lut)
group_colours.name = 'groups'

# %%
#plot heatmap
g = sns.clustermap(group_intensities, center=0, cmap='vlag', col_colors=group_colours,
                       col_cluster=False, linewidths=0.75, cbar_pos=(0.1, 0.05, 0.05, 0.18))
plt.suptitle('Formula Hits in Pathways', y=0.85)

# draw group legend
for group in used_groups:
        g.ax_col_dendrogram.bar(0, 0, color=group_lut[group], label=group, linewidth=0)
    g.ax_col_dendrogram.legend(loc="right")

    plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)

    # render plot
    st.pyplot()

    data = []
    for idx in members:
        formula = ','.join(dataset_row_id_to_unique_ids[idx])
        row = [idx, formula]
        data.append(row)
    data_df = pd.DataFrame(data, columns=['Row Index', 'Formula Annotations'])

# %%
MNET_PATH = '/Users/anamaria/git/molnet/code/'
sys.path.append(MNET_PATH)
sys.path.append('..')
import peakinfo
with open(osp+'pymz/mzmine/peak_picked_files/peakinfolist.dict', 'rb') as file:
    peakinfolist_positive = pickle.load(file)
with open(osp+'negative_mode/samples/peakinfolist.dict', 'rb') as file:
    peakinfolist_negative = pickle.load(file)
    
for peak in peakinfolist_positive:
    peak.change_cid('p')
for peak in peakinfolist_negative:
    peak.change_cid('n')

# %%
def get_peak_annotations(cid):
    if cid.startswith('n'):
        for peak in peakinfolist_negative:
            if peak.cid == cid:
                return peak.get_possible_kegg_ids()
    else:
        for peak in peakinfolist_positive:
            if peak.cid == cid:
                return peak.get_possible_kegg_ids()

# %%
def get_logfc(cid):
    if cid.startswith('n'):
        for peak in peakinfolist_negative:
            if peak.cid == cid:
                return peak.logfc
    else:
        for peak in peakinfolist_positive:
            if peak.cid == cid:
                return peak.logfc

# %%
def get_peak(cid):
    if cid.startswith('n'):
        for peak in peakinfolist_negative:
            if peak.cid == cid:
                return peak
    else:
        for peak in peakinfolist_positive:
            if peak.cid == cid:
                return peak

# %%
#added intensities to peakinfo
for cid in int_df.index:
    intensities = {}
    length = len(int_df.loc[cid])
    for i in range(length):
        intensities[int_df.loc[cid].index[i]] = int_df.loc[cid][i]

# %%
intensities
# Out:
# {'KM_10.mzXML': 17186613.05,
#  'KM_9.mzXML': 13797797.8,
#  'KM_3.mzXML': 32745048.05,
#  'KM_4.mzXML': 25800199.16,
#  'KM_1.mzXML': 40975623.07,
#  'KM_16.mzXML': 16051225.69,
#  'KM_13.mzXML': 14364477.53,
#  'KM_12.mzXML': 14768384.9,
#  'KM_19.mzXML': 15232686.65,
#  'KM_18.mzXML': 18552731.84,
#  'KM_15.mzXML': 17813351.0,
#  'KM_21.mzXML': 21744430.05,
#  'KM_7.mzXML': 17569548.49,
#  'KM_6.mzXML': 19078341.28,
#  'C7_2.mzXML': 42847335.84,
#  'C10_2.mzXML': 48234259.52,
#  'VL7.mzXML': 28440550.37,
#  'C18_2.mzXML': 45397271.78,
#  'C2_2.mzXML': 43252999.04,
#  'VL17.mzXML': 83811408.15,
#  'VL16.mzXML': 59913060.79,
#  'C12_2.mzXML': 36125496.58,
#  'C5_2.mzXML': 32269382.2,
#  'C8_2.mzXML': 25101048.48,
#  'VL10.mzXML': 97601512.18,
#  'VL11.mzXML': 27148021.91,
#  'VL1.mzXML': 44558194.03,
#  'C17_2.mzXML': 44130181.51,
#  'C20_2.mzXML': 41509261.68,
#  'VL14.mzXML': 28739324.89,
#  'VL15.mzXML': 25372759.12,
#  'C19_2.mzXML': 62212558.3,
#  'C14_2.mzXML': 48669963.09,
#  'C3_2.mzXML': 53138417.66,
#  'C11_2.mzXML': 42120715.33,
#  'C6_2.mzXML': 53049947.22,
#  'VL5.mzXML': 41027211.74,
#  'VL4.mzXML': 51917673.6,
#  'VL8.mzXML': 72506622.66,
#  'VL9.mzXML': 42279695.24,
#  'C1_2.mzXML': 46143531.44,
#  'C16_2.mzXML': 43369773.78,
#  'VL3.mzXML': 50560354.94,
#  'C4_2.mzXML': 43000356.79,
#  'C13_2.mzXML': 32356097.98,
#  'VL13.mzXML': 40430943.34,
#  'C9_2.mzXML': 56157208.65,
#  'VL12.mzXML': 40097850.62,
#  'VL19.mzXML': 47958875.4,
#  'VL18.mzXML': 21221673.08,
#  'ZIK6.mzXML': 28621253.99,
#  'ZIK10.mzXML': 33008265.78,
#  'ZIK7.mzXML': 24640484.38,
#  'C1.mzXML': 20854256.24,
#  'ZIK1.mzXML': 30493883.11,
#  'C7.mzXML': 30793380.8,
#  'C6_r.mzXML': 33884016.85,
#  'C3.mzXML': 33834689.27,
#  'C2.mzXML': 30139297.5,
#  'C9.mzXML': 43779531.76,
#  'ZIK4.mzXML': 27815138.88,
#  'ZIK5.mzXML': 22048613.11,
#  'C5.mzXML': 35297636.28,
#  'C4.mzXML': 43534569.8,
#  'ZIK9.mzXML': 37816910.3,
#  'ZIK8.mzXML': 24640157.92,
#  'ZIK3.mzXML': 29446070.64,
#  'ZIK2.mzXML': 30737764.9,
#  'C10.mzXML': 30297188.64}

# %%
for i in int_df.loc['p1']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-37f3f70cbd37> in <module>
# ----> 1 for _,i in int_df.loc['p1']:
#       2     print(i)
#
# TypeError: cannot unpack non-iterable float object

# %%
for row_ids, row in int_df.iterrows():
    print(row.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-2d70ce6b98aa> in <module>
#       1 for row_ids, row in int_df.iterrows():
# ----> 2     print(row.columns)
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
annotation_df
# Out:
#            entity_id
# peak_id
# n36           C05984
# n36           C01089
# n36           C03197
# n36           C06001
# n36           C00989
# n1480         C04717
# n1480         C14827
# n493          C00064
# n493          C05100
# n493          C00819
# n1436         C01595
# n351          C00233
# n351          C06102
# n351          C03465
# n337          C00418
# n55           C00256
# n55           C01013
# n55           C00186
# n55           C00184
# n62           C00256
# n62           C01013
# n62           C00186
# n62           C00184
# n509          C00064
# n509          C05100
# n509          C00819
# n41           C00258
# n1608         C06124
# n296          C00245
# n484          C00026
# n54           C00209
# n1597         C04555
# n1607         C06124
# n1192         C00491
# n194          C00141
# n385          C00149
# n774          C00031
# n774          C00221
# n774          C00247
# n774          C02336
# n774          C00267
# n774          C00738
# n774          C00936
# n774          C00095
# n774          C00962
# n774          C01582
# n774          C00795
# n774          C00137
# n774          C00293
# n774          C00124
# n774          C00984
# n774          C00159
# n1218         C00299
# n160          C00106
# n142          C00065
# n142          C00740
# n856          CE2122
# n137          C01188
# n336          C01879
# n336          C04281
# n336          C04282
# n647          C00079
# n647          CE2172
# n663          C00079
# n663          CE2172
# n526          C00073
# n52           C00213
# n52           C00041
# n52           C00099
# n52           C00133
# n1355         C00249
# n10           C00037
# n204          C03214
# n204          C00441
# n204          C03508
# n2431         C00233
# n2431         C06102
# n2431         C03465
# n2431         C00671
# n1619         C15517
# n1619         C04483
# n1619         C02528
# n934          C02679
# n1374         lneldc
# n1374         ocdcya
# n964          C05660
# n765          C00355
# n171          C00900
# n171          C06010
# n366          C02642
# n366          C00152
# n657          C16358
# n657          C16353
# n1453         C00219
# n1588         C04555
# n797          C01507
# n797          C00794
# n797          C01697
# n954          C00078
# n954          C00525
# n1395         C01530
# n1398         C01530
# n572          CE2006
# n572          CE6506
# n191          C00122
# n312          C00906
# n4644         C00259
# n4644         C00309
# n4644         C00312
# n4644         C00310
# n4644         C00121
# n4644         C00181
# n1323         C04148
# n1323         C05642
# n535          CE6252
# n105          C00059
# n355          C00123
# n355          C00407
# n478          C05572
# n478          C00940
# n507          C03341
# n507          C01165
# n507          C01157
# n507          C00430
# n507          C03440
# n507          C01110
# n92           C00059
# n929          C02679
# n742          C00954
# n742          C05634
# n1125         C06424
# n2033         C06103
# n786          C00082
# n786          CE2174
# n247          C05519
# n247          C00188
# n1097         ttdcea
# n412          C01620
# n1515         C06429
# n479          C05572
# n479          C00940
# n1123         C06424
# p633          C00418
# p613          C00906
# p613          C00064
# p613          C00047
# p324          C00245
# p324          C00245
# p425          C02642
# p425          C00152
# p926          C00064
# p926          C05100
# p926          C00819
# p101          C00906
# p397          C01879
# p397          C04281
# p397          C04282
# p168          C05522
# p168          C00380
# p168          C00380
# p365          C02238
# p659          C00418
# p2549         C06124
# p2548         C06124
# p952          C02727
# p1839         C00491
# p1839         C00491
# p459          C00155
# p459             NaN
# p366          C00217
# p366          C00025
# p366          C05938
# p366          C00408
# p2664      tmndnccrn
# p2600         C02990
# p2696     dcsptn1crn
# p2696       clpndcrn
# p3577         C05587
# p3577         C07453
# p3577         C00250
# p2151         C00410
# p1463         C00328
# p1463         C05647
# p1463         C00328
# p1463         C00328
# p667          C00073
# p667          C00073
# p667          C00073
# p634          C00064
# p634          C05100
# p634          C00819
# p109          C05519
# p109          C00188
# p614          C00064
# p614          C05100
# p614          C00819
# p1100         C13747
# p1100         C07480
# p1100         C01586
# p690          C00073
# p690             NaN
# p121          C00073
# p38           C05519
# p38           C00188
# p38           C00408
# p2235         C02838
# p264          C00483
# p264          C01183
# p264          C02735
# p264          C00079
# p2693        c226crn
# p906          C00079
# p906          CE2172
# p423          C00073
# p2384            NaN
# p3317         C00079
# p3317         CE2172
# p676          C00906
# p1002         C00135
# p1401         C00031
# p1401         C00221
# p1401         C00247
# p1401         C02336
# p1401         C00267
# p1401         C00738
# p1401         C00936
# p1401         C00095
# p1401         C00962
# p1401         C01582
# p1401         C00795
# p1401         C00137
# p1401         C00293
# p1401         C00124
# p1401         C00984
# p1401         C00159
# p3867           pcrn
# p298          C05828
# p298          C00153
# p1229         CE2122
# p2234         C02838
# p1591           pcrn
# p330          C00178
# p678          C00073
# p2620      lneldccrn
# p2620        lnlccrn
# p726          CE2577
# p259          C05519
# p259          C00188
# p152          C06178
# p424          C02642
# p424          C00152
# p424          C00300
# p2646         C05462
# p2646         C05466
# p599          C03239
# p599          C02946
# p599          C04076
# p4109         C04148
# p4109         C05642
# p1221         C01252
# p602          C01035
# p137          C01026
# p2629       elaidcrn
# p2629        vacccrn
# p2629         odecrn
# p615          C00439
# p798          C00327
# p1033         C16595
# p1033         C16587
# p1033         C00954
# p162          C01035
# p2726    tetpent6crn
# p2726    tetpent3crn
# p756          C00135
# p2647         C05462
# p2647         C05466
# p714          C00300
# p714          C06804
# p1189         C05660
# p1189         C00078
# p1037         C00327
# p134          C02356
# p134          C01026
# p134          C00334
# p134          C05145
# p134          C01205
# p134          C03284
# p198          C00077
# p198          C00515
# p198          C01602
# p2727    tetpent6crn
# p2727    tetpent3crn
# p1439         C00078
# p1439         C00525
# p1439         C00078
# p1439         C00078
# p1053         C00327
# p1448         C00078
# p1448         C00525
# p668          C00073
# p460          C00791
# p460          C00147
# p460          C03758
# p510          C00719
# p510          C00431
# p510          C00183
# p3256         C08261
# p144          C00065
# p144          C00740
# p144          C00065
# p1592           pcrn
# p487          C00785
# p487          C00262
# p1213         C02727
# p122          C02356
# p122          C01026
# p122          C00334
# p122          C05145
# p122          C01205
# p122          C03284
# p122          C01026
# p3305         C00906

# %%
for row_id,row in int_df:
    if row_id in annotation_df.index:
        new_row_id =
