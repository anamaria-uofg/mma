# %%
import xml.etree.ElementTree
import pandas as pd
import os, sys
import pickle

MNET_PATH = '/Users/anamaria/git/molnet/code/'
sys.path.append(MNET_PATH)

# %%
WIN = 'D:/'
MAC = '/Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/'

osp = MAC

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('..')
import metab_utils

# %%
df = pd.read_csv(osp+'pymz/mzmine/peak_picked_files/limma_independent_toptable.csv')
description = pd.read_csv(osp+'pymz/mzmine/peak_picked_files/feature_description.csv')

# %%
for index, row in df.iterrows():
    logfc = row['logFC']
    intensity = row['AveExpr']
    pval = row['adj.P.Val']
    for _, row2 in description.iterrows():
        index2 = row2['row ID']
        mz = row2['row m/z']
        rt = row2['row retention time']
        if index == index2:
            df.at[index, 'mz'] = mz
            df.at[index, 'rt'] = rt

# %% [markdown]
# ## Create metabolites dictionary

# %% [markdown]
# Parse metabolites list downloaded from HMDB in xml format;
#
# And extract into a dictionary the information we are interested in for each metabolite.

# %%
path_to_hmdbfile = osp+ 'Metabolomics_datasets/serum_metabolites.xml'
et = xml.etree.ElementTree.parse(path_to_hmdbfile)
root = et.getroot()

# %%
metabolites = {}
stringtag = '{http://www.hmdb.ca}'
for metabolite in root.findall(stringtag+'metabolite'):
    for m in metabolite:
        print(m)
        print(m.text)
        for n in m:
            print('\t')
            print(n)
            print(n.text)
# Out:
# <Element '{http://www.hmdb.ca}version' at 0x116ed2680>
# 4.0
# <Element '{http://www.hmdb.ca}creation_date' at 0x116ed2720>
# 2005-11-16 15:48:42 UTC
# <Element '{http://www.hmdb.ca}update_date' at 0x116ed2810>
# 2019-01-11 19:13:56 UTC
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2900>
# HMDB0000001
# <Element '{http://www.hmdb.ca}status' at 0x116ed29a0>
# quantified
# <Element '{http://www.hmdb.ca}secondary_accessions' at 0x116ed2a40>
#
#
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2a90>
# HMDB00001
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2ae0>
# HMDB0004935
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2b30>
# HMDB0006703
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2b80>
# HMDB0006704
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2bd0>
# HMDB04935
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2c20>
# HMDB06703
#
# <Element '{http://www.hmdb.ca}accession' at 0x116ed2c70>
# HMDB06704
# <Element '{http://www.hmdb.ca}name' at 0x116ed2d10>
# 1-Methylhistidine
# <Element '{http://www.hmdb.ca}cs_description' at 0x116ed2e00>
# 1-Methylhistidine, also known as 1-mhis, belongs to the class of organic compounds known as histidine and derivatives. Histidine and derivatives are compounds containing cysteine or a derivative thereof resulting from reaction of cysteine at the amino group or the carboxy group, or from the replacement of any hydrogen of glycine by a heteroatom. 1-Methylhistidine has been found in human muscle and skeletal muscle tissues, and has also been detected in most biofluids, including cerebrospinal fluid, saliva, blood, and feces. Within the cell, 1-methylhistidine is primarily located in the cytoplasm. 1-Methylhistidine participates in a number of enzymatic reactions. In particular, 1-Methylhistidine and Beta-alanine can be converted into anserine; which is catalyzed by the enzyme carnosine synthase 1. In addition, Beta-Alanine and 1-methylhistidine can be biosynthesized from anserine; which is mediated by the enzyme cytosolic non-specific dipeptidase. In humans, 1-methylhistidine is involved in the histidine metabolism pathway. 1-Methylhistidine is also involved in the metabolic disorder called the histidinemia pathway.
# <Element '{http://www.hmdb.ca}description' at 0x116ed2ea0>
# One-methylhistidine (1-MHis) is derived mainly from the anserine of dietary flesh sources, especially poultry. The enzyme, carnosinase, splits anserine into b-alanine and 1-MHis. High levels of 1-MHis tend to inhibit the enzyme carnosinase and increase anserine levels. Conversely, genetic variants with deficient carnosinase activity in plasma show increased 1-MHis excretions when they consume a high meat diet. Reduced serum carnosinase activity is also found in patients with Parkinson's disease and multiple sclerosis and patients following a cerebrovascular accident. Vitamin E deficiency can lead to 1-methylhistidinuria from increased oxidative effects in skeletal muscle. 1-Methylhistidine is a biomarker for the consumption of meat, especially red meat.
# <Element '{http://www.hmdb.ca}synonyms' at 0x116ed2f40>
#
#
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8040>
# (2S)-2-amino-3-(1-Methyl-1H-imidazol-4-yl)propanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8090>
# 1-Methylhistidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8130>
# Pi-methylhistidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed81d0>
# (2S)-2-amino-3-(1-Methyl-1H-imidazol-4-yl)propanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8220>
# 1 Methylhistidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed82c0>
# 1-Methyl histidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8360>
# 1-Methyl-histidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8400>
# 1-Methyl-L-histidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed84a0>
# 1-MHis
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed84f0>
# 1-N-Methyl-L-histidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8590>
# L-1-Methylhistidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed8630>
# N1-Methyl-L-histidine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116ed86d0>
# 1-Methylhistidine dihydrochloride
# <Element '{http://www.hmdb.ca}chemical_formula' at 0x116ed8770>
# C7H11N3O2
# <Element '{http://www.hmdb.ca}average_molecular_weight' at 0x116ed8860>
# 169.1811
# <Element '{http://www.hmdb.ca}monisotopic_molecular_weight' at 0x116ed8900>
# 169.085126611
# <Element '{http://www.hmdb.ca}iupac_name' at 0x116ed89a0>
# (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)propanoic acid
# <Element '{http://www.hmdb.ca}traditional_iupac' at 0x116ed8a40>
# 1 methylhistidine
# <Element '{http://www.hmdb.ca}cas_registry_number' at 0x116ed8b30>
# 332-80-9
# <Element '{http://www.hmdb.ca}smiles' at 0x116ed8bd0>
# CN1C=NC(C[C@H](N)C(O)=O)=C1
# <Element '{http://www.hmdb.ca}inchi' at 0x116ed8cc0>
# InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11)12/h3-4,6H,2,8H2,1H3,(H,11,12)/t6-/m0/s1
# <Element '{http://www.hmdb.ca}inchikey' at 0x116ed8d60>
# BRMWTNUJHUMWMS-LURJTMIESA-N
# <Element '{http://www.hmdb.ca}taxonomy' at 0x116ed8e50>
#
#
#
# <Element '{http://www.hmdb.ca}description' at 0x116ed8ea0>
# This compound belongs to the class of organic compounds known as histidine and derivatives. These are compounds containing cysteine or a derivative thereof resulting from reaction of cysteine at the amino group or the carboxy group, or from the replacement of any hydrogen of glycine by a heteroatom.
#
# <Element '{http://www.hmdb.ca}direct_parent' at 0x116ed8f40>
# Histidine and derivatives
#
# <Element '{http://www.hmdb.ca}kingdom' at 0x116ed9090>
# Organic compounds
#
# <Element '{http://www.hmdb.ca}super_class' at 0x116ed9180>
# Organic acids and derivatives
#
# <Element '{http://www.hmdb.ca}class' at 0x116ed9270>
# Carboxylic acids and derivatives
#
# <Element '{http://www.hmdb.ca}sub_class' at 0x116ed9310>
# Amino acids, peptides, and analogues
#
# <Element '{http://www.hmdb.ca}molecular_framework' at 0x116ed93b0>
# Aromatic heteromonocyclic compounds
#
# <Element '{http://www.hmdb.ca}alternative_parents' at 0x116ed9450>
#
#
#
# <Element '{http://www.hmdb.ca}substituents' at 0x116ed9bd0>
#
#
#
# <Element '{http://www.hmdb.ca}external_descriptors' at 0x116edc950>
#
#
# <Element '{http://www.hmdb.ca}ontology' at 0x116edcb30>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116edcbd0>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116ee1b80>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116eeab80>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116eedf40>
#
#
# <Element '{http://www.hmdb.ca}state' at 0x116ef0cc0>
# Solid
# <Element '{http://www.hmdb.ca}experimental_properties' at 0x116ef0d60>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef0e00>
#
#
# <Element '{http://www.hmdb.ca}predicted_properties' at 0x116ef20e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2130>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2270>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef23b0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2540>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef26d0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2810>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2950>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2a90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2c20>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2d60>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef2ea0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6090>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6220>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6360>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef64a0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6630>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6770>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef68b0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6a40>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6b80>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6cc0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6e00>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef6f40>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef90e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116ef9220>
#
#
# <Element '{http://www.hmdb.ca}spectra' at 0x116ef93b0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9450>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9590>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9680>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9770>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9860>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9950>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9a40>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9b30>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9c20>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9d10>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9e00>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116ef9ef0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116efe040>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116efe130>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116efe220>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116efe310>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116efe400>
#
#
# <Element '{http://www.hmdb.ca}biological_properties' at 0x116efe540>
#
#
#
# <Element '{http://www.hmdb.ca}cellular_locations' at 0x116efe5e0>
#
#
#
# <Element '{http://www.hmdb.ca}biospecimen_locations' at 0x116efe720>
#
#
#
# <Element '{http://www.hmdb.ca}tissue_locations' at 0x116efe9f0>
#
#
#
# <Element '{http://www.hmdb.ca}pathways' at 0x116efeb80>
#
#
# <Element '{http://www.hmdb.ca}normal_concentrations' at 0x116f01040>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f010e0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f01720>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f01a90>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f01e00>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f061d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f06540>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f06900>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f06c70>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0a090>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0a4a0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0a860>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0abd0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0af90>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0f360>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0f720>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0fb30>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f0fef0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f143b0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f14770>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f14bd0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f18090>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f184a0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f18900>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f18d60>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1b220>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1b630>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1b9f0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1bdb0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1f1d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1f590>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1f950>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f1fd10>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f24130>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f244f0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f248b0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f24d60>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f281d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f285e0>
#
#
# <Element '{http://www.hmdb.ca}abnormal_concentrations' at 0x116f289f0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f28a40>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f28ef0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f2c2c0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f2c680>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f2c9f0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f2cdb0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f301d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f30590>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f30900>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f30d60>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f33180>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f334f0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f33900>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f33cc0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f380e0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f38590>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f38a90>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f38ea0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f3b310>
#
#
# <Element '{http://www.hmdb.ca}diseases' at 0x116f3b720>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f3b7c0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f3fd60>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f45040>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f4c0e0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f4c360>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f4fbd0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f538b0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f5e8b0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f5ef40>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116f62bd0>
#
#
# <Element '{http://www.hmdb.ca}drugbank_id' at 0x116f62ea0>
# DB04151
# <Element '{http://www.hmdb.ca}chebi_id' at 0x116f62f40>
# 50599
# <Element '{http://www.hmdb.ca}pubchem_compound_id' at 0x116f66040>
# 92105
# <Element '{http://www.hmdb.ca}phenol_explorer_compound_id' at 0x116f660e0>
# None
# <Element '{http://www.hmdb.ca}foodb_id' at 0x116f66180>
# FDB012119
# <Element '{http://www.hmdb.ca}knapsack_id' at 0x116f66220>
# None
# <Element '{http://www.hmdb.ca}chemspider_id' at 0x116f662c0>
# 83153
# <Element '{http://www.hmdb.ca}kegg_id' at 0x116f66360>
# C01152
# <Element '{http://www.hmdb.ca}meta_cyc_id' at 0x116f66400>
# CPD-1823
# <Element '{http://www.hmdb.ca}bigg_id' at 0x116f664a0>
# None
# <Element '{http://www.hmdb.ca}metlin_id' at 0x116f66540>
# 3741
# <Element '{http://www.hmdb.ca}pdb_id' at 0x116f665e0>
# HIC
# <Element '{http://www.hmdb.ca}wikipedia_id' at 0x116f66630>
# None
# <Element '{http://www.hmdb.ca}synthesis_reference' at 0x116f666d0>
# Jain, Rahul; Cohen, Louis A. Regiospecific alkylation of histidine and histamine at N-1 (t).Tetrahedron  (1996),  52(15),  5363-70.
# <Element '{http://www.hmdb.ca}general_references' at 0x116f66770>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f667c0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f668b0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f669a0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66a90>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66b80>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66c70>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66d60>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66e50>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f66f40>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f6a090>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f6a180>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116f6a270>
#
#
# <Element '{http://www.hmdb.ca}protein_associations' at 0x116f6a3b0>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116f6a450>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116f6a770>
#
#
# <Element '{http://www.hmdb.ca}version' at 0x116f6a9a0>
# 4.0
# <Element '{http://www.hmdb.ca}creation_date' at 0x116f6a9f0>
# 2005-11-16 15:48:42 UTC
# <Element '{http://www.hmdb.ca}update_date' at 0x116f6aa90>
# 2019-01-11 19:13:56 UTC
# <Element '{http://www.hmdb.ca}accession' at 0x116f6ab30>
# HMDB0000002
# <Element '{http://www.hmdb.ca}status' at 0x116f6ab80>
# quantified
# <Element '{http://www.hmdb.ca}secondary_accessions' at 0x116f6abd0>
#
#
#
# <Element '{http://www.hmdb.ca}accession' at 0x116f6ac20>
# HMDB00002
# <Element '{http://www.hmdb.ca}name' at 0x116f6ac70>
# 1,3-Diaminopropane
# <Element '{http://www.hmdb.ca}cs_description' at 0x116f6ad10>
# 1,3-Diaminopropane, also known as 1,3-propanediamine or trimethylenediamine, belongs to the class of organic compounds known as monoalkylamines. These are organic compounds containing an primary aliphatic amine group. 1,3-Diaminopropane exists as a liquid, soluble (in water), and a very strong basic compound (based on its pKa). 1,3-Diaminopropane has been detected in multiple biofluids, such as feces, urine, and blood. Within the cell, 1,3-diaminopropane is primarily located in the cytoplasm. 1,3-Diaminopropane exists in all eukaryotes, ranging from yeast to humans. 1,3-Diaminopropane can be converted into 3-aminopropionaldehyde through the action of the enzyme membrane primary amine oxidase. In humans, 1,3-diaminopropane is involved in the Beta-alanine metabolism pathway. 1,3-Diaminopropane is also involved in a few metabolic disorders, which include gaba-transaminase deficiency, the carnosinuria, carnosinemia pathway, and ureidopropionase deficiency. Outside of the human body, 1,3-diaminopropane can be found in a number of food items such as garden onion (var.), saskatoon berry, towel gourd, and pomegranate. This makes 1,3-diaminopropane a potential biomarker for the consumption of these food products.
# <Element '{http://www.hmdb.ca}description' at 0x116f6ad60>
# 1,3-Diaminopropane is a stable, flammable and highly hydroscopic fluid. It is a polyamine that is normally quite toxic if swallowed, inhaled or absorbed through the skin. It is a catabolic byproduct of spermidine. It is also a precursor in the enzymatic synthesis of beta-alanine. 1, 3-Diaminopropane is involved in the arginine/proline metabolic pathways and the beta-alanine metabolic pathway.
# <Element '{http://www.hmdb.ca}synonyms' at 0x116f6adb0>
#
#
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f6ae00>
# 1,3-Propanediamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f6aea0>
# 1,3-Propylenediamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f6af40>
# Propane-1,3-diamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70040>
# tn
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70090>
# 1,3-diamino-N-Propane
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70130>
# 1,3-Trimethylenediamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f701d0>
# 3-Aminopropylamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70270>
# a,W-Propanediamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70310>
# Trimethylenediamine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f703b0>
# Trimethylenediamine hydrochloride
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70400>
# Trimethylenediamine dihydrochloride
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116f70450>
# 1,3-Diaminepropane
# <Element '{http://www.hmdb.ca}chemical_formula' at 0x116f704f0>
# C3H10N2
# <Element '{http://www.hmdb.ca}average_molecular_weight' at 0x116f70540>
# 74.1249
# <Element '{http://www.hmdb.ca}monisotopic_molecular_weight' at 0x116f70590>
# 74.08439833
# <Element '{http://www.hmdb.ca}iupac_name' at 0x116f705e0>
# propane-1,3-diamine
# <Element '{http://www.hmdb.ca}traditional_iupac' at 0x116f70680>
# α,ω-propanediamine
# <Element '{http://www.hmdb.ca}cas_registry_number' at 0x116f706d0>
# 109-76-2
# <Element '{http://www.hmdb.ca}smiles' at 0x116f70720>
# NCCCN
# <Element '{http://www.hmdb.ca}inchi' at 0x116f70770>
# InChI=1S/C3H10N2/c4-2-1-3-5/h1-5H2
# <Element '{http://www.hmdb.ca}inchikey' at 0x116f707c0>
# XFNJVJPLKCPIBV-UHFFFAOYSA-N
# <Element '{http://www.hmdb.ca}taxonomy' at 0x116f70860>
#
#
#
# <Element '{http://www.hmdb.ca}description' at 0x116f708b0>
# This compound belongs to the class of organic compounds known as monoalkylamines. These are organic compounds containing an primary aliphatic amine group.
#
# <Element '{http://www.hmdb.ca}direct_parent' at 0x116f70900>
# Monoalkylamines
#
# <Element '{http://www.hmdb.ca}kingdom' at 0x116f70950>
# Organic compounds
#
# <Element '{http://www.hmdb.ca}super_class' at 0x116f709f0>
# Organic nitrogen compounds
#
# <Element '{http://www.hmdb.ca}class' at 0x116f70a90>
# Organonitrogen compounds
#
# <Element '{http://www.hmdb.ca}sub_class' at 0x116f70b30>
# Amines
#
# <Element '{http://www.hmdb.ca}molecular_framework' at 0x116f70b80>
# Aliphatic acyclic compounds
#
# <Element '{http://www.hmdb.ca}alternative_parents' at 0x116f70c20>
#
#
#
# <Element '{http://www.hmdb.ca}substituents' at 0x116f70db0>
#
#
#
# <Element '{http://www.hmdb.ca}external_descriptors' at 0x116f730e0>
#
#
# <Element '{http://www.hmdb.ca}ontology' at 0x116f73270>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116f732c0>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116f75680>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116f84900>
#
#
# <Element '{http://www.hmdb.ca}state' at 0x116f87cc0>
# Liquid
# <Element '{http://www.hmdb.ca}experimental_properties' at 0x116f87d10>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f87d60>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f87ef0>
#
#
# <Element '{http://www.hmdb.ca}predicted_properties' at 0x116f8b0e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b130>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b270>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b3b0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b4f0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b630>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b7c0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8b950>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8ba90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8bbd0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8bd10>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8be50>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8bf90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f180>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f310>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f450>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f590>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f720>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f860>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8f9a0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8fb30>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8fc70>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8fdb0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f8fef0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f93090>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f931d0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116f93310>
#
#
# <Element '{http://www.hmdb.ca}spectra' at 0x116f93450>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f934a0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93590>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93680>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93770>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93860>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93950>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93a40>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93b30>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93c20>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93d10>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93e00>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f93ef0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97040>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97130>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97220>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97310>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97400>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f974f0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f975e0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f976d0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f977c0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f978b0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f979a0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97a90>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97b80>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97c70>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97d60>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97e50>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f97f40>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b090>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b180>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b270>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b360>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b450>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b540>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b630>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b720>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b810>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b900>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9b9f0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bae0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bbd0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bcc0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bdb0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bea0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9bf90>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9f0e0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116f9f1d0>
#
#
# <Element '{http://www.hmdb.ca}biological_properties' at 0x116f9f2c0>
#
#
#
# <Element '{http://www.hmdb.ca}cellular_locations' at 0x116f9f310>
#
#
#
# <Element '{http://www.hmdb.ca}biospecimen_locations' at 0x116f9f3b0>
#
#
#
# <Element '{http://www.hmdb.ca}tissue_locations' at 0x116f9f4f0>
#
#
#
# <Element '{http://www.hmdb.ca}pathways' at 0x116f9f540>
#
#
# <Element '{http://www.hmdb.ca}normal_concentrations' at 0x116f9fbd0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f9fc20>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116f9ff90>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa4400>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa4810>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa4bd0>
#
#
# <Element '{http://www.hmdb.ca}abnormal_concentrations' at 0x116fa8040>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa8090>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa8400>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116fa87c0>
#
#
# <Element '{http://www.hmdb.ca}diseases' at 0x116fa8c70>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116fa8cc0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116fac7c0>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x116fb0770>
#
#
# <Element '{http://www.hmdb.ca}kegg_id' at 0x116fb0d60>
# C00986
# <Element '{http://www.hmdb.ca}chebi_id' at 0x116fb0db0>
# 15725
# <Element '{http://www.hmdb.ca}chemspider_id' at 0x116fb0e00>
# 415
# <Element '{http://www.hmdb.ca}pubchem_compound_id' at 0x116fb0e50>
# 428
# <Element '{http://www.hmdb.ca}foodb_id' at 0x116fb0ea0>
# FDB005274
# <Element '{http://www.hmdb.ca}drugbank_id' at 0x116fb0ef0>
# None
# <Element '{http://www.hmdb.ca}phenol_explorer_compound_id' at 0x116fb0f40>
# None
# <Element '{http://www.hmdb.ca}meta_cyc_id' at 0x116fb0f90>
# CPD-313
# <Element '{http://www.hmdb.ca}wikipedia_id' at 0x116fb6040>
# 1,3-Diaminopropane
# <Element '{http://www.hmdb.ca}knapsack_id' at 0x116fb60e0>
# C00007404
# <Element '{http://www.hmdb.ca}bigg_id' at 0x116fb6130>
# 36543
# <Element '{http://www.hmdb.ca}metlin_id' at 0x116fb6180>
# 5081
# <Element '{http://www.hmdb.ca}pdb_id' at 0x116fb61d0>
# 13D
# <Element '{http://www.hmdb.ca}synthesis_reference' at 0x116fb6220>
# Takayanagi, Yasuyuki; Oohinata, Takahiro.  Preparation of 1,3-diaminopropane from acrylonitrile and ammonia.    Jpn. Kokai Tokkyo Koho  (1994),     5 pp.
# <Element '{http://www.hmdb.ca}general_references' at 0x116fb6270>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb62c0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb63b0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb64a0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6590>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6680>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6770>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6860>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6950>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6a40>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x116fb6b30>
#
#
# <Element '{http://www.hmdb.ca}protein_associations' at 0x116fb6c20>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fb6c70>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fb6ea0>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fba130>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fba310>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fba540>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fba720>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x116fba900>
#
#
# <Element '{http://www.hmdb.ca}version' at 0x116fbab80>
# 4.0
# <Element '{http://www.hmdb.ca}creation_date' at 0x116fbabd0>
# 2005-11-16 15:48:42 UTC
# <Element '{http://www.hmdb.ca}update_date' at 0x116fbac70>
# 2019-01-11 19:13:56 UTC
# <Element '{http://www.hmdb.ca}accession' at 0x116fbad10>
# HMDB0000005
# <Element '{http://www.hmdb.ca}status' at 0x116fbad60>
# quantified
# <Element '{http://www.hmdb.ca}secondary_accessions' at 0x116fbadb0>
#
#
#
# <Element '{http://www.hmdb.ca}accession' at 0x116fbae00>
# HMDB00005
#
# <Element '{http://www.hmdb.ca}accession' at 0x116fbae50>
# HMDB0006544
#
# <Element '{http://www.hmdb.ca}accession' at 0x116fbaea0>
# HMDB06544
# <Element '{http://www.hmdb.ca}name' at 0x116fbaef0>
# 2-Ketobutyric acid
# <Element '{http://www.hmdb.ca}cs_description' at 0x116fbaf90>
# 3-Methyl pyruvic acid, also known as alpha-ketobutyric acid or 2-oxobutyric acid, belongs to the class of organic compounds known as short-chain keto acids and derivatives. These are keto acids with an alkyl chain the contains less than 6 carbon atoms. 3-Methyl pyruvic acid exists as a solid, soluble (in water), and a weakly acidic compound (based on its pKa). 3-Methyl pyruvic acid has been primarily detected in saliva, urine, blood, and cerebrospinal fluid. Within the cell, 3-methyl pyruvic acid is primarily located in the cytoplasm. 3-Methyl pyruvic acid exists in all eukaryotes, ranging from yeast to humans. In humans, 3-methyl pyruvic acid is involved in the methionine metabolism pathway, the selenoamino acid metabolism pathway, the glycine and serine metabolism pathway, and the threonine and 2-oxobutanoate degradation pathway. 3-Methyl pyruvic acid is also involved in several metabolic disorders, some of which include S-adenosylhomocysteine (sah) hydrolase deficiency, homocystinuria, cystathionine beta-synthase deficiency, the NON ketotic hyperglycinemia pathway, and the hypermethioninemia pathway. Outside of the human body, 3-methyl pyruvic acid can be found in a number of food items such as dock, common persimmon, nutmeg, and common pea. This makes 3-methyl pyruvic acid a potential biomarker for the consumption of these food products.
# <Element '{http://www.hmdb.ca}description' at 0x116fbe040>
# 2-Ketobutyric acid is a substance that is involved in the metabolism of many amino acids (glycine, methionine, valine, leucine, serine, threonine, isoleucine) as well as propanoate metabolism and C-5 branched dibasic acid metabolism. More specifically, alpha-ketobutyric acid is a product of the lysis of cystathionine. It is also one of the degradation products of threonine. It can be converted into propionyl-CoA (and subsequently methylmalonyl CoA, which can be converted into succinyl CoA, a citric acid cycle intermediate), and thus enter the citric acid cycle.
# <Element '{http://www.hmdb.ca}synonyms' at 0x116fbe090>
#
#
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe0e0>
# 2-Ketobutanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe180>
# 2-Oxobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe220>
# 3-Methyl pyruvic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe2c0>
# alpha-Ketobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe360>
# alpha-Ketobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe400>
# alpha-oxo-N-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe4a0>
# 2-Ketobutanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe4f0>
# 2-Ketobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe540>
# 2-Oxobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe590>
# 3-Methyl pyruvate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe630>
# a-Ketobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe680>
# a-Ketobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe720>
# α-ketobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe770>
# α-ketobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe7c0>
# a-oxo-N-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe860>
# a-oxo-N-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe900>
# alpha-oxo-N-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe9a0>
# α-oxo-N-butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbe9f0>
# α-oxo-N-butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbea40>
# 2-oxo-Butanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbea90>
# 2-oxo-Butanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbeb30>
# 2-oxo-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbeb80>
# 2-oxo-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbec20>
# 2-oxo-N-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbecc0>
# 2-oxo-N-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbed60>
# 2-Oxobutanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbedb0>
# 2-Oxobutanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbee50>
# 3-Methylpyruvate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbeef0>
# 3-Methylpyruvic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fbef90>
# a-keto-N-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0090>
# a-keto-N-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0130>
# a-Oxobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0180>
# a-Oxobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0220>
# alpha-keto-N-Butyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc02c0>
# alpha-keto-N-Butyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0360>
# alpha-Ketobutric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0400>
# alpha-Oxobutyrate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc04a0>
# alpha-Oxobutyric acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0540>
# Methyl-pyruvate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0590>
# Methyl-pyruvic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0630>
# Propionyl-formate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc06d0>
# Propionyl-formic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x116fc0770>
# alpha-Ketobutyric acid, sodium salt
# <Element '{http://www.hmdb.ca}chemical_formula' at 0x116fc07c0>
# C4H6O3
# <Element '{http://www.hmdb.ca}average_molecular_weight' at 0x116fc0810>
# 102.0886
# <Element '{http://www.hmdb.ca}monisotopic_molecular_weight' at 0x116fc0860>
# 102.031694058
# <Element '{http://www.hmdb.ca}iupac_name' at 0x116fc08b0>
# 2-oxobutanoic acid
# <Element '{http://www.hmdb.ca}traditional_iupac' at 0x116fc0950>
# 2-oxobutanoic acid
# <Element '{http://www.hmdb.ca}cas_registry_number' at 0x116fc09f0>
# 600-18-0
# <Element '{http://www.hmdb.ca}smiles' at 0x116fc0a40>
# CCC(=O)C(O)=O
# <Element '{http://www.hmdb.ca}inchi' at 0x116fc0a90>
# InChI=1S/C4H6O3/c1-2-3(5)4(6)7/h2H2,1H3,(H,6,7)
# <Element '{http://www.hmdb.ca}inchikey' at 0x116fc0ae0>
# TYEYBOSBBBHJIV-UHFFFAOYSA-N
# <Element '{http://www.hmdb.ca}taxonomy' at 0x116fc0b80>
#
#
#
# <Element '{http://www.hmdb.ca}description' at 0x116fc0bd0>
# This compound belongs to the class of organic compounds known as short-chain keto acids and derivatives. These are keto acids with an alkyl chain the contains less than 6 carbon atoms.
#
# <Element '{http://www.hmdb.ca}direct_parent' at 0x116fc0c20>
# Short-chain keto acids and derivatives
#
# <Element '{http://www.hmdb.ca}kingdom' at 0x116fc0c70>
# Organic compounds
#
# <Element '{http://www.hmdb.ca}super_class' at 0x116fc0d10>
# Organic acids and derivatives
#
# <Element '{http://www.hmdb.ca}class' at 0x116fc0db0>
# Keto acids and derivatives
#
# <Element '{http://www.hmdb.ca}sub_class' at 0x116fc0e50>
# Short-chain keto acids and derivatives
#
# <Element '{http://www.hmdb.ca}molecular_framework' at 0x116fc0ea0>
# Aliphatic acyclic compounds
#
# <Element '{http://www.hmdb.ca}alternative_parents' at 0x116fc0f40>
#
#
#
# <Element '{http://www.hmdb.ca}substituents' at 0x116fc22c0>
#
#
#
# <Element '{http://www.hmdb.ca}external_descriptors' at 0x116fc2950>
#
#
# <Element '{http://www.hmdb.ca}ontology' at 0x116fc2b80>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116fc2bd0>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116fd4270>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x116fda130>
#
#
# <Element '{http://www.hmdb.ca}state' at 0x116fdae00>
# Solid
# <Element '{http://www.hmdb.ca}experimental_properties' at 0x116fdae50>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdaea0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd090>
#
#
# <Element '{http://www.hmdb.ca}predicted_properties' at 0x116fdd220>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd270>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd3b0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd4f0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd630>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd770>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdd900>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fdda90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fddc20>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fddd60>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fddea0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1040>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1180>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe12c0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1450>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe15e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1720>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1860>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe19f0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1b30>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1c70>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1e00>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe1f40>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe40e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe4220>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe4360>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe44a0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x116fe45e0>
#
#
# <Element '{http://www.hmdb.ca}spectra' at 0x116fe4720>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4770>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4860>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4950>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4a40>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4b30>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4c20>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4d10>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4e00>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe4ef0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9040>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9130>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9220>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9310>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9400>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe94f0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe95e0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe96d0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe97c0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe98b0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe99a0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9a90>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9b80>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9c70>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9d60>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9e50>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fe9f40>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fed090>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fed180>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fed270>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fed360>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x116fed450>
#
#
# <Element '{http://www.hmdb.ca}biological_properties' at 0x116fed540>
#
#
#
# <Element '{http://www.hmdb.ca}cellular_locations' at 0x116fed590>
#
#
#
# <Element '{http://www.hmdb.ca}biospecimen_locations' at 0x116fed630>
#
#
#
# <Element '{http://www.hmdb.ca}tissue_locations' at 0x116fed810>
#
#
#
# <Element '{http://www.hmdb.ca}pathways' at 0x116fed860>
#
#
# <Element '{http://www.hmdb.ca}normal_concentrations' at 0x116ff5b80>
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff5bd0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff5f40>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff9310>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff96d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff9ae0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ff9ef0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ffe310>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ffe6d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ffeae0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x116ffeea0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117001310>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x1170016d0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117001b30>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117001f40>
#
#
# <Element '{http://www.hmdb.ca}abnormal_concentrations' at 0x117005360>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x1170053b0>
#
#
# <Element '{http://www.hmdb.ca}diseases' at 0x117005860>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x1170058b0>
#
#
# <Element '{http://www.hmdb.ca}kegg_id' at 0x117005b30>
# C00109
# <Element '{http://www.hmdb.ca}chebi_id' at 0x117005b80>
# 30831
# <Element '{http://www.hmdb.ca}chemspider_id' at 0x117005bd0>
# 57
# <Element '{http://www.hmdb.ca}pubchem_compound_id' at 0x117005c20>
# 58
# <Element '{http://www.hmdb.ca}foodb_id' at 0x117005c70>
# FDB003359
# <Element '{http://www.hmdb.ca}drugbank_id' at 0x117005cc0>
# DB04553
# <Element '{http://www.hmdb.ca}phenol_explorer_compound_id' at 0x117005d10>
# None
# <Element '{http://www.hmdb.ca}meta_cyc_id' at 0x117005d60>
# 2-OXOBUTANOATE
# <Element '{http://www.hmdb.ca}wikipedia_id' at 0x117005db0>
# Alpha-Ketobutyric_acid
# <Element '{http://www.hmdb.ca}knapsack_id' at 0x117005e50>
# C00019675
# <Element '{http://www.hmdb.ca}bigg_id' at 0x117005ea0>
# 33889
# <Element '{http://www.hmdb.ca}metlin_id' at 0x117005ef0>
# None
# <Element '{http://www.hmdb.ca}pdb_id' at 0x117005f40>
# 2KT
# <Element '{http://www.hmdb.ca}synthesis_reference' at 0x117005f90>
# Figge, Rainer; Lux, Fabien; Raynaud, Celine; Soucaille, Philippe. Production of a-ketobutyrate by engineered Escherichia coli.PCT Int. Appl.  (2006), 31pp.
# <Element '{http://www.hmdb.ca}general_references' at 0x117008040>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117008090>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117008180>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117008270>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117008360>
#
#
# <Element '{http://www.hmdb.ca}protein_associations' at 0x117008450>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x1170084a0>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117008680>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117008860>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117008a40>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117008c20>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117008e00>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700d040>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700d270>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700d450>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700d630>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700d860>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700da40>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700dc70>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11700dea0>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117010130>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117010310>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x1170104f0>
#
#
#
# ...
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528540>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528630>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528720>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528810>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528900>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x1175289f0>
#
#
#
# <Element '{http://www.hmdb.ca}spectrum' at 0x117528ae0>
#
#
# <Element '{http://www.hmdb.ca}biological_properties' at 0x117528bd0>
#
#
#
# <Element '{http://www.hmdb.ca}cellular_locations' at 0x117528c20>
#
#
#
# <Element '{http://www.hmdb.ca}biospecimen_locations' at 0x117528d10>
#
#
#
# <Element '{http://www.hmdb.ca}tissue_locations' at 0x117528f40>
#
#
#
# <Element '{http://www.hmdb.ca}pathways' at 0x117528f90>
#
#
# <Element '{http://www.hmdb.ca}normal_concentrations' at 0x117530810>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117530860>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117530c20>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117533040>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117533450>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117533810>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117533b80>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117538040>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x1175384a0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x1175388b0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117538c70>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753b130>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753b540>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753b950>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753bd60>
#
#
# <Element '{http://www.hmdb.ca}abnormal_concentrations' at 0x11753e220>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753e270>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753e630>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753ea40>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x11753ee50>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x1175423b0>
#
#
#
# <Element '{http://www.hmdb.ca}concentration' at 0x117542810>
#
#
# <Element '{http://www.hmdb.ca}diseases' at 0x117542d10>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x117542d60>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x11754bd60>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x117551d10>
#
#
#
# <Element '{http://www.hmdb.ca}disease' at 0x117556040>
#
#
# <Element '{http://www.hmdb.ca}kegg_id' at 0x1175562c0>
# C06001
# <Element '{http://www.hmdb.ca}chebi_id' at 0x117556310>
# 37373
# <Element '{http://www.hmdb.ca}chemspider_id' at 0x117556360>
# 389707
# <Element '{http://www.hmdb.ca}pubchem_compound_id' at 0x1175563b0>
# 440873
# <Element '{http://www.hmdb.ca}foodb_id' at 0x117556400>
# FDB021877
# <Element '{http://www.hmdb.ca}drugbank_id' at 0x117556450>
# None
# <Element '{http://www.hmdb.ca}phenol_explorer_compound_id' at 0x1175564a0>
# None
# <Element '{http://www.hmdb.ca}meta_cyc_id' at 0x1175564f0>
# 3-HYDROXY-ISOBUTYRATE
# <Element '{http://www.hmdb.ca}wikipedia_id' at 0x117556590>
# None
# <Element '{http://www.hmdb.ca}knapsack_id' at 0x1175565e0>
# None
# <Element '{http://www.hmdb.ca}bigg_id' at 0x117556630>
# 37034
# <Element '{http://www.hmdb.ca}metlin_id' at 0x117556680>
# 483
# <Element '{http://www.hmdb.ca}pdb_id' at 0x1175566d0>
# None
# <Element '{http://www.hmdb.ca}synthesis_reference' at 0x117556720>
# Robison, Robert S.; Doremus, Michael G.L-(+)-b-Hydroxyisobutyric acid by fermentation. U.S.  (1986),   5 pp.
# <Element '{http://www.hmdb.ca}general_references' at 0x117556770>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x1175567c0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x1175568b0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x1175569a0>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117556a90>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117556b80>
#
#
#
# <Element '{http://www.hmdb.ca}reference' at 0x117556c70>
#
#
# <Element '{http://www.hmdb.ca}protein_associations' at 0x117556d60>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x117556db0>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11755a040>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11755a220>
#
#
#
# <Element '{http://www.hmdb.ca}protein' at 0x11755a400>
#
#
# <Element '{http://www.hmdb.ca}version' at 0x11755a630>
# 4.0
# <Element '{http://www.hmdb.ca}creation_date' at 0x11755a680>
# 2005-11-16 15:48:42 UTC
# <Element '{http://www.hmdb.ca}update_date' at 0x11755a720>
# 2019-01-11 19:13:58 UTC
# <Element '{http://www.hmdb.ca}accession' at 0x11755a7c0>
# HMDB0000026
# <Element '{http://www.hmdb.ca}status' at 0x11755a810>
# quantified
# <Element '{http://www.hmdb.ca}secondary_accessions' at 0x11755a860>
#
#
#
# <Element '{http://www.hmdb.ca}accession' at 0x11755a8b0>
# HMDB00026
# <Element '{http://www.hmdb.ca}name' at 0x11755a900>
# Ureidopropionic acid
# <Element '{http://www.hmdb.ca}cs_description' at 0x11755a9a0>
# Ureidopropionic acid, also known as 3-ureidopropanoate or N-carbamoyl-b-alanine, belongs to the class of organic compounds known as ureas. Ureas are compounds containing two amine groups joined by a carbonyl (C=O) functional group. Ureidopropionic acid exists as a solid, soluble (in water), and a weakly acidic compound (based on its pKa). Ureidopropionic acid has been primarily detected in feces, urine, blood, and cerebrospinal fluid. Within the cell, ureidopropionic acid is primarily located in the cytoplasm. Ureidopropionic acid participates in a number of enzymatic reactions. In particular, Ureidopropionic acid can be biosynthesized from dihydrouracil; which is mediated by the enzyme dihydropyrimidinase. Furthermore, Ureidopropionic acid can be converted into Beta-alanine through the action of the enzyme Beta-ureidopropionase. Furthermore, Ureidopropionic acid can be converted into Beta-alanine through the action of the enzyme Beta-ureidopropionase. Finally, Ureidopropionic acid can be biosynthesized from dihydrouracil; which is catalyzed by the enzyme dihydropyrimidinase. In humans, ureidopropionic acid is involved in the Beta-alanine metabolism pathway and the pyrimidine metabolism pathway. Ureidopropionic acid is also involved in several metabolic disorders, some of which include UMP synthase deficiency (orotic aciduria), gaba-transaminase deficiency, the carnosinuria, carnosinemia pathway, and the mngie (mitochondrial neurogastrointestinal encephalopathy) pathway. Outside of the human body, ureidopropionic acid can be found in a number of food items such as red bell pepper, garlic, yautia, and sparkleberry. This makes ureidopropionic acid a potential biomarker for the consumption of these food products.
# <Element '{http://www.hmdb.ca}description' at 0x11755a9f0>
# Ureidopropionic acid is an intermediate in the metabolism of uracil. More specifically it is a breakdown product of dihydrouracil and is produced by the enzyme dihydropyrimidase. It is further decomposed to beta-alanine via the enzyme beta-ureidopropionase. Ureidopropionic acid is essentially a urea derivative of beta-alanine. High levels of Ureidopropionic acid are found in individuals with beta-ureidopropionase (UP) deficiency [PMID: 11675655]. Enzyme deficiencies in pyrimidine metabolism are associated with a risk for severe toxicity against the antineoplastic agent 5-fluorouracil.
# <Element '{http://www.hmdb.ca}synonyms' at 0x11755aa40>
#
#
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755aa90>
# 3-[(Aminocarbonyl)amino]propanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755aae0>
# 3-Ureidopropanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755ab80>
# 3-Ureidopropanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755ac20>
# 3-Ureidopropionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755acc0>
# 3-Ureidopropionic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755ad60>
# beta-Ureidopropionic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755ae00>
# N-(AMINOCARBONYL)-BETA-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755aea0>
# Ureidopropanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755af40>
# 3-[(Aminocarbonyl)amino]propanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755af90>
# Ureidopropionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d090>
# b-Ureidopropionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d130>
# b-Ureidopropionic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d1d0>
# beta-Ureidopropionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d270>
# β-ureidopropionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d2c0>
# β-ureidopropionic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d310>
# N-(AMINOCARBONYL)-b-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d3b0>
# N-(AMINOCARBONYL)-β-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d400>
# Ureidopropanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d4a0>
# 3-(carbamoylamino)Propanoate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d540>
# 3-(carbamoylamino)Propanoic acid
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d590>
# 3-ureido-Propionate
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d630>
# Carbamoyl-b-ala-OH
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d6d0>
# Carbamoyl-beta-ala-OH
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d770>
# N-(Aminocarbonyl)-'b-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d810>
# N-Carbamoyl-b-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d8b0>
# N-Carbamoyl-beta-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d950>
# N-Carbamyl-b-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755d9f0>
# N-Carbamyl-beta-alanine
#
# <Element '{http://www.hmdb.ca}synonym' at 0x11755da90>
# Ion(-1) OF N-carbamoyl-beta-alanine
# <Element '{http://www.hmdb.ca}chemical_formula' at 0x11755dae0>
# C4H8N2O3
# <Element '{http://www.hmdb.ca}average_molecular_weight' at 0x11755db30>
# 132.1179
# <Element '{http://www.hmdb.ca}monisotopic_molecular_weight' at 0x11755db80>
# 132.053492132
# <Element '{http://www.hmdb.ca}iupac_name' at 0x11755dbd0>
# 3-(carbamoylamino)propanoic acid
# <Element '{http://www.hmdb.ca}traditional_iupac' at 0x11755dc20>
# ureidopropionic acid
# <Element '{http://www.hmdb.ca}cas_registry_number' at 0x11755dcc0>
# 462-88-4
# <Element '{http://www.hmdb.ca}smiles' at 0x11755dd10>
# NC(=O)NCCC(O)=O
# <Element '{http://www.hmdb.ca}inchi' at 0x11755dd60>
# InChI=1S/C4H8N2O3/c5-4(9)6-2-1-3(7)8/h1-2H2,(H,7,8)(H3,5,6,9)
# <Element '{http://www.hmdb.ca}inchikey' at 0x11755ddb0>
# JSJWCHRYRHKBBW-UHFFFAOYSA-N
# <Element '{http://www.hmdb.ca}taxonomy' at 0x11755de50>
#
#
#
# <Element '{http://www.hmdb.ca}description' at 0x11755dea0>
# This compound belongs to the class of organic compounds known as ureas. These are compounds containing two amine groups joined by a carbonyl (C=O) functional group.
#
# <Element '{http://www.hmdb.ca}direct_parent' at 0x11755def0>
# Ureas
#
# <Element '{http://www.hmdb.ca}kingdom' at 0x11755df40>
# Organic compounds
#
# <Element '{http://www.hmdb.ca}super_class' at 0x11755f040>
# Organic acids and derivatives
#
# <Element '{http://www.hmdb.ca}class' at 0x11755f0e0>
# Organic carbonic acids and derivatives
#
# <Element '{http://www.hmdb.ca}sub_class' at 0x11755f130>
# Ureas
#
# <Element '{http://www.hmdb.ca}molecular_framework' at 0x11755f180>
# Aliphatic acyclic compounds
#
# <Element '{http://www.hmdb.ca}alternative_parents' at 0x11755f220>
#
#
#
# <Element '{http://www.hmdb.ca}substituents' at 0x11755f630>
#
#
#
# <Element '{http://www.hmdb.ca}external_descriptors' at 0x11755fd10>
#
#
# <Element '{http://www.hmdb.ca}ontology' at 0x11755fe00>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x11755fe50>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x11756f770>
#
#
#
# <Element '{http://www.hmdb.ca}root' at 0x1175765e0>
#
#
# <Element '{http://www.hmdb.ca}state' at 0x117576cc0>
# Solid
# <Element '{http://www.hmdb.ca}experimental_properties' at 0x117576d10>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117576d60>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117576ef0>
#
#
# <Element '{http://www.hmdb.ca}predicted_properties' at 0x1175790e0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579130>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579270>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x1175793b0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x1175794f0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579630>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x1175797c0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579950>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579a90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579bd0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579d10>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579e50>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117579f90>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d130>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d2c0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d450>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d590>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d6d0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d860>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757d9a0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757dae0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757dc70>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757ddb0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x11757def0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117581090>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x1175811d0>
#
#
#
# <Element '{http://www.hmdb.ca}property' at 0x117581310>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f763e538c51c> in <module>
#       6         print(m.text)
#       7         for n in m:
# ----> 8             print('\t')
#       9             print(n)
#      10             print(n.text)
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
for metabolite in root.findall(stringtag+'metabolite'):
    accid = metabolite.find(stringtag+'accession').text
    name = metabolite.find(stringtag+'name').text
    mass = metabolite.find(stringtag+'average_molecular_weight').text
    chemform = metabolite.find(stringtag+'chemical_formula').text
    smiles = metabolite.find(stringtag+'smiles').text
    kegg_id = metabolite.find(stringtag+'kegg_id').text
    metlin_id = metabolite.find(stringtag+'metlin_id').text
    
    taxonomy = metabolite.findall(stringtag+'taxonomy')
    print(taxonomy)
    for tax in taxonomy:
        clas = tax.find(stringtag+'class').text
        subclass = tax.find(stringtag+'sub_class').text
        molecular_framework = tax.find(stringtag+'molecular_framework').text
        print(clas, subclass, molecular_framework)
# Out:
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x116ed8e50>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x116f70860>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x116fc0b80>]
# Keto acids and derivatives Short-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117016c70>]
# Hydroxy acids and derivatives Alpha hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1170a4bd0>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1170f4c20>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117154090>]
# Pyrimidine nucleosides Pyrimidine 2'-deoxyribonucleosides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1171c1b80>]
# Pyrimidine nucleosides Pyrimidine 2'-deoxyribonucleosides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11721c950>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1172899a0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1172db630>]
# Pyridines and derivatives Pyridinecarboxylic acids and derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11733f680>]
# Keto acids and derivatives Short-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1173badb0>]
# Phenols 1-hydroxy-2-unsubstituted benzenoids Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11749b180>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1174cc090>]
# Phenols Methoxyphenols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11750b7c0>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11755de50>]
# Organic carbonic acids and derivatives Ureas Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1175a3f40>]
# Pteridines and derivatives Pterins and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1175fb540>]
# Biotin and derivatives None Aliphatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117697180>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117704770>]
# Steroids and steroid derivatives Cholestane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11776e900>]
# Peptidomimetics Hybrid peptides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1177f44a0>]
# Imidazopyrimidines Purines and purine derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11788d270>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11791d1d0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1179dc130>]
# Pteridines and derivatives Pterins and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117a24450>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117b16b80>]
# Carboxylic acids and derivatives Carboxylic acids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117c41ef0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117d3eb80>]
# Dihydrofurans Furanones Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117ddf630>]
# Purine nucleotides Purine ribonucleotides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117f41090>]
# Purine nucleosides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x117fe7b30>]
# Homogeneous other non-metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1181039f0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118148e50>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118209220>]
# Organoheterocyclic compounds Tetrapyrroles and derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1182b2040>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11837bae0>]
# Purine nucleotides Cyclic purine nucleotides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11844fa40>]
# Keto acids and derivatives Short-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118519130>]
# Organonitrogen compounds Quaternary ammonium salts Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11863e9f0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118731bd0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11882d310>]
# Steroids and steroid derivatives Cholestane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11894ba90>]
# Phenols Benzenediols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1189d4b80>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118aaa040>]
# Purine nucleosides Purine 2'-deoxyribonucleosides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118aff860>]
# Phenols Benzenediols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118bd6810>]
# Diazines Pyrimidines and pyrimidine derivatives Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118c467c0>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118ce4e00>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118d33b80>]
# Diazines Pyrimidines and pyrimidine derivatives Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118d7fb80>]
# Purine nucleosides Purine 2'-deoxyribonucleosides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118de4ae0>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118e5da40>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118f0c540>]
# Pyrimidine nucleosides None Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x118f93040>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119003130>]
# Carboxylic acids and derivatives Tricarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11912f2c0>]
# Organonitrogen compounds Quaternary ammonium salts Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1194564a0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1194dc4a0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11955f590>]
# Purine nucleosides Purine 2'-deoxyribonucleosides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1195b4360>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119614d60>]
# Organooxygen compounds Alcohols and polyols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119712450>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119809400>]
# Hydroxy acids and derivatives Alpha hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1198ce540>]
# Phenols Methoxyphenols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1199dbae0>]
# Carboxylic acids and derivatives Carboxylic acids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119a30360>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119abcef0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119c77e00>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119e8c770>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119eee720>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x119fba2c0>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11d9ae4a0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11d9fa6d0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11da971d0>]
# Benzene and substituted derivatives Phenylacetic acids Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11db061d0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11dbfb400>]
# Purine nucleosides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11dc7f630>]
# Carboxylic acids and derivatives Dicarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11dd4ff90>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ddec950>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11de84360>]
# Sphingolipids Glycosphingolipids Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11deea180>]
# Carboxylic acids and derivatives Carboxylic acids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11dfb7ef0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e042c20>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e0c4b30>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e2929f0>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e57ab80>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e5b1db0>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e6732c0>]
# Benzene and substituted derivatives Benzoic acids and derivatives Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e6bf0e0>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e731590>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e7b2900>]
# Imidazopyrimidines Purines and purine derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11e8d2860>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ea4de50>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ebdf6d0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11eda3a90>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ef24400>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ef77770>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11eff26d0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f155270>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f272e00>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f2f9c20>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f4834a0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f4e7c20>]
# Purine nucleotides Purine ribonucleotides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f5502c0>]
# Carboxylic acids and derivatives Dicarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f5a4360>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f73a5e0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f7a9900>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f92a400>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11f97fcc0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11fc173b0>]
# Hydroxy acids and derivatives Alpha hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11fe185e0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11ff419a0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x11fff7cc0>]
# Carboxylic acids and derivatives Tricarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120064770>]
# Peptidomimetics Hybrid peptides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1200bcb30>]
# Purine nucleosides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120172310>]
# Indoles and derivatives Indolyl carboxylic acids and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12022d2c0>]
# Fatty Acyls Fatty acid esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1202cb720>]
# Carboxylic acids and derivatives Dicarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12036fc20>]
# Benzene and substituted derivatives Phenylpyruvic acid derivatives Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1203ba0e0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120406a90>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1204ba4f0>]
# Keto acids and derivatives Gamma-keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1205d23b0>]
# Benzene and substituted derivatives None Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120690360>]
# Alcohols and polyols Polyols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12071a9f0>]
# Organooxygen compounds Alcohols and polyols Aliphatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1207be2c0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12090ed10>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12097b860>]
# Phenols Benzenediols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120a55e50>]
# (5'->5')-dinucleotides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120b9ae00>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120ca04f0>]
# (5'->5')-dinucleotides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120dd5450>]
# Fatty Acyls Fatty acid esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x120e4d0e0>]
# Organic phosphoric acids and derivatives Phosphate esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121101b30>]
# Keto acids and derivatives Medium-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121144c20>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1211da040>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121238ef0>]
# Phenols 1-hydroxy-4-unsubstituted benzenoids Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1212ea360>]
# Pyridine nucleotides Nicotinamide nucleotides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121324270>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121390810>]
# Pyridines and derivatives Pyridinecarboxylic acids and derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12141ad60>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1214ea4a0>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12156c090>]
# Carboxylic acids and derivatives Carboxylic acids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121635b80>]
# Pyridines and derivatives Pyridoxines Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1216a2a40>]
# Non-metal oxoanionic compounds Non-metal sulfites None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1216de860>]
# Tetrapyrroles and derivatives Porphyrins Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12172b450>]
# Keto acids and derivatives Alpha-keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1218962c0>]
# Pteridines and derivatives Alloxazines and isoalloxazines Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12190e220>]
# Organonitrogen compounds Amines Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121956360>]
# Tetrahydrofurans None Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12197fe00>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121a159f0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x121a89d60>]
# Non-metal oxoanionic compounds Non-metal pyrophosphates Acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123b7dbd0>]
# Organic sulfonic acids and derivatives Organosulfonic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123c8c400>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123cfd9a0>]
# Steroids and steroid derivatives Pregnane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123d83180>]
# Carboxylic acids and derivatives Dicarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123ebc5e0>]
# Prenol lipids Triterpenoids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123f12cc0>]
# Non-metal oxoanionic compounds Non-metal thiosulfates None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123f46f40>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x123fcd180>]
# Indoles and derivatives Tryptamines and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1240a37c0>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12411a770>]
# Organic phosphoric acids and derivatives Phosphate esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124173a90>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1241d39a0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12427b9f0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1242be810>]
# Organonitrogen compounds Amines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1243398b0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1243cac20>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1243ffd60>]
# Pyrimidine nucleosides Pyrimidine 2'-deoxyribonucleosides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124483720>]
# Sphingolipids Phosphosphingolipids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1244e9680>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124530310>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12456fe00>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1245dbb80>]
# Pyrimidine nucleotides Pyrimidine nucleotide sugars Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124628680>]
# Pyrimidine nucleotides Pyrimidine ribonucleotides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1246a6d10>]
# Imidazopyrimidines Purines and purine derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1247edc20>]
# Phenols Methoxyphenols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124851680>]
# Imidazopyrimidines Purines and purine derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124928bd0>]
# Organic carbonic acids and derivatives Ureas Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124a00130>]
# Pyrimidine nucleotides Pyrimidine ribonucleotides Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124aafbd0>]
# Pyrimidine nucleosides None Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124b34d60>]
# Purine nucleosides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124b8a400>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124c38cc0>]
# Azoles Imidazoles Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124c9c1d0>]
# Indoles and derivatives Tryptamines and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124cf0950>]
# Prenol lipids Retinoids Aliphatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124dafd60>]
# Benzene and substituted derivatives Phenethylamines Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124e43630>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124e86180>]
# Steroids and steroid derivatives Pregnane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124ebea40>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124f1f3b0>]
# Phenols Benzenediols Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124f622c0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124fa4d60>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x124feef90>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1250136d0>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125057180>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125090ea0>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1250d09f0>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1250fc360>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125127e00>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12516be00>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125198630>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1251d14a0>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1251f9130>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125235a40>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125344810>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125385950>]
# Hydroxy acids and derivatives Short-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1253ab180>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1253d0360>]
# Steroids and steroid derivatives Pregnane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125435590>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125486ef0>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1254cdef0>]
# Steroids and steroid derivatives Pregnane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12556a040>]
# Phenylpropanoic acids None Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1255b3f40>]
# Carboxylic acids and derivatives Tricarboxylic acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1255f81d0>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125632040>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125664090>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12569c2c0>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1256dde50>]
# Benzene and substituted derivatives Benzoic acids and derivatives Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12570ce50>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12575b180>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1257c5040>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1257efe00>]
# Steroids and steroid derivatives Sulfated steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12582dae0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125867b80>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1258ae090>]
# Phenylpropanoic acids None Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12590de00>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125930b80>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12597da90>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1259b2a40>]
# Steroids and steroid derivatives Estrane steroids Aromatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1259f2590>]
# Steroids and steroid derivatives Vitamin D and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125a2cef0>]
# Benzene and substituted derivatives Methoxybenzenes Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125a59f40>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125a95d10>]
# Phenols 1-hydroxy-4-unsubstituted benzenoids Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125b0b270>]
# Hydroxy acids and derivatives Beta hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125b38d60>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125bd9db0>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125c17680>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125c71040>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125ceb4a0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125d29540>]
# Azoles Imidazoles Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x125dae5e0>]
# Homogeneous alkaline earth metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126185e00>]
# Pteridines and derivatives Pterins and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1261ced60>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1261fa810>]
# Indoles and derivatives Tryptamines and derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126252540>]
# Imidazopyrimidines Purines and purine derivatives Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12626d1d0>]
# Organooxygen compounds Carbonyl compounds Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1262e1270>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126370ea0>]
# Pyrazolo[3,4-d]pyrimidine glycosides None Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1263905e0>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126420450>]
# Benzene and substituted derivatives Benzoic acids and derivatives Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126494f40>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1264f67c0>]
# Keto acids and derivatives Short-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126563590>]
# Homogeneous halogens None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1266537c0>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12669acc0>]
# Steroids and steroid derivatives Stigmastanes and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1266e84a0>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1267294f0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126758220>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126776ae0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126792a90>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1267c5f90>]
# Benzene and substituted derivatives Benzoic acids and derivatives Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126853900>]
# Steroids and steroid derivatives Cholestane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1268a58b0>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1268f5810>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12697fa90>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126a01ef0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126b95310>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126c0df90>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126c4bd10>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126c97310>]
# Steroids and steroid derivatives Hydroxysteroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126cd5180>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126d0e400>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126d47720>]
# Steroids and steroid derivatives Ergostane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126d84d10>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x126e2e950>]
# Purine nucleotides Purine ribonucleotides Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127436860>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12747adb0>]
# Homogeneous alkaline earth metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1276d5a90>]
# Lactones Gamma butyrolactones Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127716540>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12774e040>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127780db0>]
# Fatty Acyls Fatty acid esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1277bc9f0>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1277f3b30>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127855220>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127899270>]
# Prenol lipids Tetraterpenoids Aliphatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1279668b0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127ab2450>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127b2dd60>]
# Hydroxy acids and derivatives Medium-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127b62180>]
# Cinnamic acids and derivatives Cinnamic acids Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127b92040>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127bccbd0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127c02ea0>]
# Tetrapyrroles and derivatives Porphyrins Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127c46810>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127c8eb80>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127d8bf40>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127dbb540>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127deedb0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127e2d130>]
# Fatty Acyls Fatty acyl glycosides Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127e5dd10>]
# Homogeneous alkali metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x127fb1ea0>]
# Homogeneous alkali metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12810c040>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128186a40>]
# Organic carbonic acids and derivatives Organic carbonic acids Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1282569a0>]
# Other non-metal organides Other non-metal sulfides None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128295720>]
# Homogeneous transition metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1282f84f0>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128326f90>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12837e630>]
# Hydroxy acids and derivatives Short-chain hydroxy acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1283eb450>]
# Tetrapyrroles and derivatives Corrinoids Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12846bea0>]
# Homogeneous transition metal compounds None None
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1284daf90>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aromatic homomonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1285203b0>]
# Steroids and steroid derivatives Steroid esters Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12855b090>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128594770>]
# Carbohydrates and carbohydrate conjugates Monosaccharides Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1285ec590>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12868bc20>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128705590>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128769950>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1287cabd0>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128842090>]
# Steroids and steroid derivatives Androstane steroids Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1288892c0>]
# Diazines Pyrimidines and pyrimidine derivatives Aromatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1288e2450>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128937590>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x12897bc20>]
# Keto acids and derivatives Medium-chain keto acids and derivatives Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1289b04a0>]
# Steroids and steroid derivatives Bile acids, alcohols and derivatives Aliphatic homopolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128a12720>]
# Fatty Acyls Fatty acids and conjugates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128a88b30>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128c10db0>]
# Tetrapyrroles and derivatives Porphyrins Aromatic heteropolycyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128c54b80>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128c88130>]
# Organooxygen compounds Carbohydrates and carbohydrate conjugates Aliphatic heteromonocyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128cc4040>]
# Carboxylic acids and derivatives Amino acids, peptides, and analogues Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128cff590>]
# Fatty Acyls Fatty acid esters Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x128d73770>]
# ...
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155924540>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15599b360>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155a16130>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155a8ae00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155b02b30>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155b794f0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155bf1180>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155c6adb0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155ce3a40>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155d59e50>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155dd4ef0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155e4d9a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155ec7270>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155f45720>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x155fbeae0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156034f40>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1560b0360>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1561297c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1561a5a90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15621bdb0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1562984a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156310f90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15638e2c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156407950>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1564844a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156500040>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15657bb80>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1565f6270>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156670d10>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1566e8950>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15675e9a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1567d7630>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156850310>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1568c4e00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156940950>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1569b74a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156a2cf90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156aa5ea0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156b1fdb0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156b97cc0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156c114f0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156c8c900>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156d04db0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156d7dcc0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156df47c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156e6b680>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156ee59f0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156f61b80>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x156fd9e00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157050d10>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1570c9ae0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157142c70>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1571bcef0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157239130>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1572acea0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15731fe00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157397180>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157410d10>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157481f40>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1574fc590>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15756e7c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1575e4db0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15765d400>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1576d3ea0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15774d4f0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1577c1ae0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157839590>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1578aea40>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157924ef0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15799c400>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157a10d10>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157a892c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157b0e540>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157b8a2c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157c0f450>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157c8c040>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157d093b0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157d82a90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157dfe130>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157e76720>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157ef0cc0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157f6a270>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x157fe14a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158057ea0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1580d1900>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158149270>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1581bdae0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158236770>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1582ae8b0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158327130>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1583a1180>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158418090>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15848fb80>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158508a90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15857fe50>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1585f5db0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158670900>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1586e98b0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1587632c0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1587db0e0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1588523b0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1588cc270>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158941c20>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1589b75e0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158a2bd10>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158aa50e0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158b1ad60>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158b969f0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158c0c0e0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158c7f310>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158cf5e00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158d6c090>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158dde310>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158e57e00>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158ed79a0>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158f51a90>]
# Glycerolipids Diradylglycerols Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x158fc8b80>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1590397c0>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1590aa360>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x159113ef0>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15917de00>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1591ee450>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15925ddb0>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1592cee00>]
# Glycerophospholipids Glycerophosphates Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x159339a90>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15939c180>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x159412630>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1594845e0>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1594fa950>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x15956a8b0>]
# Glycerophospholipids Glycerophosphocholines Aliphatic acyclic compounds
# [<Element '{http://www.hmdb.ca}taxonomy' at 0x1595e54f0>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7a89008c039a> in <module>
#      11     print(taxonomy)
#      12     for tax in taxonomy:
# ---> 13         clas = tax.find(stringtag+'class').text
#      14         subclass = tax.find(stringtag+'sub_class').text
#      15         molecular_framework = tax.find(stringtag+'molecular_framework').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
metabolites = {}
stringtag = '{http://www.hmdb.ca}'
for metabolite in root.findall(stringtag+'metabolite'):
    accid = metabolite.find(stringtag+'accession').text
    name = metabolite.find(stringtag+'name').text
    mass = metabolite.find(stringtag+'average_molecular_weight').text
    chemform = metabolite.find(stringtag+'chemical_formula').text
    smiles = metabolite.find(stringtag+'smiles').text
    kegg_id = metabolite.find(stringtag+'kegg_id').text
    metlin_id = metabolite.find(stringtag+'metlin_id').text
    
    taxonomy = metabolite.findall(stringtag+'taxonomy')
    
    for tax in taxonomy:
        clas = tax.find(stringtag+'class')
        if clas is None:
            clas = None
        else:
            clas = clas.text
            
        subclass = tax.find(stringtag+'sub_class')
        if subclass is None:
            subclass = None
        else:
            subclass = subclass.text
            
        molecular_framework = tax.find(stringtag+'molecular_framework')
        if molecular_framework is None:
            molecular_framework = None
        else:
            molecular_framework = molecular_framework.text
            
            

    biological_properties = metabolite.findall(stringtag+'biological_properties')
    for properties in biological_properties:
        pathways = properties.find(stringtag+'pathways')
        for pathway in pathways:
            kegg_map = pathway.find(stringtag+'kegg_map_id').text
    
    
    metabolites[accid] = (mass, chemform, name, smiles, metlin_id, kegg_id, kegg_map, clas, subclass, molecular_framework)  
    
with open(os.path.join(osp,'Metabolomics_datasets/metabolites.dict'), 'wb') as handle:
    pickle.dump(metabolites, handle)

# %%
with open(os.path.join(osp,'Metabolomics_datasets/metabolites.dict'), 'rb') as file:
    metabolites = pickle.load(file)

# %%
metabolites
# Out:
# {'HMDB0000001': ('169.1811',
#   'C7H11N3O2',
#   '1-Methylhistidine',
#   'CN1C=NC(C[C@H](N)C(O)=O)=C1',
#   '3741',
#   'C01152',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000002': ('74.1249',
#   'C3H10N2',
#   '1,3-Diaminopropane',
#   'NCCCN',
#   '5081',
#   'C00986',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000005': ('102.0886',
#   'C4H6O3',
#   '2-Ketobutyric acid',
#   'CCC(=O)C(O)=O',
#   None,
#   'C00109',
#   None,
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000008': ('104.1045',
#   'C4H8O3',
#   '2-Hydroxybutyric acid',
#   'CCC(O)C(O)=O',
#   '3783',
#   'C05984',
#   'map00640',
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000010': ('300.3921',
#   'C19H24O3',
#   '2-Methoxyestrone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C(OC)=C3',
#   '2578',
#   'C05299',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000011': ('104.1045',
#   'C4H8O3',
#   '(R)-3-Hydroxybutyric acid',
#   'C[C@@H](O)CC(O)=O',
#   None,
#   'C01089',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000012': ('228.202',
#   'C9H12N2O5',
#   'Deoxyuridine',
#   'OC[C@H]1O[C@H](C[C@@H]1O)N1C=CC(=O)NC1=O',
#   '5086',
#   'C00526',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000014': ('227.2172',
#   'C9H13N3O4',
#   'Deoxycytidine',
#   'NC1=NC(=O)N(C=C1)[C@H]1C[C@H](O)[C@@H](CO)O1',
#   '3367',
#   'C00881',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000015': ('346.4605',
#   'C21H30O4',
#   'Cortexolone',
#   '[H][C@@]12CC[C@](O)(C(=O)CO)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5088',
#   'C05488',
#   None,
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000016': ('330.4611',
#   'C21H30O3',
#   'Deoxycorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5089',
#   'C03205',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000017': ('183.1614',
#   'C8H9NO4',
#   '4-Pyridoxic acid',
#   'CC1=NC=C(CO)C(C(O)=O)=C1O',
#   '239',
#   'C00847',
#   'map00750',
#   'Pyridines and derivatives',
#   'Pyridinecarboxylic acids and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000019': ('116.1152',
#   'C5H8O3',
#   'alpha-Ketoisovaleric acid',
#   'CC(C)C(=O)C(O)=O',
#   '5091',
#   'C00141',
#   'map00280',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000020': ('152.1473',
#   'C8H8O3',
#   'p-Hydroxyphenylacetic acid',
#   'OC(=O)CC1=CC=C(O)C=C1',
#   '130',
#   'C00642',
#   None,
#   'Phenols',
#   '1-hydroxy-2-unsubstituted benzenoids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000021': ('307.0851',
#   'C9H10INO3',
#   'Iodotyrosine',
#   'N[C@@H](CC1=CC=C(O)C(I)=C1)C(O)=O',
#   None,
#   'C02515',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000022': ('167.205',
#   'C9H13NO2',
#   '3-Methoxytyramine',
#   'COC1=C(O)C=CC(CCN)=C1',
#   '5094',
#   'C05587',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000023': ('104.1045',
#   'C4H8O3',
#   '(S)-3-Hydroxyisobutyric acid',
#   'C[C@@H](CO)C(O)=O',
#   '483',
#   'C06001',
#   'map00280',
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000026': ('132.1179',
#   'C4H8N2O3',
#   'Ureidopropionic acid',
#   'NC(=O)NCCC(O)=O',
#   '5097',
#   'C02642',
#   None,
#   'Organic carbonic acids and derivatives',
#   'Ureas',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000027': ('241.2471',
#   'C9H15N5O3',
#   'Tetrahydrobiopterin',
#   'CC(O)C(O)C1CNC2=C(N1)C(=O)N=C(N)N2',
#   '5098',
#   'C00272',
#   None,
#   'Pteridines and derivatives',
#   'Pterins and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000030': ('244.311',
#   'C10H16N2O3S',
#   'Biotin',
#   '[H][C@]12CS[C@@H](CCCCC(O)=O)[C@@]1([H])NC(=O)N2',
#   '243',
#   'C00120',
#   None,
#   'Biotin and derivatives',
#   None,
#   'Aliphatic heteropolycyclic compounds'),
#  'HMDB0000031': ('290.4403',
#   'C19H30O2',
#   'Androsterone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC[C@@]2([H])C[C@H](O)CC[C@]12C',
#   '2797',
#   'C00523',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000032': ('384.6377',
#   'C27H44O',
#   '7-Dehydrocholesterol',
#   '[H][C@@]1(CC[C@@]2([H])C3=CC=C4C[C@@H](O)CC[C@]4(C)[C@@]3([H])CC[C@]12C)[C@H](C)CCCC(C)C',
#   '5101',
#   'C01164',
#   None,
#   'Steroids and steroid derivatives',
#   'Cholestane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000033': ('226.2325',
#   'C9H14N4O3',
#   'Carnosine',
#   'NCCC(=O)N[C@@H](CC1=CN=CN1)C(O)=O',
#   '38',
#   'C00386',
#   None,
#   'Peptidomimetics',
#   'Hybrid peptides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000034': ('135.1267',
#   'C5H5N5',
#   'Adenine',
#   'NC1=C2NC=NC2=NC=N1',
#   '85',
#   'C00147',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000036': ('515.703',
#   'C26H45NO7S',
#   'Taurocholic acid',
#   '[H][C@@]1(CC[C@@]2([H])[C@]3([H])[C@H](O)C[C@]4([H])C[C@H](O)CC[C@]4(C)[C@@]3([H])C[C@H](O)[C@]12C)[C@H](C)CCC(=O)NCCS(O)(=O)=O',
#   '5104',
#   'C05122',
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000037': ('360.444',
#   'C21H28O5',
#   'Aldosterone',
#   'C[C@]12CCC(=O)C=C1CCC1C3CC[C@H](C(=O)CO)[C@]3(C[C@H](O)C21)C=O',
#   '418',
#   'C01780',
#   None,
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000038': ('239.2312',
#   'C9H13N5O3',
#   'Dihydrobiopterin',
#   'CC(O)C(O)C1=NC2=C(NC1)N=C(N)NC2=O',
#   '5106',
#   'C02953',
#   None,
#   'Pteridines and derivatives',
#   'Pterins and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000039': ('88.1051',
#   'C4H8O2',
#   'Butyric acid',
#   'CCCC(O)=O',
#   '107',
#   'C00246',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000042': ('60.052',
#   'C2H4O2',
#   'Acetic acid',
#   'CC(O)=O',
#   '3206',
#   'C00033',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000043': ('117.1463',
#   'C5H11NO2',
#   'Betaine',
#   'C[N+](C)(C)CC([O-])=O',
#   '287',
#   'C00719',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000044': ('176.1241',
#   'C6H8O6',
#   'Ascorbic acid',
#   '[H][C@@]1(OC(=O)C(O)=C1O)[C@@H](O)CO',
#   '3753',
#   'C01041',
#   None,
#   'Dihydrofurans',
#   'Furanones',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000045': ('347.2212',
#   'C10H14N5O7P',
#   'Adenosine monophosphate',
#   'NC1=C2N=CN([C@@H]3O[C@H](COP(O)(O)=O)[C@@H](O)[C@H]3O)C2=NC=N1',
#   '5111',
#   'C00020',
#   None,
#   'Purine nucleotides',
#   'Purine ribonucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000050': ('267.2413',
#   'C10H13N5O4',
#   'Adenosine',
#   'NC1=C2N=CN([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O)C2=NC=N1',
#   '86',
#   'C00212',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000051': ('17.0305',
#   'H3N',
#   'Ammonia',
#   'N',
#   '3189',
#   'C00014',
#   None,
#   'Homogeneous other non-metal compounds',
#   None,
#   None),
#  'HMDB0000052': ('290.2731',
#   'C10H18N4O6',
#   'Argininosuccinic acid',
#   'N[C@@H](CCCNC(=N)N[C@@H](CC(O)=O)C(O)=O)C(O)=O',
#   '5115',
#   'C03406',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000053': ('286.4085',
#   'C19H26O2',
#   'Androstenedione',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '2795',
#   'C00280',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000054': ('584.6621',
#   'C33H36N4O6',
#   'Bilirubin',
#   'CC1=C(C=C)\\C(NC1=O)=C\\C1=C(C)C(CCC(O)=O)=C(CC2=C(CCC(O)=O)C(C)=C(N2)\\C=C2/NC(=O)C(C=C)=C2C)N1',
#   '5475',
#   None,
#   'map00860',
#   'Organoheterocyclic compounds',
#   'Tetrapyrroles and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000056': ('89.0932',
#   'C3H7NO2',
#   'beta-Alanine',
#   'NCCC(O)=O',
#   '5119',
#   'C00099',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000058': ('329.2059',
#   'C10H12N5O6P',
#   'Cyclic AMP',
#   'NC1=NC=NC2=C1N=CN2[C@@H]1O[C@@H]2COP(O)(=O)O[C@H]2[C@H]1O',
#   '5120',
#   'C00575',
#   None,
#   'Purine nucleotides',
#   'Cyclic purine nucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000060': ('102.0886',
#   'C4H6O3',
#   'Acetoacetic acid',
#   'CC(=O)CC(O)=O',
#   '276',
#   'C00164',
#   'map00280',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000062': ('161.1989',
#   'C7H15NO3',
#   'L-Carnitine',
#   'C[N+](C)(C)C[C@H](O)CC([O-])=O',
#   '52',
#   'C00318',
#   None,
#   'Organonitrogen compounds',
#   'Quaternary ammonium salts',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000063': ('362.4599',
#   'C21H30O5',
#   'Cortisol',
#   '[H][C@@]12CC[C@](O)(C(=O)CO)[C@@]1(C)C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5124',
#   'C00735',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000064': ('131.1332',
#   'C4H9N3O2',
#   'Creatine',
#   'CN(CC(O)=O)C(N)=N',
#   '7',
#   'C00300',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000067': ('386.6535',
#   'C27H46O',
#   'Cholesterol',
#   '[H][C@@]1(CC[C@@]2([H])[C@]3([H])CC=C4C[C@@H](O)CC[C@]4(C)[C@@]3([H])CC[C@]12C)[C@H](C)CCCC(C)C',
#   None,
#   'C00187',
#   None,
#   'Steroids and steroid derivatives',
#   'Cholestane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000068': ('183.2044',
#   'C9H13NO3',
#   'Epinephrine',
#   'CNC[C@H](O)C1=CC(O)=C(O)C=C1',
#   '5127',
#   'C00788',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000070': ('129.157',
#   'C6H11NO2',
#   'Pipecolic acid',
#   'OC(=O)C1CCCCN1',
#   '50',
#   'C00408',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000071': ('252.23',
#   'C10H12N4O4',
#   'Deoxyinosine',
#   'OC[C@H]1O[C@H](C[C@@H]1O)N1C=NC2=C1N=CNC2=O',
#   '3383',
#   'C05512',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000073': ('153.1784',
#   'C8H11NO2',
#   'Dopamine',
#   'NCCC1=CC(O)=C(O)C=C1',
#   '64',
#   'C03758',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000076': ('114.1026',
#   'C4H6N2O2',
#   'Dihydrouracil',
#   'O=C1CCNC(=O)N1',
#   '285',
#   'C00429',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000077': ('288.4244',
#   'C19H28O2',
#   'Dehydroepiandrosterone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5133',
#   'C01227',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000078': ('178.21',
#   'C5H10N2O3S',
#   'Cysteinylglycine',
#   'N[C@@H](CS)C(=O)NCC(O)=O',
#   '5134',
#   'C01419',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000079': ('128.1292',
#   'C5H8N2O2',
#   'Dihydrothymine',
#   'CC1CNC(=O)NC1=O',
#   '5135',
#   'C00906',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000085': ('267.2413',
#   'C10H13N5O4',
#   'Deoxyguanosine',
#   'NC1=NC2=C(N=CN2[C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)N1',
#   '3395',
#   'C00330',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000086': ('257.2213',
#   'C8H20NO6P',
#   'Glycerophosphocholine',
#   'C[N+](C)(C)CCOP([O-])(=O)OC[C@@H](O)CO',
#   '370',
#   'C00670',
#   None,
#   'Glycerophospholipids',
#   'Glycerophosphocholines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000087': ('45.0837',
#   'C2H7N',
#   'Dimethylamine',
#   'CNC',
#   '3758',
#   'C00543',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000089': ('243.2166',
#   'C9H13N3O5',
#   'Cytidine',
#   'NC1=NC(=O)N(C=C1)[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O',
#   None,
#   'C02961',
#   None,
#   'Pyrimidine nucleosides',
#   None,
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000092': ('103.1198',
#   'C4H9NO2',
#   'Dimethylglycine',
#   'CN(C)CC(O)=O',
#   '277',
#   'C01026',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000094': ('192.1235',
#   'C6H8O7',
#   'Citric acid',
#   'OC(=O)CC(O)(CC(O)=O)C(O)=O',
#   '124',
#   'C00158',
#   None,
#   'Carboxylic acids and derivatives',
#   'Tricarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000097': ('104.1708',
#   'C5H14NO',
#   'Choline',
#   'C[N+](C)(C)CCO',
#   '56',
#   'C00114',
#   None,
#   'Organonitrogen compounds',
#   'Quaternary ammonium salts',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000098': ('150.1299',
#   'C5H10O5',
#   'D-Xylose',
#   'O[C@@H]1COC(O)[C@H](O)[C@H]1O',
#   '314',
#   'C00181',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000099': ('222.262',
#   'C7H14N2O4S',
#   'L-Cystathionine',
#   'N[C@@H](CCSC[C@H](N)C(O)=O)C(O)=O',
#   '39',
#   'C02291',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000101': ('251.2419',
#   'C10H13N5O3',
#   'Deoxyadenosine',
#   'NC1=NC=NC2=C1N=CN2[C@H]1C[C@H](O)[C@@H](CO)O1',
#   '3382',
#   'C00559',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000107': ('182.1718',
#   'C6H14O6',
#   'Galactitol',
#   'OC[C@H](O)[C@@H](O)[C@@H](O)[C@H](O)CO',
#   '5148',
#   'C01697',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000108': ('46.0684',
#   'C2H6O',
#   'Ethanol',
#   'CCO',
#   '3203',
#   'C00469',
#   None,
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000112': ('103.1198',
#   'C4H9NO2',
#   'gamma-Aminobutyric acid',
#   'NCCCC(O)=O',
#   None,
#   'C00334',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000115': ('76.0514',
#   'C2H4O3',
#   'Glycolic acid',
#   'OCC(O)=O',
#   '3219',
#   'C03547',
#   None,
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000118': ('182.1733',
#   'C9H10O4',
#   'Homovanillic acid',
#   'COC1=CC(CC(O)=O)=CC=C1O',
#   '971',
#   'C05582',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000119': ('74.0355',
#   'C2H2O3',
#   'Glyoxylic acid',
#   'OC(=O)C=O',
#   '3213',
#   'C00048',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000121': ('441.3975',
#   'C19H19N7O6',
#   'Folic acid',
#   'NC1=NC(=O)C2=NC(CNC3=CC=C(C=C3)C(=O)N[C@@H](CCC(O)=O)C(O)=O)=CN=C2N1',
#   '246',
#   'C00504',
#   'map00790',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000122': ('180.1559',
#   'C6H12O6',
#   'D-Glucose',
#   'OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O',
#   '133',
#   'C00031',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000123': ('75.0666',
#   'C2H5NO2',
#   'Glycine',
#   'NCC(O)=O',
#   '20',
#   'C00037',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000124': ('260.1358',
#   'C6H13O9P',
#   'Fructose 6-phosphate',
#   'OCC(=O)[C@@H](O)[C@H](O)[C@H](O)COP(O)(O)=O',
#   '5159',
#   'C00085',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000125': ('307.323',
#   'C10H17N3O6S',
#   'Glutathione',
#   'N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(O)=O)C(O)=O',
#   '44',
#   'C02471',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000126': ('172.0737',
#   'C3H9O6P',
#   'Glycerol 3-phosphate',
#   'OC[C@@H](O)COP(O)(O)=O',
#   '5161',
#   'C00093',
#   'map00564',
#   'Glycerophospholipids',
#   'Glycerophosphates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000127': ('194.1394',
#   'C6H10O7',
#   'D-Glucuronic acid',
#   'O[C@H]1O[C@@H]([C@@H](O)[C@H](O)[C@H]1O)C(O)=O',
#   '161',
#   'C00191',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000128': ('117.1066',
#   'C3H7N3O2',
#   'Guanidoacetic acid',
#   'NC(=N)NCC(O)=O',
#   '5163',
#   'C00581',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000130': ('168.1467',
#   'C8H8O4',
#   'Homogentisic acid',
#   'OC(=O)CC1=C(O)C=CC(O)=C1',
#   '331',
#   'C00544',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenylacetic acids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000131': ('92.0938',
#   'C3H8O3',
#   'Glycerol',
#   'OCC(O)CO',
#   '105',
#   'C00116',
#   'map00561',
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000133': ('283.2407',
#   'C10H13N5O5',
#   'Guanosine',
#   'NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)C(=O)N1',
#   '87',
#   'C00387',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000134': ('116.0722',
#   'C4H4O4',
#   'Fumaric acid',
#   'OC(=O)\\C=C\\C(O)=O',
#   '3242',
#   'C00122',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000138': ('465.6227',
#   'C26H43NO6',
#   'Glycocholic acid',
#   '[H][C@@]12CC[C@H]([C@H](C)CCC(=O)NCC(O)=O)[C@@]1(C)[C@@H](O)C[C@@]1([H])[C@@]2([H])[C@H](O)CC2C[C@H](O)CC[C@]12C',
#   '5169',
#   'C01921',
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000139': ('106.0773',
#   'C3H6O4',
#   'Glyceric acid',
#   'OC[C@@H](O)C(O)=O',
#   '280',
#   'C00258',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000140': ('812.2539',
#   'C48H93NO8',
#   'Glucosylceramide',
#   'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](CO[C@@H]1O[C@H](CO)C(O)[C@H](O)[C@H]1O)[C@H](O)\\C=C\\CCCCCCCCCCCCC',
#   None,
#   'C01190',
#   'map00500',
#   'Sphingolipids',
#   'Glycosphingolipids',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000142': ('46.0254',
#   'CH2O2',
#   'Formic acid',
#   'OC=O',
#   '3202',
#   'C00058',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000143': ('180.1559',
#   'C6H12O6',
#   'D-Galactose',
#   'OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@H]1O',
#   '134',
#   'C00984',
#   'map00500',
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000145': ('270.3661',
#   'C18H22O2',
#   'Estrone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '264',
#   'C00468',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000148': ('147.1293',
#   'C5H9NO4',
#   'L-Glutamic acid',
#   'N[C@@H](CCC(O)=O)C(O)=O',
#   '5174',
#   'C00025',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000149': ('61.0831',
#   'C2H7NO',
#   'Ethanolamine',
#   'NCCO',
#   '3207',
#   'C00189',
#   'map00564',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000150': ('178.14',
#   'C6H10O6',
#   'Gluconolactone',
#   'OC[C@H]1OC(=O)[C@H](O)[C@@H](O)[C@@H]1O',
#   '353',
#   'C00198',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000151': ('272.382',
#   'C18H24O2',
#   'Estradiol',
#   '[H][C@@]12CC[C@H](O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '263',
#   'C00951',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000152': ('154.121',
#   'C7H6O4',
#   'Gentisic acid',
#   'OC(=O)C1=C(O)C=CC(O)=C1',
#   '618',
#   'C00628',
#   None,
#   'Benzene and substituted derivatives',
#   'Benzoic acids and derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000153': ('288.3814',
#   'C18H24O3',
#   'Estriol',
#   '[H][C@@]12C[C@@H](O)[C@H](O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '2581',
#   'C05141',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000156': ('134.0874',
#   'C4H6O5',
#   'L-Malic acid',
#   'O[C@@H](CC(O)=O)C(O)=O',
#   None,
#   'C00149',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000157': ('136.1115',
#   'C5H4N4O',
#   'Hypoxanthine',
#   'OC1=NC=NC2=C1NC=N2',
#   '83',
#   'C00262',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000158': ('181.1885',
#   'C9H11NO3',
#   'L-Tyrosine',
#   'N[C@@H](CC1=CC=C(O)C=C1)C(O)=O',
#   '34',
#   'C00082',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000159': ('165.1891',
#   'C9H11NO2',
#   'L-Phenylalanine',
#   'N[C@@H](CC1=CC=CC=C1)C(O)=O',
#   '28',
#   'C00079',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000161': ('89.0932',
#   'C3H7NO2',
#   'L-Alanine',
#   'C[C@H](N)C(O)=O',
#   None,
#   'C00041',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000162': ('115.1305',
#   'C5H9NO2',
#   'L-Proline',
#   'OC(=O)[C@@H]1CCCN1',
#   '29',
#   'C00148',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000163': ('342.2965',
#   'C12H22O11',
#   'D-Maltose',
#   'OC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@H](O)[C@@H](O)O[C@@H]2CO)[C@H](O)[C@@H](O)[C@@H]1O',
#   '413',
#   'C00208',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000164': ('31.0571',
#   'CH5N',
#   'Methylamine',
#   'CN',
#   '3767',
#   'C00218',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000167': ('119.1192',
#   'C4H9NO3',
#   'L-Threonine',
#   'C[C@@H](O)[C@H](N)C(O)=O',
#   '32',
#   'C00188',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000168': ('132.1179',
#   'C4H8N2O3',
#   'L-Asparagine',
#   'N[C@@H](CC(N)=O)C(O)=O',
#   '14',
#   'C00152',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000169': ('180.1559',
#   'C6H12O6',
#   'D-Mannose',
#   'OC[C@H]1OC(O)[C@@H](O)[C@@H](O)[C@@H]1O',
#   None,
#   'C00159',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000172': ('131.1729',
#   'C6H13NO2',
#   'L-Isoleucine',
#   'CC[C@H](C)[C@H](N)C(O)=O',
#   '5193',
#   'C00407',
#   'map00280',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000174': ('164.1565',
#   'C6H12O5',
#   'L-Fucose',
#   'C[C@@H]1OC(O)[C@@H](O)[C@H](O)[C@@H]1O',
#   '5812',
#   'C00507',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000175': ('348.206',
#   'C10H13N4O8P',
#   'Inosinic acid',
#   'O[C@@H]1[C@@H](COP(O)(O)=O)O[C@H]([C@@H]1O)N1C=NC2=C1N=CNC2=O',
#   '5196',
#   'C00130',
#   None,
#   'Purine nucleotides',
#   'Purine ribonucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000176': ('116.0722',
#   'C4H4O4',
#   'Maleic acid',
#   'OC(=O)\\C=C/C(O)=O',
#   '3242',
#   'C00122',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000177': ('155.1546',
#   'C6H9N3O2',
#   'L-Histidine',
#   'N[C@@H](CC1=CN=CN1)C(O)=O',
#   '21',
#   'C00135',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000181': ('197.1879',
#   'C9H11NO4',
#   'L-Dopa',
#   'N[C@@H](CC1=CC(O)=C(O)C=C1)C(O)=O',
#   '42',
#   'C00355',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000182': ('146.1876',
#   'C6H14N2O2',
#   'L-Lysine',
#   'NCCCC[C@H](N)C(O)=O',
#   '5200',
#   'C00047',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000186': ('342.2965',
#   'C12H22O11',
#   'Alpha-Lactose',
#   'OC[C@H]1O[C@@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O)O[C@@H]2CO)[C@H](O)[C@@H](O)[C@H]1O',
#   '267',
#   'C00243',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000187': ('105.0926',
#   'C3H7NO3',
#   'L-Serine',
#   'N[C@@H](CO)C(O)=O',
#   '5203',
#   'C00065',
#   'map00500',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000190': ('90.0779',
#   'C3H6O3',
#   'L-Lactic acid',
#   'C[C@H](O)C(O)=O',
#   '6150',
#   'C00256',
#   None,
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000191': ('133.1027',
#   'C4H7NO4',
#   'L-Aspartic acid',
#   'N[C@@H](CC(O)=O)C(O)=O',
#   '5206',
#   'C00049',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000192': ('240.3',
#   'C6H12N2O4S2',
#   'L-Cystine',
#   'N[C@@H](CSSC[C@H](N)C(O)=O)C(O)=O',
#   '5207',
#   'C00491',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000193': ('192.1235',
#   'C6H8O7',
#   'Isocitric acid',
#   'OC(C(CC(O)=O)C(O)=O)C(O)=O',
#   '3328',
#   'C00311',
#   None,
#   'Carboxylic acids and derivatives',
#   'Tricarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000194': ('240.259',
#   'C10H16N4O3',
#   'Anserine',
#   'CN1C=NC=C1C[C@H](NC(=O)CCN)C(O)=O',
#   '5209',
#   'C01262',
#   None,
#   'Peptidomimetics',
#   'Hybrid peptides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000195': ('268.2261',
#   'C10H12N4O5',
#   'Inosine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=NC2=C1NC=NC2=O',
#   '84',
#   'C00294',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000197': ('175.184',
#   'C10H9NO2',
#   'Indoleacetic acid',
#   'OC(=O)CC1=CNC2=C1C=CC=C2',
#   '5211',
#   'C00954',
#   'map00380',
#   'Indoles and derivatives',
#   'Indolyl carboxylic acids and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000201': ('203.238',
#   'C9H17NO4',
#   'L-Acetylcarnitine',
#   'CC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C',
#   None,
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000202': ('118.088',
#   'C4H6O4',
#   'Methylmalonic acid',
#   'CC(C(O)=O)C(O)=O',
#   '3712',
#   'C02170',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000205': ('164.158',
#   'C9H8O3',
#   'Phenylpyruvic acid',
#   'OC(=O)C(=O)CC1=CC=CC=C1',
#   '328',
#   'C00166',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenylpyruvic acid derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000206': ('188.2242',
#   'C8H16N2O3',
#   'N6-Acetyl-L-lysine',
#   'CC(=O)NCCCC[C@H](N)C(O)=O',
#   '5216',
#   'C02727',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000207': ('282.4614',
#   'C18H34O2',
#   'Oleic acid',
#   'CCCCCCCC\\C=C/CCCCCCCC(O)=O',
#   '190',
#   'C00712',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000208': ('146.0981',
#   'C5H6O5',
#   'Oxoglutaric acid',
#   'OC(=O)CCC(=O)C(O)=O',
#   '5218',
#   'C00026',
#   None,
#   'Keto acids and derivatives',
#   'Gamma-keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000209': ('136.1479',
#   'C8H8O2',
#   'Phenylacetic acid',
#   'OC(=O)CC1=CC=CC=C1',
#   '129',
#   'C07086',
#   'map00360',
#   'Benzene and substituted derivatives',
#   None,
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000210': ('219.235',
#   'C9H17NO5',
#   'Pantothenic acid',
#   'CC(C)(CO)[C@@H](O)C(=O)NCCC(O)=O',
#   None,
#   'C00864',
#   None,
#   'Alcohols and polyols',
#   'Polyols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000211': ('180.1559',
#   'C6H12O6',
#   'myo-Inositol',
#   'O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@H](O)[C@@H]1O',
#   '5221',
#   'C00137',
#   'map00562',
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0000214': ('132.161',
#   'C5H12N2O2',
#   'Ornithine',
#   'NCCC[C@H](N)C(O)=O',
#   '27',
#   'C00077',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000215': ('221.2078',
#   'C8H15NO6',
#   'N-Acetyl-D-glucosamine',
#   'CC(=O)N[C@H]1C(O)O[C@H](CO)[C@@H](O)[C@@H]1O',
#   '3356',
#   'C00140',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000216': ('169.1778',
#   'C8H11NO3',
#   'Norepinephrine',
#   'NC[C@H](O)C1=CC(O)=C(O)C=C1',
#   '5226',
#   'C00547',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000217': ('744.4129',
#   'C21H29N7O17P3',
#   'NADP',
#   'NC(=O)C1=C[N+](=CC=C1)[C@@H]1O[C@H](CO[P@](O)(=O)O[P@](O)(=O)OC[C@H]2O[C@H]([C@H](OP(O)(O)=O)[C@@H]2O)N2C=NC3=C(N)N=CN=C23)[C@@H](O)[C@H]1O',
#   '5227',
#   'C00006',
#   None,
#   "(5'->5')-dinucleotides",
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000220': ('256.4241',
#   'C16H32O2',
#   'Palmitic acid',
#   'CCCCCCCCCCCCCCCC(O)=O',
#   '187',
#   'C00249',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000221': ('745.4209',
#   'C21H30N7O17P3',
#   'NADPH',
#   'NC(=O)C1=CN(C=CC1)[C@H]1O[C@@H](COP(O)(=O)OP(O)(=O)OC[C@@H]2O[C@@H]([C@@H](OP(O)(O)=O)[C@H]2O)N2C=NC3=C(N)N=CN=C23)[C@H](O)[C@@H]1O',
#   '3691',
#   'C00005',
#   None,
#   "(5'->5')-dinucleotides",
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000222': ('399.6077',
#   'C23H45NO4',
#   'L-Palmitoylcarnitine',
#   'CCCCCCCCCCCCCCCC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C',
#   '5231',
#   'C02990',
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000224': ('141.063',
#   'C2H8NO4P',
#   'O-Phosphoethanolamine',
#   'NCCOP(O)(O)=O',
#   '5233',
#   'C00346',
#   'map00500',
#   'Organic phosphoric acids and derivatives',
#   'Phosphate esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000225': ('160.1247',
#   'C6H8O5',
#   'Oxoadipic acid',
#   'OC(=O)CCCC(=O)C(O)=O',
#   '5234',
#   'C00322',
#   None,
#   'Keto acids and derivatives',
#   'Medium-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000226': ('156.0963',
#   'C5H4N2O4',
#   'Orotic acid',
#   'OC(=O)C1=CC(=O)NC(=O)N1',
#   '318',
#   'C00295',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000227': ('148.1571',
#   'C6H12O4',
#   'Mevalonic acid',
#   'CC(O)(CCO)CC(O)=O',
#   '127',
#   'C00418',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000228': ('94.1112',
#   'C6H6O',
#   'Phenol',
#   'OC1=CC=CC=C1',
#   '128',
#   'C15584',
#   None,
#   'Phenols',
#   '1-hydroxy-4-unsubstituted benzenoids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000229': ('334.2192',
#   'C11H15N2O8P',
#   'Nicotinamide ribotide',
#   'NC(=O)C1=CC=C[N+](=C1)[C@@H]1O[C@H](COP(O)([O-])=O)[C@@H](O)[C@H]1O',
#   '5238',
#   'C00455',
#   'map00760',
#   'Pyridine nucleotides',
#   'Nicotinamide nucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000230': ('309.2699',
#   'C11H19NO9',
#   'N-Acetylneuraminic acid',
#   'CC(=O)N[C@@H]1[C@@H](O)C[C@](O)(O[C@H]1[C@H](O)[C@H](O)CO)C(O)=O',
#   '3321',
#   'C19910',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000232': ('167.1189',
#   'C7H5NO4',
#   'Quinolinic acid',
#   'OC(=O)C1=CC=CN=C1C(O)=O',
#   '330',
#   'C03722',
#   'map00380',
#   'Pyridines and derivatives',
#   'Pyridinecarboxylic acids and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000234': ('288.4244',
#   'C19H28O2',
#   'Testosterone',
#   '[H][C@@]12CC[C@H](O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5601',
#   None,
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000235': ('265.355',
#   'C12H17N4OS',
#   'Thiamine',
#   'CC1=C(CCO)SC=[N+]1CC1=CN=C(C)N=C1N',
#   '5242',
#   'C00378',
#   'map00730',
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000237': ('74.0785',
#   'C3H6O2',
#   'Propionic acid',
#   'CCC(O)=O',
#   '3215',
#   'C00163',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000239': ('169.1778',
#   'C8H11NO3',
#   'Pyridoxine',
#   'CC1=C(O)C(CO)=C(CO)C=N1',
#   '5245',
#   'C00314',
#   'map00750',
#   'Pyridines and derivatives',
#   'Pyridoxines',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000240': ('82.079',
#   'H2O3S',
#   'Sulfite',
#   'OS(O)=O',
#   None,
#   'C00094',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal sulfites',
#   None),
#  'HMDB0000241': ('562.6582',
#   'C34H34N4O4',
#   'Protoporphyrin IX',
#   'CC1=C(CCC(O)=O)/C2=C/C3=N/C(=C\\C4=C(C)C(C=C)=C(N4)/C=C4\\N=C(\\C=C\\1/N\\2)C(C=C)=C4C)/C(C)=C3CCC(O)=O',
#   '4158',
#   'C02191',
#   'map00860',
#   'Tetrapyrroles and derivatives',
#   'Porphyrins',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000243': ('88.0621',
#   'C3H4O3',
#   'Pyruvic acid',
#   'CC(=O)C(O)=O',
#   '117',
#   'C00022',
#   None,
#   'Keto acids and derivatives',
#   'Alpha-keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000244': ('376.3639',
#   'C17H20N4O6',
#   'Riboflavin',
#   'CC1=C(C)C=C2N(C[C@H](O)[C@H](O)[C@H](O)CO)C3=NC(=O)NC(=O)C3=NC2=C1',
#   '5249',
#   'C00255',
#   'map00740',
#   'Pteridines and derivatives',
#   'Alloxazines and isoalloxazines',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000245': ('226.2292',
#   'C10H14N2O4',
#   'Porphobilinogen',
#   'NCC1=C(CC(O)=O)C(CCC(O)=O)=CN1',
#   '76',
#   'C00931',
#   'map00860',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000246': ('72.1057',
#   'C4H8O',
#   'Tetrahydrofuran',
#   'C1CCOC1',
#   None,
#   None,
#   'map00860',
#   'Tetrahydrofurans',
#   None,
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000247': ('182.1718',
#   'C6H14O6',
#   'Sorbitol',
#   'OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#   '143',
#   'C00794',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000248': ('776.87',
#   'C15H11I4NO4',
#   'Thyroxine',
#   'N[C@@H](CC1=CC(I)=C(OC2=CC(I)=C(O)C(I)=C2)C(I)=C1)C(O)=O',
#   '439',
#   'C01829',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000250': ('177.9751',
#   'H4O7P2',
#   'Pyrophosphate',
#   'OP(O)(=O)OP(O)(O)=O',
#   None,
#   'C00013',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal pyrophosphates',
#   'Acyclic compounds'),
#  'HMDB0000251': ('125.147',
#   'C2H7NO3S',
#   'Taurine',
#   'NCCS(O)(=O)=O',
#   '31',
#   'C00245',
#   None,
#   'Organic sulfonic acids and derivatives',
#   'Organosulfonic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000252': ('299.4919',
#   'C18H37NO2',
#   'Sphingosine',
#   'CCCCCCCCCCCCC\\C=C\\C(O)C(N)CO',
#   '392',
#   'C00319',
#   'map00500',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000253': ('316.4776',
#   'C21H32O2',
#   'Pregnenolone',
#   '[H][C@@]12CC[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   None,
#   'C01953',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000254': ('118.088',
#   'C4H6O4',
#   'Succinic acid',
#   'OC(=O)CCC(O)=O',
#   '114',
#   'C00042',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000256': ('410.718',
#   'C30H50',
#   'Squalene',
#   'CC(C)=CCC\\C(C)=C/CC\\C(C)=C\\CC\\C=C(/C)CC\\C=C(/C)CCC=C(C)C',
#   '197',
#   'C00751',
#   None,
#   'Prenol lipids',
#   'Triterpenoids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000257': ('114.144',
#   'H2O3S2',
#   'Thiosulfate',
#   'OS(S)(=O)=O',
#   None,
#   'C05529',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal thiosulfates',
#   None),
#  'HMDB0000258': ('342.2965',
#   'C12H22O11',
#   'Sucrose',
#   'OC[C@H]1O[C@@](CO)(O[C@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O',
#   '137',
#   'C00089',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000259': ('176.2151',
#   'C10H12N2O',
#   'Serotonin',
#   'NCCC1=CNC2=CC=C(O)C=C12',
#   '74',
#   'C00780',
#   'map00380',
#   'Indoles and derivatives',
#   'Tryptamines and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000262': ('126.1133',
#   'C5H6N2O2',
#   'Thymine',
#   'CC1=CNC(=O)NC1=O',
#   '290',
#   'C00178',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000263': ('168.042',
#   'C3H5O6P',
#   'Phosphoenolpyruvic acid',
#   'OC(=O)C(=C)OP(O)(O)=O',
#   '5264',
#   'C00074',
#   None,
#   'Organic phosphoric acids and derivatives',
#   'Phosphate esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000265': ('650.9735',
#   'C15H12I3NO4',
#   'Liothyronine',
#   'N[C@@H](CC1=CC(I)=C(OC2=CC(I)=C(O)C=C2)C(I)=C1)C(O)=O',
#   '5265',
#   'C02465',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000267': ('129.114',
#   'C5H7NO3',
#   'Pyroglutamic acid',
#   'OC(=O)[C@@H]1CCC(=O)N1',
#   '3251',
#   'C01879',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000268': ('350.4923',
#   'C21H34O4',
#   'Tetrahydrocorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(C)C[C@H](O)[C@@]1([H])C2CC[C@]2([H])C[C@H](O)CC[C@]12C',
#   '5267',
#   'C05476',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000269': ('301.5078',
#   'C18H39NO2',
#   'Sphinganine',
#   'CCCCCCCCCCCCCCC[C@@H](O)[C@@H](N)CO',
#   '5268',
#   'C00836',
#   'map00500',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000271': ('89.0932',
#   'C3H7NO2',
#   'Sarcosine',
#   'CNCC(O)=O',
#   '51',
#   'C00213',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000272': ('185.0725',
#   'C3H8NO6P',
#   'Phosphoserine',
#   'N[C@@H](COP(O)(O)=O)C(O)=O',
#   '5270',
#   'C01005',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000273': ('242.2286',
#   'C10H14N2O5',
#   'Thymidine',
#   'CC1=CN([C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)NC1=O',
#   '3375',
#   'C00214',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000277': ('379.4718',
#   'C18H38NO5P',
#   'Sphingosine 1-phosphate',
#   'CCCCCCCCCCCCC\\C=C\\[C@@H](O)[C@@H](N)COP(O)(O)=O',
#   '5272',
#   'C06124',
#   'map00500',
#   'Sphingolipids',
#   'Phosphosphingolipids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000279': ('276.2863',
#   'C11H20N2O6',
#   'Saccharopine',
#   'N[C@@H](CCCCN[C@@H](CCC(O)=O)C(O)=O)C(O)=O',
#   '383',
#   'C00449',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000280': ('390.0696',
#   'C5H13O14P3',
#   'Phosphoribosyl pyrophosphate',
#   'O[C@H]1[C@@H](O)[C@@H](O[P@](O)(=O)OP(O)(O)=O)O[C@@H]1COP(O)(O)=O',
#   '5274',
#   'C00119',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000283': ('150.1299',
#   'C5H10O5',
#   'D-Ribose',
#   'OC[C@H]1OC(O)[C@H](O)[C@@H]1O',
#   '313',
#   'C00121',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000286': ('566.3018',
#   'C15H24N2O17P2',
#   'Uridine diphosphate glucose',
#   'OC[C@@H]1OC(OP(O)(=O)OP(O)(=O)OC[C@@H]2O[C@@H]([C@@H](O)[C@H]2O)N2C=CC(=O)NC2=O)[C@@H](O)[C@H](O)[C@H]1O',
#   '5278',
#   'C00029',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine nucleotide sugars',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000288': ('324.1813',
#   'C9H13N2O9P',
#   "Uridine 5'-monophosphate",
#   'O[C@H]1[C@@H](O)[C@@H](O[C@@H]1COP(O)(O)=O)N1C=CC(=O)NC1=O',
#   None,
#   'C00105',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine ribonucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000289': ('168.1103',
#   'C5H4N4O3',
#   'Uric acid',
#   'O=C1NC2=C(N1)C(=O)NC(=O)N2',
#   '88',
#   'C00366',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000291': ('198.1727',
#   'C9H10O5',
#   'Vanillylmandelic acid',
#   'COC1=C(O)C=CC(=C1)[C@H](O)C(O)=O',
#   '697',
#   'C05584',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000292': ('152.1109',
#   'C5H4N4O2',
#   'Xanthine',
#   'O=C1NC2=C(NC=N2)C(=O)N1',
#   '82',
#   'C00385',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000294': ('60.0553',
#   'CH4N2O',
#   'Urea',
#   'NC(N)=O',
#   '6',
#   'C00086',
#   'map00330',
#   'Organic carbonic acids and derivatives',
#   'Ureas',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000295': ('404.1612',
#   'C9H14N2O12P2',
#   "Uridine 5'-diphosphate",
#   'O[C@H]1[C@@H](O)[C@@H](O[C@@H]1COP(O)(=O)OP(O)(O)=O)N1C=CC(=O)NC1=O',
#   None,
#   'C00015',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine ribonucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000296': ('244.2014',
#   'C9H12N2O6',
#   'Uridine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(=O)NC1=O',
#   '90',
#   'C00299',
#   None,
#   'Pyrimidine nucleosides',
#   None,
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000299': ('284.2255',
#   'C10H12N4O6',
#   'Xanthosine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=NC2=C1N=C(O)N=C2O',
#   '3408',
#   'C01762',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000300': ('112.0868',
#   'C4H4N2O2',
#   'Uracil',
#   'O=C1NC=CC(=O)N1',
#   '258',
#   'C00106',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000301': ('138.124',
#   'C6H6N2O2',
#   'Urocanic acid',
#   'OC(=O)\\C=C\\C1=CNC=N1',
#   '298',
#   'C00785',
#   None,
#   'Azoles',
#   'Imidazoles',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000303': ('160.2157',
#   'C10H12N2',
#   'Tryptamine',
#   'NCCC1=CNC2=CC=CC=C12',
#   '325',
#   'C00398',
#   'map00380',
#   'Indoles and derivatives',
#   'Tryptamines and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000305': ('286.4516',
#   'C20H30O',
#   'Vitamin A',
#   'C\\C(=C/CO)\\C=C\\C=C(/C)\\C=C\\C1=C(C)CCCC1(C)C',
#   None,
#   'C19962',
#   None,
#   'Prenol lipids',
#   'Retinoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0000306': ('137.179',
#   'C8H11NO',
#   'Tyramine',
#   'NCCC1=CC=C(O)C=C1',
#   '60',
#   'C00483',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenethylamines',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000308': ('374.5567',
#   'C24H38O3',
#   '3b-Hydroxy-5-cholenoic acid',
#   '[H][C@@]12CC[C@H]([C@H](C)CCC(O)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5297',
#   None,
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000315': ('332.477',
#   'C21H32O3',
#   '16-a-Hydroxypregnenolone',
#   '[H][C@@]12C[C@@H](O)[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5304',
#   'C06390  ',
#   None,
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000317': ('132.1577',
#   'C6H12O3',
#   '2-Hydroxy-3-methylpentanoic acid',
#   'CC[C@@H](C)[C@@H](O)C(O)=O',
#   '5306',
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000318': ('170.1626',
#   'C8H10O4',
#   '3,4-Dihydroxyphenylglycol',
#   'OCC(O)C1=CC(O)=C(O)C=C1',
#   '5307',
#   'C05576',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000319': ('362.4599',
#   'C21H30O5',
#   '18-Hydroxycorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(CO)C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5308',
#   'C01124',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000321': ('162.1406',
#   'C6H10O5',
#   '2-Hydroxyadipic acid',
#   'OC(CCCC(O)=O)C(O)=O',
#   '5310',
#   'C02360',
#   'map00140',
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000325': ('190.1938',
#   'C8H14O5',
#   '3-Hydroxysuberic acid',
#   'OC(CCCCC(O)=O)CC(O)=O',
#   '5314',
#   None,
#   'map00140',
#   'Hydroxy acids and derivatives',
#   'Medium-chain hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000326': ('408.5714',
#   'C24H40O5',
#   '1b,3a,12a-Trihydroxy-5b-cholanoic acid',
#   'C[C@H](CCC(O)=O)C1CCC2C3CCC4C[C@H](O)C[C@@H](O)[C@]4(C)C3C[C@H](O)[C@]12C',
#   '5315',
#   None,
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000332': ('376.4434',
#   'C21H28O6',
#   '18-Oxocortisol',
#   '[H][C@@]12CC[C@@](O)(C(=O)CO)[C@]1(C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C)C=O',
#   '5321',
#   None,
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000335': ('286.3655',
#   'C18H22O3',
#   '16a-Hydroxyestrone',
#   '[H][C@@]12C[C@@H](O)C(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '2580',
#   'C05300',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000336': ('104.1045',
#   'C4H8O3',
#   '(R)-3-Hydroxyisobutyric acid',
#   'C[C@H](CO)C(O)=O',
#   None,
#   None,
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000337': ('120.1039',
#   'C4H8O4',
#   '(S)-3,4-Dihydroxybutyric acid',
#   'OCC(O)CC(O)=O',
#   None,
#   None,
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000343': ('286.3655',
#   'C18H22O3',
#   '2-Hydroxyestrone',
# ...
#   'Raffinose',
#   'OC[C@H]1O[C@@](CO)(OC2O[C@H](COC3O[C@H](CO)[C@H](O)[C@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O',
#   '138',
#   'C00492',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003217': ('270.24',
#   'C15H10O5',
#   'Genistein',
#   'OC1=CC=C(C=C1)C1=COC2=CC(O)=CC(O)=C2C1=O',
#   '3398',
#   'C06563',
#   None,
#   'Isoflavonoids',
#   'Isoflav-2-enes',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003227': ('48.107',
#   'CH4S',
#   'Methanethiol',
#   'CS',
#   '3204',
#   'C00409',
#   None,
#   'Thiols',
#   'Alkylthiols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003229': ('254.4082',
#   'C16H30O2',
#   'Palmitoleic acid',
#   'CCCCCC\\C=C/CCCCCCCC(O)=O',
#   '188',
#   'C08362',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003231': ('282.468',
#   'C18H34O2',
#   'Vaccenic acid',
#   'CCCCCC\\C=C\\CCCCCCCCCC(O)=O',
#   None,
#   'C08367',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003233': ('568.8714',
#   'C40H56O2',
#   'Lutein',
#   'O[C@@H]1CC(C)=C(\\C=C\\C(\\C)=C\\C=C\\C(\\C)=C\\C=C\\C=C(/C)\\C=C\\C=C(/C)\\C=C\\[C@H]2C(C)=CC(O)CC2(C)C)C(C)(C)C1',
#   '3601',
#   'C08601',
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003236': ('397.6364',
#   'C27H43NO',
#   'Solanidine',
#   '[H][C@]12CC[C@H](C)CN1[C@@]1([H])C[C@@]3([H])[C@]4([H])CC=C5C[C@@H](O)CC[C@]5(C)[C@@]4([H])CC[C@]3(C)[C@@]1([H])[C@@H]2C',
#   '3517',
#   'C06543',
#   None,
#   'Steroids and steroid derivatives',
#   'Steroidal alkaloids',
#   'Aliphatic heteropolycyclic compounds'),
#  'HMDB0003243': ('88.1051',
#   'C4H8O2',
#   'Acetoin',
#   'CC(O)C(C)=O',
#   '103',
#   'C00466',
#   None,
#   'Organooxygen compounds',
#   'Carbonyl compounds',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003249': ('610.5175',
#   'C27H30O16',
#   'Rutin',
#   'C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](OC3=C(OC4=CC(O)=CC(O)=C4C3=O)C3=CC(O)=C(O)C=C3)[C@H](O)[C@@H](O)[C@@H]2O)[C@H](O)[C@H](O)[C@H]1O',
#   '3677',
#   'C05625',
#   None,
#   'Flavonoids',
#   'Flavonoid glycosides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003252': ('370.4804',
#   'C20H34O6',
#   'Thromboxane B2',
#   'CCCCC[C@H](O)\\C=C\\[C@H]1OC(O)C[C@H](O)[C@@H]1C\\C=C/CCCC(O)=O',
#   '422',
#   'C05963',
#   None,
#   'Fatty Acyls',
#   'Eicosanoids',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003269': ('180.1607',
#   'C8H8N2O3',
#   'Nicotinuric acid',
#   'OC(=O)CNC(=O)C1=CN=CC=C1',
#   '1499',
#   'C05380',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0003276': ('34.081',
#   'H2S',
#   'Hydrogen sulfide',
#   'S',
#   '3193',
#   'C00283',
#   None,
#   'Other non-metal organides',
#   'Other non-metal sulfides',
#   None),
#  'HMDB0003306': ('274.2687',
#   'C15H14O5',
#   'Phloretin',
#   'OC1=CC=C(CCC(=O)C2=C(O)C=C(O)C=C2O)C=C1',
#   '3405',
#   'C00774',
#   None,
#   'Linear 1,3-diarylpropanoids',
#   'Chalcones and dihydrochalcones',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003312': ('254.241',
#   'C15H10O4',
#   'Daidzein',
#   'OC1=CC=C(C=C1)C1=COC2=C(C=CC(O)=C2)C1=O',
#   None,
#   'C10208',
#   None,
#   'Isoflavonoids',
#   'Isoflav-2-enes',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003325': ('936.921',
#   'C45H52N4O18',
#   'Bilirubin diglucuronide',
#   '[H]\\C(C1=C(C)C(CCC(=O)O[C@]2([H])O[C@]([H])(C(O)=O)[C@@]([H])(O)[C@]([H])(O)[C@@]2([H])O)=C(CC2=C(CCC(=O)O[C@]3([H])O[C@]([H])(C(O)=O)[C@@]([H])(O)[C@]([H])(O)[C@@]3([H])O)C(C)=C(N2)C(\\[H])=C2/N=C(O)C(C)=C2C=C)N1)=C1/N=C(O)C(C=C)=C1C',
#   None,
#   None,
#   'map00860',
#   'Tetrapyrroles and derivatives',
#   'Bilirubins',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0003331': ('281.2679',
#   'C11H15N5O4',
#   '1-Methyladenosine',
#   'CN1C=NC2=C(N=CN2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)C1=N',
#   '6888',
#   'C02494',
#   'map00860',
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003332': ('264.252',
#   'C9H12O7S',
#   '3-Methoxy-4-Hydroxyphenylglycol sulfate',
#   'COC1=C(O)C=CC(=C1)C(CO)OS(O)(=O)=O',
#   '6889',
#   None,
#   'map00860',
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003333': ('283.2407',
#   'C10H13N5O5',
#   '8-Hydroxy-deoxyguanosine',
#   'NC1=NC2=C(N=C(O)N2[C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)N1',
#   '6890',
#   None,
#   'map00860',
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003334': ('202.2541',
#   'C8H18N4O2',
#   'Symmetric dimethylarginine',
#   'CN\\C(NCCC[C@H](N)C(O)=O)=N/C',
#   '6891',
#   None,
#   'map00860',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003337': ('612.631',
#   'C20H32N6O12S2',
#   'Oxidized glutathione',
#   'NC(CCC(=O)NC(CSSCC(NC(=O)CCC(N)C(O)=O)C(=O)NCC(O)=O)C(=O)NCC(O)=O)C(O)=O',
#   '6893',
#   'C00127',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003338': ('33.0299',
#   'H3NO',
#   'Hydroxylamine',
#   'NO',
#   '6894',
#   'C00192',
#   None,
#   'Homogeneous other non-metal compounds',
#   None,
#   None),
#  'HMDB0003339': ('147.1293',
#   'C5H9NO4',
#   'D-Glutamic acid',
#   'N[C@H](CCC(O)=O)C(O)=O',
#   '6895',
#   'C00217',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003352': ('156.269',
#   'C10H20O',
#   'Menthol',
#   'CC(C)[C@@H]1CC[C@@H](C)C[C@H]1O',
#   None,
#   'C00400',
#   None,
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003355': ('117.1463',
#   'C5H11NO2',
#   '5-Aminopentanoic acid',
#   'NCCCCC(O)=O',
#   '6902',
#   'C00431',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003357': ('174.1977',
#   'C7H14N2O3',
#   'N-Acetylornithine',
#   'CC(=O)N[C@@H](CCCN)C(O)=O',
#   None,
#   'C00437',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003374': ('132.161',
#   'C5H12N2O2',
#   'D-Ornithine',
#   'NCCC[C@@H](N)C(O)=O',
#   '6910',
#   'C00515',
#   'map00472',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003375': ('136.234',
#   'C10H16',
#   'D-Limonene',
#   'CC(=C)[C@H]1CCC(C)=CC1',
#   '6911',
#   'C00521',
#   'map00472',
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003378': ('30.0061',
#   'NO',
#   'Nitric oxide',
#   '[N]=O',
#   '6912',
#   'C00533',
#   None,
#   'Other non-metal organides',
#   'Other non-metal oxides',
#   None),
#  'HMDB0003406': ('105.0926',
#   'C3H7NO3',
#   'D-Serine',
#   'N[C@H](CO)C(O)=O',
#   '6920',
#   'C00740',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003409': ('336.3612',
#   'C20H18NO4',
#   'Berberine',
#   'COC1=CC=C2C=C3C4=CC5=C(OCO5)C=C4CC[N+]3=CC2=C1OC',
#   '3471',
#   'C00757',
#   None,
#   'Protoberberine alkaloids and derivatives',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003415': ('568.886',
#   'C40H56O2',
#   "(3R,3'S,6'R)-b,e-Carotene-3,3'-diol",
#   'C\\C(\\C=C\\C=C(/C)\\C=C\\[C@H]1C(C)=C[C@@H](O)CC1(C)C)=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)C[C@@H](O)CC1(C)C',
#   None,
#   None,
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003429': ('1330.378',
#   'C62H89CoN13O14P',
#   'Cob(I)alamin',
#   '[H][C@]12[C@H](CC(N)=O)[C@@]3(C)CCC(=O)NC[C@@H](C)OP(O)(=O)O[C@@H]4[C@@H](CO)O[C@@H]([C@@H]4O)N4C=[N+](C5=CC(C)=C(C)C=C45)[Co-4]456N1C3=C(C)C1=[N+]4C(=CC3=[N+]5C(=C(C)C4=[N+]6[C@]2(C)[C@@](C)(CC(N)=O)[C@@H]4CCC(N)=O)[C@@](C)(CC(N)=O)[C@@H]3CCC(N)=O)C(C)(C)[C@@H]1CCC(N)=O',
#   None,
#   'C00853',
#   None,
#   'Tetrapyrroles and derivatives',
#   'Corrinoids',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003448': ('566.8556',
#   'C40H54O2',
#   "3-Hydroxy-b,e-caroten-3'-one",
#   'C\\C(\\C=C\\C=C(/C)\\C=C\\C1C(C)=CC(=O)CC1(C)C)=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CC(O)CC1(C)C',
#   None,
#   None,
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003458': ('1636.69',
#   'C72H105CoN16O20PS',
#   'Aquacobalamin',
#   '[N+]12=C3C(C(C)(C1=C(C1=[N+]4C(C(CC(N)=O)(C)C1CCC(N)=O)(C)C1N5C6=C(C7=[N+](C(=C3)C(C)(C)C7CCC(N)=O)[Co-3]245(SCC(NC(CCC(C(=O)O)N)=O)C(=O)NCC(O)=O)[N+]2=CN(C3C(C(C(CO)O3)OP(O)(OC(C)CNC(=O)CCC6(C)C1CC(N)=O)=O)O)C1=CC(=C(C=C21)C)C)C)C)CC(N)=O)CCC(N)=O',
#   None,
#   'C00992',
#   None,
#   'Tetrapyrroles and derivatives',
#   'Corrinoids',
#   None),
#  'HMDB0003464': ('145.1597',
#   'C5H11N3O2',
#   '4-Guanidinobutanoic acid',
#   'NC(N)=NCCCC(O)=O',
#   '6938',
#   'C01035',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003466': ('178.14',
#   'C6H10O6',
#   'L-Gulonolactone',
#   '[H][C@@]1(OC(=O)[C@@H](O)[C@H]1O)[C@@H](O)CO',
#   None,
#   'C01040',
#   None,
#   'Lactones',
#   'Gamma butyrolactones',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003474': ('432.9816',
#   'C9H9I2NO3',
#   '3,5-Diiodo-L-tyrosine',
#   '[H][C@](N)(CC1=CC(I)=C(O)C(I)=C1)C(O)=O',
#   '6940',
#   'C01060',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003502': ('660.0353',
#   'C6H18O24P6',
#   'Myo-inositol hexakisphosphate',
#   'OP(O)(=O)OC1C(OP(O)(O)=O)C(OP(O)(O)=O)C(OP(O)(O)=O)C(OP(O)(O)=O)C1OP(O)(O)=O',
#   '6941',
#   'C01204',
#   'map00562',
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003503': ('198.1727',
#   'C9H10O5',
#   '3-(3,4-Dihydroxyphenyl)lactic acid',
#   'OC(CC1=CC(O)=C(O)C=C1)C(O)=O',
#   '6942',
#   'C01207',
#   'map00562',
#   'Phenylpropanoic acids',
#   None,
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003514': ('340.1157',
#   'C6H14O12P2',
#   'Alpha-D-Glucose 1,6-bisphosphate',
#   'O[C@H]1[C@H](O)[C@@H](COP(O)(O)=O)O[C@H](OP(O)(O)=O)[C@@H]1O',
#   None,
#   'C01231',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003550': ('400.6371',
#   'C27H44O2',
#   'Calcidiol',
#   'C[C@H](CCCC(C)(C)O)[C@@]1([H])CC[C@@]2([H])\\C(CCC[C@]12C)=C\\C=C1\\C[C@@H](O)CCC1=C',
#   '6949',
#   'C01561',
#   None,
#   'Steroids and steroid derivatives',
#   'Vitamin D and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003555': ('450.6957',
#   'C31H46O2',
#   'Vitamin K1',
#   'CC(C)CCCC(C)CCCC(C)CCC\\C(C)=C\\CC1=C(C)C(=O)C2=CC=CC=C2C1=O',
#   '6952',
#   'C02059',
#   None,
#   'Prenol lipids',
#   'Quinone and hydroquinone lipids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0003572': ('360.3148',
#   'C18H16O8',
#   'Rosmarinic acid',
#   'OC(=O)[C@@H](CC1=CC(O)=C(O)C=C1)OC(=O)\\C=C\\C1=CC(O)=C(O)C=C1',
#   '6960',
#   'C01850',
#   None,
#   'Cinnamic acids and derivatives',
#   'Hydroxycinnamic acids and derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003573': ('303.3529',
#   'C17H21NO4',
#   'Scopolamine',
#   'CN1[C@H]2C[C@@H](C[C@@H]1[C@H]1O[C@@H]21)OC(=O)[C@H](CO)C1=CC=CC=C1',
#   '3433',
#   'C01851',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003584': ('167.187',
#   'C3H9N3O3S',
#   'Taurocyamine',
#   'NC(N)=NCCS(O)(=O)=O',
#   '6962',
#   'C01959',
#   None,
#   'Organic sulfonic acids and derivatives',
#   'Organosulfonic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003598': ('302.451',
#   'C20H30O2',
#   'Retinyl ester',
#   'CC1CCCC(C)(C)C1\\C=C\\C(\\C)=C\\C=C\\C(\\C)=C\\C(O)=O',
#   '6966',
#   'C02075',
#   None,
#   'Prenol lipids',
#   'Retinoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003625': ('200.59',
#   'Hg',
#   'Mercury',
#   '[Hg++]',
#   None,
#   'C00703',
#   None,
#   'Homogeneous transition metal compounds',
#   None,
#   None),
#  'HMDB0003634': ('152.237',
#   'C10H16O',
#   'Perillyl alcohol',
#   'CC(=C)C1CCC(CO)=CC1',
#   '6969',
#   'C02452',
#   None,
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003638': ('112.411',
#   'Cd',
#   'Cadmium',
#   '[Cd++]',
#   None,
#   'C01413',
#   None,
#   'Homogeneous transition metal compounds',
#   None,
#   None),
#  'HMDB0003640': ('131.1729',
#   'C6H13NO2',
#   'Beta-Leucine',
#   'CC(C)[C@@H](N)CC(O)=O',
#   None,
#   'C02486',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003642': ('87.62',
#   'Sr',
#   'Strontium',
#   '[Sr++]',
#   None,
#   'C13884',
#   None,
#   'Homogeneous alkaline earth metal compounds',
#   None,
#   None),
#  'HMDB0003646': ('114.1026',
#   'C4H6N2O2',
#   'N-Methylhydantoin',
#   'CN1CC(=O)NC1=O',
#   None,
#   'C02565',
#   None,
#   'Azolines',
#   'Imidazolines',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003648': ('524.8604',
#   'C36H60O2',
#   'Retinyl palmitate',
#   'CCCCCCCCCCCCCCCC(=O)OC\\C=C(/C)\\C=C\\C=C(/C)\\C=C\\C1=C(C)CCCC1(C)C',
#   '6970',
#   'C02588',
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003681': ('145.1564',
#   'C6H11NO3',
#   '4-Acetamidobutanoic acid',
#   'CC(=O)NCCCC(O)=O',
#   None,
#   'C02946',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003733': ('376.4865',
#   'C22H32O5',
#   'Resolvin D1',
#   'CC\\C=C/C[C@H](O)\\C=C\\C=C/C=C/C=C/C(O)[C@@H](O)C\\C=C/CCC(O)=O',
#   None,
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003759': ('316.4776',
#   'C21H32O2',
#   '5a-Pregnane-3,20-dione',
#   '[H][C@@]12CC[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC[C@@]2([H])CC(=O)CC[C@]12C',
#   '6981',
#   'C03681',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003771': ('116.1152',
#   'C5H8O3',
#   '2-Methylacetoacetic acid',
#   'CC(C(C)=O)C(O)=O',
#   None,
#   None,
#   'map00140',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003797': ('280.4455',
#   'C18H32O2',
#   'Bovinic acid',
#   'CCCCCC\\C=C\\C=C/CCCCCCCC(O)=O',
#   None,
#   'C04056',
#   'map00140',
#   'Fatty Acyls',
#   'Lineolic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003869': ('275.3015',
#   'C11H21N3O5',
#   'Epsilon-(gamma-Glutamyl)-lysine',
#   'N[C@@H](CCCCNC(=O)CC[C@H](N)C(O)=O)C(O)=O',
#   None,
#   None,
#   'map00140',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003871': ('312.4443',
#   'C18H32O4',
#   '13-L-Hydroperoxylinoleic acid',
#   'CCCCC[C@H](OO)\\C=C\\C=C/CCCCCCCC(O)=O',
#   None,
#   'C04717',
#   'map00140',
#   'Fatty Acyls',
#   'Lineolic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003876': ('320.4663',
#   'C20H32O3',
#   '15(S)-HETE',
#   'CCCCC[C@H](O)\\C=C\\C=C/C\\C=C/C\\C=C/CCCC(O)=O',
#   None,
#   'C04742',
#   None,
#   'Fatty Acyls',
#   'Eicosanoids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003911': ('103.1198',
#   'C4H9NO2',
#   '3-Aminoisobutanoic acid',
#   'CC(CN)C(O)=O',
#   '5472',
#   'C05145',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003933': ('378.4261',
#   'C17H26N6O4',
#   'Pentosidine',
#   'N[C@@H](CCCCN1C=CC=C2N=C(NCCC[C@H](N)C(O)=O)N=C12)C(O)=O',
#   None,
#   None,
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003955': ('302.4079',
#   'C19H26O3',
#   '19-Hydroxyandrost-4-ene-3,17-dione',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12CO',
#   '6990',
#   'C05290',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003966': ('196.11',
#   'C5H11NO2Se',
#   'Selenomethionine',
#   'C[Se]CCC(N)C(O)=O',
#   '6993',
#   'C05335',
#   'map00450',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  ...}

# %%
standards_dict
# Out:
# {233.12831: ('melatonin', 257.4, '+', 2046167614),
#  109.07607: ('phenylhydrazine', 288.0, '+', 8384383),
#  124.03938000000001: ('nicotinate', 437.4, '+', 593840852),
#  170.08116: ('pyridoxine', 445.79999999999995, '+', 3992986142),
#  377.14547999999996: ('riboflavin', 463.2, '+', 16465628),
#  136.06181: ('adenine', 525.0, '+', 1645830897),
#  114.0662: ('creatinine', 538.8000000000001, '+', 1662180782),
#  166.08629: ('l-phenylalanine', 549.0, '+', 489171784),
#  132.10193: ('l-leucine', 576.5999999999999, '+', 215023034),
#  269.08792: ('inosine', 588.0, '+', 167162672),
#  152.07071000000002: ('2-phenylglycine', 605.4, '+', 110631677),
#  192.00876: ('selenomethionine', 605.4, '+', 3561650),
#  150.05835: ('l-methionine', 610.8, '+', 350754691),
#  127.05018999999999: ('imidazole-4-acetate', 624.0, '+', 1886781792),
#  205.09721000000002: ('l-tryptophan', 620.4, '+', 134951099),
#  222.0972: ('n-acetyl-d-glucosamine', 620.4, '+', 73176907),
#  244.09276: ('cytidine', 631.8, '+', 173683264),
#  152.05671999999998: ('guanine', 665.4, '+', 85427744),
#  118.08622: ('l-valine', 650.4, '+', 242715581),
#  116.07056999999999: ('l-proline', 660.6, '+', 1163492927),
#  258.10995: ('sn-glycero-3-phosphocholine', 702.0, '+', 907884629),
#  120.06557: ('l-threonine', 727.1999999999999, '+', 49595838),
#  132.06555: ('5-aminolevulinate', 696.0, '+', 117468272),
#  189.12335: ('n2-acetyl-l-lysine', 727.1999999999999, '+', 743632812),
#  180.08665: ('d-glucosamine', 756.0, '+', 3291359),
#  147.07631: ('l-glutamine', 739.2, '+', 245430777),
#  126.022: ('taurine', 766.1999999999999, '+', 2883130),
#  134.04475: ('l-aspartate', 736.8, '+', 2399778),
#  133.06081: ('l-asparagine', 756.0, '+', 9522625),
#  90.05497: ('beta-alanine', 750.6, '+', 83562505),
#  76.03933: ('glycine', 768.6, '+', 1489947),
#  106.04991000000001: ('l-serine', 776.4, '+', 4503387),
#  142.02646000000001: ('ethanolamine phosphate', 748.2, '+', 1329108),
#  176.10299999999998: ('l-citrulline', 768.6, '+', 108998311),
#  191.10271: ('meso-2_6-diaminoheptanedioate', 834.0, '+', 587594),
#  147.11285: ('l-lysine', 1101.0, '+', 437556),
#  175.11902: ('l-arginine', 1195.8, '+', 18216551),
#  167.0386: ('thiopurine s-methylether', 359.40000000000003, '+', 904422285),
#  298.09668: ("5'-methylthioadenosine", 365.4, '+', 524356477),
#  123.05525: ('nicotinamide', 390.59999999999997, '+', 1740532795),
#  154.09732: ('4-(beta-acetylaminoethyl)imidazole', 408.0, '+', 3666183277),
#  168.06548999999998: ('pyridoxal', 456.6, '+', 889847527),
#  150.07736: ('6-methylaminopurine', 435.59999999999997, '+', 1950746313),
#  252.10895: ('deoxyadenosine', 445.2, '+', 1211290733),
#  220.11789: ('pantothenate', 492.6, '+', 838972108),
#  124.03936999999999: ('picolinic acid', 499.8, '+', 41585742),
#  127.05021: ('thymine', 419.40000000000003, '+', 11765736),
#  268.10385: ('adenosine', 491.4, '+', 422979860),
#  137.04584: ('hypoxanthine', 564.0, '+', 100595112),
#  130.04993000000002: ('5-oxoproline', 580.2, '+', 70105872),
#  239.10591000000002: ('hepes', 576.5999999999999, '+', 256803296),
#  209.09212: ('l-kynurenine', 580.2, '+', 84699030),
#  118.08618999999999: ('betaine', 599.4, '+', 4552981067),
#  112.05051999999999: ('cytosine', 613.2, '+', 685005504),
#  132.10191: ('l-isoleucine', 623.4000000000001, '+', 885111581),
#  136.04273999999998: ('methylcysteine', 631.1999999999999, '+', 73661632),
#  147.0764: ('ala-gly', 644.4, '+', 43935836),
#  284.09866: ('guanosine', 662.4, '+', 3856885),
#  332.07538: ('damp', 633.0, '+', 11568498),
#  170.09235: ('n(pi)-methyl-l-histidine', 655.8, '+', 461704354),
#  162.11258: ('l-carnitine', 672.6, '+', 921584521),
#  183.09396: ('eflornithine', 676.1999999999999, '+', 226209658),
#  182.08127: ('l-tyrosine', 679.8, '+', 39740700),
#  146.11763: ('4-trimethylammoniobutanoate', 666.0, '+', 7634059076),
#  385.12857: ('s-adenosyl-l-homocysteine', 659.4, '+', 11855257),
#  348.06973: ('amp', 672.6, '+', 891093),
#  133.06082: ('glycylglycine', 712.1999999999999, '+', 4813167),
#  90.05499: ('l-alanine', 737.4, '+', 19042955),
#  184.07335: ('choline phosphate', 706.8, '+', 435627129),
#  308.06421: ('dcmp', 709.2, '+', 426273),
#  162.07613: ('l-2-aminoadipate', 726.0, '+', 4607679),
#  120.06553999999998: ('l-homoserine', 742.8000000000001, '+', 134553196),
#  175.10776: ('n-acetylornithine', 737.4, '+', 247009406),
#  104.07056: ('4-aminobutanoate', 752.4, '+', 205910257),
#  223.07474: ('l-cystathionine', 795.6, '+', 139185),
#  104.10694000000001: ('choline', 1045.8, '+', 392195944),
#  76.0757: ('1-aminopropan-2-ol', 1125.0, '+', 24700144),
#  133.0972: ('l-ornithine', 1038.6, '+', 2655807),
#  516.29913: ('taurocholate', 253.8, '+', 2634703),
#  207.05098999999998: ('lipoate', 265.2, '+', 166523),
#  194.08123999999998: ('phenylacetylglycine', 347.4, '+', 521142752),
#  206.06682: ('lipoamide', 273.59999999999997, '+', 820195961),
#  102.05499: ('2-aminobutan-4-olide', 376.8, '+', 20617729),
#  124.03934: ('isonicotinic acid', 451.2, '+', 3439069645),
#  204.12311: ('o-acetylcarnitine', 576.5999999999999, '+', 4650224635),
#  148.06042: ('o-acetyl-l-serine', 703.2, '+', 47465680),
#  251.06956: ('gamma-l-glutamyl-l-cysteine', 711.0, '+', 9513001),
#  146.11746000000002: ('acetylcholine', 811.1999999999999, '+', 3062188675),
#  241.03099: ('l-cystine', 774.6, '+', 2760178),
#  269.06241: ('homocystine', 771.0, '+', 83272),
#  79.02121: ('mercaptoethanol', 385.79999999999995, '+', 2885531953),
#  179.05505: ('d-glucono-1_4-lactone', 478.2, '+', 2482380),
#  117.01827: ('maleic acid', 694.2, '+', 161216)}

# %% [markdown]
# ## Load peakinfo objects data

# %%
sys.path.append('..')
import peakinfo
with open(osp+'positive_mode/peakinfolist.dict', 'rb') as file:
    peakinfolist_positive = pickle.load(file)

# %%
for peak in peakinfolist_positive:
    peak.change_cid('p')
for peak in peakinfolist_positive:
    peak.add_adduct_list()
    peak.add_std_match(standards_dict, metabolites)

# %%
for peak in peakinfolist_positive:
    print(peak)
# Out:
# Peak 633: m/z = 148.07345756155544, rt = 11.915376878181446
#
#                 p-val: 2.36533127803315e-07, logFC = -11.182687216628802
#
#                 mm annotation: ['(r)-mevalonate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 613: m/z = 147.07640748274954, rt = 11.905213776127336
#
#                 p-val: 2.36533127803315e-07, logFC = -2.63034608332642
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation: l-glutamine
#
#                 hmdb annotation: L-Lysine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1218291f0>, 'gnps2': <mnet.Spectrum object at 0x1218298b0>}
#
# Peak 3109: m/z = 905.5937710121028, rt = 2.9989393770564763
#
#                 p-val: 2.36533127803315e-07, logFC = -10.211343208638901
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3028: m/z = 837.618204752604, rt = 3.1507679296929143
#
#                 p-val: 2.70414980254621e-07, logFC = -12.542239855974099
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2989: m/z = 810.6000113236278, rt = 3.1712747307827622
#
#                 p-val: 2.76791180335004e-07, logFC = -1.7812251168870903
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12183abe0>, 'gnps2': <mnet.Spectrum object at 0x12183a6d0>}
#
# Peak 2936: m/z = 782.5687384354442, rt = 3.204236220992103
#
#                 p-val: 3.0085549137798603e-07, logFC = -1.79450144331877
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1218326d0>, 'gnps2': <mnet.Spectrum object at 0x121832dc0>}
#
# Peak 324: m/z = 126.0219806871916, rt = 12.209535511372454
#
#                 p-val: 3.0085549137798603e-07, logFC = -1.04710511580883
#
#                 mm annotation: ['taurine']
#
#                 std annotation: taurine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12182e0d0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12182ed00>}
#
# Peak 2938: m/z = 784.5840506302683, rt = 3.1956754108132674
#
#                 p-val: 4.5992847415129796e-07, logFC = -1.4497776489092902
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 425: m/z = 133.06077505412858, rt = 10.333907314956184
#
#                 p-val: 4.7551680724052403e-07, logFC = 1.75011143914939
#
#                 mm annotation: ['n-carbamoyl-beta-alanine$l-asparagine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2992: m/z = 812.6144790649414, rt = 3.1738542476404548
#
#                 p-val: 4.7551680724052403e-07, logFC = -1.64557792833309
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2939: m/z = 785.5879516601562, rt = 3.2024338052303265
#
#                 p-val: 4.7551680724052403e-07, logFC = -1.5088271608142
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 926: m/z = 169.05836848208781, rt = 11.897038272605002
#
#                 p-val: 4.7551680724052403e-07, logFC = -2.1962780494017102
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 951: m/z = 171.0764231430857, rt = 11.892799220401725
#
#                 p-val: 4.7551680724052403e-07, logFC = -1.01155938493891
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3026: m/z = 835.6033615604524, rt = 3.1581256673739664
#
#                 p-val: 4.7551680724052403e-07, logFC = -10.698209641023999
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 101: m/z = 101.07095439850336, rt = 11.929978879334824
#
#                 p-val: 6.53074216211131e-07, logFC = -10.0563554026259
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1236: m/z = 191.040284656343, rt = 11.911427014102307
#
#                 p-val: 7.89897469259601e-07, logFC = -9.938461505396711
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 397: m/z = 131.05327114306002, rt = 11.88734120795674
#
#                 p-val: 7.89897469259601e-07, logFC = -1.09706950943779
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 168: m/z = 112.05056200027464, rt = 9.76502164353295
#
#                 p-val: 7.99477046240436e-07, logFC = 12.962342802325802
#
#                 mm annotation: ['cytosine (in dna)$cytosine']
#
#                 std annotation: cytosine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 626: m/z = 148.04266542004, rt = 6.714252903696112
#
#                 p-val: 7.99477046240436e-07, logFC = -9.32533296988524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12184a9d0>}
#
# Peak 365: m/z = 130.04992655703896, rt = 11.890277826892214
#
#                 p-val: 1.05024419938963e-06, logFC = -1.06619681316973
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', '5-oxo-l-proline']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12187caf0>}
#
# Peak 940: m/z = 170.06167554098462, rt = 11.90249255506668
#
#                 p-val: 1.92835842935321e-06, logFC = -9.27771118975633
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3027: m/z = 836.6139644499748, rt = 3.1561264739296693
#
#                 p-val: 2.9505073492907003e-06, logFC = -10.0650161116301
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 893: m/z = 166.05330748307077, rt = 10.840145684201556
#
#                 p-val: 4.41604350281446e-06, logFC = 1.76020601831562
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 659: m/z = 149.08066248893738, rt = 11.907904572957134
#
#                 p-val: 4.54967390080049e-06, logFC = -9.146391237297369
#
#                 mm annotation: ['(r)-mevalonate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2720: m/z = 520.3400409096166, rt = 3.764698097898109
#
#                 p-val: 4.8883574651252896e-06, logFC = -1.8785086352406397
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1218b1130>, 'gnps2': <mnet.Spectrum object at 0x1218b1eb0>}
#
# Peak 2958: m/z = 792.5890053196957, rt = 3.17424326168862
#
#                 p-val: 6.0055864528364e-06, logFC = -10.9429380908455
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12190c6d0>}
#
# Peak 3025: m/z = 834.6000561714172, rt = 3.156962816942129
#
#                 p-val: 6.0055864528364e-06, logFC = -9.80446366154065
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1218eb040>}
#
# Peak 2695: m/z = 495.3275594559927, rt = 3.861196866296261
#
#                 p-val: 6.63827017559769e-06, logFC = -9.524063986363391
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1031: m/z = 176.03766284072609, rt = 6.714380459353793
#
#                 p-val: 9.08455353881614e-06, logFC = -9.89260363338719
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1993: m/z = 258.1100018149928, rt = 11.350615870550547
#
#                 p-val: 1.06997623618205e-05, logFC = -1.2072506071780602
#
#                 mm annotation:
#
#                 std annotation: sn-glycero-3-phosphocholine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1218ee130>, 'gnps2': <mnet.Spectrum object at 0x1218eed00>}
#
# Peak 2549: m/z = 380.2558107376098, rt = 6.713701956844809
#
#                 p-val: 1.06997623618205e-05, logFC = -7.99576744906867
#
#                 mm annotation: ['sphingosine 1-phosphate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1034: m/z = 176.07406287357722, rt = 4.276906994865536
#
#                 p-val: 1.14131811925047e-05, logFC = -9.51488039529544
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2944: m/z = 787.6035939266808, rt = 3.1828694994031235
#
#                 p-val: 1.34489968283814e-05, logFC = -0.811695795830687
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2942: m/z = 786.6000470613177, rt = 3.1871777436438435
#
#                 p-val: 1.63031950773526e-05, logFC = -0.810224881721162
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121910280>, 'gnps2': <mnet.Spectrum object at 0x121910160>}
#
# Peak 2876: m/z = 743.5770635431462, rt = 3.2019822291768096
#
#                 p-val: 1.8096029988737e-05, logFC = -10.499363695357
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1517: m/z = 213.0222165089733, rt = 11.904522592934331
#
#                 p-val: 1.90609500963983e-05, logFC = -9.77013845614376
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2548: m/z = 380.25582956167364, rt = 4.248077275139069
#
#                 p-val: 2.1192977896602104e-05, logFC = -7.566345467740621
#
#                 mm annotation: ['sphingosine 1-phosphate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1449: m/z = 206.1273452258501, rt = 9.281201471607208
#
#                 p-val: 2.55917309234202e-05, logFC = -8.73395464702139
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2913: m/z = 767.5771116059402, rt = 3.1909653266929685
#
#                 p-val: 2.5967268139142604e-05, logFC = -10.188379344532802
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2963: m/z = 796.6194324493408, rt = 3.1777290687711117
#
#                 p-val: 2.8346473639426195e-05, logFC = -8.57228796923272
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 952: m/z = 171.07645948309647, rt = 9.235934544397882
#
#                 p-val: 3.5018622602417e-05, logFC = -0.714991555271641
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: N6-Acetyl-L-lysine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1219076d0>}
#
# Peak 2982: m/z = 807.5720968535452, rt = 3.1823487249259754
#
#                 p-val: 3.6798146556911296e-05, logFC = -8.81094068253091
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2987: m/z = 809.5875447591147, rt = 3.1851688642355116
#
#                 p-val: 3.9496079216554705e-05, logFC = -8.59564301986815
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2912: m/z = 766.5738016764321, rt = 3.1928454645942037
#
#                 p-val: 4.5480560425578494e-05, logFC = -8.26699527159509
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2898: m/z = 759.5722881116367, rt = 3.215870431703981
#
#                 p-val: 4.8475851444684295e-05, logFC = -0.860037548566861
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2921: m/z = 770.6031951904297, rt = 3.1982725889677845
#
#                 p-val: 4.9763544446885604e-05, logFC = -9.04872368899591
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 4343: m/z = 512.334872713956, rt = 4.200786223475737
#
#                 p-val: 5.5257637520246104e-05, logFC = -9.75694823122524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121928490>}
#
# Peak 2725: m/z = 523.3591457166169, rt = 3.73649391466906
#
#                 p-val: 5.87393970920915e-05, logFC = -1.06070944941986
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2724: m/z = 522.3558831465872, rt = 3.736986901958506
#
#                 p-val: 5.87393970920915e-05, logFC = -1.04259944784816
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12195a5b0>}
#
# Peak 2666: m/z = 469.3119622055365, rt = 3.974227894946392
#
#                 p-val: 6.4592566742871e-05, logFC = -10.4571264726801
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2897: m/z = 758.5688291850843, rt = 3.2135804173217304
#
#                 p-val: 6.6401718832451e-05, logFC = -0.8480436843108728
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1219874c0>}
#
# Peak 1839: m/z = 241.03100315217048, rt = 12.597870757674437
#
#                 p-val: 0.000128588292728543, logFC = -7.814946930091041
#
#                 mm annotation: ['l-cystine; l-dicysteine; l-alpha-diamino-beta-dithiolactic acid']
#
#                 std annotation: l-cystine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1219b0160>, 'gnps2': <mnet.Spectrum object at 0x1219b0b50>}
#
# Peak 1238: m/z = 191.08493292331696, rt = 9.80184624307863
#
#                 p-val: 0.00013606969283101798, logFC = -7.7314922084382305
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2895: m/z = 757.5567353347252, rt = 3.222214152778468
#
#                 p-val: 0.00013606969283101798, logFC = -8.836315173894391
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 459: m/z = 136.0427669178356, rt = 10.099289180795346
#
#                 p-val: 0.00013606969283101798, logFC = -7.274170874511159
#
#                 mm annotation: ['l-homocysteine']
#
#                 std annotation: methylcysteine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1219415e0>}
#
# Peak 1299: m/z = 194.1468843732561, rt = 4.1319048248802615
#
#                 p-val: 0.00013606969283101798, logFC = -7.987008453444231
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2230: m/z = 287.2215092307643, rt = 3.3367347899412936
#
#                 p-val: 0.00014126727281628702, logFC = -0.586381569788568
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12197bb80>}
#
# Peak 2960: m/z = 794.6050793092642, rt = 3.173322675393975
#
#                 p-val: 0.00014126727281628702, logFC = -7.7205801295514505
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121966d00>}
#
# Peak 3022: m/z = 832.5839935878537, rt = 3.1621105008565693
#
#                 p-val: 0.00015576660907671203, logFC = -9.43086179995322
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 970: m/z = 172.0968251479299, rt = 6.7103843760710635
#
#                 p-val: 0.000173383899093696, logFC = 0.573492283316948
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 366: m/z = 130.04995717500387, rt = 9.235738236152981
#
#                 p-val: 0.000173383899093696, logFC = -0.649141706140043
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate$5-oxo-l-proline', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde']
#
#                 std annotation: 5-oxoproline
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1219a7b80>, 'frag_pos_vl': <mnet.Spectrum object at 0x1219a46d0>}
#
# Peak 2664: m/z = 468.30843577665433, rt = 3.9705792974931056
#
#                 p-val: 0.00021192593325321298, logFC = -7.16605473174531
#
#                 mm annotation: ['timnodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1219b8d90>, 'frag_pos_vl': <mnet.Spectrum object at 0x1219b8490>, 'gnps2': <mnet.Spectrum object at 0x1219b8760>}
#
# Peak 2763: m/z = 568.3397577459162, rt = 3.6748810702065318
#
#                 p-val: 0.000231571778535832, logFC = -7.68958109514351
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121997e50>}
#
# Peak 835: m/z = 161.0923203901811, rt = 6.7305915190221075
#
#                 p-val: 0.000327055432858532, logFC = -6.9326302438739695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 410: m/z = 132.05415382385254, rt = 11.897504272757521
#
#                 p-val: 0.000327055432858532, logFC = -7.65710068300612
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2678: m/z = 482.3242121244732, rt = 3.85737394875471
#
#                 p-val: 0.000416134599517341, logFC = -0.8749238353790891
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121962760>}
#
# Peak 2600: m/z = 400.34202806877363, rt = 3.7688438162451448
#
#                 p-val: 0.00044618949259690597, logFC = -7.29695106527337
#
#                 mm annotation: ['l-palmitoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2696: m/z = 496.33967911569704, rt = 3.8194716747786335
#
#                 p-val: 0.0004661011700295, logFC = -0.83225318745524
#
#                 mm annotation: ['docosa-4,7,10,13,16-pentaenoyl carnitine$clupanodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1218b95e0>}
#
# Peak 3577: m/z = 168.1019774350253, rt = 6.7144123909849425
#
#                 p-val: 0.000481732044298059, logFC = -8.996025354335519
#
#                 mm annotation: ['3-methoxytyramine$epinine; deoxyepinephrine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2701: m/z = 498.34583282470703, rt = 3.813956823367649
#
#                 p-val: 0.000502872711474008, logFC = -0.8320918333858921
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2997: m/z = 814.6262374014224, rt = 3.1529000260658964
#
#                 p-val: 0.000502872711474008, logFC = -8.905429303000039
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1216abb80>}
#
# Peak 2698: m/z = 497.3431362352873, rt = 3.822709234947065
#
#                 p-val: 0.000504686945799091, logFC = -0.8212467821292401
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2711: m/z = 510.3556785583496, rt = 3.7555667299139857
#
#                 p-val: 0.000504686945799091, logFC = -0.8362220656501441
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12154e9a0>}
#
# Peak 2918: m/z = 769.5926121303012, rt = 3.1880956485680785
#
#                 p-val: 0.000504686945799091, logFC = -7.951626308988299
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1526: m/z = 213.12338502945443, rt = 6.713599596972838
#
#                 p-val: 0.000734802030371738, logFC = -6.25827129846341
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3108: m/z = 904.5903413192084, rt = 2.9967184966263014
#
#                 p-val: 0.0007681549423716519, logFC = -5.78517187742563
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1210e4d00>}
#
# Peak 2894: m/z = 756.5531342450312, rt = 3.2379690459708006
#
#                 p-val: 0.000779364128494012, logFC = -6.52583070072173
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2969: m/z = 799.6681079864502, rt = 3.29227476759155
#
#                 p-val: 0.000784853659301993, logFC = -7.448786730111589
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2151: m/z = 279.15896526135896, rt = 3.3596950838369133
#
#                 p-val: 0.000924210709573541, logFC = -0.6153697696145001
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Progesterone
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1211a4f40>, 'gnps2': <mnet.Spectrum object at 0x1211a4a60>}
#
# Peak 785: m/z = 158.15401699668482, rt = 3.614794642976292
#
#                 p-val: 0.0009331187467670099, logFC = 0.7371260370925758
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1212e9b50>}
#
# Peak 2743: m/z = 542.3226473533501, rt = 3.78322037280904
#
#                 p-val: 0.0009331187467670099, logFC = -8.6075950227748
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12127a0d0>}
#
# Peak 1463: m/z = 209.09213899311263, rt = 9.323316198803509
#
#                 p-val: 0.0009553937728149891, logFC = 0.588843857846385
#
#                 mm annotation: ['porphobilinogen', 'l-kynurenine$formyl-5-hydroxykynurenamine']
#
#                 std annotation: l-kynurenine
#
#                 hmdb annotation: L-Kynurenine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121255760>}
#
# Peak 667: m/z = 150.05838434319747, rt = 9.801560467510669
#
#                 p-val: 0.000980043526528498, logFC = -1.65735553998747
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation: l-methionine
#
#                 hmdb annotation: L-Methionine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1215fa9a0>, 'gnps2': <mnet.Spectrum object at 0x1215fa8b0>}
#
# Peak 2949: m/z = 788.6120846396997, rt = 3.1883200045755458
#
#                 p-val: 0.0010055749133208302, logFC = -0.5409474076376629
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2881: m/z = 745.5926278921273, rt = 3.1969129754988503
#
#                 p-val: 0.0010641619604790599, logFC = -8.54809981046208
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2966: m/z = 797.6236220537606, rt = 3.1602520058825827
#
#                 p-val: 0.00107311786489198, logFC = -7.50616733415771
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 634: m/z = 148.07970658393756, rt = 11.903578089878053
#
#                 p-val: 0.00110447355700778, logFC = -4.68884618786971
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 109: m/z = 102.05497522065134, rt = 9.799513957381537
#
#                 p-val: 0.00116303089013512, logFC = -5.730288516100289
#
#                 mm annotation: ['d-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2980: m/z = 806.5687849017937, rt = 3.1798349846770173
#
#                 p-val: 0.00119037984810586, logFC = -5.78029597655704
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1217b65e0>}
#
# Peak 1580: m/z = 217.10714016538682, rt = 3.7185520069170006
#
#                 p-val: 0.0012569444077158301, logFC = -6.853070474624991
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2745: m/z = 545.3430971891984, rt = 3.7169377354093087
#
#                 p-val: 0.0013056771892329699, logFC = -6.1104320110392
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2837: m/z = 689.5586529632112, rt = 3.445898404061168
#
#                 p-val: 0.0013630418798614, logFC = -5.84589767678799
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 614: m/z = 147.07638807857737, rt = 6.878839972532079
#
#                 p-val: 0.00140982085940211, logFC = -5.339399840333269
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1218901c0>}
#
# Peak 1100: m/z = 181.0720427293044, rt = 6.703730118801477
#
#                 p-val: 0.00201548301741714, logFC = -6.5173316425727705
#
#                 mm annotation: ['1,7-dimethylxanthine; paraxanthine$']
#
#                 std annotation:
#
#                 hmdb annotation: Hippuric acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1218d20a0>, 'frag_pos_vl': <mnet.Spectrum object at 0x1218d2d00>, 'gnps2': <mnet.Spectrum object at 0x1218d2dc0>}
#
# Peak 690: m/z = 152.05416253033806, rt = 9.800490879735172
#
#                 p-val: 0.0020573558555547103, logFC = -6.12941923451816
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 121: m/z = 104.05283815720502, rt = 9.801547535280642
#
#                 p-val: 0.0020573558555547103, logFC = -6.016609444999091
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2961: m/z = 795.6087868430398, rt = 3.1704207339950474
#
#                 p-val: 0.0020573558555547103, logFC = -6.688622284367441
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 38: m/z = 84.0442725231773, rt = 11.882381163503108
#
#                 p-val: 0.0020863615968792, logFC = -0.462357094192591
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12198fe50>}
#
# Peak 2995: m/z = 813.620170710637, rt = 3.167355073023148
#
#                 p-val: 0.0020863615968792, logFC = -7.08358005679473
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121297af0>}
#
# Peak 2235: m/z = 288.21679216272685, rt = 6.710575387813409
#
#                 p-val: 0.0020863615968792, logFC = -5.3375279109251395
#
#                 mm annotation: ['l-octanoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1214479a0>}
#
# Peak 2875: m/z = 742.5739977155413, rt = 3.210162847197511
#
#                 p-val: 0.00219347469240114, logFC = -5.31308950842934
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2832: m/z = 676.546512075571, rt = 3.4645076315949384
#
#                 p-val: 0.00219347469240114, logFC = -6.4463203853301705
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2923: m/z = 772.5841475777004, rt = 3.2090239941698546
#
#                 p-val: 0.00219661741643397, logFC = -5.6112715565427695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12153dca0>}
#
# Peak 2998: m/z = 814.6869326139753, rt = 3.2671478973107004
#
#                 p-val: 0.00229219117816704, logFC = -0.404490596399754
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 264: m/z = 120.0808048248291, rt = 8.854499598965873
#
#                 p-val: 0.00242465814194477, logFC = 0.43672795603462705
#
#                 mm annotation: ['l-phenylalanine$', 'tyramine$n,n-dimethylaniline n-oxide$phenylethanolamine; 2-amino-1-phenylethanol']
#
#                 std annotation:
#
#                 hmdb annotation: L-Phenylalanine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12167e790>, 'gnps2': <mnet.Spectrum object at 0x12167e040>}
#
# Peak 2800: m/z = 615.5388493691721, rt = 2.9921706546524263
#
#                 p-val: 0.00253277058482182, logFC = -6.762732664023289
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2320: m/z = 304.21173236553483, rt = 6.7225817387372375
#
#                 p-val: 0.002610983871737, logFC = -5.96396391236004
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1450: m/z = 207.11288060640038, rt = 8.850467543611357
#
#                 p-val: 0.0026777963876329, logFC = 0.41647283631293797
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2925: m/z = 773.5876270162648, rt = 3.2031847475751585
#
#                 p-val: 0.0030183034157522802, logFC = -7.347379735301059
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2934: m/z = 781.5560995434957, rt = 3.2225692162120723
#
#                 p-val: 0.00308672102038959, logFC = -7.0724599902029
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2693: m/z = 494.32407618931364, rt = 3.8649246277064218
#
#                 p-val: 0.00331696027804435, logFC = -5.459129030377059
#
#                 mm annotation: ['cervonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1216af820>}
#
# Peak 906: m/z = 167.08961125424034, rt = 8.857153671083873
#
#                 p-val: 0.00331696027804435, logFC = 0.444213460023956
#
#                 mm annotation: ['l-phenylalanine$']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 535: m/z = 142.12273035551368, rt = 3.803460912354821
#
#                 p-val: 0.00337096914190805, logFC = 0.613266831209529
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1219acc70>}
#
# Peak 2985: m/z = 808.58344708067, rt = 3.1691686547228097
#
#                 p-val: 0.0035682048531857705, logFC = -6.45748125058159
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 423: m/z = 133.03179997983187, rt = 9.801642939217606
#
#                 p-val: 0.0035682048531857705, logFC = -5.82276475936575
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1441: m/z = 205.1264040205214, rt = 9.29280034267381
#
#                 p-val: 0.00388625073504543, logFC = -4.62308434517701
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 253: m/z = 119.01619202750071, rt = 10.097554040691968
#
#                 p-val: 0.00388625073504543, logFC = -4.91710300958007
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1219cca60>}
#
# Peak 1078: m/z = 179.127837532445, rt = 4.375178398752974
#
#                 p-val: 0.00388625073504543, logFC = -0.461903565293252
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2384: m/z = 316.24817137787306, rt = 4.315124863489827
#
#                 p-val: 0.00474323372943019, logFC = -5.15303235001915
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Dodecanoylcarnitine
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1219d9c10>}
#
# Peak 3317: m/z = 130.065154281317, rt = 6.726810434132585
#
#                 p-val: 0.00474323372943019, logFC = -6.76452846483441
#
#                 mm annotation: ['l-phenylalanine$']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2315: m/z = 302.23251875620036, rt = 4.370994817087583
#
#                 p-val: 0.0048538347667039, logFC = -5.68865814410717
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 677: m/z = 151.0579272576098, rt = 9.807276094071767
#
#                 p-val: 0.00529882602040456, logFC = -7.504486277174769
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 676: m/z = 151.04779716159987, rt = 11.872232773025232
#
#                 p-val: 0.00531791568590832, logFC = -4.643943261505339
#
#                 mm annotation: ['5,6-dihydrothymine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2842: m/z = 701.5587664152448, rt = 3.4205349542944568
#
#                 p-val: 0.00565846926928893, logFC = -0.38648752681206106
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1219eec10>}
#
# Peak 4735: m/z = 154.07240237611714, rt = 9.03697799012916
#
#                 p-val: 0.00580197772289792, logFC = -5.53090651942889
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 885: m/z = 165.11223471792118, rt = 4.267475591169922
#
#                 p-val: 0.0060696590348587294, logFC = -0.4773147500611579
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1002: m/z = 174.08740496279592, rt = 11.517982648461464
#
#                 p-val: 0.00628093273391419, logFC = -4.99007224281755
#
#                 mm annotation: ['5-guanidino-2-oxopentanoate; 5-guanidino-2-oxo-pentanoate; 2-oxo-5-guanidinopentanoate; 2-oxo-5-guanidino-pentanoate', 'l-histidine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2990: m/z = 811.60400390625, rt = 3.1664475966712713
#
#                 p-val: 0.00644274737442449, logFC = -2.5095173494596
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1401: m/z = 203.05238235473632, rt = 12.05103861917583
#
#                 p-val: 0.0065110815543302294, logFC = 7.995276342107531
#
#                 mm annotation: ['d-glucose$beta-d-glucose$l-sorbose; l-xylo-hexulose$beta-d-fructose; beta-fruit sugar; beta-d-arabino-hexulose; beta-levulose; fructose$alpha-d-glucose$d-hexose$$d-fructose$beta-d-galactose$galactose$d-tagatose; lyxo-hexulose$myo-inositol$glucose$d-galactose$alpha-d-galactose$d-mannose']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121a02400>, 'frag_pos_vl': <mnet.Spectrum object at 0x121a02040>}
#
# Peak 3867: m/z = 219.14204296167347, rt = 8.414122199886636
#
#                 p-val: 0.00654899906730296, logFC = -4.88663221704702
#
#                 mm annotation: ['propionyl-carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121a0aa60>}
#
# Peak 298: m/z = 123.05528043445787, rt = 6.715846041707633
#
#                 p-val: 0.00657358184959701, logFC = -0.5728940387899039
#
#                 mm annotation: ['nicotinamide', '3-methylimidazoleacetic acid']
#
#                 std annotation: nicotinamide
#
#                 hmdb annotation: Niacinamide
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121a0f1c0>, 'gnps2': <mnet.Spectrum object at 0x121a0f820>}
#
# Peak 2877: m/z = 744.5532271067302, rt = 3.195004986122018
#
#                 p-val: 0.007142497002528691, logFC = -7.23844389322983
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2192: m/z = 283.1034067327326, rt = 7.638936587781288
#
#                 p-val: 0.00753680148237805, logFC = -5.07796578442612
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1229: m/z = 190.08622629502239, rt = 6.717570800151284
#
#                 p-val: 0.0076324456121604, logFC = -4.750123753699389
#
#                 mm annotation: ['methyl indole-3-acetate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121a1f250>, 'gnps2': <mnet.Spectrum object at 0x121a1f0d0>}
#
# Peak 3083: m/z = 880.5899320660216, rt = 3.0012072328324013
#
#                 p-val: 0.007911679009956079, logFC = -5.384293528964401
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2234: m/z = 288.2168204171317, rt = 4.384022985095052
#
#                 p-val: 0.00805111504154785, logFC = -4.42697382769785
#
#                 mm annotation: ['l-octanoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121a27f40>, 'gnps2': <mnet.Spectrum object at 0x121a27b80>}
#
# Peak 1591: m/z = 218.13872538114845, rt = 8.41637103850833
#
#                 p-val: 0.00838902715496165, logFC = -0.7169359895918391
#
#                 mm annotation: ['propionyl-carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121a2bd90>}
#
# Peak 2937: m/z = 783.5721797688803, rt = 3.2044670684797745
#
#                 p-val: 0.00878772999923806, logFC = -2.48144665572742
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2999: m/z = 815.6969108012186, rt = 3.3167827055011414
#
#                 p-val: 0.008797248780225609, logFC = -5.826060016924191
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 330: m/z = 127.08659606144346, rt = 6.717903104634009
#
#                 p-val: 0.0088994065501646, logFC = -5.06312431998468
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1724: m/z = 230.09579192614947, rt = 11.951036929785865
#
#                 p-val: 0.00922330571123698, logFC = -5.84348422635007
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 678: m/z = 151.06173039825867, rt = 9.799460908142995
#
#                 p-val: 0.00935107678833482, logFC = -4.4428986783918
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 862: m/z = 163.13287734985354, rt = 3.7994672006916432
#
#                 p-val: 0.009365600106272921, logFC = 0.5512954871296071
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121a48880>}
#
# Peak 1089: m/z = 180.15944360431868, rt = 3.7993752859691465
#
#                 p-val: 0.009521966184408221, logFC = 0.560347284001462
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121a4cc10>, 'gnps2': <mnet.Spectrum object at 0x121a4c760>}
#
# Peak 2703: m/z = 499.34838518415177, rt = 3.821352176761092
#
#                 p-val: 0.0102199718483427, logFC = -4.714446344658639
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2620: m/z = 424.34192075567734, rt = 3.7025443473800332
#
#                 p-val: 0.0103239821794437, logFC = -6.879584330156031
#
#                 mm annotation: ['linoelaidyl carnitine$linoleyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 878: m/z = 164.136320013749, rt = 3.800138472932415
#
#                 p-val: 0.0104778459354165, logFC = 0.571903381258856
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1122: m/z = 183.11287488435443, rt = 6.716411567771383
#
#                 p-val: 0.0116430018731403, logFC = 5.25903461498913
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2158: m/z = 280.09168243408203, rt = 11.380053096860028
#
#                 p-val: 0.012466553451009, logFC = -4.17350124433524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1829: m/z = 239.16410007116932, rt = 3.5122459269786073
#
#                 p-val: 0.012466553451009, logFC = 6.52208127260134
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2915: m/z = 768.5890444402826, rt = 3.1956967501615114
#
#                 p-val: 0.012466553451009, logFC = -3.5029282947256406
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1217eba30>}
#
# Peak 2943: m/z = 786.6569239298503, rt = 3.3011916889778767
#
#                 p-val: 0.0125377250193032, logFC = -6.59164788856987
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 726: m/z = 155.106687515501, rt = 4.195650174830067
#
#                 p-val: 0.0125436166164404, logFC = -5.7001288137702595
#
#                 mm annotation: ['nan', 'nan']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12181de50>}
#
# Peak 2114: m/z = 275.1033547384697, rt = 11.891297595769975
#
#                 p-val: 0.0127220534298435, logFC = 6.96632405455268
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1217f0910>}
#
# Peak 259: m/z = 120.06554317474364, rt = 9.577770676367102
#
#                 p-val: 0.013805337578808002, logFC = 0.535536762546421
#
#                 mm annotation: ['d-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation: ('adenine', 'M-H2O+H[1+]')
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 6915: m/z = 234.13358319600425, rt = 3.7269341891864696
#
#                 p-val: 0.0139906476651965, logFC = -6.14127352361042
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1754: m/z = 232.1543136395906, rt = 7.606980700398988
#
# ...
#
# Peak 2796: m/z = 612.5196630859375, rt = 2.9911716878237957
#
#                 p-val: 0.8826157582540829, logFC = -0.165336457852955
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121b91be0>}
#
# Peak 448: m/z = 134.0833956631747, rt = 11.693696195774493
#
#                 p-val: 0.886259205945672, logFC = -0.456827173466316
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1191: m/z = 188.09179316068952, rt = 6.711392215119629
#
#                 p-val: 0.886259205945672, logFC = 0.0234341285808348
#
#                 mm annotation: ['6-acetamido-2-oxohexanoate; 2-oxo-6-acetamidocaproate', 'norepinephrine$pyridoxine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 402: m/z = 131.08965702380164, rt = 9.512981113606862
#
#                 p-val: 0.886259205945672, logFC = 0.5508910993436371
#
#                 mm annotation: ['n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121b9d5b0>}
#
# Peak 2654: m/z = 454.29274400983536, rt = 3.8159728910583217
#
#                 p-val: 0.8874989605699749, logFC = 0.339750603413943
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 352: m/z = 129.10223881648136, rt = 10.14010518333536
#
#                 p-val: 0.8953647583207219, logFC = 0.3648836210393929
#
#                 mm annotation: ['l-lysine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121baa9a0>}
#
# Peak 1832: m/z = 240.1422054893092, rt = 6.703257039831552
#
#                 p-val: 0.8953647583207219, logFC = -0.0170690938672458
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 107: m/z = 102.05497400084538, rt = 11.59886927335523
#
#                 p-val: 0.902503466928448, logFC = -0.312855419792593
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 480: m/z = 137.04583913167318, rt = 9.042706687232048
#
#                 p-val: 0.902503466928448, logFC = 0.19371489166566
#
#                 mm annotation: ['hypoxanthine']
#
#                 std annotation: hypoxanthine
#
#                 hmdb annotation: Hypoxanthine
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121bb6940>}
#
# Peak 1898: m/z = 246.24264697024697, rt = 6.663635200020018
#
#                 p-val: 0.902503466928448, logFC = -0.011066145006203999
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 267: m/z = 120.0905162911666, rt = 10.404289303482257
#
#                 p-val: 0.902503466928448, logFC = -0.018763401044648
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1394: m/z = 202.14386417554766, rt = 6.7111876242452855
#
#                 p-val: 0.902503466928448, logFC = -0.21192572134454898
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 241: m/z = 118.0862263629311, rt = 10.406100857570118
#
#                 p-val: 0.902503466928448, logFC = -0.0178921842297015
#
#                 mm annotation: ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine']
#
#                 std annotation: betaine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 6: m/z = 72.08080402173493, rt = 10.404729128701526
#
#                 p-val: 0.904998291768816, logFC = -0.0180060231432506
#
#                 mm annotation: ['glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121bcfac0>, 'frag_pos_vl': <mnet.Spectrum object at 0x121bcfdc0>}
#
# Peak 2697: m/z = 496.3396652430704, rt = 6.678386501453447
#
#                 p-val: 0.9058423232566659, logFC = 0.22795007222816502
#
#                 mm annotation: ['docosa-4,7,10,13,16-pentaenoyl carnitine$clupanodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 748: m/z = 156.13839948177338, rt = 4.388823158162995
#
#                 p-val: 0.9078237083704621, logFC = -0.323015062012058
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1982: m/z = 257.11304651547783, rt = 8.046585805480474
#
#                 p-val: 0.911229124195237, logFC = 0.14789396409563002
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 35: m/z = 82.94497322549627, rt = 4.719298169027288
#
#                 p-val: 0.911229124195237, logFC = -0.425975792750767
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121bdf6d0>}
#
# Peak 929: m/z = 169.0859831689109, rt = 6.707108772998255
#
#                 p-val: 0.911229124195237, logFC = 0.167451685298969
#
#                 mm annotation: ['n-trimethyl-2-aminoethylphosphonate; 2-trimethylaminoethylphosphonate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 192: m/z = 115.0695485064858, rt = 8.601991402136887
#
#                 p-val: 0.911229124195237, logFC = 0.0201309087432797
#
#                 mm annotation: ['nan']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1360: m/z = 199.18053660074867, rt = 3.613996589181411
#
#                 p-val: 0.9191842373140471, logFC = 0.0985019544622148
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121beb910>}
#
# Peak 2951: m/z = 788.6709195650542, rt = 3.3210114504885047
#
#                 p-val: 0.9242826992226609, logFC = 0.38388303016867
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2472: m/z = 343.1896204168146, rt = 9.292335726703062
#
#                 p-val: 0.9271756782136691, logFC = -0.326072572055448
#
#                 mm annotation: ["cortisone; 17alpha,21-dihydroxy-4-pregnene-3,11,20-trione; kendall's compound e; reichstein's substance fa$aldosterone; 11beta,21-dihydroxy-3,20-dioxo-4-pregnen-18-al"]
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 374: m/z = 130.08630989693307, rt = 6.714664681169856
#
#                 p-val: 0.9287664352605779, logFC = -0.125085878785598
#
#                 mm annotation: ['n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1822: m/z = 239.13897132873532, rt = 4.38045851106912
#
#                 p-val: 0.9308777841008241, logFC = -0.0142660461151394
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121bfcca0>, 'frag_pos_vl': <mnet.Spectrum object at 0x121bfce50>}
#
# Peak 3438: m/z = 147.12094518300648, rt = 10.732846025554746
#
#                 p-val: 0.934622676283128, logFC = 0.10922221649578
#
#                 mm annotation: ['3-dehydroxycarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121c047f0>}
#
# Peak 3349: m/z = 134.10863405863444, rt = 9.300184216818623
#
#                 p-val: 0.934622676283128, logFC = -0.22201821042000502
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 327: m/z = 127.07272237889907, rt = 9.996741524796928
#
#                 p-val: 0.934622676283128, logFC = -0.188927757197327
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 759: m/z = 157.0860331608699, rt = 4.401590453178399
#
#                 p-val: 0.934622676283128, logFC = -0.190903733394633
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2864: m/z = 732.6082223745492, rt = 3.341070460316012
#
#                 p-val: 0.934622676283128, logFC = -0.291068218847474
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 236: m/z = 118.06511846081965, rt = 9.960984627765214
#
#                 p-val: 0.934622676283128, logFC = 0.197539586486876
#
#                 mm annotation: ['2-phenylacetamide']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 805: m/z = 159.11286996540267, rt = 10.40698936936049
#
#                 p-val: 0.9352302452836129, logFC = -0.0102167342489565
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121c1ceb0>, 'gnps2': <mnet.Spectrum object at 0x121c1c160>}
#
# Peak 2319: m/z = 303.0239378276624, rt = 10.412414360512496
#
#                 p-val: 0.9407272141032851, logFC = 0.20882947096049695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 725: m/z = 155.09272153753983, rt = 8.605884724296029
#
#                 p-val: 0.943008688633634, logFC = -0.0116718583227353
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2706: m/z = 508.37631204094686, rt = 3.773383831409169
#
#                 p-val: 0.9446253537953622, logFC = -0.118308035625386
#
#                 mm annotation: ['lysophosphatidylcholine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1095: m/z = 181.03970273335773, rt = 9.670247417689332
#
#                 p-val: 0.946951349074675, logFC = -0.10806119291986599
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3975: m/z = 243.94808880488083, rt = 10.077530369438463
#
#                 p-val: 0.946951349074675, logFC = 0.22891225135642998
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 583: m/z = 145.09719601192992, rt = 11.143932312458295
#
#                 p-val: 0.9488037513719991, logFC = 0.0756659357417924
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 565: m/z = 144.10197530110676, rt = 9.196256324482755
#
#                 p-val: 0.95005038720559, logFC = -0.0750461811594789
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121c3a5e0>}
#
# Peak 683: m/z = 151.09652974870468, rt = 6.697604342702687
#
#                 p-val: 0.95005038720559, logFC = -0.10568427625881698
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121c3eac0>, 'gnps2': <mnet.Spectrum object at 0x121c3ec70>}
#
# Peak 2037: m/z = 264.1804777292105, rt = 3.47083174785214
#
#                 p-val: 0.9565892731687758, logFC = -0.16031319699595098
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 636: m/z = 148.0967851587244, rt = 6.832714637077744
#
#                 p-val: 0.9581210000371109, logFC = -0.0557491077574497
#
#                 mm annotation: ['(r)-pantothenate', 'n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121c46eb0>}
#
# Peak 269: m/z = 120.09291960063732, rt = 10.404521617841146
#
#                 p-val: 0.9709702827524079, logFC = 0.00569097567446875
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 325: m/z = 127.05023574829102, rt = 10.061188714238039
#
#                 p-val: 0.974313633482738, logFC = 0.0259566639089179
#
#                 mm annotation: ['thymine$imidazole-4-acetate; imidazoleacetic acid; 4-imidazoleacetate']
#
#                 std annotation: imidazole-4-acetate
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 541: m/z = 142.94811766488212, rt = 12.479464782309474
#
#                 p-val: 0.9744893823154991, logFC = -0.0920299763482362
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121c56a30>}
#
# Peak 240: m/z = 118.08624432538006, rt = 9.607425459917092
#
#                 p-val: 0.983014788401197, logFC = -0.0356890921986768
#
#                 mm annotation: ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine', 'l-2-aminoadipate; l-alpha-aminoadipate; l-alpha-aminoadipic acid; l-2-aminoadipic acid; l-2-aminohexanedioate']
#
#                 std annotation: betaine
#
#                 hmdb annotation: Betaine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x121c5a0d0>, 'gnps2': <mnet.Spectrum object at 0x121c5a280>}
#
# Peak 191: m/z = 115.06321776540658, rt = 8.604204271160157
#
#                 p-val: 0.983654993288002, logFC = -0.00326709502646594
#
#                 mm annotation: ['acetamidopropanal$d-proline$l-proline']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1154: m/z = 186.1125436731287, rt = 9.397406494197273
#
#                 p-val: 0.9844138270008891, logFC = -0.0171085286223835
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x121c635b0>}
#
# Peak 175: m/z = 114.03404131802642, rt = 8.589866932858449
#
#                 p-val: 0.9917762908608689, logFC = -0.0293358220104984
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Creatinine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121c66910>, 'frag_pos_vl': <mnet.Spectrum object at 0x121c66ac0>}

# %%
sys.path.append('..')
import peakinfo
with open(osp+'positive_mode/samples_including_hat/peakinfolist_hat.dict', 'rb') as file:
    peakinfolist_positive = pickle.load(file)

# %%
sys.path.append('..')
import peakinfo
with open(osp+'positive_mode/samples_including_tryps/peakinfolist_tryps_specific.dict', 'rb') as file:
    peakinfolist_positive = pickle.load(file)

# %%
with open(osp+'negative_mode/samples/peakinfolist.dict', 'rb') as file:
    peakinfolist_negative = pickle.load(file)

# %%
with open(osp+'negative_mode/standards_list.dict', 'rb') as file:
    stdsneg = pickle.load(file)

# %%
for peak in peakinfolist_negative:
    peak.add_adduct_list(mode = False)

# %%
for peak in peakinfolist_negative:
    if peak.pval != 0:
        peak.add_std_match(stdsneg, metabolites)

# %%
file = open(osp+'negative_mode/peaks.txt', 'w')
for peak in peakinfolist_negative:
    if peak.pval != 0:
        file.write(str(peak.mz)+'\t'+str(peak.rt)+'\t'+str(peak.pval)+'\t'+str(peak.logfc)+'\t'+str(peak.cid)+
                  '\t'+str(peak.mm_annotation)+'\t'+str(peak.std_annotation)+'\n')
file.close()

# %%
stdsneg
# Out:
# {353.04926: ('phenolsulfonphthalein', 341.40000000000003, '-', 237563187),
#  241.08319: ('thymidine', 387.0, '-', 55965922),
#  208.06512: ('mops', 421.8, '-', 93178795),
#  87.00878: ('pyruvate', 490.2, '-', 9196824),
#  227.0676: ('deoxyuridine', 459.0, '-', 38943631),
#  163.04023999999998: ('4-coumarate', 478.8, '-', 137879575),
#  123.02008000000001: ('pyrazinoate', 513.0, '-', 12085996),
#  103.04008: ('(r)-3-hydroxybutanoate', 530.4, '-', 27365508),
#  328.04562000000004: ("3'_5'-cyclic amp", 528.0, '-', 41469443),
#  243.06239: ('uridine', 549.6, '-', 54886480),
#  179.05638000000002: ('d-glucose', 755.4, '-', 808433),
#  155.00993: ('orotate', 583.8000000000001, '-', 237865845),
#  163.06145: ('l-rhamnose', 609.6, '-', 429088),
#  151.02632: ('xanthine', 630.0, '-', 3045272),
#  167.03513999999998: ('3_4-dihydroxyphenylacetate', 709.2, '-', 3054178),
#  165.01945: ('phthalate', 721.1999999999999, '-', 703934845),
#  195.05125: ('d-gluconic acid', 714.0, '-', 47479612),
#  323.02896: ('ump', 696.5999999999999, '-', 9448552),
#  146.04607: ('l-glutamate', 724.8, '-', 9151574),
#  117.01933000000001: ('methylmalonate', 741.5999999999999, '-', 233883135),
#  322.04507: ('cmp', 731.4, '-', 3568357),
#  147.03001: ('(r)-2-hydroxyglutarate', 746.4, '-', 194337600),
#  167.99738: ('l-cysteate', 780.0, '-', 109414616),
#  229.01212: ('d-ribose 5-phosphate', 750.0, '-', 2887784),
#  103.00359: ('malonate', 772.1999999999999, '-', 165330544),
#  193.0356: ('d-galacturonate', 791.4, '-', 15490552),
#  115.00368: ('fumarate', 786.0, '-', 20482832),
#  259.02246: ('d-fructose 6-phosphate', 754.8, '-', 10894058),
#  209.03052: ('d-galactarate', 814.2, '-', 10856139),
#  166.9753: ('phosphoenolpyruvate', 814.2, '-', 41043204),
#  173.00929: ('cis-aconitate', 838.2, '-', 248941920),
#  119.035: ('d-erythrose', 622.1999999999999, '-', 3614914),
#  341.10934: ('maltose', 775.8, '-', 906425),
#  101.02431999999999: ('2-oxobutanoate', 394.8, '-', 35866546),
#  205.03558: ('2-methylcitrate', 813.0, '-', 141291117),
#  151.04019: ('3-hydroxyphenylacetate', 528.0, '-', 4348425),
#  163.04018: ('phenylpyruvate', 426.0, '-', 207574952),
#  119.03473999999999: ('d-threose', 559.8, '-', 988432),
#  101.02412: ('succinate semialdehyde', 561.0, '-', 418244151),
#  187.07242: ('n-acetylglutamine', 579.6, '-', 94505603),
#  179.03521999999998: ('3-(4-hydroxyphenyl)pyruvate', 471.0, '-', 18517597),
#  149.04564: ('d-ribose', 640.8, '-', 413977),
#  455.09634000000005: ('fmn', 582.6, '-', 46880),
#  177.04066: ('l-gulono-1_4-lactone', 698.4000000000001, '-', 32274805),
#  287.05228: ('orotidine', 661.8, '-', 54681516),
#  308.09918: ('n-acetylneuraminate', 680.4, '-', 1677564),
#  307.03412000000003: ('dump', 679.2, '-', 1122771),
#  157.03688: ('allantoin', 753.0, '-', 4649052),
#  331.04578: ('dimp', 693.6, '-', 160875),
#  171.00665: ('sn-glycerol 3-phosphate', 721.8, '-', 307049),
#  341.10938: ('sucrose', 742.1999999999999, '-', 7508640),
#  117.01931: ('succinate', 745.8, '-', 161658040),
#  175.0249: ('d-glucuronolactone', 768.6, '-', 14121549),
#  129.01944: ('mesaconate', 343.8, '-', 21198474),
#  145.01434: ('2-oxoglutarate', 458.4, '-', 120732704),
#  133.01433: ('(s)-malate', 778.2, '-', 18840110),
#  184.98578: ('3-phospho-d-glycerate', 788.4000000000001, '-', 20501),
#  88.98813: ('oxalate', 846.0, '-', 46075),
#  191.0201: ('citrate', 837.0, '-', 52980),
#  89.02428: ('(r)-lactate', 555.0, '-', 14140931),
#  149.04561: ('d-arabinose', 706.8, '-', 400347),
#  179.05637: ('d-fructose', 706.8, '-', 1219376),
#  96.9696: ('orthophosphate', 760.2, '-', 77959181),
#  188.05659: ('n-acetyl-l-glutamate', 703.8000000000001, '-', 471960292),
#  129.01938: ('itaconate', 748.2, '-', 159815117),
#  426.02252000000004: ("adenosine 2'_5'-bisphosphate",
#   763.8000000000001,
#   '-',
#   601250),
#  184.98584: ('2-phospho-d-glycerate', 783.0, '-', 88062055),
#  176.9362: ('pyrophosphate', 761.4, '-', 17033802),
#  352.2245: ('PGE2', 150, '-', 193945)}

# %%
stdsneg[351.2245] = ('PGE2', 150, '-', 193945)

# %%
for peak in peakinfolist_negative:
    if peak.pval !=0:
        if peak.std_annotation != '':
            print(peak)

# %%
with open('/Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pymz/mzmine/peak_picked_files/peakinfolist.dict', 'rb') as file:
    peakinfolist_positive = pickle.load(file)

# %%
peakinfolist = []
for peak in peakinfolist_positive:
    if peak.pval != 0.0:
        peakinfolist.append(peak)

# %%
for peak in peakinfolist:
    print(peak)
# Out:
# Peak 633: m/z = 148.07345756155544, rt = 11.915376878181446
#
#                 p-val: 4.917262464543361e-10, logFC = -11.182687216628802
#
#                 mm annotation: ['(r)-mevalonate']
#
#                 std annotation: o-acetyl-l-serine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 613: m/z = 147.07640748274954, rt = 11.905213776127336
#
#                 p-val: 9.50855356149344e-10, logFC = -2.63034608332642
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation: l-glutamine
#
#                 hmdb annotation: L-Lysine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x124f323d0>, 'gnps2': <mnet.Spectrum object at 0x124f32490>}
#
# Peak 3109: m/z = 905.5937710121028, rt = 2.9989393770564763
#
#                 p-val: 1.13535901345591e-09, logFC = -10.211343208638901
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3028: m/z = 837.618204752604, rt = 3.1507679296929143
#
#                 p-val: 1.7306558736295801e-09, logFC = -12.542239855974099
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2989: m/z = 810.6000113236278, rt = 3.1712747307827622
#
#                 p-val: 2.21432944268004e-09, logFC = -1.7812251168870903
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x124faf610>, 'gnps2': <mnet.Spectrum object at 0x124faf6d0>}
#
# Peak 2936: m/z = 782.5687384354442, rt = 3.204236220992103
#
#                 p-val: 3.0424836229794397e-09, logFC = -1.79450144331877
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x124fc0220>, 'gnps2': <mnet.Spectrum object at 0x124fc02e0>}
#
# Peak 324: m/z = 126.0219806871916, rt = 12.209535511372454
#
#                 p-val: 3.3695815034334397e-09, logFC = -1.04710511580883
#
#                 mm annotation: ['taurine']
#
#                 std annotation: taurine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x124fc0e20>, 'frag_pos_vl': <mnet.Spectrum object at 0x124fc0ee0>}
#
# Peak 2938: m/z = 784.5840506302683, rt = 3.1956754108132674
#
#                 p-val: 5.88708446913662e-09, logFC = -1.4497776489092902
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 425: m/z = 133.06077505412858, rt = 10.333907314956184
#
#                 p-val: 7.1258297834603085e-09, logFC = 1.75011143914939
#
#                 mm annotation: ['n-carbamoyl-beta-alanine$l-asparagine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2992: m/z = 812.6144790649414, rt = 3.1738542476404548
#
#                 p-val: 8.0465948665371e-09, logFC = -1.64557792833309
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2939: m/z = 785.5879516601562, rt = 3.2024338052303265
#
#                 p-val: 8.52143735836283e-09, logFC = -1.5088271608142
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 926: m/z = 169.05836848208781, rt = 11.897038272605002
#
#                 p-val: 1.0322050457876e-08, logFC = -2.1962780494017102
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 951: m/z = 171.0764231430857, rt = 11.892799220401725
#
#                 p-val: 1.05267228742764e-08, logFC = -1.01155938493891
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3026: m/z = 835.6033615604524, rt = 3.1581256673739664
#
#                 p-val: 1.06515764821877e-08, logFC = -10.698209641023999
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 101: m/z = 101.07095439850336, rt = 11.929978879334824
#
#                 p-val: 1.56737811890671e-08, logFC = -10.0563554026259
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1236: m/z = 191.040284656343, rt = 11.911427014102307
#
#                 p-val: 2.0480956149758998e-08, logFC = -9.938461505396711
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 397: m/z = 131.05327114306002, rt = 11.88734120795674
#
#                 p-val: 2.14852111638612e-08, logFC = -1.09706950943779
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 168: m/z = 112.05056200027464, rt = 9.76502164353295
#
#                 p-val: 2.41580743450072e-08, logFC = 12.962342802325802
#
#                 mm annotation: ['cytosine (in dna)$cytosine']
#
#                 std annotation: cytosine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 626: m/z = 148.04266542004, rt = 6.714252903696112
#
#                 p-val: 2.4304102205709303e-08, logFC = -9.32533296988524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1250682b0>}
#
# Peak 365: m/z = 130.04992655703896, rt = 11.890277826892214
#
#                 p-val: 3.36078143804683e-08, logFC = -1.06619681316973
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', '5-oxo-l-proline']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1250da040>}
#
# Peak 940: m/z = 170.06167554098462, rt = 11.90249255506668
#
#                 p-val: 6.4792843226268e-08, logFC = -9.27771118975633
#
#                 mm annotation:
#
#                 std annotation: n(pi)-methyl-l-histidine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3027: m/z = 836.6139644499748, rt = 3.1561264739296693
#
#                 p-val: 1.0385785869503301e-07, logFC = -10.0650161116301
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 893: m/z = 166.05330748307077, rt = 10.840145684201556
#
#                 p-val: 1.6251040090357199e-07, logFC = 1.76020601831562
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 659: m/z = 149.08066248893738, rt = 11.907904572957134
#
#                 p-val: 1.7470747779073902e-07, logFC = -9.146391237297369
#
#                 mm annotation: ['(r)-mevalonate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2720: m/z = 520.3400409096166, rt = 3.764698097898109
#
#                 p-val: 1.9553429860501102e-07, logFC = -1.8785086352406397
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1251416d0>, 'gnps2': <mnet.Spectrum object at 0x125141790>}
#
# Peak 2958: m/z = 792.5890053196957, rt = 3.17424326168862
#
#                 p-val: 2.5675050223618004e-07, logFC = -10.9429380908455
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1251aa370>}
#
# Peak 3025: m/z = 834.6000561714172, rt = 3.156962816942129
#
#                 p-val: 2.59441334762532e-07, logFC = -9.80446366154065
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1251aae80>}
#
# Peak 2695: m/z = 495.3275594559927, rt = 3.861196866296261
#
#                 p-val: 2.9739450386677604e-07, logFC = -9.524063986363391
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1031: m/z = 176.03766284072609, rt = 6.714380459353793
#
#                 p-val: 4.21523284201069e-07, logFC = -9.89260363338719
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1993: m/z = 258.1100018149928, rt = 11.350615870550547
#
#                 p-val: 5.17135144550214e-07, logFC = -1.2072506071780602
#
#                 mm annotation:
#
#                 std annotation: sn-glycero-3-phosphocholine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125200f10>, 'gnps2': <mnet.Spectrum object at 0x125200fd0>}
#
# Peak 2549: m/z = 380.2558107376098, rt = 6.713701956844809
#
#                 p-val: 5.307082131462971e-07, logFC = -7.99576744906867
#
#                 mm annotation: ['sphingosine 1-phosphate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1034: m/z = 176.07406287357722, rt = 4.276906994865536
#
#                 p-val: 5.843548770562411e-07, logFC = -9.51488039529544
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2944: m/z = 787.6035939266808, rt = 3.1828694994031235
#
#                 p-val: 7.10107032538536e-07, logFC = -0.811695795830687
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2942: m/z = 786.6000470613177, rt = 3.1871777436438435
#
#                 p-val: 8.868938122079821e-07, logFC = -0.810224881721162
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125246ca0>, 'gnps2': <mnet.Spectrum object at 0x125246d60>}
#
# Peak 2876: m/z = 743.5770635431462, rt = 3.2019822291768096
#
#                 p-val: 1.0133776793692699e-06, logFC = -10.499363695357
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1517: m/z = 213.0222165089733, rt = 11.904522592934331
#
#                 p-val: 1.09791072555254e-06, logFC = -9.77013845614376
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2548: m/z = 380.25582956167364, rt = 4.248077275139069
#
#                 p-val: 1.2546242914788402e-06, logFC = -7.566345467740621
#
#                 mm annotation: ['sphingosine 1-phosphate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1449: m/z = 206.1273452258501, rt = 9.281201471607208
#
#                 p-val: 1.5559772401439501e-06, logFC = -8.73395464702139
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2913: m/z = 767.5771116059402, rt = 3.1909653266929685
#
#                 p-val: 1.6203575318825e-06, logFC = -10.188379344532802
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2963: m/z = 796.6194324493408, rt = 3.1777290687711117
#
#                 p-val: 1.81417431292328e-06, logFC = -8.57228796923272
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 952: m/z = 171.07645948309647, rt = 9.235934544397882
#
#                 p-val: 2.2972216427185602e-06, logFC = -0.714991555271641
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: N6-Acetyl-L-lysine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12527c8e0>}
#
# Peak 2982: m/z = 807.5720968535452, rt = 3.1823487249259754
#
#                 p-val: 2.47283544862444e-06, logFC = -8.81094068253091
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2987: m/z = 809.5875447591147, rt = 3.1851688642355116
#
#                 p-val: 2.71733025009897e-06, logFC = -8.59564301986815
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2912: m/z = 766.5738016764321, rt = 3.1928454645942037
#
#                 p-val: 3.20183145396073e-06, logFC = -8.26699527159509
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2898: m/z = 759.5722881116367, rt = 3.215870431703981
#
#                 p-val: 3.49026130401727e-06, logFC = -0.860037548566861
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2921: m/z = 770.6031951904297, rt = 3.1982725889677845
#
#                 p-val: 3.6625968712907797e-06, logFC = -9.04872368899591
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 4343: m/z = 512.334872713956, rt = 4.200786223475737
#
#                 p-val: 4.15537434152251e-06, logFC = -9.75694823122524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1252d6ac0>}
#
# Peak 2725: m/z = 523.3591457166169, rt = 3.73649391466906
#
#                 p-val: 4.5157033164442395e-06, logFC = -1.06070944941986
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2724: m/z = 522.3558831465872, rt = 3.736986901958506
#
#                 p-val: 4.60516873201997e-06, logFC = -1.04259944784816
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125342130>}
#
# Peak 2666: m/z = 469.3119622055365, rt = 3.974227894946392
#
#                 p-val: 5.16740533942968e-06, logFC = -10.4571264726801
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2897: m/z = 758.5688291850843, rt = 3.2135804173217304
#
#                 p-val: 5.418380256728e-06, logFC = -0.8480436843108728
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125390760>}
#
# Peak 1839: m/z = 241.03100315217048, rt = 12.597870757674437
#
#                 p-val: 1.06985459550148e-05, logFC = -7.814946930091041
#
#                 mm annotation: ['l-cystine; l-dicysteine; l-alpha-diamino-beta-dithiolactic acid']
#
#                 std annotation: l-cystine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12539d2b0>, 'gnps2': <mnet.Spectrum object at 0x12539d370>}
#
# Peak 1238: m/z = 191.08493292331696, rt = 9.80184624307863
#
#                 p-val: 1.1558697630388801e-05, logFC = -7.7314922084382305
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2895: m/z = 757.5567353347252, rt = 3.222214152778468
#
#                 p-val: 1.18162740021872e-05, logFC = -8.836315173894391
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 459: m/z = 136.0427669178356, rt = 10.099289180795346
#
#                 p-val: 1.2107639662209e-05, logFC = -7.274170874511159
#
#                 mm annotation: ['l-homocysteine']
#
#                 std annotation: methylcysteine
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1253dc4f0>}
#
# Peak 1299: m/z = 194.1468843732561, rt = 4.1319048248802615
#
#                 p-val: 1.21918444776592e-05, logFC = -7.987008453444231
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2230: m/z = 287.2215092307643, rt = 3.3367347899412936
#
#                 p-val: 1.29888795721924e-05, logFC = -0.586381569788568
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12541bd60>}
#
# Peak 2960: m/z = 794.6050793092642, rt = 3.173322675393975
#
#                 p-val: 1.31096029173515e-05, logFC = -7.7205801295514505
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125434a30>}
#
# Peak 3022: m/z = 832.5839935878537, rt = 3.1621105008565693
#
#                 p-val: 1.4704367896841599e-05, logFC = -9.43086179995322
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 970: m/z = 172.0968251479299, rt = 6.7103843760710635
#
#                 p-val: 1.67963681632756e-05, logFC = 0.573492283316948
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 366: m/z = 130.04995717500387, rt = 9.235738236152981
#
#                 p-val: 1.69222685515447e-05, logFC = -0.649141706140043
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate$5-oxo-l-proline', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde']
#
#                 std annotation: 5-oxoproline
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125516af0>, 'frag_pos_vl': <mnet.Spectrum object at 0x125516bb0>}
#
# Peak 2664: m/z = 468.30843577665433, rt = 3.9705792974931056
#
#                 p-val: 2.1023052578718697e-05, logFC = -7.16605473174531
#
#                 mm annotation: ['timnodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1255288e0>, 'frag_pos_vl': <mnet.Spectrum object at 0x1255289a0>, 'gnps2': <mnet.Spectrum object at 0x125528a60>}
#
# Peak 2763: m/z = 568.3397577459162, rt = 3.6748810702065318
#
#                 p-val: 2.33424352764119e-05, logFC = -7.68958109514351
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12557f5e0>}
#
# Peak 835: m/z = 161.0923203901811, rt = 6.7305915190221075
#
#                 p-val: 3.3708125949296995e-05, logFC = -6.9326302438739695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 410: m/z = 132.05415382385254, rt = 11.897504272757521
#
#                 p-val: 3.4013765017287394e-05, logFC = -7.65710068300612
#
#                 mm annotation:
#
#                 std annotation: 5-aminolevulinate
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2678: m/z = 482.3242121244732, rt = 3.85737394875471
#
#                 p-val: 4.39438137090312e-05, logFC = -0.8749238353790891
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1255b56d0>}
#
# Peak 2600: m/z = 400.34202806877363, rt = 3.7688438162451448
#
#                 p-val: 4.78315136063884e-05, logFC = -7.29695106527337
#
#                 mm annotation: ['l-palmitoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2696: m/z = 496.33967911569704, rt = 3.8194716747786335
#
#                 p-val: 5.07118072992095e-05, logFC = -0.83225318745524
#
#                 mm annotation: ['docosa-4,7,10,13,16-pentaenoyl carnitine$clupanodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1255c3cd0>}
#
# Peak 3577: m/z = 168.1019774350253, rt = 6.7144123909849425
#
#                 p-val: 5.31832176905057e-05, logFC = -8.996025354335519
#
#                 mm annotation: ['3-methoxytyramine$epinine; deoxyepinephrine']
#
#                 std annotation: pyridoxal
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2701: m/z = 498.34583282470703, rt = 3.813956823367649
#
#                 p-val: 5.67389979457912e-05, logFC = -0.8320918333858921
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2997: m/z = 814.6262374014224, rt = 3.1529000260658964
#
#                 p-val: 5.71263400234474e-05, logFC = -8.905429303000039
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12565adf0>}
#
# Peak 2698: m/z = 497.3431362352873, rt = 3.822709234947065
#
#                 p-val: 5.9007857014818994e-05, logFC = -0.8212467821292401
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2711: m/z = 510.3556785583496, rt = 3.7555667299139857
#
#                 p-val: 5.923162388792379e-05, logFC = -0.8362220656501441
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125674400>}
#
# Peak 2918: m/z = 769.5926121303012, rt = 3.1880956485680785
#
#                 p-val: 5.975493438261229e-05, logFC = -7.951626308988299
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1526: m/z = 213.12338502945443, rt = 6.713599596972838
#
#                 p-val: 8.817624364460859e-05, logFC = -6.25827129846341
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3108: m/z = 904.5903413192084, rt = 2.9967184966263014
#
#                 p-val: 9.340764099239291e-05, logFC = -5.78517187742563
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x12568b490>}
#
# Peak 2894: m/z = 756.5531342450312, rt = 3.2379690459708006
#
#                 p-val: 9.60176606304623e-05, logFC = -6.52583070072173
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2969: m/z = 799.6681079864502, rt = 3.29227476759155
#
#                 p-val: 9.79497366808887e-05, logFC = -7.448786730111589
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2151: m/z = 279.15896526135896, rt = 3.3596950838369133
#
#                 p-val: 0.000116820233690096, logFC = -0.6153697696145001
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Progesterone
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1256a5520>, 'gnps2': <mnet.Spectrum object at 0x1256a55e0>}
#
# Peak 785: m/z = 158.15401699668482, rt = 3.614794642976292
#
#                 p-val: 0.000120897298818185, logFC = 0.7371260370925758
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125710250>}
#
# Peak 2743: m/z = 542.3226473533501, rt = 3.78322037280904
#
#                 p-val: 0.000120932189581004, logFC = -8.6075950227748
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125710f70>}
#
# Peak 1463: m/z = 209.09213899311263, rt = 9.323316198803509
#
#                 p-val: 0.000125347662993327, logFC = 0.588843857846385
#
#                 mm annotation: ['porphobilinogen', 'l-kynurenine$formyl-5-hydroxykynurenamine']
#
#                 std annotation: l-kynurenine
#
#                 hmdb annotation: L-Kynurenine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12577cb80>}
#
# Peak 667: m/z = 150.05838434319747, rt = 9.801560467510669
#
#                 p-val: 0.000130149780322985, logFC = -1.65735553998747
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation: l-methionine
#
#                 hmdb annotation: L-Methionine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1257a0880>, 'gnps2': <mnet.Spectrum object at 0x1257a0940>}
#
# Peak 2949: m/z = 788.6120846396997, rt = 3.1883200045755458
#
#                 p-val: 0.000135149268350319, logFC = -0.5409474076376629
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2881: m/z = 745.5926278921273, rt = 3.1969129754988503
#
#                 p-val: 0.000144726026625152, logFC = -8.54809981046208
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2966: m/z = 797.6236220537606, rt = 3.1602520058825827
#
#                 p-val: 0.00014766101820913602, logFC = -7.50616733415771
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 634: m/z = 148.07970658393756, rt = 11.903578089878053
#
#                 p-val: 0.000153742719135484, logFC = -4.68884618786971
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation: o-acetyl-l-serine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 109: m/z = 102.05497522065134, rt = 9.799513957381537
#
#                 p-val: 0.000163754749331025, logFC = -5.730288516100289
#
#                 mm annotation: ['d-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2980: m/z = 806.5687849017937, rt = 3.1798349846770173
#
#                 p-val: 0.000169510090370274, logFC = -5.78029597655704
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125880b50>}
#
# Peak 1580: m/z = 217.10714016538682, rt = 3.7185520069170006
#
#                 p-val: 0.00018099999471108002, logFC = -6.853070474624991
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2745: m/z = 545.3430971891984, rt = 3.7169377354093087
#
#                 p-val: 0.000190106598752321, logFC = -6.1104320110392
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2837: m/z = 689.5586529632112, rt = 3.445898404061168
#
#                 p-val: 0.000200639764715598, logFC = -5.84589767678799
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 614: m/z = 147.07638807857737, rt = 6.878839972532079
#
#                 p-val: 0.000209781343879034, logFC = -5.339399840333269
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12589f6a0>}
#
# Peak 1100: m/z = 181.0720427293044, rt = 6.703730118801477
#
#                 p-val: 0.000303128645819538, logFC = -6.5173316425727705
#
#                 mm annotation: ['1,7-dimethylxanthine; paraxanthine$']
#
#                 std annotation:
#
#                 hmdb annotation: Hippuric acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1259042b0>, 'frag_pos_vl': <mnet.Spectrum object at 0x125904370>, 'gnps2': <mnet.Spectrum object at 0x125904430>}
#
# Peak 690: m/z = 152.05416253033806, rt = 9.800490879735172
#
#                 p-val: 0.000315493881428101, logFC = -6.12941923451816
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation: 2-phenylglycine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 121: m/z = 104.05283815720502, rt = 9.801547535280642
#
#                 p-val: 0.00031832393371228703, logFC = -6.016609444999091
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2961: m/z = 795.6087868430398, rt = 3.1704207339950474
#
#                 p-val: 0.00031930162878209104, logFC = -6.688622284367441
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 38: m/z = 84.0442725231773, rt = 11.882381163503108
#
#                 p-val: 0.000332351104081367, logFC = -0.462357094192591
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125947130>}
#
# Peak 2995: m/z = 813.620170710637, rt = 3.167355073023148
#
#                 p-val: 0.00033280079859890495, logFC = -7.08358005679473
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125947d90>}
#
# Peak 2235: m/z = 288.21679216272685, rt = 6.710575387813409
#
#                 p-val: 0.000333817855500673, logFC = -5.3375279109251395
#
#                 mm annotation: ['l-octanoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1259618e0>}
#
# Peak 2875: m/z = 742.5739977155413, rt = 3.210162847197511
#
#                 p-val: 0.000355079466763485, logFC = -5.31308950842934
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2832: m/z = 676.546512075571, rt = 3.4645076315949384
#
#                 p-val: 0.000357975069799867, logFC = -6.4463203853301705
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2923: m/z = 772.5841475777004, rt = 3.2090239941698546
#
#                 p-val: 0.000362002550228319, logFC = -5.6112715565427695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1259f3b20>}
#
# Peak 2998: m/z = 814.6869326139753, rt = 3.2671478973107004
#
#                 p-val: 0.000381420612046995, logFC = -0.404490596399754
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 264: m/z = 120.0808048248291, rt = 8.854499598965873
#
#                 p-val: 0.00040734256784672097, logFC = 0.43672795603462705
#
#                 mm annotation: ['l-phenylalanine$', 'tyramine$n,n-dimethylaniline n-oxide$phenylethanolamine; 2-amino-1-phenylethanol']
#
#                 std annotation:
#
#                 hmdb annotation: L-Phenylalanine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125a09190>, 'gnps2': <mnet.Spectrum object at 0x125a09250>}
#
# Peak 2800: m/z = 615.5388493691721, rt = 2.9921706546524263
#
#                 p-val: 0.00042955789118577996, logFC = -6.762732664023289
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2320: m/z = 304.21173236553483, rt = 6.7225817387372375
#
#                 p-val: 0.000447000438841374, logFC = -5.96396391236004
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1450: m/z = 207.11288060640038, rt = 8.850467543611357
#
#                 p-val: 0.000462723215782965, logFC = 0.41647283631293797
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2925: m/z = 773.5876270162648, rt = 3.2031847475751585
#
#                 p-val: 0.000526392115707198, logFC = -7.347379735301059
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2934: m/z = 781.5560995434957, rt = 3.2225692162120723
#
#                 p-val: 0.000543262899588568, logFC = -7.0724599902029
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2693: m/z = 494.32407618931364, rt = 3.8649246277064218
#
#                 p-val: 0.00059212346720305, logFC = -5.459129030377059
#
#                 mm annotation: ['cervonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125a4a4c0>}
#
# Peak 906: m/z = 167.08961125424034, rt = 8.857153671083873
#
#                 p-val: 0.000594399281825547, logFC = 0.444213460023956
#
#                 mm annotation: ['l-phenylalanine$']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 535: m/z = 142.12273035551368, rt = 3.803460912354821
#
#                 p-val: 0.0006094712208569759, logFC = 0.613266831209529
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125b1fbb0>}
#
# Peak 2985: m/z = 808.58344708067, rt = 3.1691686547228097
#
#                 p-val: 0.000653841773849463, logFC = -6.45748125058159
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 423: m/z = 133.03179997983187, rt = 9.801642939217606
#
#                 p-val: 0.000656549692986182, logFC = -5.82276475936575
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1441: m/z = 205.1264040205214, rt = 9.29280034267381
#
#                 p-val: 0.0007288598240569361, logFC = -4.62308434517701
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 253: m/z = 119.01619202750071, rt = 10.097554040691968
#
#                 p-val: 0.0007292702554440651, logFC = -4.91710300958007
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125b4d8e0>}
#
# Peak 1078: m/z = 179.127837532445, rt = 4.375178398752974
#
#                 p-val: 0.000733724138776576, logFC = -0.461903565293252
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2384: m/z = 316.24817137787306, rt = 4.315124863489827
#
#                 p-val: 0.0009036331704478461, logFC = -5.15303235001915
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Dodecanoylcarnitine
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125bf8070>}
#
# Peak 3317: m/z = 130.065154281317, rt = 6.726810434132585
#
#                 p-val: 0.000910700876050597, logFC = -6.76452846483441
#
#                 mm annotation: ['l-phenylalanine$']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2315: m/z = 302.23251875620036, rt = 4.370994817087583
#
#                 p-val: 0.000939702410833875, logFC = -5.68865814410717
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 677: m/z = 151.0579272576098, rt = 9.807276094071767
#
#                 p-val: 0.0010343308391829698, logFC = -7.504486277174769
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 676: m/z = 151.04779716159987, rt = 11.872232773025232
#
#                 p-val: 0.00104656580698676, logFC = -4.643943261505339
#
#                 mm annotation: ['5,6-dihydrothymine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2842: m/z = 701.5587664152448, rt = 3.4205349542944568
#
#                 p-val: 0.00112264030302692, logFC = -0.38648752681206106
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125caa760>}
#
# Peak 4735: m/z = 154.07240237611714, rt = 9.03697799012916
#
#                 p-val: 0.00116039554457958, logFC = -5.53090651942889
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 885: m/z = 165.11223471792118, rt = 4.267475591169922
#
#                 p-val: 0.00122364326142752, logFC = -0.4773147500611579
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1002: m/z = 174.08740496279592, rt = 11.517982648461464
#
#                 p-val: 0.00127628553153136, logFC = -4.99007224281755
#
#                 mm annotation: ['5-guanidino-2-oxopentanoate; 5-guanidino-2-oxo-pentanoate; 2-oxo-5-guanidinopentanoate; 2-oxo-5-guanidino-pentanoate', 'l-histidine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2990: m/z = 811.60400390625, rt = 3.1664475966712713
#
#                 p-val: 0.00131947466228214, logFC = -2.5095173494596
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1401: m/z = 203.05238235473632, rt = 12.05103861917583
#
#                 p-val: 0.00134388723281376, logFC = 7.995276342107531
#
#                 mm annotation: ['d-glucose$beta-d-glucose$l-sorbose; l-xylo-hexulose$beta-d-fructose; beta-fruit sugar; beta-d-arabino-hexulose; beta-levulose; fructose$alpha-d-glucose$d-hexose$$d-fructose$beta-d-galactose$galactose$d-tagatose; lyxo-hexulose$myo-inositol$glucose$d-galactose$alpha-d-galactose$d-mannose']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125cc9d90>, 'frag_pos_vl': <mnet.Spectrum object at 0x125cc9e50>}
#
# Peak 3867: m/z = 219.14204296167347, rt = 8.414122199886636
#
#                 p-val: 0.00136219180599901, logFC = -4.88663221704702
#
#                 mm annotation: ['propionyl-carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125cebb50>}
#
# Peak 298: m/z = 123.05528043445787, rt = 6.715846041707633
#
#                 p-val: 0.00137782275567553, logFC = -0.5728940387899039
#
#                 mm annotation: ['nicotinamide', '3-methylimidazoleacetic acid']
#
#                 std annotation: nicotinamide
#
#                 hmdb annotation: Niacinamide
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125dfa7f0>, 'gnps2': <mnet.Spectrum object at 0x125dfa8b0>}
#
# Peak 2877: m/z = 744.5532271067302, rt = 3.195004986122018
#
#                 p-val: 0.00150849536693406, logFC = -7.23844389322983
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2192: m/z = 283.1034067327326, rt = 7.638936587781288
#
#                 p-val: 0.00160383135545005, logFC = -5.07796578442612
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1229: m/z = 190.08622629502239, rt = 6.717570800151284
#
#                 p-val: 0.00163639633924719, logFC = -4.750123753699389
#
#                 mm annotation: ['methyl indole-3-acetate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125e51a30>, 'gnps2': <mnet.Spectrum object at 0x125e51af0>}
#
# Peak 3083: m/z = 880.5899320660216, rt = 3.0012072328324013
#
#                 p-val: 0.00170892266615051, logFC = -5.384293528964401
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2234: m/z = 288.2168204171317, rt = 4.384022985095052
#
#                 p-val: 0.00175192263304081, logFC = -4.42697382769785
#
#                 mm annotation: ['l-octanoylcarnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x125e78190>, 'gnps2': <mnet.Spectrum object at 0x125e78250>}
#
# Peak 1591: m/z = 218.13872538114845, rt = 8.41637103850833
#
#                 p-val: 0.0018388747523675898, logFC = -0.7169359895918391
#
#                 mm annotation: ['propionyl-carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125e78f10>}
#
# Peak 2937: m/z = 783.5721797688803, rt = 3.2044670684797745
#
#                 p-val: 0.0019403307838317602, logFC = -2.48144665572742
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2999: m/z = 815.6969108012186, rt = 3.3167827055011414
#
#                 p-val: 0.00195650812872217, logFC = -5.826060016924191
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 330: m/z = 127.08659606144346, rt = 6.717903104634009
#
#                 p-val: 0.00199346706723687, logFC = -5.06312431998468
#
#                 mm annotation:
#
#                 std annotation: thymine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1724: m/z = 230.09579192614947, rt = 11.951036929785865
#
#                 p-val: 0.0020807777684550602, logFC = -5.84348422635007
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 678: m/z = 151.06173039825867, rt = 9.799460908142995
#
#                 p-val: 0.00212456464630967, logFC = -4.4428986783918
#
#                 mm annotation: ['l-methionine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 862: m/z = 163.13287734985354, rt = 3.7994672006916432
#
#                 p-val: 0.0021428493043152397, logFC = 0.5512954871296071
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x125fec130>}
#
# Peak 1089: m/z = 180.15944360431868, rt = 3.7993752859691465
#
#                 p-val: 0.00219386100888766, logFC = 0.560347284001462
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x125feccd0>, 'gnps2': <mnet.Spectrum object at 0x125fecd90>}
#
# Peak 2703: m/z = 499.34838518415177, rt = 3.821352176761092
#
#                 p-val: 0.0023710334688155, logFC = -4.714446344658639
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2620: m/z = 424.34192075567734, rt = 3.7025443473800332
#
#                 p-val: 0.00241168223711806, logFC = -6.879584330156031
#
#                 mm annotation: ['linoelaidyl carnitine$linoleyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 878: m/z = 164.136320013749, rt = 3.800138472932415
#
#                 p-val: 0.00246438936400995, logFC = 0.571903381258856
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1122: m/z = 183.11287488435443, rt = 6.716411567771383
#
#                 p-val: 0.00275706284355963, logFC = 5.25903461498913
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2158: m/z = 280.09168243408203, rt = 11.380053096860028
#
#                 p-val: 0.00300246742646495, logFC = -4.17350124433524
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1829: m/z = 239.16410007116932, rt = 3.5122459269786073
#
#                 p-val: 0.00301009135987046, logFC = 6.52208127260134
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2915: m/z = 768.5890444402826, rt = 3.1956967501615114
#
#                 p-val: 0.00301191931376378, logFC = -3.5029282947256406
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1260839d0>}
#
# Peak 2943: m/z = 786.6569239298503, rt = 3.3011916889778767
#
#                 p-val: 0.00304917472469454, logFC = -6.59164788856987
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 726: m/z = 155.106687515501, rt = 4.195650174830067
#
#                 p-val: 0.0030706773477046, logFC = -5.7001288137702595
#
#                 mm annotation: ['nan', 'nan']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x126090fd0>}
#
# Peak 2114: m/z = 275.1033547384697, rt = 11.891297595769975
#
#                 p-val: 0.00313471396511345, logFC = 6.96632405455268
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12609cc10>}
#
# Peak 259: m/z = 120.06554317474364, rt = 9.577770676367102
#
#                 p-val: 0.00342372371954439, logFC = 0.535536762546421
#
#                 mm annotation: ['d-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 6915: m/z = 234.13358319600425, rt = 3.7269341891864696
#
#                 p-val: 0.0035128160829178603, logFC = -6.14127352361042
#
#                 mm annotation:
#
#                 std annotation:
#
# ...
#
# Peak 2796: m/z = 612.5196630859375, rt = 2.9911716878237957
#
#                 p-val: 0.81483086802017, logFC = -0.165336457852955
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1294a2c10>}
#
# Peak 448: m/z = 134.0833956631747, rt = 11.693696195774493
#
#                 p-val: 0.8204824219458822, logFC = -0.456827173466316
#
#                 mm annotation:
#
#                 std annotation: l-aspartate
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1191: m/z = 188.09179316068952, rt = 6.711392215119629
#
#                 p-val: 0.8215184495985369, logFC = 0.0234341285808348
#
#                 mm annotation: ['6-acetamido-2-oxohexanoate; 2-oxo-6-acetamidocaproate', 'norepinephrine$pyridoxine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 402: m/z = 131.08965702380164, rt = 9.512981113606862
#
#                 p-val: 0.8224485431175841, logFC = 0.5508910993436371
#
#                 mm annotation: ['n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation: Pipecolic acid
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12954cd30>}
#
# Peak 2654: m/z = 454.29274400983536, rt = 3.8159728910583217
#
#                 p-val: 0.8250190337458492, logFC = 0.339750603413943
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 352: m/z = 129.10223881648136, rt = 10.14010518333536
#
#                 p-val: 0.8347447046963861, logFC = 0.3648836210393929
#
#                 mm annotation: ['l-lysine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x129575490>}
#
# Peak 1832: m/z = 240.1422054893092, rt = 6.703257039831552
#
#                 p-val: 0.83519624656157, logFC = -0.0170690938672458
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 107: m/z = 102.05497400084538, rt = 11.59886927335523
#
#                 p-val: 0.8438870201350841, logFC = -0.312855419792593
#
#                 mm annotation: ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', 'l-allo-threonine$l-threonine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 480: m/z = 137.04583913167318, rt = 9.042706687232048
#
#                 p-val: 0.8480333751309369, logFC = 0.19371489166566
#
#                 mm annotation: ['hypoxanthine']
#
#                 std annotation: hypoxanthine
#
#                 hmdb annotation: Hypoxanthine
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1295d26a0>}
#
# Peak 1898: m/z = 246.24264697024697, rt = 6.663635200020018
#
#                 p-val: 0.848257817288408, logFC = -0.011066145006203999
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 267: m/z = 120.0905162911666, rt = 10.404289303482257
#
#                 p-val: 0.8493570695969459, logFC = -0.018763401044648
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1394: m/z = 202.14386417554766, rt = 6.7111876242452855
#
#                 p-val: 0.849692582924792, logFC = -0.21192572134454898
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 241: m/z = 118.0862263629311, rt = 10.406100857570118
#
#                 p-val: 0.850519267233369, logFC = -0.0178921842297015
#
#                 mm annotation: ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine']
#
#                 std annotation: betaine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 6: m/z = 72.08080402173493, rt = 10.404729128701526
#
#                 p-val: 0.8543183874297621, logFC = -0.0180060231432506
#
#                 mm annotation: ['glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12960be80>, 'frag_pos_vl': <mnet.Spectrum object at 0x12960bf40>}
#
# Peak 2697: m/z = 496.3396652430704, rt = 6.678386501453447
#
#                 p-val: 0.8565645008715029, logFC = 0.22795007222816502
#
#                 mm annotation: ['docosa-4,7,10,13,16-pentaenoyl carnitine$clupanodonyl carnitine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 748: m/z = 156.13839948177338, rt = 4.388823158162995
#
#                 p-val: 0.8598906165685021, logFC = -0.323015062012058
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1982: m/z = 257.11304651547783, rt = 8.046585805480474
#
#                 p-val: 0.8656845882478058, logFC = 0.14789396409563002
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 35: m/z = 82.94497322549627, rt = 4.719298169027288
#
#                 p-val: 0.8686833612099201, logFC = -0.425975792750767
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x129634b80>}
#
# Peak 929: m/z = 169.0859831689109, rt = 6.707108772998255
#
#                 p-val: 0.868871054165843, logFC = 0.167451685298969
#
#                 mm annotation: ['n-trimethyl-2-aminoethylphosphonate; 2-trimethylaminoethylphosphonate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 192: m/z = 115.0695485064858, rt = 8.601991402136887
#
#                 p-val: 0.868948092832578, logFC = 0.0201309087432797
#
#                 mm annotation: ['nan']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1360: m/z = 199.18053660074867, rt = 3.613996589181411
#
#                 p-val: 0.8780047834823771, logFC = 0.0985019544622148
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12964bc70>}
#
# Peak 2951: m/z = 788.6709195650542, rt = 3.3210114504885047
#
#                 p-val: 0.884353686616242, logFC = 0.38388303016867
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2472: m/z = 343.1896204168146, rt = 9.292335726703062
#
#                 p-val: 0.8886051699999801, logFC = -0.326072572055448
#
#                 mm annotation: ["cortisone; 17alpha,21-dihydroxy-4-pregnene-3,11,20-trione; kendall's compound e; reichstein's substance fa$aldosterone; 11beta,21-dihydroxy-3,20-dioxo-4-pregnen-18-al"]
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 374: m/z = 130.08630989693307, rt = 6.714664681169856
#
#                 p-val: 0.8916157778501551, logFC = -0.125085878785598
#
#                 mm annotation: ['n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1822: m/z = 239.13897132873532, rt = 4.38045851106912
#
#                 p-val: 0.8951320771913521, logFC = -0.0142660461151394
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1296a38e0>, 'frag_pos_vl': <mnet.Spectrum object at 0x1296a39a0>}
#
# Peak 3438: m/z = 147.12094518300648, rt = 10.732846025554746
#
#                 p-val: 0.900922570020593, logFC = 0.10922221649578
#
#                 mm annotation: ['3-dehydroxycarnitine']
#
#                 std annotation: ala-gly
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1297bb6d0>}
#
# Peak 3349: m/z = 134.10863405863444, rt = 9.300184216818623
#
#                 p-val: 0.902032028299987, logFC = -0.22201821042000502
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 327: m/z = 127.07272237889907, rt = 9.996741524796928
#
#                 p-val: 0.9073149087543342, logFC = -0.188927757197327
#
#                 mm annotation:
#
#                 std annotation: imidazole-4-acetate
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 759: m/z = 157.0860331608699, rt = 4.401590453178399
#
#                 p-val: 0.9073322663850379, logFC = -0.190903733394633
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2864: m/z = 732.6082223745492, rt = 3.341070460316012
#
#                 p-val: 0.907453604494437, logFC = -0.291068218847474
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 236: m/z = 118.06511846081965, rt = 9.960984627765214
#
#                 p-val: 0.907705543206174, logFC = 0.197539586486876
#
#                 mm annotation: ['2-phenylacetamide']
#
#                 std annotation: betaine
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 805: m/z = 159.11286996540267, rt = 10.40698936936049
#
#                 p-val: 0.9097919826118991, logFC = -0.0102167342489565
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x129888850>, 'gnps2': <mnet.Spectrum object at 0x129888910>}
#
# Peak 2319: m/z = 303.0239378276624, rt = 10.412414360512496
#
#                 p-val: 0.916644597422241, logFC = 0.20882947096049695
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 725: m/z = 155.09272153753983, rt = 8.605884724296029
#
#                 p-val: 0.920376480106427, logFC = -0.0116718583227353
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 2706: m/z = 508.37631204094686, rt = 3.773383831409169
#
#                 p-val: 0.923465745870346, logFC = -0.118308035625386
#
#                 mm annotation: ['lysophosphatidylcholine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1095: m/z = 181.03970273335773, rt = 9.670247417689332
#
#                 p-val: 0.9284609571115642, logFC = -0.10806119291986599
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 3975: m/z = 243.94808880488083, rt = 10.077530369438463
#
#                 p-val: 0.928769883172441, logFC = 0.22891225135642998
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 583: m/z = 145.09719601192992, rt = 11.143932312458295
#
#                 p-val: 0.9321048053478521, logFC = 0.0756659357417924
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 565: m/z = 144.10197530110676, rt = 9.196256324482755
#
#                 p-val: 0.9360891576222471, logFC = -0.0750461811594789
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1298d15e0>}
#
# Peak 683: m/z = 151.09652974870468, rt = 6.697604342702687
#
#                 p-val: 0.93636966162983, logFC = -0.10568427625881698
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1298f12b0>, 'gnps2': <mnet.Spectrum object at 0x1298f1370>}
#
# Peak 2037: m/z = 264.1804777292105, rt = 3.47083174785214
#
#                 p-val: 0.944344930472215, logFC = -0.16031319699595098
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 636: m/z = 148.0967851587244, rt = 6.832714637077744
#
#                 p-val: 0.947390044836696, logFC = -0.0557491077574497
#
#                 mm annotation: ['(r)-pantothenate', 'n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12990b9d0>}
#
# Peak 269: m/z = 120.09291960063732, rt = 10.404521617841146
#
#                 p-val: 0.9616489680379849, logFC = 0.00569097567446875
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 325: m/z = 127.05023574829102, rt = 10.061188714238039
#
#                 p-val: 0.966519124414876, logFC = 0.0259566639089179
#
#                 mm annotation: ['thymine$imidazole-4-acetate; imidazoleacetic acid; 4-imidazoleacetate']
#
#                 std annotation: imidazole-4-acetate
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 541: m/z = 142.94811766488212, rt = 12.479464782309474
#
#                 p-val: 0.96825265026868, logFC = -0.0920299763482362
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x129986c70>}
#
# Peak 240: m/z = 118.08624432538006, rt = 9.607425459917092
#
#                 p-val: 0.9782963174168711, logFC = -0.0356890921986768
#
#                 mm annotation: ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine', 'l-2-aminoadipate; l-alpha-aminoadipate; l-alpha-aminoadipic acid; l-2-aminoadipic acid; l-2-aminohexanedioate']
#
#                 std annotation: betaine
#
#                 hmdb annotation: Betaine
#
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x1299968e0>, 'gnps2': <mnet.Spectrum object at 0x1299969a0>}
#
# Peak 191: m/z = 115.06321776540658, rt = 8.604204271160157
#
#                 p-val: 0.9805072973094809, logFC = -0.00326709502646594
#
#                 mm annotation: ['acetamidopropanal$d-proline$l-proline']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# Peak 1154: m/z = 186.1125436731287, rt = 9.397406494197273
#
#                 p-val: 0.982838764877687, logFC = -0.0171085286223835
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1299bd070>}
#
# Peak 175: m/z = 114.03404131802642, rt = 8.589866932858449
#
#                 p-val: 0.9917762908608689, logFC = -0.0293358220104984
#
#                 mm annotation:
#
#                 std annotation: creatinine
#
#                 hmdb annotation: Creatinine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x1299bdc70>, 'frag_pos_vl': <mnet.Spectrum object at 0x1299bdd30>}

# %%
import pickle
with open(osp+'Metabolomics_datasets/standards_list.dict', 'rb') as file:
    standards_dict = pickle.load(file)

# %%
for peak in peakinfolist_positive:
    peak.add_adduct_list(metabolites, tolerance = 3)
    peak.add_std_match(standards_dict=standards_dict, metabolites_dict=metabolites, ppm =10, ppm_rt = 90)

# %%
metabolites
# Out:
# {'HMDB0000001': ('169.1811',
#   'C7H11N3O2',
#   '1-Methylhistidine',
#   'CN1C=NC(C[C@H](N)C(O)=O)=C1',
#   '3741',
#   'C01152',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000002': ('74.1249',
#   'C3H10N2',
#   '1,3-Diaminopropane',
#   'NCCCN',
#   '5081',
#   'C00986',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000005': ('102.0886',
#   'C4H6O3',
#   '2-Ketobutyric acid',
#   'CCC(=O)C(O)=O',
#   None,
#   'C00109',
#   None,
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000008': ('104.1045',
#   'C4H8O3',
#   '2-Hydroxybutyric acid',
#   'CCC(O)C(O)=O',
#   '3783',
#   'C05984',
#   'map00640',
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000010': ('300.3921',
#   'C19H24O3',
#   '2-Methoxyestrone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C(OC)=C3',
#   '2578',
#   'C05299',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000011': ('104.1045',
#   'C4H8O3',
#   '(R)-3-Hydroxybutyric acid',
#   'C[C@@H](O)CC(O)=O',
#   None,
#   'C01089',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000012': ('228.202',
#   'C9H12N2O5',
#   'Deoxyuridine',
#   'OC[C@H]1O[C@H](C[C@@H]1O)N1C=CC(=O)NC1=O',
#   '5086',
#   'C00526',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000014': ('227.2172',
#   'C9H13N3O4',
#   'Deoxycytidine',
#   'NC1=NC(=O)N(C=C1)[C@H]1C[C@H](O)[C@@H](CO)O1',
#   '3367',
#   'C00881',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000015': ('346.4605',
#   'C21H30O4',
#   'Cortexolone',
#   '[H][C@@]12CC[C@](O)(C(=O)CO)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5088',
#   'C05488',
#   None,
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000016': ('330.4611',
#   'C21H30O3',
#   'Deoxycorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5089',
#   'C03205',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000017': ('183.1614',
#   'C8H9NO4',
#   '4-Pyridoxic acid',
#   'CC1=NC=C(CO)C(C(O)=O)=C1O',
#   '239',
#   'C00847',
#   'map00750',
#   'Pyridines and derivatives',
#   'Pyridinecarboxylic acids and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000019': ('116.1152',
#   'C5H8O3',
#   'alpha-Ketoisovaleric acid',
#   'CC(C)C(=O)C(O)=O',
#   '5091',
#   'C00141',
#   'map00280',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000020': ('152.1473',
#   'C8H8O3',
#   'p-Hydroxyphenylacetic acid',
#   'OC(=O)CC1=CC=C(O)C=C1',
#   '130',
#   'C00642',
#   None,
#   'Phenols',
#   '1-hydroxy-2-unsubstituted benzenoids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000021': ('307.0851',
#   'C9H10INO3',
#   'Iodotyrosine',
#   'N[C@@H](CC1=CC=C(O)C(I)=C1)C(O)=O',
#   None,
#   'C02515',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000022': ('167.205',
#   'C9H13NO2',
#   '3-Methoxytyramine',
#   'COC1=C(O)C=CC(CCN)=C1',
#   '5094',
#   'C05587',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000023': ('104.1045',
#   'C4H8O3',
#   '(S)-3-Hydroxyisobutyric acid',
#   'C[C@@H](CO)C(O)=O',
#   '483',
#   'C06001',
#   'map00280',
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000026': ('132.1179',
#   'C4H8N2O3',
#   'Ureidopropionic acid',
#   'NC(=O)NCCC(O)=O',
#   '5097',
#   'C02642',
#   None,
#   'Organic carbonic acids and derivatives',
#   'Ureas',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000027': ('241.2471',
#   'C9H15N5O3',
#   'Tetrahydrobiopterin',
#   'CC(O)C(O)C1CNC2=C(N1)C(=O)N=C(N)N2',
#   '5098',
#   'C00272',
#   None,
#   'Pteridines and derivatives',
#   'Pterins and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000030': ('244.311',
#   'C10H16N2O3S',
#   'Biotin',
#   '[H][C@]12CS[C@@H](CCCCC(O)=O)[C@@]1([H])NC(=O)N2',
#   '243',
#   'C00120',
#   None,
#   'Biotin and derivatives',
#   None,
#   'Aliphatic heteropolycyclic compounds'),
#  'HMDB0000031': ('290.4403',
#   'C19H30O2',
#   'Androsterone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC[C@@]2([H])C[C@H](O)CC[C@]12C',
#   '2797',
#   'C00523',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000032': ('384.6377',
#   'C27H44O',
#   '7-Dehydrocholesterol',
#   '[H][C@@]1(CC[C@@]2([H])C3=CC=C4C[C@@H](O)CC[C@]4(C)[C@@]3([H])CC[C@]12C)[C@H](C)CCCC(C)C',
#   '5101',
#   'C01164',
#   None,
#   'Steroids and steroid derivatives',
#   'Cholestane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000033': ('226.2325',
#   'C9H14N4O3',
#   'Carnosine',
#   'NCCC(=O)N[C@@H](CC1=CN=CN1)C(O)=O',
#   '38',
#   'C00386',
#   None,
#   'Peptidomimetics',
#   'Hybrid peptides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000034': ('135.1267',
#   'C5H5N5',
#   'Adenine',
#   'NC1=C2NC=NC2=NC=N1',
#   '85',
#   'C00147',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000036': ('515.703',
#   'C26H45NO7S',
#   'Taurocholic acid',
#   '[H][C@@]1(CC[C@@]2([H])[C@]3([H])[C@H](O)C[C@]4([H])C[C@H](O)CC[C@]4(C)[C@@]3([H])C[C@H](O)[C@]12C)[C@H](C)CCC(=O)NCCS(O)(=O)=O',
#   '5104',
#   'C05122',
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000037': ('360.444',
#   'C21H28O5',
#   'Aldosterone',
#   'C[C@]12CCC(=O)C=C1CCC1C3CC[C@H](C(=O)CO)[C@]3(C[C@H](O)C21)C=O',
#   '418',
#   'C01780',
#   None,
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000038': ('239.2312',
#   'C9H13N5O3',
#   'Dihydrobiopterin',
#   'CC(O)C(O)C1=NC2=C(NC1)N=C(N)NC2=O',
#   '5106',
#   'C02953',
#   None,
#   'Pteridines and derivatives',
#   'Pterins and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000039': ('88.1051',
#   'C4H8O2',
#   'Butyric acid',
#   'CCCC(O)=O',
#   '107',
#   'C00246',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000042': ('60.052',
#   'C2H4O2',
#   'Acetic acid',
#   'CC(O)=O',
#   '3206',
#   'C00033',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000043': ('117.1463',
#   'C5H11NO2',
#   'Betaine',
#   'C[N+](C)(C)CC([O-])=O',
#   '287',
#   'C00719',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000044': ('176.1241',
#   'C6H8O6',
#   'Ascorbic acid',
#   '[H][C@@]1(OC(=O)C(O)=C1O)[C@@H](O)CO',
#   '3753',
#   'C01041',
#   None,
#   'Dihydrofurans',
#   'Furanones',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000045': ('347.2212',
#   'C10H14N5O7P',
#   'Adenosine monophosphate',
#   'NC1=C2N=CN([C@@H]3O[C@H](COP(O)(O)=O)[C@@H](O)[C@H]3O)C2=NC=N1',
#   '5111',
#   'C00020',
#   None,
#   'Purine nucleotides',
#   'Purine ribonucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000050': ('267.2413',
#   'C10H13N5O4',
#   'Adenosine',
#   'NC1=C2N=CN([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O)C2=NC=N1',
#   '86',
#   'C00212',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000051': ('17.0305',
#   'H3N',
#   'Ammonia',
#   'N',
#   '3189',
#   'C00014',
#   None,
#   'Homogeneous other non-metal compounds',
#   None,
#   None),
#  'HMDB0000052': ('290.2731',
#   'C10H18N4O6',
#   'Argininosuccinic acid',
#   'N[C@@H](CCCNC(=N)N[C@@H](CC(O)=O)C(O)=O)C(O)=O',
#   '5115',
#   'C03406',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000053': ('286.4085',
#   'C19H26O2',
#   'Androstenedione',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '2795',
#   'C00280',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000054': ('584.6621',
#   'C33H36N4O6',
#   'Bilirubin',
#   'CC1=C(C=C)\\C(NC1=O)=C\\C1=C(C)C(CCC(O)=O)=C(CC2=C(CCC(O)=O)C(C)=C(N2)\\C=C2/NC(=O)C(C=C)=C2C)N1',
#   '5475',
#   None,
#   'map00860',
#   'Organoheterocyclic compounds',
#   'Tetrapyrroles and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000056': ('89.0932',
#   'C3H7NO2',
#   'beta-Alanine',
#   'NCCC(O)=O',
#   '5119',
#   'C00099',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000058': ('329.2059',
#   'C10H12N5O6P',
#   'Cyclic AMP',
#   'NC1=NC=NC2=C1N=CN2[C@@H]1O[C@@H]2COP(O)(=O)O[C@H]2[C@H]1O',
#   '5120',
#   'C00575',
#   None,
#   'Purine nucleotides',
#   'Cyclic purine nucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000060': ('102.0886',
#   'C4H6O3',
#   'Acetoacetic acid',
#   'CC(=O)CC(O)=O',
#   '276',
#   'C00164',
#   'map00280',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000062': ('161.1989',
#   'C7H15NO3',
#   'L-Carnitine',
#   'C[N+](C)(C)C[C@H](O)CC([O-])=O',
#   '52',
#   'C00318',
#   None,
#   'Organonitrogen compounds',
#   'Quaternary ammonium salts',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000063': ('362.4599',
#   'C21H30O5',
#   'Cortisol',
#   '[H][C@@]12CC[C@](O)(C(=O)CO)[C@@]1(C)C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5124',
#   'C00735',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000064': ('131.1332',
#   'C4H9N3O2',
#   'Creatine',
#   'CN(CC(O)=O)C(N)=N',
#   '7',
#   'C00300',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000067': ('386.6535',
#   'C27H46O',
#   'Cholesterol',
#   '[H][C@@]1(CC[C@@]2([H])[C@]3([H])CC=C4C[C@@H](O)CC[C@]4(C)[C@@]3([H])CC[C@]12C)[C@H](C)CCCC(C)C',
#   None,
#   'C00187',
#   None,
#   'Steroids and steroid derivatives',
#   'Cholestane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000068': ('183.2044',
#   'C9H13NO3',
#   'Epinephrine',
#   'CNC[C@H](O)C1=CC(O)=C(O)C=C1',
#   '5127',
#   'C00788',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000070': ('129.157',
#   'C6H11NO2',
#   'Pipecolic acid',
#   'OC(=O)C1CCCCN1',
#   '50',
#   'C00408',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000071': ('252.23',
#   'C10H12N4O4',
#   'Deoxyinosine',
#   'OC[C@H]1O[C@H](C[C@@H]1O)N1C=NC2=C1N=CNC2=O',
#   '3383',
#   'C05512',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000073': ('153.1784',
#   'C8H11NO2',
#   'Dopamine',
#   'NCCC1=CC(O)=C(O)C=C1',
#   '64',
#   'C03758',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000076': ('114.1026',
#   'C4H6N2O2',
#   'Dihydrouracil',
#   'O=C1CCNC(=O)N1',
#   '285',
#   'C00429',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000077': ('288.4244',
#   'C19H28O2',
#   'Dehydroepiandrosterone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5133',
#   'C01227',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000078': ('178.21',
#   'C5H10N2O3S',
#   'Cysteinylglycine',
#   'N[C@@H](CS)C(=O)NCC(O)=O',
#   '5134',
#   'C01419',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000079': ('128.1292',
#   'C5H8N2O2',
#   'Dihydrothymine',
#   'CC1CNC(=O)NC1=O',
#   '5135',
#   'C00906',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000085': ('267.2413',
#   'C10H13N5O4',
#   'Deoxyguanosine',
#   'NC1=NC2=C(N=CN2[C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)N1',
#   '3395',
#   'C00330',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000086': ('257.2213',
#   'C8H20NO6P',
#   'Glycerophosphocholine',
#   'C[N+](C)(C)CCOP([O-])(=O)OC[C@@H](O)CO',
#   '370',
#   'C00670',
#   None,
#   'Glycerophospholipids',
#   'Glycerophosphocholines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000087': ('45.0837',
#   'C2H7N',
#   'Dimethylamine',
#   'CNC',
#   '3758',
#   'C00543',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000089': ('243.2166',
#   'C9H13N3O5',
#   'Cytidine',
#   'NC1=NC(=O)N(C=C1)[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O',
#   None,
#   'C02961',
#   None,
#   'Pyrimidine nucleosides',
#   None,
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000092': ('103.1198',
#   'C4H9NO2',
#   'Dimethylglycine',
#   'CN(C)CC(O)=O',
#   '277',
#   'C01026',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000094': ('192.1235',
#   'C6H8O7',
#   'Citric acid',
#   'OC(=O)CC(O)(CC(O)=O)C(O)=O',
#   '124',
#   'C00158',
#   None,
#   'Carboxylic acids and derivatives',
#   'Tricarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000097': ('104.1708',
#   'C5H14NO',
#   'Choline',
#   'C[N+](C)(C)CCO',
#   '56',
#   'C00114',
#   None,
#   'Organonitrogen compounds',
#   'Quaternary ammonium salts',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000098': ('150.1299',
#   'C5H10O5',
#   'D-Xylose',
#   'O[C@@H]1COC(O)[C@H](O)[C@H]1O',
#   '314',
#   'C00181',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000099': ('222.262',
#   'C7H14N2O4S',
#   'L-Cystathionine',
#   'N[C@@H](CCSC[C@H](N)C(O)=O)C(O)=O',
#   '39',
#   'C02291',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000101': ('251.2419',
#   'C10H13N5O3',
#   'Deoxyadenosine',
#   'NC1=NC=NC2=C1N=CN2[C@H]1C[C@H](O)[C@@H](CO)O1',
#   '3382',
#   'C00559',
#   None,
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000107': ('182.1718',
#   'C6H14O6',
#   'Galactitol',
#   'OC[C@H](O)[C@@H](O)[C@@H](O)[C@H](O)CO',
#   '5148',
#   'C01697',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000108': ('46.0684',
#   'C2H6O',
#   'Ethanol',
#   'CCO',
#   '3203',
#   'C00469',
#   None,
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000112': ('103.1198',
#   'C4H9NO2',
#   'gamma-Aminobutyric acid',
#   'NCCCC(O)=O',
#   None,
#   'C00334',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000115': ('76.0514',
#   'C2H4O3',
#   'Glycolic acid',
#   'OCC(O)=O',
#   '3219',
#   'C03547',
#   None,
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000118': ('182.1733',
#   'C9H10O4',
#   'Homovanillic acid',
#   'COC1=CC(CC(O)=O)=CC=C1O',
#   '971',
#   'C05582',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000119': ('74.0355',
#   'C2H2O3',
#   'Glyoxylic acid',
#   'OC(=O)C=O',
#   '3213',
#   'C00048',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000121': ('441.3975',
#   'C19H19N7O6',
#   'Folic acid',
#   'NC1=NC(=O)C2=NC(CNC3=CC=C(C=C3)C(=O)N[C@@H](CCC(O)=O)C(O)=O)=CN=C2N1',
#   '246',
#   'C00504',
#   'map00790',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000122': ('180.1559',
#   'C6H12O6',
#   'D-Glucose',
#   'OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O',
#   '133',
#   'C00031',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000123': ('75.0666',
#   'C2H5NO2',
#   'Glycine',
#   'NCC(O)=O',
#   '20',
#   'C00037',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000124': ('260.1358',
#   'C6H13O9P',
#   'Fructose 6-phosphate',
#   'OCC(=O)[C@@H](O)[C@H](O)[C@H](O)COP(O)(O)=O',
#   '5159',
#   'C00085',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000125': ('307.323',
#   'C10H17N3O6S',
#   'Glutathione',
#   'N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(O)=O)C(O)=O',
#   '44',
#   'C02471',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000126': ('172.0737',
#   'C3H9O6P',
#   'Glycerol 3-phosphate',
#   'OC[C@@H](O)COP(O)(O)=O',
#   '5161',
#   'C00093',
#   'map00564',
#   'Glycerophospholipids',
#   'Glycerophosphates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000127': ('194.1394',
#   'C6H10O7',
#   'D-Glucuronic acid',
#   'O[C@H]1O[C@@H]([C@@H](O)[C@H](O)[C@H]1O)C(O)=O',
#   '161',
#   'C00191',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000128': ('117.1066',
#   'C3H7N3O2',
#   'Guanidoacetic acid',
#   'NC(=N)NCC(O)=O',
#   '5163',
#   'C00581',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000130': ('168.1467',
#   'C8H8O4',
#   'Homogentisic acid',
#   'OC(=O)CC1=C(O)C=CC(O)=C1',
#   '331',
#   'C00544',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenylacetic acids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000131': ('92.0938',
#   'C3H8O3',
#   'Glycerol',
#   'OCC(O)CO',
#   '105',
#   'C00116',
#   'map00561',
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000133': ('283.2407',
#   'C10H13N5O5',
#   'Guanosine',
#   'NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)C(=O)N1',
#   '87',
#   'C00387',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000134': ('116.0722',
#   'C4H4O4',
#   'Fumaric acid',
#   'OC(=O)\\C=C\\C(O)=O',
#   '3242',
#   'C00122',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000138': ('465.6227',
#   'C26H43NO6',
#   'Glycocholic acid',
#   '[H][C@@]12CC[C@H]([C@H](C)CCC(=O)NCC(O)=O)[C@@]1(C)[C@@H](O)C[C@@]1([H])[C@@]2([H])[C@H](O)CC2C[C@H](O)CC[C@]12C',
#   '5169',
#   'C01921',
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000139': ('106.0773',
#   'C3H6O4',
#   'Glyceric acid',
#   'OC[C@@H](O)C(O)=O',
#   '280',
#   'C00258',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000140': ('812.2539',
#   'C48H93NO8',
#   'Glucosylceramide',
#   'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](CO[C@@H]1O[C@H](CO)C(O)[C@H](O)[C@H]1O)[C@H](O)\\C=C\\CCCCCCCCCCCCC',
#   None,
#   'C01190',
#   'map00500',
#   'Sphingolipids',
#   'Glycosphingolipids',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000142': ('46.0254',
#   'CH2O2',
#   'Formic acid',
#   'OC=O',
#   '3202',
#   'C00058',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000143': ('180.1559',
#   'C6H12O6',
#   'D-Galactose',
#   'OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@H]1O',
#   '134',
#   'C00984',
#   'map00500',
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000145': ('270.3661',
#   'C18H22O2',
#   'Estrone',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '264',
#   'C00468',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000148': ('147.1293',
#   'C5H9NO4',
#   'L-Glutamic acid',
#   'N[C@@H](CCC(O)=O)C(O)=O',
#   '5174',
#   'C00025',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000149': ('61.0831',
#   'C2H7NO',
#   'Ethanolamine',
#   'NCCO',
#   '3207',
#   'C00189',
#   'map00564',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000150': ('178.14',
#   'C6H10O6',
#   'Gluconolactone',
#   'OC[C@H]1OC(=O)[C@H](O)[C@@H](O)[C@@H]1O',
#   '353',
#   'C00198',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000151': ('272.382',
#   'C18H24O2',
#   'Estradiol',
#   '[H][C@@]12CC[C@H](O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '263',
#   'C00951',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000152': ('154.121',
#   'C7H6O4',
#   'Gentisic acid',
#   'OC(=O)C1=C(O)C=CC(O)=C1',
#   '618',
#   'C00628',
#   None,
#   'Benzene and substituted derivatives',
#   'Benzoic acids and derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000153': ('288.3814',
#   'C18H24O3',
#   'Estriol',
#   '[H][C@@]12C[C@@H](O)[C@H](O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '2581',
#   'C05141',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000156': ('134.0874',
#   'C4H6O5',
#   'L-Malic acid',
#   'O[C@@H](CC(O)=O)C(O)=O',
#   None,
#   'C00149',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000157': ('136.1115',
#   'C5H4N4O',
#   'Hypoxanthine',
#   'OC1=NC=NC2=C1NC=N2',
#   '83',
#   'C00262',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000158': ('181.1885',
#   'C9H11NO3',
#   'L-Tyrosine',
#   'N[C@@H](CC1=CC=C(O)C=C1)C(O)=O',
#   '34',
#   'C00082',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000159': ('165.1891',
#   'C9H11NO2',
#   'L-Phenylalanine',
#   'N[C@@H](CC1=CC=CC=C1)C(O)=O',
#   '28',
#   'C00079',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000161': ('89.0932',
#   'C3H7NO2',
#   'L-Alanine',
#   'C[C@H](N)C(O)=O',
#   None,
#   'C00041',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000162': ('115.1305',
#   'C5H9NO2',
#   'L-Proline',
#   'OC(=O)[C@@H]1CCCN1',
#   '29',
#   'C00148',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000163': ('342.2965',
#   'C12H22O11',
#   'D-Maltose',
#   'OC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@H](O)[C@@H](O)O[C@@H]2CO)[C@H](O)[C@@H](O)[C@@H]1O',
#   '413',
#   'C00208',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000164': ('31.0571',
#   'CH5N',
#   'Methylamine',
#   'CN',
#   '3767',
#   'C00218',
#   None,
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000167': ('119.1192',
#   'C4H9NO3',
#   'L-Threonine',
#   'C[C@@H](O)[C@H](N)C(O)=O',
#   '32',
#   'C00188',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000168': ('132.1179',
#   'C4H8N2O3',
#   'L-Asparagine',
#   'N[C@@H](CC(N)=O)C(O)=O',
#   '14',
#   'C00152',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000169': ('180.1559',
#   'C6H12O6',
#   'D-Mannose',
#   'OC[C@H]1OC(O)[C@@H](O)[C@@H](O)[C@@H]1O',
#   None,
#   'C00159',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000172': ('131.1729',
#   'C6H13NO2',
#   'L-Isoleucine',
#   'CC[C@H](C)[C@H](N)C(O)=O',
#   '5193',
#   'C00407',
#   'map00280',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000174': ('164.1565',
#   'C6H12O5',
#   'L-Fucose',
#   'C[C@@H]1OC(O)[C@@H](O)[C@H](O)[C@@H]1O',
#   '5812',
#   'C00507',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000175': ('348.206',
#   'C10H13N4O8P',
#   'Inosinic acid',
#   'O[C@@H]1[C@@H](COP(O)(O)=O)O[C@H]([C@@H]1O)N1C=NC2=C1N=CNC2=O',
#   '5196',
#   'C00130',
#   None,
#   'Purine nucleotides',
#   'Purine ribonucleotides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000176': ('116.0722',
#   'C4H4O4',
#   'Maleic acid',
#   'OC(=O)\\C=C/C(O)=O',
#   '3242',
#   'C00122',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000177': ('155.1546',
#   'C6H9N3O2',
#   'L-Histidine',
#   'N[C@@H](CC1=CN=CN1)C(O)=O',
#   '21',
#   'C00135',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000181': ('197.1879',
#   'C9H11NO4',
#   'L-Dopa',
#   'N[C@@H](CC1=CC(O)=C(O)C=C1)C(O)=O',
#   '42',
#   'C00355',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000182': ('146.1876',
#   'C6H14N2O2',
#   'L-Lysine',
#   'NCCCC[C@H](N)C(O)=O',
#   '5200',
#   'C00047',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000186': ('342.2965',
#   'C12H22O11',
#   'Alpha-Lactose',
#   'OC[C@H]1O[C@@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O)O[C@@H]2CO)[C@H](O)[C@@H](O)[C@H]1O',
#   '267',
#   'C00243',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000187': ('105.0926',
#   'C3H7NO3',
#   'L-Serine',
#   'N[C@@H](CO)C(O)=O',
#   '5203',
#   'C00065',
#   'map00500',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000190': ('90.0779',
#   'C3H6O3',
#   'L-Lactic acid',
#   'C[C@H](O)C(O)=O',
#   '6150',
#   'C00256',
#   None,
#   'Hydroxy acids and derivatives',
#   'Alpha hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000191': ('133.1027',
#   'C4H7NO4',
#   'L-Aspartic acid',
#   'N[C@@H](CC(O)=O)C(O)=O',
#   '5206',
#   'C00049',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000192': ('240.3',
#   'C6H12N2O4S2',
#   'L-Cystine',
#   'N[C@@H](CSSC[C@H](N)C(O)=O)C(O)=O',
#   '5207',
#   'C00491',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000193': ('192.1235',
#   'C6H8O7',
#   'Isocitric acid',
#   'OC(C(CC(O)=O)C(O)=O)C(O)=O',
#   '3328',
#   'C00311',
#   None,
#   'Carboxylic acids and derivatives',
#   'Tricarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000194': ('240.259',
#   'C10H16N4O3',
#   'Anserine',
#   'CN1C=NC=C1C[C@H](NC(=O)CCN)C(O)=O',
#   '5209',
#   'C01262',
#   None,
#   'Peptidomimetics',
#   'Hybrid peptides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000195': ('268.2261',
#   'C10H12N4O5',
#   'Inosine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=NC2=C1NC=NC2=O',
#   '84',
#   'C00294',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000197': ('175.184',
#   'C10H9NO2',
#   'Indoleacetic acid',
#   'OC(=O)CC1=CNC2=C1C=CC=C2',
#   '5211',
#   'C00954',
#   'map00380',
#   'Indoles and derivatives',
#   'Indolyl carboxylic acids and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000201': ('203.238',
#   'C9H17NO4',
#   'L-Acetylcarnitine',
#   'CC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C',
#   None,
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000202': ('118.088',
#   'C4H6O4',
#   'Methylmalonic acid',
#   'CC(C(O)=O)C(O)=O',
#   '3712',
#   'C02170',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000205': ('164.158',
#   'C9H8O3',
#   'Phenylpyruvic acid',
#   'OC(=O)C(=O)CC1=CC=CC=C1',
#   '328',
#   'C00166',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenylpyruvic acid derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000206': ('188.2242',
#   'C8H16N2O3',
#   'N6-Acetyl-L-lysine',
#   'CC(=O)NCCCC[C@H](N)C(O)=O',
#   '5216',
#   'C02727',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000207': ('282.4614',
#   'C18H34O2',
#   'Oleic acid',
#   'CCCCCCCC\\C=C/CCCCCCCC(O)=O',
#   '190',
#   'C00712',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000208': ('146.0981',
#   'C5H6O5',
#   'Oxoglutaric acid',
#   'OC(=O)CCC(=O)C(O)=O',
#   '5218',
#   'C00026',
#   None,
#   'Keto acids and derivatives',
#   'Gamma-keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000209': ('136.1479',
#   'C8H8O2',
#   'Phenylacetic acid',
#   'OC(=O)CC1=CC=CC=C1',
#   '129',
#   'C07086',
#   'map00360',
#   'Benzene and substituted derivatives',
#   None,
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000210': ('219.235',
#   'C9H17NO5',
#   'Pantothenic acid',
#   'CC(C)(CO)[C@@H](O)C(=O)NCCC(O)=O',
#   None,
#   'C00864',
#   None,
#   'Alcohols and polyols',
#   'Polyols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000211': ('180.1559',
#   'C6H12O6',
#   'myo-Inositol',
#   'O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@H](O)[C@@H]1O',
#   '5221',
#   'C00137',
#   'map00562',
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0000214': ('132.161',
#   'C5H12N2O2',
#   'Ornithine',
#   'NCCC[C@H](N)C(O)=O',
#   '27',
#   'C00077',
#   'map00330',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000215': ('221.2078',
#   'C8H15NO6',
#   'N-Acetyl-D-glucosamine',
#   'CC(=O)N[C@H]1C(O)O[C@H](CO)[C@@H](O)[C@@H]1O',
#   '3356',
#   'C00140',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000216': ('169.1778',
#   'C8H11NO3',
#   'Norepinephrine',
#   'NC[C@H](O)C1=CC(O)=C(O)C=C1',
#   '5226',
#   'C00547',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000217': ('744.4129',
#   'C21H29N7O17P3',
#   'NADP',
#   'NC(=O)C1=C[N+](=CC=C1)[C@@H]1O[C@H](CO[P@](O)(=O)O[P@](O)(=O)OC[C@H]2O[C@H]([C@H](OP(O)(O)=O)[C@@H]2O)N2C=NC3=C(N)N=CN=C23)[C@@H](O)[C@H]1O',
#   '5227',
#   'C00006',
#   None,
#   "(5'->5')-dinucleotides",
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000220': ('256.4241',
#   'C16H32O2',
#   'Palmitic acid',
#   'CCCCCCCCCCCCCCCC(O)=O',
#   '187',
#   'C00249',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000221': ('745.4209',
#   'C21H30N7O17P3',
#   'NADPH',
#   'NC(=O)C1=CN(C=CC1)[C@H]1O[C@@H](COP(O)(=O)OP(O)(=O)OC[C@@H]2O[C@@H]([C@@H](OP(O)(O)=O)[C@H]2O)N2C=NC3=C(N)N=CN=C23)[C@H](O)[C@@H]1O',
#   '3691',
#   'C00005',
#   None,
#   "(5'->5')-dinucleotides",
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000222': ('399.6077',
#   'C23H45NO4',
#   'L-Palmitoylcarnitine',
#   'CCCCCCCCCCCCCCCC(=O)O[C@H](CC([O-])=O)C[N+](C)(C)C',
#   '5231',
#   'C02990',
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000224': ('141.063',
#   'C2H8NO4P',
#   'O-Phosphoethanolamine',
#   'NCCOP(O)(O)=O',
#   '5233',
#   'C00346',
#   'map00500',
#   'Organic phosphoric acids and derivatives',
#   'Phosphate esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000225': ('160.1247',
#   'C6H8O5',
#   'Oxoadipic acid',
#   'OC(=O)CCCC(=O)C(O)=O',
#   '5234',
#   'C00322',
#   None,
#   'Keto acids and derivatives',
#   'Medium-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000226': ('156.0963',
#   'C5H4N2O4',
#   'Orotic acid',
#   'OC(=O)C1=CC(=O)NC(=O)N1',
#   '318',
#   'C00295',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000227': ('148.1571',
#   'C6H12O4',
#   'Mevalonic acid',
#   'CC(O)(CCO)CC(O)=O',
#   '127',
#   'C00418',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000228': ('94.1112',
#   'C6H6O',
#   'Phenol',
#   'OC1=CC=CC=C1',
#   '128',
#   'C15584',
#   None,
#   'Phenols',
#   '1-hydroxy-4-unsubstituted benzenoids',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000229': ('334.2192',
#   'C11H15N2O8P',
#   'Nicotinamide ribotide',
#   'NC(=O)C1=CC=C[N+](=C1)[C@@H]1O[C@H](COP(O)([O-])=O)[C@@H](O)[C@H]1O',
#   '5238',
#   'C00455',
#   'map00760',
#   'Pyridine nucleotides',
#   'Nicotinamide nucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000230': ('309.2699',
#   'C11H19NO9',
#   'N-Acetylneuraminic acid',
#   'CC(=O)N[C@@H]1[C@@H](O)C[C@](O)(O[C@H]1[C@H](O)[C@H](O)CO)C(O)=O',
#   '3321',
#   'C19910',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000232': ('167.1189',
#   'C7H5NO4',
#   'Quinolinic acid',
#   'OC(=O)C1=CC=CN=C1C(O)=O',
#   '330',
#   'C03722',
#   'map00380',
#   'Pyridines and derivatives',
#   'Pyridinecarboxylic acids and derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000234': ('288.4244',
#   'C19H28O2',
#   'Testosterone',
#   '[H][C@@]12CC[C@H](O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5601',
#   None,
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000235': ('265.355',
#   'C12H17N4OS',
#   'Thiamine',
#   'CC1=C(CCO)SC=[N+]1CC1=CN=C(C)N=C1N',
#   '5242',
#   'C00378',
#   'map00730',
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000237': ('74.0785',
#   'C3H6O2',
#   'Propionic acid',
#   'CCC(O)=O',
#   '3215',
#   'C00163',
#   None,
#   'Carboxylic acids and derivatives',
#   'Carboxylic acids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000239': ('169.1778',
#   'C8H11NO3',
#   'Pyridoxine',
#   'CC1=C(O)C(CO)=C(CO)C=N1',
#   '5245',
#   'C00314',
#   'map00750',
#   'Pyridines and derivatives',
#   'Pyridoxines',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000240': ('82.079',
#   'H2O3S',
#   'Sulfite',
#   'OS(O)=O',
#   None,
#   'C00094',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal sulfites',
#   None),
#  'HMDB0000241': ('562.6582',
#   'C34H34N4O4',
#   'Protoporphyrin IX',
#   'CC1=C(CCC(O)=O)/C2=C/C3=N/C(=C\\C4=C(C)C(C=C)=C(N4)/C=C4\\N=C(\\C=C\\1/N\\2)C(C=C)=C4C)/C(C)=C3CCC(O)=O',
#   '4158',
#   'C02191',
#   'map00860',
#   'Tetrapyrroles and derivatives',
#   'Porphyrins',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000243': ('88.0621',
#   'C3H4O3',
#   'Pyruvic acid',
#   'CC(=O)C(O)=O',
#   '117',
#   'C00022',
#   None,
#   'Keto acids and derivatives',
#   'Alpha-keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000244': ('376.3639',
#   'C17H20N4O6',
#   'Riboflavin',
#   'CC1=C(C)C=C2N(C[C@H](O)[C@H](O)[C@H](O)CO)C3=NC(=O)NC(=O)C3=NC2=C1',
#   '5249',
#   'C00255',
#   'map00740',
#   'Pteridines and derivatives',
#   'Alloxazines and isoalloxazines',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000245': ('226.2292',
#   'C10H14N2O4',
#   'Porphobilinogen',
#   'NCC1=C(CC(O)=O)C(CCC(O)=O)=CN1',
#   '76',
#   'C00931',
#   'map00860',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000246': ('72.1057',
#   'C4H8O',
#   'Tetrahydrofuran',
#   'C1CCOC1',
#   None,
#   None,
#   'map00860',
#   'Tetrahydrofurans',
#   None,
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000247': ('182.1718',
#   'C6H14O6',
#   'Sorbitol',
#   'OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#   '143',
#   'C00794',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000248': ('776.87',
#   'C15H11I4NO4',
#   'Thyroxine',
#   'N[C@@H](CC1=CC(I)=C(OC2=CC(I)=C(O)C(I)=C2)C(I)=C1)C(O)=O',
#   '439',
#   'C01829',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000250': ('177.9751',
#   'H4O7P2',
#   'Pyrophosphate',
#   'OP(O)(=O)OP(O)(O)=O',
#   None,
#   'C00013',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal pyrophosphates',
#   'Acyclic compounds'),
#  'HMDB0000251': ('125.147',
#   'C2H7NO3S',
#   'Taurine',
#   'NCCS(O)(=O)=O',
#   '31',
#   'C00245',
#   None,
#   'Organic sulfonic acids and derivatives',
#   'Organosulfonic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000252': ('299.4919',
#   'C18H37NO2',
#   'Sphingosine',
#   'CCCCCCCCCCCCC\\C=C\\C(O)C(N)CO',
#   '392',
#   'C00319',
#   'map00500',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000253': ('316.4776',
#   'C21H32O2',
#   'Pregnenolone',
#   '[H][C@@]12CC[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   None,
#   'C01953',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000254': ('118.088',
#   'C4H6O4',
#   'Succinic acid',
#   'OC(=O)CCC(O)=O',
#   '114',
#   'C00042',
#   None,
#   'Carboxylic acids and derivatives',
#   'Dicarboxylic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000256': ('410.718',
#   'C30H50',
#   'Squalene',
#   'CC(C)=CCC\\C(C)=C/CC\\C(C)=C\\CC\\C=C(/C)CC\\C=C(/C)CCC=C(C)C',
#   '197',
#   'C00751',
#   None,
#   'Prenol lipids',
#   'Triterpenoids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000257': ('114.144',
#   'H2O3S2',
#   'Thiosulfate',
#   'OS(S)(=O)=O',
#   None,
#   'C05529',
#   None,
#   'Non-metal oxoanionic compounds',
#   'Non-metal thiosulfates',
#   None),
#  'HMDB0000258': ('342.2965',
#   'C12H22O11',
#   'Sucrose',
#   'OC[C@H]1O[C@@](CO)(O[C@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O',
#   '137',
#   'C00089',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000259': ('176.2151',
#   'C10H12N2O',
#   'Serotonin',
#   'NCCC1=CNC2=CC=C(O)C=C12',
#   '74',
#   'C00780',
#   'map00380',
#   'Indoles and derivatives',
#   'Tryptamines and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000262': ('126.1133',
#   'C5H6N2O2',
#   'Thymine',
#   'CC1=CNC(=O)NC1=O',
#   '290',
#   'C00178',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000263': ('168.042',
#   'C3H5O6P',
#   'Phosphoenolpyruvic acid',
#   'OC(=O)C(=C)OP(O)(O)=O',
#   '5264',
#   'C00074',
#   None,
#   'Organic phosphoric acids and derivatives',
#   'Phosphate esters',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000265': ('650.9735',
#   'C15H12I3NO4',
#   'Liothyronine',
#   'N[C@@H](CC1=CC(I)=C(OC2=CC(I)=C(O)C=C2)C(I)=C1)C(O)=O',
#   '5265',
#   'C02465',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000267': ('129.114',
#   'C5H7NO3',
#   'Pyroglutamic acid',
#   'OC(=O)[C@@H]1CCC(=O)N1',
#   '3251',
#   'C01879',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000268': ('350.4923',
#   'C21H34O4',
#   'Tetrahydrocorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(C)C[C@H](O)[C@@]1([H])C2CC[C@]2([H])C[C@H](O)CC[C@]12C',
#   '5267',
#   'C05476',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000269': ('301.5078',
#   'C18H39NO2',
#   'Sphinganine',
#   'CCCCCCCCCCCCCCC[C@@H](O)[C@@H](N)CO',
#   '5268',
#   'C00836',
#   'map00500',
#   'Organonitrogen compounds',
#   'Amines',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000271': ('89.0932',
#   'C3H7NO2',
#   'Sarcosine',
#   'CNCC(O)=O',
#   '51',
#   'C00213',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000272': ('185.0725',
#   'C3H8NO6P',
#   'Phosphoserine',
#   'N[C@@H](COP(O)(O)=O)C(O)=O',
#   '5270',
#   'C01005',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000273': ('242.2286',
#   'C10H14N2O5',
#   'Thymidine',
#   'CC1=CN([C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)NC1=O',
#   '3375',
#   'C00214',
#   None,
#   'Pyrimidine nucleosides',
#   "Pyrimidine 2'-deoxyribonucleosides",
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000277': ('379.4718',
#   'C18H38NO5P',
#   'Sphingosine 1-phosphate',
#   'CCCCCCCCCCCCC\\C=C\\[C@@H](O)[C@@H](N)COP(O)(O)=O',
#   '5272',
#   'C06124',
#   'map00500',
#   'Sphingolipids',
#   'Phosphosphingolipids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000279': ('276.2863',
#   'C11H20N2O6',
#   'Saccharopine',
#   'N[C@@H](CCCCN[C@@H](CCC(O)=O)C(O)=O)C(O)=O',
#   '383',
#   'C00449',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000280': ('390.0696',
#   'C5H13O14P3',
#   'Phosphoribosyl pyrophosphate',
#   'O[C@H]1[C@@H](O)[C@@H](O[P@](O)(=O)OP(O)(O)=O)O[C@@H]1COP(O)(O)=O',
#   '5274',
#   'C00119',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000283': ('150.1299',
#   'C5H10O5',
#   'D-Ribose',
#   'OC[C@H]1OC(O)[C@H](O)[C@@H]1O',
#   '313',
#   'C00121',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0000286': ('566.3018',
#   'C15H24N2O17P2',
#   'Uridine diphosphate glucose',
#   'OC[C@@H]1OC(OP(O)(=O)OP(O)(=O)OC[C@@H]2O[C@@H]([C@@H](O)[C@H]2O)N2C=CC(=O)NC2=O)[C@@H](O)[C@H](O)[C@H]1O',
#   '5278',
#   'C00029',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine nucleotide sugars',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000288': ('324.1813',
#   'C9H13N2O9P',
#   "Uridine 5'-monophosphate",
#   'O[C@H]1[C@@H](O)[C@@H](O[C@@H]1COP(O)(O)=O)N1C=CC(=O)NC1=O',
#   None,
#   'C00105',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine ribonucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000289': ('168.1103',
#   'C5H4N4O3',
#   'Uric acid',
#   'O=C1NC2=C(N1)C(=O)NC(=O)N2',
#   '88',
#   'C00366',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000291': ('198.1727',
#   'C9H10O5',
#   'Vanillylmandelic acid',
#   'COC1=C(O)C=CC(=C1)[C@H](O)C(O)=O',
#   '697',
#   'C05584',
#   None,
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000292': ('152.1109',
#   'C5H4N4O2',
#   'Xanthine',
#   'O=C1NC2=C(NC=N2)C(=O)N1',
#   '82',
#   'C00385',
#   None,
#   'Imidazopyrimidines',
#   'Purines and purine derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000294': ('60.0553',
#   'CH4N2O',
#   'Urea',
#   'NC(N)=O',
#   '6',
#   'C00086',
#   'map00330',
#   'Organic carbonic acids and derivatives',
#   'Ureas',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000295': ('404.1612',
#   'C9H14N2O12P2',
#   "Uridine 5'-diphosphate",
#   'O[C@H]1[C@@H](O)[C@@H](O[C@@H]1COP(O)(=O)OP(O)(O)=O)N1C=CC(=O)NC1=O',
#   None,
#   'C00015',
#   None,
#   'Pyrimidine nucleotides',
#   'Pyrimidine ribonucleotides',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000296': ('244.2014',
#   'C9H12N2O6',
#   'Uridine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=CC(=O)NC1=O',
#   '90',
#   'C00299',
#   None,
#   'Pyrimidine nucleosides',
#   None,
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000299': ('284.2255',
#   'C10H12N4O6',
#   'Xanthosine',
#   'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)N1C=NC2=C1N=C(O)N=C2O',
#   '3408',
#   'C01762',
#   None,
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000300': ('112.0868',
#   'C4H4N2O2',
#   'Uracil',
#   'O=C1NC=CC(=O)N1',
#   '258',
#   'C00106',
#   None,
#   'Diazines',
#   'Pyrimidines and pyrimidine derivatives',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000301': ('138.124',
#   'C6H6N2O2',
#   'Urocanic acid',
#   'OC(=O)\\C=C\\C1=CNC=N1',
#   '298',
#   'C00785',
#   None,
#   'Azoles',
#   'Imidazoles',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0000303': ('160.2157',
#   'C10H12N2',
#   'Tryptamine',
#   'NCCC1=CNC2=CC=CC=C12',
#   '325',
#   'C00398',
#   'map00380',
#   'Indoles and derivatives',
#   'Tryptamines and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0000305': ('286.4516',
#   'C20H30O',
#   'Vitamin A',
#   'C\\C(=C/CO)\\C=C\\C=C(/C)\\C=C\\C1=C(C)CCCC1(C)C',
#   None,
#   'C19962',
#   None,
#   'Prenol lipids',
#   'Retinoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0000306': ('137.179',
#   'C8H11NO',
#   'Tyramine',
#   'NCCC1=CC=C(O)C=C1',
#   '60',
#   'C00483',
#   None,
#   'Benzene and substituted derivatives',
#   'Phenethylamines',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000308': ('374.5567',
#   'C24H38O3',
#   '3b-Hydroxy-5-cholenoic acid',
#   '[H][C@@]12CC[C@H]([C@H](C)CCC(O)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5297',
#   None,
#   None,
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000315': ('332.477',
#   'C21H32O3',
#   '16-a-Hydroxypregnenolone',
#   '[H][C@@]12C[C@@H](O)[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC=C2C[C@@H](O)CC[C@]12C',
#   '5304',
#   'C06390  ',
#   None,
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000317': ('132.1577',
#   'C6H12O3',
#   '2-Hydroxy-3-methylpentanoic acid',
#   'CC[C@@H](C)[C@@H](O)C(O)=O',
#   '5306',
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000318': ('170.1626',
#   'C8H10O4',
#   '3,4-Dihydroxyphenylglycol',
#   'OCC(O)C1=CC(O)=C(O)C=C1',
#   '5307',
#   'C05576',
#   None,
#   'Phenols',
#   'Benzenediols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0000319': ('362.4599',
#   'C21H30O5',
#   '18-Hydroxycorticosterone',
#   '[H][C@@]12CC[C@H](C(=O)CO)[C@@]1(CO)C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C',
#   '5308',
#   'C01124',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000321': ('162.1406',
#   'C6H10O5',
#   '2-Hydroxyadipic acid',
#   'OC(CCCC(O)=O)C(O)=O',
#   '5310',
#   'C02360',
#   'map00140',
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000325': ('190.1938',
#   'C8H14O5',
#   '3-Hydroxysuberic acid',
#   'OC(CCCCC(O)=O)CC(O)=O',
#   '5314',
#   None,
#   'map00140',
#   'Hydroxy acids and derivatives',
#   'Medium-chain hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000326': ('408.5714',
#   'C24H40O5',
#   '1b,3a,12a-Trihydroxy-5b-cholanoic acid',
#   'C[C@H](CCC(O)=O)C1CCC2C3CCC4C[C@H](O)C[C@@H](O)[C@]4(C)C3C[C@H](O)[C@]12C',
#   '5315',
#   None,
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Bile acids, alcohols and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000332': ('376.4434',
#   'C21H28O6',
#   '18-Oxocortisol',
#   '[H][C@@]12CC[C@@](O)(C(=O)CO)[C@]1(C[C@H](O)[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C)C=O',
#   '5321',
#   None,
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Hydroxysteroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0000335': ('286.3655',
#   'C18H22O3',
#   '16a-Hydroxyestrone',
#   '[H][C@@]12C[C@@H](O)C(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[C@@]21[H])C=C(O)C=C3',
#   '2580',
#   'C05300',
#   None,
#   'Steroids and steroid derivatives',
#   'Estrane steroids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0000336': ('104.1045',
#   'C4H8O3',
#   '(R)-3-Hydroxyisobutyric acid',
#   'C[C@H](CO)C(O)=O',
#   None,
#   None,
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000337': ('120.1039',
#   'C4H8O4',
#   '(S)-3,4-Dihydroxybutyric acid',
#   'OCC(O)CC(O)=O',
#   None,
#   None,
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0000343': ('286.3655',
#   'C18H22O3',
#   '2-Hydroxyestrone',
# ...
#   'Raffinose',
#   'OC[C@H]1O[C@@](CO)(OC2O[C@H](COC3O[C@H](CO)[C@H](O)[C@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O',
#   '138',
#   'C00492',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003217': ('270.24',
#   'C15H10O5',
#   'Genistein',
#   'OC1=CC=C(C=C1)C1=COC2=CC(O)=CC(O)=C2C1=O',
#   '3398',
#   'C06563',
#   None,
#   'Isoflavonoids',
#   'Isoflav-2-enes',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003227': ('48.107',
#   'CH4S',
#   'Methanethiol',
#   'CS',
#   '3204',
#   'C00409',
#   None,
#   'Thiols',
#   'Alkylthiols',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003229': ('254.4082',
#   'C16H30O2',
#   'Palmitoleic acid',
#   'CCCCCC\\C=C/CCCCCCCC(O)=O',
#   '188',
#   'C08362',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003231': ('282.468',
#   'C18H34O2',
#   'Vaccenic acid',
#   'CCCCCC\\C=C\\CCCCCCCCCC(O)=O',
#   None,
#   'C08367',
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003233': ('568.8714',
#   'C40H56O2',
#   'Lutein',
#   'O[C@@H]1CC(C)=C(\\C=C\\C(\\C)=C\\C=C\\C(\\C)=C\\C=C\\C=C(/C)\\C=C\\C=C(/C)\\C=C\\[C@H]2C(C)=CC(O)CC2(C)C)C(C)(C)C1',
#   '3601',
#   'C08601',
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003236': ('397.6364',
#   'C27H43NO',
#   'Solanidine',
#   '[H][C@]12CC[C@H](C)CN1[C@@]1([H])C[C@@]3([H])[C@]4([H])CC=C5C[C@@H](O)CC[C@]5(C)[C@@]4([H])CC[C@]3(C)[C@@]1([H])[C@@H]2C',
#   '3517',
#   'C06543',
#   None,
#   'Steroids and steroid derivatives',
#   'Steroidal alkaloids',
#   'Aliphatic heteropolycyclic compounds'),
#  'HMDB0003243': ('88.1051',
#   'C4H8O2',
#   'Acetoin',
#   'CC(O)C(C)=O',
#   '103',
#   'C00466',
#   None,
#   'Organooxygen compounds',
#   'Carbonyl compounds',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003249': ('610.5175',
#   'C27H30O16',
#   'Rutin',
#   'C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](OC3=C(OC4=CC(O)=CC(O)=C4C3=O)C3=CC(O)=C(O)C=C3)[C@H](O)[C@@H](O)[C@@H]2O)[C@H](O)[C@H](O)[C@H]1O',
#   '3677',
#   'C05625',
#   None,
#   'Flavonoids',
#   'Flavonoid glycosides',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003252': ('370.4804',
#   'C20H34O6',
#   'Thromboxane B2',
#   'CCCCC[C@H](O)\\C=C\\[C@H]1OC(O)C[C@H](O)[C@@H]1C\\C=C/CCCC(O)=O',
#   '422',
#   'C05963',
#   None,
#   'Fatty Acyls',
#   'Eicosanoids',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003269': ('180.1607',
#   'C8H8N2O3',
#   'Nicotinuric acid',
#   'OC(=O)CNC(=O)C1=CN=CC=C1',
#   '1499',
#   'C05380',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0003276': ('34.081',
#   'H2S',
#   'Hydrogen sulfide',
#   'S',
#   '3193',
#   'C00283',
#   None,
#   'Other non-metal organides',
#   'Other non-metal sulfides',
#   None),
#  'HMDB0003306': ('274.2687',
#   'C15H14O5',
#   'Phloretin',
#   'OC1=CC=C(CCC(=O)C2=C(O)C=C(O)C=C2O)C=C1',
#   '3405',
#   'C00774',
#   None,
#   'Linear 1,3-diarylpropanoids',
#   'Chalcones and dihydrochalcones',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003312': ('254.241',
#   'C15H10O4',
#   'Daidzein',
#   'OC1=CC=C(C=C1)C1=COC2=C(C=CC(O)=C2)C1=O',
#   None,
#   'C10208',
#   None,
#   'Isoflavonoids',
#   'Isoflav-2-enes',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003325': ('936.921',
#   'C45H52N4O18',
#   'Bilirubin diglucuronide',
#   '[H]\\C(C1=C(C)C(CCC(=O)O[C@]2([H])O[C@]([H])(C(O)=O)[C@@]([H])(O)[C@]([H])(O)[C@@]2([H])O)=C(CC2=C(CCC(=O)O[C@]3([H])O[C@]([H])(C(O)=O)[C@@]([H])(O)[C@]([H])(O)[C@@]3([H])O)C(C)=C(N2)C(\\[H])=C2/N=C(O)C(C)=C2C=C)N1)=C1/N=C(O)C(C=C)=C1C',
#   None,
#   None,
#   'map00860',
#   'Tetrapyrroles and derivatives',
#   'Bilirubins',
#   'Aromatic heteromonocyclic compounds'),
#  'HMDB0003331': ('281.2679',
#   'C11H15N5O4',
#   '1-Methyladenosine',
#   'CN1C=NC2=C(N=CN2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)C1=N',
#   '6888',
#   'C02494',
#   'map00860',
#   'Purine nucleosides',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003332': ('264.252',
#   'C9H12O7S',
#   '3-Methoxy-4-Hydroxyphenylglycol sulfate',
#   'COC1=C(O)C=CC(=C1)C(CO)OS(O)(=O)=O',
#   '6889',
#   None,
#   'map00860',
#   'Phenols',
#   'Methoxyphenols',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003333': ('283.2407',
#   'C10H13N5O5',
#   '8-Hydroxy-deoxyguanosine',
#   'NC1=NC2=C(N=C(O)N2[C@H]2C[C@H](O)[C@@H](CO)O2)C(=O)N1',
#   '6890',
#   None,
#   'map00860',
#   'Purine nucleosides',
#   "Purine 2'-deoxyribonucleosides",
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003334': ('202.2541',
#   'C8H18N4O2',
#   'Symmetric dimethylarginine',
#   'CN\\C(NCCC[C@H](N)C(O)=O)=N/C',
#   '6891',
#   None,
#   'map00860',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003337': ('612.631',
#   'C20H32N6O12S2',
#   'Oxidized glutathione',
#   'NC(CCC(=O)NC(CSSCC(NC(=O)CCC(N)C(O)=O)C(=O)NCC(O)=O)C(=O)NCC(O)=O)C(O)=O',
#   '6893',
#   'C00127',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003338': ('33.0299',
#   'H3NO',
#   'Hydroxylamine',
#   'NO',
#   '6894',
#   'C00192',
#   None,
#   'Homogeneous other non-metal compounds',
#   None,
#   None),
#  'HMDB0003339': ('147.1293',
#   'C5H9NO4',
#   'D-Glutamic acid',
#   'N[C@H](CCC(O)=O)C(O)=O',
#   '6895',
#   'C00217',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003352': ('156.269',
#   'C10H20O',
#   'Menthol',
#   'CC(C)[C@@H]1CC[C@@H](C)C[C@H]1O',
#   None,
#   'C00400',
#   None,
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003355': ('117.1463',
#   'C5H11NO2',
#   '5-Aminopentanoic acid',
#   'NCCCCC(O)=O',
#   '6902',
#   'C00431',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003357': ('174.1977',
#   'C7H14N2O3',
#   'N-Acetylornithine',
#   'CC(=O)N[C@@H](CCCN)C(O)=O',
#   None,
#   'C00437',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003374': ('132.161',
#   'C5H12N2O2',
#   'D-Ornithine',
#   'NCCC[C@@H](N)C(O)=O',
#   '6910',
#   'C00515',
#   'map00472',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003375': ('136.234',
#   'C10H16',
#   'D-Limonene',
#   'CC(=C)[C@H]1CCC(C)=CC1',
#   '6911',
#   'C00521',
#   'map00472',
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003378': ('30.0061',
#   'NO',
#   'Nitric oxide',
#   '[N]=O',
#   '6912',
#   'C00533',
#   None,
#   'Other non-metal organides',
#   'Other non-metal oxides',
#   None),
#  'HMDB0003406': ('105.0926',
#   'C3H7NO3',
#   'D-Serine',
#   'N[C@H](CO)C(O)=O',
#   '6920',
#   'C00740',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003409': ('336.3612',
#   'C20H18NO4',
#   'Berberine',
#   'COC1=CC=C2C=C3C4=CC5=C(OCO5)C=C4CC[N+]3=CC2=C1OC',
#   '3471',
#   'C00757',
#   None,
#   'Protoberberine alkaloids and derivatives',
#   None,
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003415': ('568.886',
#   'C40H56O2',
#   "(3R,3'S,6'R)-b,e-Carotene-3,3'-diol",
#   'C\\C(\\C=C\\C=C(/C)\\C=C\\[C@H]1C(C)=C[C@@H](O)CC1(C)C)=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)C[C@@H](O)CC1(C)C',
#   None,
#   None,
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003429': ('1330.378',
#   'C62H89CoN13O14P',
#   'Cob(I)alamin',
#   '[H][C@]12[C@H](CC(N)=O)[C@@]3(C)CCC(=O)NC[C@@H](C)OP(O)(=O)O[C@@H]4[C@@H](CO)O[C@@H]([C@@H]4O)N4C=[N+](C5=CC(C)=C(C)C=C45)[Co-4]456N1C3=C(C)C1=[N+]4C(=CC3=[N+]5C(=C(C)C4=[N+]6[C@]2(C)[C@@](C)(CC(N)=O)[C@@H]4CCC(N)=O)[C@@](C)(CC(N)=O)[C@@H]3CCC(N)=O)C(C)(C)[C@@H]1CCC(N)=O',
#   None,
#   'C00853',
#   None,
#   'Tetrapyrroles and derivatives',
#   'Corrinoids',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003448': ('566.8556',
#   'C40H54O2',
#   "3-Hydroxy-b,e-caroten-3'-one",
#   'C\\C(\\C=C\\C=C(/C)\\C=C\\C1C(C)=CC(=O)CC1(C)C)=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CC(O)CC1(C)C',
#   None,
#   None,
#   None,
#   'Prenol lipids',
#   'Tetraterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003458': ('1636.69',
#   'C72H105CoN16O20PS',
#   'Aquacobalamin',
#   '[N+]12=C3C(C(C)(C1=C(C1=[N+]4C(C(CC(N)=O)(C)C1CCC(N)=O)(C)C1N5C6=C(C7=[N+](C(=C3)C(C)(C)C7CCC(N)=O)[Co-3]245(SCC(NC(CCC(C(=O)O)N)=O)C(=O)NCC(O)=O)[N+]2=CN(C3C(C(C(CO)O3)OP(O)(OC(C)CNC(=O)CCC6(C)C1CC(N)=O)=O)O)C1=CC(=C(C=C21)C)C)C)C)CC(N)=O)CCC(N)=O',
#   None,
#   'C00992',
#   None,
#   'Tetrapyrroles and derivatives',
#   'Corrinoids',
#   None),
#  'HMDB0003464': ('145.1597',
#   'C5H11N3O2',
#   '4-Guanidinobutanoic acid',
#   'NC(N)=NCCCC(O)=O',
#   '6938',
#   'C01035',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003466': ('178.14',
#   'C6H10O6',
#   'L-Gulonolactone',
#   '[H][C@@]1(OC(=O)[C@@H](O)[C@H]1O)[C@@H](O)CO',
#   None,
#   'C01040',
#   None,
#   'Lactones',
#   'Gamma butyrolactones',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003474': ('432.9816',
#   'C9H9I2NO3',
#   '3,5-Diiodo-L-tyrosine',
#   '[H][C@](N)(CC1=CC(I)=C(O)C(I)=C1)C(O)=O',
#   '6940',
#   'C01060',
#   'map00350',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003502': ('660.0353',
#   'C6H18O24P6',
#   'Myo-inositol hexakisphosphate',
#   'OP(O)(=O)OC1C(OP(O)(O)=O)C(OP(O)(O)=O)C(OP(O)(O)=O)C(OP(O)(O)=O)C1OP(O)(O)=O',
#   '6941',
#   'C01204',
#   'map00562',
#   'Organooxygen compounds',
#   'Alcohols and polyols',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003503': ('198.1727',
#   'C9H10O5',
#   '3-(3,4-Dihydroxyphenyl)lactic acid',
#   'OC(CC1=CC(O)=C(O)C=C1)C(O)=O',
#   '6942',
#   'C01207',
#   'map00562',
#   'Phenylpropanoic acids',
#   None,
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003514': ('340.1157',
#   'C6H14O12P2',
#   'Alpha-D-Glucose 1,6-bisphosphate',
#   'O[C@H]1[C@H](O)[C@@H](COP(O)(O)=O)O[C@H](OP(O)(O)=O)[C@@H]1O',
#   None,
#   'C01231',
#   None,
#   'Organooxygen compounds',
#   'Carbohydrates and carbohydrate conjugates',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003550': ('400.6371',
#   'C27H44O2',
#   'Calcidiol',
#   'C[C@H](CCCC(C)(C)O)[C@@]1([H])CC[C@@]2([H])\\C(CCC[C@]12C)=C\\C=C1\\C[C@@H](O)CCC1=C',
#   '6949',
#   'C01561',
#   None,
#   'Steroids and steroid derivatives',
#   'Vitamin D and derivatives',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003555': ('450.6957',
#   'C31H46O2',
#   'Vitamin K1',
#   'CC(C)CCCC(C)CCCC(C)CCC\\C(C)=C\\CC1=C(C)C(=O)C2=CC=CC=C2C1=O',
#   '6952',
#   'C02059',
#   None,
#   'Prenol lipids',
#   'Quinone and hydroquinone lipids',
#   'Aromatic homopolycyclic compounds'),
#  'HMDB0003572': ('360.3148',
#   'C18H16O8',
#   'Rosmarinic acid',
#   'OC(=O)[C@@H](CC1=CC(O)=C(O)C=C1)OC(=O)\\C=C\\C1=CC(O)=C(O)C=C1',
#   '6960',
#   'C01850',
#   None,
#   'Cinnamic acids and derivatives',
#   'Hydroxycinnamic acids and derivatives',
#   'Aromatic homomonocyclic compounds'),
#  'HMDB0003573': ('303.3529',
#   'C17H21NO4',
#   'Scopolamine',
#   'CN1[C@H]2C[C@@H](C[C@@H]1[C@H]1O[C@@H]21)OC(=O)[C@H](CO)C1=CC=CC=C1',
#   '3433',
#   'C01851',
#   None,
#   'Hydroxy acids and derivatives',
#   'Beta hydroxy acids and derivatives',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003584': ('167.187',
#   'C3H9N3O3S',
#   'Taurocyamine',
#   'NC(N)=NCCS(O)(=O)=O',
#   '6962',
#   'C01959',
#   None,
#   'Organic sulfonic acids and derivatives',
#   'Organosulfonic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003598': ('302.451',
#   'C20H30O2',
#   'Retinyl ester',
#   'CC1CCCC(C)(C)C1\\C=C\\C(\\C)=C\\C=C\\C(\\C)=C\\C(O)=O',
#   '6966',
#   'C02075',
#   None,
#   'Prenol lipids',
#   'Retinoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003625': ('200.59',
#   'Hg',
#   'Mercury',
#   '[Hg++]',
#   None,
#   'C00703',
#   None,
#   'Homogeneous transition metal compounds',
#   None,
#   None),
#  'HMDB0003634': ('152.237',
#   'C10H16O',
#   'Perillyl alcohol',
#   'CC(=C)C1CCC(CO)=CC1',
#   '6969',
#   'C02452',
#   None,
#   'Prenol lipids',
#   'Monoterpenoids',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003638': ('112.411',
#   'Cd',
#   'Cadmium',
#   '[Cd++]',
#   None,
#   'C01413',
#   None,
#   'Homogeneous transition metal compounds',
#   None,
#   None),
#  'HMDB0003640': ('131.1729',
#   'C6H13NO2',
#   'Beta-Leucine',
#   'CC(C)[C@@H](N)CC(O)=O',
#   None,
#   'C02486',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003642': ('87.62',
#   'Sr',
#   'Strontium',
#   '[Sr++]',
#   None,
#   'C13884',
#   None,
#   'Homogeneous alkaline earth metal compounds',
#   None,
#   None),
#  'HMDB0003646': ('114.1026',
#   'C4H6N2O2',
#   'N-Methylhydantoin',
#   'CN1CC(=O)NC1=O',
#   None,
#   'C02565',
#   None,
#   'Azolines',
#   'Imidazolines',
#   'Aliphatic heteromonocyclic compounds'),
#  'HMDB0003648': ('524.8604',
#   'C36H60O2',
#   'Retinyl palmitate',
#   'CCCCCCCCCCCCCCCC(=O)OC\\C=C(/C)\\C=C\\C=C(/C)\\C=C\\C1=C(C)CCCC1(C)C',
#   '6970',
#   'C02588',
#   None,
#   'Fatty Acyls',
#   'Fatty acid esters',
#   'Aliphatic homomonocyclic compounds'),
#  'HMDB0003681': ('145.1564',
#   'C6H11NO3',
#   '4-Acetamidobutanoic acid',
#   'CC(=O)NCCCC(O)=O',
#   None,
#   'C02946',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003733': ('376.4865',
#   'C22H32O5',
#   'Resolvin D1',
#   'CC\\C=C/C[C@H](O)\\C=C\\C=C/C=C/C=C/C(O)[C@@H](O)C\\C=C/CCC(O)=O',
#   None,
#   None,
#   None,
#   'Fatty Acyls',
#   'Fatty acids and conjugates',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003759': ('316.4776',
#   'C21H32O2',
#   '5a-Pregnane-3,20-dione',
#   '[H][C@@]12CC[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC[C@@]2([H])CC(=O)CC[C@]12C',
#   '6981',
#   'C03681',
#   'map00140',
#   'Steroids and steroid derivatives',
#   'Pregnane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003771': ('116.1152',
#   'C5H8O3',
#   '2-Methylacetoacetic acid',
#   'CC(C(C)=O)C(O)=O',
#   None,
#   None,
#   'map00140',
#   'Keto acids and derivatives',
#   'Short-chain keto acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003797': ('280.4455',
#   'C18H32O2',
#   'Bovinic acid',
#   'CCCCCC\\C=C\\C=C/CCCCCCCC(O)=O',
#   None,
#   'C04056',
#   'map00140',
#   'Fatty Acyls',
#   'Lineolic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003869': ('275.3015',
#   'C11H21N3O5',
#   'Epsilon-(gamma-Glutamyl)-lysine',
#   'N[C@@H](CCCCNC(=O)CC[C@H](N)C(O)=O)C(O)=O',
#   None,
#   None,
#   'map00140',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003871': ('312.4443',
#   'C18H32O4',
#   '13-L-Hydroperoxylinoleic acid',
#   'CCCCC[C@H](OO)\\C=C\\C=C/CCCCCCCC(O)=O',
#   None,
#   'C04717',
#   'map00140',
#   'Fatty Acyls',
#   'Lineolic acids and derivatives',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003876': ('320.4663',
#   'C20H32O3',
#   '15(S)-HETE',
#   'CCCCC[C@H](O)\\C=C\\C=C/C\\C=C/C\\C=C/CCCC(O)=O',
#   None,
#   'C04742',
#   None,
#   'Fatty Acyls',
#   'Eicosanoids',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003911': ('103.1198',
#   'C4H9NO2',
#   '3-Aminoisobutanoic acid',
#   'CC(CN)C(O)=O',
#   '5472',
#   'C05145',
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  'HMDB0003933': ('378.4261',
#   'C17H26N6O4',
#   'Pentosidine',
#   'N[C@@H](CCCCN1C=CC=C2N=C(NCCC[C@H](N)C(O)=O)N=C12)C(O)=O',
#   None,
#   None,
#   None,
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aromatic heteropolycyclic compounds'),
#  'HMDB0003955': ('302.4079',
#   'C19H26O3',
#   '19-Hydroxyandrost-4-ene-3,17-dione',
#   '[H][C@@]12CCC(=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12CO',
#   '6990',
#   'C05290',
#   None,
#   'Steroids and steroid derivatives',
#   'Androstane steroids',
#   'Aliphatic homopolycyclic compounds'),
#  'HMDB0003966': ('196.11',
#   'C5H11NO2Se',
#   'Selenomethionine',
#   'C[Se]CCC(N)C(O)=O',
#   '6993',
#   'C05335',
#   'map00450',
#   'Carboxylic acids and derivatives',
#   'Amino acids, peptides, and analogues',
#   'Aliphatic acyclic compounds'),
#  ...}

# %%
for peak in peakinfolist_positive:
    print(peak.cid)
    print([p[3] for p in peak.adducts])
# Out:
# 256
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-27df222bb31a> in <module>
#       1 for peak in peakinfolist_positive:
#       2     print(peak.cid)
# ----> 3     print([p[3] for p in peak.adducts])
#       4
#
# <ipython-input-69-27df222bb31a> in <listcomp>(.0)
#       1 for peak in peakinfolist_positive:
#       2     print(peak.cid)
# ----> 3     print([p[3] for p in peak.adducts])
#       4
#
# IndexError: tuple index out of range

# %%
file = open(osp+'positive_mode/samples_including_tryps/peaksspecific.txt', 'w')
for peak in peakinfolist_positive:
    
    file.write(str(peak.mz) +'\t' + str(peak.rt) +'\t' +
               str(peak.cid)+'\t' + str(peak.std_annotation) + '\n')
file.close()

# %%
file = open(osp+'positive_mode/samples/peaks.txt', 'w')
for peak in peakinfolist_positive:
    
    file.write(str(peak.mz) +'\t' + str(peak.rt) +'\t' + str(peak.pval) +'\t' + str(peak.logfc) +'\t' +
               str(peak.cid)+'\t' + str(peak.std_annotation) + '\n')
file.close()

# %% [markdown]
# ## Filter out data with no spectra

# %%
sys.path.append("/Users/anamaria/git/pymzm_mine")
#from mass_spec_utils.data_processing.alignment import JoinAligner
from alignment import JoinAligner
with open(os.path.join(osp,'pymz/mzmine/aligner_gp.txt'), 'rb') as file:
    aligner_gp = pickle.load(file)

# %%
sys.path.append("/Users/anamaria/git/pymzm_mine")
from alignment import JoinAligner
with open(os.path.join(osp,'negative_mode/aligner_gp.txt'), 'rb') as file:
    aligner_gp = pickle.load(file)

# %%
for i in aligner_gp:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-e7ef2f7877f5> in <module>
# ----> 1 for i in aligner_gp:
#       2     print(i)
#
# TypeError: 'JoinAligner' object is not iterable

# %% [markdown]
# ## Create the peakInfo object

# %%
with open(osp+'Metabolomics_datasets/standards_list.dict', 'rb') as file:
    standards_dict = pickle.load(file)
file = open(osp+'positive_mode/annotations_3ppm.txt', 'w')
for peak in peakinfolist_positive:
    peak.add_adduct_list()
    peak.add_std_match(standards_dict, metabolites)
    
        
    file.write(str(peak.cid)+'\t'+str(peak.std_annotation)+'\n')
file.close()

# %%
ms2_files = osp+ 'Metabolomics_datasets/hmdb_experimental_msms_spectra/'

i=0
for peak in peakinfolist_negative:
    if peak.pval != 0:
        peak.add_spectra(aligner_gp)
        peak.add_adducts(metabolites, ms2_files, positive = False)
        peak.add_ms2_match(metabolites)
        i+=1
        if (i%100 == 0):
            print("Done: {} peaks".format(i))
# Out:
# Done: 100 peaks
# Done: 200 peaks
# Done: 300 peaks
# Done: 400 peaks

# %%
ms2_files = osp+ 'Metabolomics_datasets/hmdb_experimental_msms_spectra/'

i=0
for peak in peakinfolist_positive:
   
    peak.add_spectra(aligner_gp)
    peak.add_adducts(metabolites, ms2_files)
    peak.add_ms2_match(metabolites)
    i+=1
    if (i%100 == 0):
        print("Done: {} peaks".format(i))

# %%
with open(osp+'positive_mode/peakinfolist.dict', 'wb') as handle:
    pickle.dump(peakinfolist_positive, handle)

# %%
print((peakinfolist_negative[1].best_ms2_match_adduct).score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ef38b8eb6eb1> in <module>
# ----> 1 print((peakinfolist_negative[1].best_ms2_match_adduct).score)
#
# AttributeError: 'str' object has no attribute 'score'

# %%
for peak in peakinfolist_negative:
    if peak.best_ms2_match_adduct:
        print(peak.best_ms2_match_adduct.hmdb)
# Out:
# HMDB0000050
# HMDB0002124
# HMDB0000145
# HMDB0002111
# HMDB0000929
# HMDB0000684
# HMDB0000187
# HMDB0002755
# HMDB0000732
# HMDB0000076
# HMDB0001314
# HMDB0004101
# HMDB0001389
# HMDB0000043
# HMDB0000043
# HMDB0000043
# HMDB0003164
# HMDB0014704
# HMDB0000306
# HMDB0001522
# HMDB0000002
# HMDB0001406
# HMDB0000087
# HMDB0000182
# HMDB0000070
# HMDB0000696
# HMDB0000026
# HMDB0000191
# HMDB0000020
# HMDB0002670
# HMDB0000077
# HMDB0001488
# HMDB0001522
# HMDB0001522
# HMDB0000148
# HMDB0000251
# HMDB0000121
# HMDB0000076
# HMDB0000076
# HMDB0000076
# HMDB0000076
# HMDB0000177
# HMDB0000517
# HMDB0000157
# HMDB0000462
# HMDB0000162
# HMDB0000262
# HMDB0000017
# HMDB0001406
# HMDB0001406
# HMDB0000262
# HMDB0000262
# HMDB0000262
# HMDB0000197
# HMDB0003164
# HMDB0000026
# HMDB0000191
# HMDB0000167
# HMDB0000462
# HMDB0000462
# HMDB0000034
# HMDB0000157
# HMDB0000157
# HMDB0000182
# HMDB0000929
# HMDB0000965
# HMDB0000020
# HMDB0000020
# HMDB0000152
# HMDB0001522
# HMDB0000517
# HMDB0000251
# HMDB0000732
# HMDB0000763
# HMDB0001389
# HMDB0000965
# HMDB0000099
# HMDB0000201
# HMDB0000201
# HMDB0000296
# HMDB0000206
# HMDB0000671
# HMDB0000014
# HMDB0000014
# HMDB0000076
# HMDB0014742
# HMDB0000206
# HMDB0000792
# HMDB0000201
# HMDB0000273
# HMDB0000273
# HMDB0000181
# HMDB0000030
# HMDB0000732
# HMDB0000262
# HMDB0000684
# HMDB0000151
# HMDB0000197
# HMDB0000187
# HMDB0000273
# HMDB0000273
# HMDB0000026
# HMDB0000026
# HMDB0000030
# HMDB0000099
# HMDB0000099
# HMDB0001389
# HMDB0000732
# HMDB0000077
# HMDB0000077
# HMDB0014704
# HMDB0001232
# HMDB0014884
# HMDB0000731
# HMDB0000792
# HMDB0000269
# HMDB0000671
# HMDB0015102
# HMDB0001555
# HMDB0001830
# HMDB0000017
# HMDB0000696
# HMDB0000210
# HMDB0014351
# HMDB0000016
# HMDB0000016
# HMDB0000191
# HMDB0000077
# HMDB0000965
# HMDB0015363
# HMDB0014773
# HMDB0014387
# HMDB0000016
# HMDB0014630
# HMDB0000015
# HMDB0000016
# HMDB0000201
# HMDB0000929
# HMDB0014801
# HMDB0014350
# HMDB0014538
# HMDB0014635
# HMDB0014884
# HMDB0015298
# HMDB0014363
# HMDB0013854
# HMDB0000002
# HMDB0000792
# HMDB0000792
# HMDB0015151
# HMDB0015151

# %%
with open(osp+'negative_mode/peakinfolist.dict', 'wb') as handle:
    pickle.dump(peakinfolist_negative, handle)

# %%
with open(osp+'negative_mode/peakinfolist.dict', 'rb') as file:
    peakinfolist_negative = pickle.load(file)

# %%
file = open(osp+'negative_mode/ms2annot.txt', 'w')
for peak in peakinfolist_negative:
    if peak.pval != 0:
        file.write(str(peak.cid)+
                  '\t'+str(peak.ms2_annotation)+'\n')
        
file.close()

# %% [markdown]
# ### Determining optimal cut-off score (cosine similarity)

# %%
scores = []
for peak in peakinfolist:
    if peak.best_ms2_match_adduct:
        scores.append(peak.best_ms2_match_adduct.score)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(scores)
plt.title('Distribution of scores')
# Out:
# Text(0.5, 1.0, 'Distribution of scores')

# %%
#TODO: also need to take into account the isomers, so need to calculate the formula
good_scores = []
bad_scores = []
minim = 1
for peak in peakinfolist:
    standards_kegg = peak.std_kegg_id
    if peak.best_ms2_match_adduct:
        ms2match = peak.best_ms2_match_adduct
        ms2match_kegg = metabolites[peak.best_ms2_match_adduct.hmdb][5]
    
    #get the scores for metabolites matching the standards annotation
        if standards_kegg == ms2match_kegg:
                    if ms2match.score < minim:
                        minim = ms2match.score
                    good_scores.append(ms2match.score)

                #get the scores for metabolites not matching with the standards annotation
        if standards_kegg != None:

                    if ms2match_kegg != standards_kegg:
                        #print(standards,i, name, score)
                        
                            bad_scores.append(ms2match.score)

        
print('Lowest score value for which the HMDB annotation matches with the ToxID annotation:',minim)
# Out:
# Lowest score value for which the HMDB annotation matches with the ToxID annotation: 0.27664475373310216

# %%
sns.distplot(good_scores)
plt.title('Distribution of good scores')
# Out:
# Text(0.5, 1.0, 'Distribution of good scores')

# %%
sns.distplot(bad_scores)
plt.title('Distribution of bad scores')
# Out:
# Text(0.5, 1.0, 'Distribution of bad scores')

# %%
def plot_mirror(normalised_peaks_top, normalised_peaks_bottom):
    
    import matplotlib.pyplot as plt
    fig, axs = plt.subplots(2, sharex=True, sharey=False, gridspec_kw={'hspace': 0})

    for mz,intensity in normalised_peaks_top:
        axs[0].plot([mz,mz], [0,intensity], 'k', color = 'r')
        axs[0].set_ylabel("Aligner Spectrum")
        
    
    for mz,intensity in normalised_peaks_bottom:
        axs[1].plot([mz,mz],[0,-intensity],'k', color = 'b')
        axs[1].set_ylabel("HMDB Spectrum")
   
    # Hide x labels and tick labels for all but bottom plot.
    for ax in axs:
        ax.label_outer()
        xticks = ax.xaxis.get_major_ticks()
        xticks[0].label1.set_visible(False)
    plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
for peak in peakinfolist_positive:
    
    if peak.pval!=0:
        
        if peak.spectra:

            spectra = peak.spectra
            
            num_spec = len(spectra)
            
            if num_spec > 1:
                
                
                print(peak.cid, peak.std_annotation, peak.std_kegg_id, peak.mz, peak.pval, peak.logfc)
                print(peak.mm_annotation, peak.mm_kegg_id)
                print(spectra)
        
                for i in range(num_spec-1):
                    
                    

                    plot_mirror(spectra[list(spectra.keys())[i]].normalised_peaks, 
                                spectra[list(spectra.keys())[i+1]].normalised_peaks)
                    
                    plt.show()
                print('----')
# Out:
# 613 l-glutamine C00064 147.07640748274954 9.50855356149344e-10 -2.63034608332642
# ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine'] C00906
# {'frag_pos_mal': <mnet.Spectrum object at 0x12adbb940>, 'gnps2': <mnet.Spectrum object at 0x12adbba00>}
# ----
# 2989   810.6000113236278 2.21432944268004e-09 -1.7812251168870903
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12afebb80>, 'gnps2': <mnet.Spectrum object at 0x12afebc40>}
# ----
# 2936   782.5687384354442 3.0424836229794397e-09 -1.79450144331877
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12afe4790>, 'gnps2': <mnet.Spectrum object at 0x12afe4850>}
# ----
# 324 taurine C00245 126.0219806871916 3.3695815034334397e-09 -1.04710511580883
# ['taurine'] C00245
# {'frag_pos_mal': <mnet.Spectrum object at 0x12b21f3d0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12b21f490>}
# ----
# 2720   520.3400409096166 1.9553429860501102e-07 -1.8785086352406397
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12e5fac40>, 'gnps2': <mnet.Spectrum object at 0x12e5fad00>}
# ----
# 1993 sn-glycero-3-phosphocholine  258.1100018149928 5.17135144550214e-07 -1.2072506071780602
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x1267044c0>, 'gnps2': <mnet.Spectrum object at 0x126704580>}
# ----
# 2942   786.6000470613177 8.868938122079821e-07 -0.810224881721162
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12674a250>, 'gnps2': <mnet.Spectrum object at 0x12674a310>}
# ----
# 1839 l-cystine C00491 241.03100315217048 1.06985459550148e-05 -7.814946930091041
# ['l-cystine; l-dicysteine; l-alpha-diamino-beta-dithiolactic acid'] C00491
# {'frag_pos_mal': <mnet.Spectrum object at 0x126898820>, 'gnps2': <mnet.Spectrum object at 0x1268988e0>}
# ----
# 366 5-oxoproline  130.04995717500387 1.69222685515447e-05 -0.649141706140043
# ['5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate$5-oxo-l-proline', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde'] C00217;C00025;C05938
# {'frag_pos_mal': <mnet.Spectrum object at 0x126a980a0>, 'frag_pos_vl': <mnet.Spectrum object at 0x126a98160>}
# ----
# 2664   468.30843577665433 2.1023052578718697e-05 -7.16605473174531
# ['timnodonyl carnitine'] tmndnccrn
# {'frag_pos_mal': <mnet.Spectrum object at 0x126a98e50>, 'frag_pos_vl': <mnet.Spectrum object at 0x126a98f10>, 'gnps2': <mnet.Spectrum object at 0x126a98fd0>}
# ----
# 2151   279.15896526135896 0.000116820233690096 -0.6153697696145001
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x126c5ca90>, 'gnps2': <mnet.Spectrum object at 0x126c5cb50>}
# ----
# 667 l-methionine C00073 150.05838434319747 0.000130149780322985 -1.65735553998747
# ['l-methionine'] C00073
# {'frag_pos_mal': <mnet.Spectrum object at 0x126dc6df0>, 'gnps2': <mnet.Spectrum object at 0x126dc6eb0>}
# ----
# 1100   181.0720427293044 0.000303128645819538 -6.5173316425727705
# ['1,7-dimethylxanthine; paraxanthine$'] C13747;C07480
# {'frag_pos_mal': <mnet.Spectrum object at 0x126f23820>, 'frag_pos_vl': <mnet.Spectrum object at 0x126f238e0>, 'gnps2': <mnet.Spectrum object at 0x126f239a0>}
# ----
# 264   120.0808048248291 0.00040734256784672097 0.43672795603462705
# ['l-phenylalanine$', 'tyramine$n,n-dimethylaniline n-oxide$phenylethanolamine; 2-amino-1-phenylethanol'] C00483;C01183;C02735
# {'frag_pos_vl': <mnet.Spectrum object at 0x1270bd700>, 'gnps2': <mnet.Spectrum object at 0x1270bd7c0>}
# ----
# 1401   203.05238235473632 0.00134388723281376 7.995276342107531
# ['d-glucose$beta-d-glucose$l-sorbose; l-xylo-hexulose$beta-d-fructose; beta-fruit sugar; beta-d-arabino-hexulose; beta-levulose; fructose$alpha-d-glucose$d-hexose$$d-fructose$beta-d-galactose$galactose$d-tagatose; lyxo-hexulose$myo-inositol$glucose$d-galactose$alpha-d-galactose$d-mannose'] C00031;C00221;C00247;C02336;C00267;C00738;C00936;C00095;C00962;C01582;C00795;C00137;C00293;C00124;C00984;C00159
# {'frag_pos_mal': <mnet.Spectrum object at 0x127485340>, 'frag_pos_vl': <mnet.Spectrum object at 0x127485400>}
# ----
# 298 nicotinamide  123.05528043445787 0.00137782275567553 -0.5728940387899039
# ['nicotinamide', '3-methylimidazoleacetic acid'] C05828
# {'frag_pos_mal': <mnet.Spectrum object at 0x1274e7d60>, 'gnps2': <mnet.Spectrum object at 0x1274e7e20>}
# ----
# 1229   190.08622629502239 0.00163639633924719 -4.750123753699389
# ['methyl indole-3-acetate'] CE2122
# {'frag_pos_mal': <mnet.Spectrum object at 0x127605fa0>, 'gnps2': <mnet.Spectrum object at 0x1276130a0>}
# ----
# 2234   288.2168204171317 0.00175192263304081 -4.42697382769785
# ['l-octanoylcarnitine'] C02838
# {'frag_pos_vl': <mnet.Spectrum object at 0x12762d700>, 'gnps2': <mnet.Spectrum object at 0x12762d7c0>}
# ----
# 1089   180.15944360431868 0.00219386100888766 0.560347284001462
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1277f9280>, 'gnps2': <mnet.Spectrum object at 0x1277f9340>}
# ----
# 2744   544.3396243533573 0.00383774666542568 -3.06113272483078
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x127975610>, 'gnps2': <mnet.Spectrum object at 0x1279756d0>}
# ----
# 424 glycylglycine  133.06076973362974 0.00411699896895725 -0.563278369095048
# ['n-carbamoyl-beta-alanine$l-asparagine'] C02642;C00152
# {'frag_pos_mal': <mnet.Spectrum object at 0x1279a9250>, 'frag_pos_vl': <mnet.Spectrum object at 0x1279a9310>}
# ----
# 599   146.08119874251517 0.0060061446619100395 0.516617388800999
# ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde'] C03239;C02946;C04076
# {'frag_pos_mal': <mnet.Spectrum object at 0x127abfd60>, 'frag_pos_vl': <mnet.Spectrum object at 0x127abfe20>}
# ----
# 4109   287.0999953746796 0.00605037574182198 -5.28264613797675
# ['alpha-n-phenylacetyl-l-glutamine$formyl-n-acetyl-5-methoxykynurenamine'] C04148;C05642
# {'frag_pos_mal': <mnet.Spectrum object at 0x127ad3b50>, 'gnps2': <mnet.Spectrum object at 0x127ad3c10>}
# ----
# 2351   310.20132788296405 0.00975833749417887 -4.70924553640043
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x127daec70>, 'gnps2': <mnet.Spectrum object at 0x127daed30>}
# ----
# 1033   176.07068128988774 0.0107514502058185 -3.11055939780338
# ['indole-3-acetate$5-hydroxyindoleacetaldehyde', '4-hydroxy-5-phenyltetrahydro-1,3-oxazin-2-one$3-carbamoyl-2-phenylpropionaldehyde'] C16595;C16587
# {'frag_pos_mal': <mnet.Spectrum object at 0x127e47280>, 'gnps2': <mnet.Spectrum object at 0x127e47340>}
# ----
# 2799   614.5354108418503 0.0149868682874702 -2.7421054758399
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x127f4f9d0>, 'gnps2': <mnet.Spectrum object at 0x127f4fa90>}
# ----
# 1439 l-tryptophan C00078 205.09726213154042 0.0198232026249283 -0.31578520256663
# ['l-tryptophan$d-tryptophan'] C00078;C00525
# {'frag_pos_mal': <mnet.Spectrum object at 0x128083d30>, 'frag_pos_vl': <mnet.Spectrum object at 0x128083df0>, 'gnps2': <mnet.Spectrum object at 0x128083eb0>}
# ----
# 122   104.07060181467155 0.045180604519689 0.206239508030393
# ['(s)-2-aminobutanoate; (s)-2-aminobutanoic acid; (s)-2-aminobutyric acid$n,n-dimethylglycine; dimethylglycine$4-aminobutanoate$3-aminoisobutyric acid; 3-aminoisobutanoate; 3-amino-2-methylpropanoate$d-3-amino-isobutanoate$l-3-amino-isobutanoate'] C02356;C01026;C00334;C05145;C01205;C03284
# {'frag_pos_vl': <mnet.Spectrum object at 0x1284c2d30>, 'gnps2': <mnet.Spectrum object at 0x1284c2df0>}
# ----
# 2322   304.24814770672765 0.0493499530162028 -2.2049333714837402
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1284f2070>, 'gnps2': <mnet.Spectrum object at 0x1284f2130>}
# ----
# 5793   128.07060296194894 0.0570773033773801 -2.3045954059073304
# ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'delta1-piperideine-2-carboxylate; 1,2-didehydropiperidine-2-carboxylate$2,3,4,5-tetrahydropyridine-2-carboxylate; delta1-piperideine-6-l-carboxylate'] C04092;C00450
# {'frag_pos_mal': <mnet.Spectrum object at 0x12862be20>, 'frag_pos_vl': <mnet.Spectrum object at 0x12862bee0>, 'gnps2': <mnet.Spectrum object at 0x12862bfa0>}
# ----
# 2824   663.4531615407842 0.0630616682006889 0.40548044037187503
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1286fb550>, 'gnps2': <mnet.Spectrum object at 0x1286fb610>}
# ----
# 2038   265.11811306602084 0.0736694066726246 -0.539121773311887
# ['alpha-n-phenylacetyl-l-glutamine$formyl-n-acetyl-5-methoxykynurenamine'] C04148;C05642
# {'frag_pos_mal': <mnet.Spectrum object at 0x1287b1550>, 'frag_pos_vl': <mnet.Spectrum object at 0x1287b1610>, 'gnps2': <mnet.Spectrum object at 0x1287b16d0>}
# ----
# 1068   178.07238173811402 0.0824982534802742 -1.71359852584277
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x128891c40>, 'frag_pos_vl': <mnet.Spectrum object at 0x128891d00>}
# ----
# 2478   344.22783126831047 0.125059142071159 -2.80522872353989
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x128c109a0>, 'gnps2': <mnet.Spectrum object at 0x128c10a60>}
# ----
# 704   153.06587871752288 0.128378222466171 0.359394555950587
# ["n1-methyl-2-pyridone-5-carboxamide; n'-methyl-2-pyridone-5-carboxamide; 1-methyl-5-carboxylamide-2-pyridone$n1-methyl-4-pyridone-5-carboxamide; n'-methyl-4-pyridone-5-carboxamide; 1-methyl-4-pyridone-3-carboximide"] C05842;C05843
# {'frag_pos_vl': <mnet.Spectrum object at 0x128c366a0>, 'gnps2': <mnet.Spectrum object at 0x128c36760>}
# ----
# 187 creatinine C00791 114.09845822477993 0.154923868219616 -1.18482914610513
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x128f98460>, 'frag_pos_vl': <mnet.Spectrum object at 0x128f98520>}
# ----
# 855   163.10959444547953 0.16039091289363502 0.159511040187969
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x128fbeca0>, 'gnps2': <mnet.Spectrum object at 0x128fbed60>}
# ----
# 2803   619.4907287597656 0.166473945181795 -2.5660177375789397
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x128ff44c0>, 'gnps2': <mnet.Spectrum object at 0x128ff4580>}
# ----
# 2779   592.4934650577911 0.177955177373233 -1.4568025822947
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12904e130>, 'gnps2': <mnet.Spectrum object at 0x12904e1f0>}
# ----
# 1419 o-acetylcarnitine  204.12314158121742 0.182177609989358 -1.2209154477171498
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1290f7850>, 'gnps2': <mnet.Spectrum object at 0x1290f7910>}
# ----
# 3642   180.0655281278822 0.184527382786427 -1.53007627880924
# ['4-(2-aminophenyl)-2,4-dioxobutanoate', 'adrenochrome$hippurate; hippuric acid; n-benzoylglycine; benzoylaminoacetic acid', '3,4-dihydroxy-l-phenylalanine'] C00355
# {'frag_pos_mal': <mnet.Spectrum object at 0x129148640>, 'frag_pos_vl': <mnet.Spectrum object at 0x129148700>}
# ----
# 1544   214.25295069597766 0.18519860890689702 -1.72701757147017
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12917a430>, 'frag_pos_vl': <mnet.Spectrum object at 0x12917a4f0>, 'gnps2': <mnet.Spectrum object at 0x12917a5b0>}
# ----
# 417 l-leucine C00123 132.10193634033206 0.20232800026078798 0.171461238144822
# ['5-acetamidopentanoate', 'l-leucine$l-isoleucine'] C00123;C00407
# {'frag_pos_mal': <mnet.Spectrum object at 0x12927b700>, 'frag_pos_vl': <mnet.Spectrum object at 0x12927b7c0>, 'gnps2': <mnet.Spectrum object at 0x12927b880>}
# ----
# 413   132.0655572221086 0.242164369652775 -1.1084977203776298
# ['l-glutamate 5-semialdehyde; l-glutamate gamma-semialdehyde$trans-4-hydroxy-l-proline$5-aminolevulinate; 5-amino-4-oxopentanoate; 5-amino-4-oxovaleric acid$cis-4-hydroxy-d-proline$5-amino-2-oxopentanoic acid; 5-amino-2-oxopentanoate; 2-oxo-5-amino-pentanoate; 2-oxo-5-aminopentanoate; alpha-keto-delta-aminopentanoate; 2-oxo-5-aminovalerate', '1-pyrroline-5-carboxylate$1-pyrroline-2-carboxylate; 1-pyrroline-2-carboxylic acid; delta1-pyrroline 2-carboxylate', '2-amino-4-oxopentanoic acid; 2-amino-4-oxopentanoate'] C03341
# {'frag_pos_mal': <mnet.Spectrum object at 0x12944ddf0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12944deb0>}
# ----
# 996   173.12855569939862 0.257482906957171 0.15309332083269597
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1294e9460>, 'frag_pos_vl': <mnet.Spectrum object at 0x1294e9520>, 'gnps2': <mnet.Spectrum object at 0x1294e95e0>}
# ----
# 737   156.0768249099319 0.278638899335418 1.3576680670986598
# ['5-guanidino-2-oxopentanoate; 5-guanidino-2-oxo-pentanoate; 2-oxo-5-guanidinopentanoate; 2-oxo-5-guanidino-pentanoate', 'l-histidine'] C00135
# {'frag_pos_mal': <mnet.Spectrum object at 0x12959fa60>, 'gnps2': <mnet.Spectrum object at 0x12959fb20>}
# ----
# 2820   654.331636428833 0.31270496333452896 -1.28423320935186
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x1297b6fd0>, 'gnps2': <mnet.Spectrum object at 0x1297cb0d0>}
# ----
# 49   86.09640022803997 0.327628265285334 2.2426128000308396
# ['n4-acetylaminobutanal$l-pipecolate; pipecolinic acid; pipecolic acid; 2-piperidinecarboxylic acid', 'l-leucine$l-isoleucine'] C00123;C00407
# {'frag_pos_mal': <mnet.Spectrum object at 0x12983c7c0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12983c880>}
# ----
# 2019   262.1436151203356 0.330339114049709 -0.0808118011285011
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12988f520>, 'gnps2': <mnet.Spectrum object at 0x12988f5e0>}
# ----
# 1712   229.15466378864485 0.354503236329369 0.15445863373069502
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x129a05520>, 'gnps2': <mnet.Spectrum object at 0x129a055e0>}
# ----
# 2451   338.3416043599446 0.361302119467052 1.75624155651328
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x129a8ff10>, 'gnps2': <mnet.Spectrum object at 0x129a8ffd0>}
# ----
# 1363   200.02707190262643 0.40991395810203796 -0.079473268388778
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x129d423a0>, 'frag_pos_vl': <mnet.Spectrum object at 0x129d42460>}
# ----
# 2680   482.36055799211766 0.423657679057139 -1.0415021577472299
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x129d92280>, 'gnps2': <mnet.Spectrum object at 0x129d92340>}
# ----
# 125   104.10696566944391 0.447713075053 1.00945547849601
# ['l-leucine$l-isoleucine'] C00123;C00407
# {'frag_pos_mal': <mnet.Spectrum object at 0x129e03af0>, 'gnps2': <mnet.Spectrum object at 0x129e03bb0>}
# ----
# 344   129.06585633127312 0.44811695029555204 0.149806584389648
# ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine', '4-guanidinobutanoate'] C01035
# {'frag_pos_mal': <mnet.Spectrum object at 0x129e10820>, 'frag_pos_vl': <mnet.Spectrum object at 0x129e108e0>}
# ----
# 915 pyridoxal C00250 168.06575625550514 0.46278646129455797 1.6213347296123999
# ['pyridoxal'] C00250
# {'frag_pos_mal': <mnet.Spectrum object at 0x129f64d00>, 'gnps2': <mnet.Spectrum object at 0x129f64dc0>}
# ----
# 1970   256.1654001871745 0.5040128029177671 -0.4651602152526911
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a13a400>, 'gnps2': <mnet.Spectrum object at 0x12a13a4c0>}
# ----
# 254   119.08341081518877 0.513632726379003 0.0880731209142382
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12a36c160>, 'gnps2': <mnet.Spectrum object at 0x12a36c220>}
# ----
# 418   132.1019279078433 0.523123926133732 -0.0352650335794138
# ['5-acetamidopentanoate', 'l-leucine$l-isoleucine'] C00123;C00407
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a3b6eb0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12a3b6f70>}
# ----
# 1901   247.14402987505935 0.531387891678788 -0.484207257558655
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a40ab20>, 'frag_pos_vl': <mnet.Spectrum object at 0x12a40abe0>, 'gnps2': <mnet.Spectrum object at 0x12a40aca0>}
# ----
# 412 5-aminolevulinate  132.06559622915168 0.541031612632117 0.12047423714031401
# ['l-glutamate 5-semialdehyde; l-glutamate gamma-semialdehyde$trans-4-hydroxy-l-proline$5-aminolevulinate; 5-amino-4-oxopentanoate; 5-amino-4-oxovaleric acid$cis-4-hydroxy-d-proline$5-amino-2-oxopentanoic acid; 5-amino-2-oxopentanoate; 2-oxo-5-amino-pentanoate; 2-oxo-5-aminopentanoate; alpha-keto-delta-aminopentanoate; 2-oxo-5-aminovalerate', '2-amino-4-oxopentanoic acid; 2-amino-4-oxopentanoate'] C03341
# {'frag_pos_vl': <mnet.Spectrum object at 0x12a519a30>, 'gnps2': <mnet.Spectrum object at 0x12a519af0>}
# ----
# 848 l-carnitine C00318 162.1124855982114 0.5419641176330751 -0.960372948379021
# ['l-carnitine'] C00318
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a5307c0>, 'gnps2': <mnet.Spectrum object at 0x12a530880>}
# ----
# 10779 n(pi)-methyl-l-histidine  170.0924298604329 0.547709882441706 1.67430956497127
# ['n(pi)-methyl-l-histidine; 1-methylhistidine; n-pros-methyl-l-histidine'] C01152
# {'frag_pos_vl': <mnet.Spectrum object at 0x12a5629d0>, 'gnps2': <mnet.Spectrum object at 0x12a562a90>}
# ----
# 895 l-phenylalanine C00079 166.08632090250651 0.549298729914555 -0.530904801135591
# ['l-phenylalanine$', 'l-normetanephrine$l-adrenaline; (r)-(-)-adrenaline; (r)-(-)-epinephrine; (r)-(-)-epirenamine; (r)-(-)-adnephrine; 4-[(1r)-1-hydroxy-2-(methylamino)ethyl]-1,2-benzenediol'] C05589;C00788
# {'frag_pos_vl': <mnet.Spectrum object at 0x12a5dd310>, 'gnps2': <mnet.Spectrum object at 0x12a5dd3d0>}
# ----
# 239 betaine C00719 118.07718507867109 0.606928261070307 -0.0643126611312113
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a76a8e0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12a76a9a0>}
# ----
# 183 creatinine C00791 114.06623158310398 0.6091047564053511 1.31999040878948
# ['creatine; alpha-methylguanidino acetic acid; methylglycocyamine', 'nan'] C00791
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a78e6d0>, 'frag_pos_vl': <mnet.Spectrum object at 0x12a78e790>, 'gnps2': <mnet.Spectrum object at 0x12a78e850>}
# ----
# 1684   228.12308822852975 0.638860169413339 -0.740976855234432
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12a9281f0>, 'gnps2': <mnet.Spectrum object at 0x12a9282b0>}
# ----
# 2293   300.20143837764346 0.6878075970588289 -0.7667547986143249
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12ab06160>, 'gnps2': <mnet.Spectrum object at 0x12ab06220>}
# ----
# 416 5-aminolevulinate  132.07676277160644 0.7853164680785569 -0.7517655183635229
# ['creatine; alpha-methylguanidino acetic acid; methylglycocyamine', 'nan'] C00791
# {'frag_pos_mal': <mnet.Spectrum object at 0x12ae19e50>, 'gnps2': <mnet.Spectrum object at 0x12ae19f10>}
# ----
# 1150   185.1285421708051 0.8145067431276091 -0.36517998718167605
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12b00a340>, 'frag_pos_vl': <mnet.Spectrum object at 0x12b00a400>, 'gnps2': <mnet.Spectrum object at 0x12b00a4c0>}
# ----
# 6   72.08080402173493 0.8543183874297621 -0.0180060231432506
# ['glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine'] C00719;C00431;C00183
# {'frag_pos_mal': <mnet.Spectrum object at 0x12b198430>, 'frag_pos_vl': <mnet.Spectrum object at 0x12b1984f0>}
# ----
# 1822   239.13897132873532 0.8951320771913521 -0.0142660461151394
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12b2a6e50>, 'frag_pos_vl': <mnet.Spectrum object at 0x12b2a6f10>}
# ----
# 805   159.11286996540267 0.9097919826118991 -0.0102167342489565
#
# {'frag_pos_vl': <mnet.Spectrum object at 0x12d10bdc0>, 'gnps2': <mnet.Spectrum object at 0x12d10be80>}
# ----
# 683   151.09652974870468 0.93636966162983 -0.10568427625881698
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12d164820>, 'gnps2': <mnet.Spectrum object at 0x12d1648e0>}
# ----
# 240 betaine C00719 118.08624432538006 0.9782963174168711 -0.0356890921986768
# ['6-amino-2-oxohexanoate; 2-oxo-6-aminocaproate$4-acetamidobutanoate$l-2-aminoadipate 6-semialdehyde; 2-aminoadipate 6-semialdehyde', 'glycine betaine$5-aminopentanoate; 5-aminopentanoic acid; 5-aminovaleric acid$l-valine', 'l-2-aminoadipate; l-alpha-aminoadipate; l-alpha-aminoadipic acid; l-2-aminoadipic acid; l-2-aminohexanedioate'] C00956
# {'frag_pos_vl': <mnet.Spectrum object at 0x12d212e50>, 'gnps2': <mnet.Spectrum object at 0x12d212f10>}
# ----
# 175 creatinine C00791 114.03404131802642 0.9917762908608689 -0.0293358220104984
#
# {'frag_pos_mal': <mnet.Spectrum object at 0x12d25d220>, 'frag_pos_vl': <mnet.Spectrum object at 0x12d25d2e0>}
# ----

# %%
for peak in peakinfolist:
    peak.add_ms2_match(metabolites, 0.3)
    
peakinfolist.sort(key = lambda peak: peak.pval, reverse = False)

# %%
samples_values_positive = pd.read_csv(osp+'/positive_mode/filtered_samples_nolog_description.csv', index_col = 0)
samples_values_filled_positive = pd.read_csv(osp+'/positive_mode/filtered_samples_nolog_filled_description.csv', index_col = 0)

samples_values_negative = pd.read_csv(osp+'/negative_mode/filtered_samples_log_description.csv', index_col=0)
samples_values_filled_negative = pd.read_csv(osp+'/negative_mode/filtered_samples_log_filled_description.csv', index_col=0)

# %%
samples_values_positive = pd.read_csv(osp+
        '/positive_mode/samples_including_hat/filtered_samples_including_hat_filled_description.csv', index_col = 0)

# %%
peakinfolist_positive.sort(key = lambda peak: peak.pval, reverse = False)
peakinfolist_negative.sort(key = lambda peak: peak.pval, reverse = False)

# %%
kegg_list = []
cid_list = []
for peak in peakinfolist_negative:
    if peak.pval != 0 and peak.pval < 0.05:
        keggs = peak.get_possible_kegg_ids()
        if keggs is not None:
            for kegg in keggs:
                kegg_list.append(kegg)
                cid_list.append(peak.cid)
for peak in peakinfolist_positive:
    if peak.pval != 0 and peak.pval < 0.05:
        keggs = peak.get_possible_kegg_ids()
        if keggs is not None:
            for kegg in keggs:
                kegg_list.append(kegg)
                cid_list.append(peak.cid)
# Out:
# None
# ['C05984' 'C01089' 'C03197' 'C06001' 'C00989']
# None
# None
# None
# ['C04717' 'C14827']
# None
# None
# ['C00064' 'C05100' 'C00819']
# ['C01595']
# ['C00233' 'C06102' 'C03465']
# ['C00418']
# None
# None
# ['C00256' 'C01013' 'C00186' 'C00184']
# ['C00256' 'C01013' 'C00186' 'C00184']
# None
# ['C00064' 'C05100' 'C00819']
# ['C00258']
# None
# None
# ['C06124']
# None
# None
# None
# None
# None
# None
# None
# None
# ['C00245']
# None
# None
# ['C00026']
# ['C00209']
# ['C04555']
# None
# None
# None
# None
# ['C06124']
# None
# ['C00491']
# None
# ['C00141']
# None
# ['C00149']
# None
# None
# None
# ['C00031' 'C00221' 'C00247' 'C02336' 'C00267' 'C00738' 'C00936' 'C00095'
#  'C00962' 'C01582' 'C00795' 'C00137' 'C00293' 'C00124' 'C00984' 'C00159']
# ['C00299']
# ['C00106']
# ['C00065' 'C00740']
# None
# ['CE2122']
# None
# ['C01188']
# None
# None
# None
# ['C01879' 'C04281' 'C04282']
# None
# None
# ['C00079' 'CE2172']
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ['C00079' 'CE2172']
# None
# None
# None
# ['C00073']
# None
# None
# None
# ['C00213' 'C00041' 'C00099' 'C00133']
# None
# ['C00249']
# None
# None
# ['C00037']
# None
# None
# None
# ['C03214' 'C00441' 'C03508']
# ['C00233' 'C06102' 'C03465' 'C00671']
# ['C15517' 'C04483' 'C02528']
# None
# None
# ['C02679']
# None
# None
# None
# ['lneldc' 'ocdcya']
# None
# None
# ['C05660']
# None
# None
# None
# None
# ['C00355']
# None
# ['C00900' 'C06010']
# ['C02642' 'C00152']
# None
# None
# ['C16358' 'C16353']
# None
# ['C00219']
# ['C04555']
# None
# None
# None
# ['C01507' 'C00794' 'C01697']
# ['C00078' 'C00525']
# None
# None
# None
# None
# None
# ['C01530']
# None
# ['C01530']
# ['CE2006' 'CE6506']
# None
# None
# None
# ['C00122']
# None
# None
# None
# None
# None
# ['C00906']
# None
# ['C00259' 'C00309' 'C00312' 'C00310' 'C00121' 'C00181']
# None
# None
# ['C04148' 'C05642']
# ['CE6252']
# ['C00059']
# None
# None
# None
# None
# None
# ['C00123' 'C00407']
# ['C05572' 'C00940']
# None
# None
# None
# None
# None
# None
# None
# None
# ['C03341' 'C01165' 'C01157' 'C00430' 'C03440' 'C01110']
# None
# None
# ['C00059']
# None
# ['C02679']
# None
# None
# None
# ['C00954' 'C05634']
# None
# None
# ['C06424']
# None
# ['C06103']
# None
# ['C00082' 'CE2174']
# ['C05519' 'C00188']
# ['ttdcea']
# ['C01620']
# None
# None
# None
# None
# None
# None
# ['C06429']
# None
# None
# ['C05572' 'C00940']
# None
# ['C06424']
# None
# ['C00418']
# ['C00906' 'C00064' 'C00047']
# None
# None
# None
# None
# ['C00245' 'C00245']
# None
# ['C02642' 'C00152']
# None
# None
# ['C00064' 'C05100' 'C00819']
# None
# None
# ['C00906']
# None
# ['C01879' 'C04281' 'C04282']
# ['C05522' 'C00380' 'C00380']
# None
# ['C02238']
# None
# None
# None
# ['C00418']
# None
# None
# None
# None
# None
# None
# ['C06124']
# None
# None
# None
# None
# None
# ['C06124']
# None
# None
# None
# ['C02727']
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ['C00491' 'C00491']
# None
# None
# ['C00155' None]
# None
# None
# None
# None
# None
# ['C00217' 'C00025' 'C05938' 'C00408']
# ['tmndnccrn']
# None
# None
# None
# None
# ['C02990']
# ['dcsptn1crn' 'clpndcrn']
# ['C05587' 'C07453' 'C00250']
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ['C00410']
# None
# None
# ['C00328' 'C05647' 'C00328' 'C00328']
# ['C00073' 'C00073' 'C00073']
# None
# None
# None
# ['C00064' 'C05100' 'C00819']
# ['C05519' 'C00188']
# None
# None
# None
# None
# ['C00064' 'C05100' 'C00819']
# ['C13747' 'C07480' 'C01586']
# ['C00073' None]
# ['C00073']
# None
# ['C05519' 'C00188' 'C00408']
# None
# ['C02838']
# None
# None
# None
# None
# ['C00483' 'C01183' 'C02735' 'C00079']
# None
# None
# None
# None
# None
# ['c226crn']
# ['C00079' 'CE2172']
# None
# None
# ['C00073']
# None
# None
# None
# [None]
# ['C00079' 'CE2172']
# None
# None
# ['C00906']
# None
# None
# None
# ['C00135']
# None
# ['C00031' 'C00221' 'C00247' 'C02336' 'C00267' 'C00738' 'C00936' 'C00095'
#  'C00962' 'C01582' 'C00795' 'C00137' 'C00293' 'C00124' 'C00984' 'C00159']
# ['pcrn']
# ['C05828' 'C00153']
# None
# None
# ['CE2122']
# None
# ['C02838']
# ['pcrn']
# None
# None
# ['C00178']
# None
# ['C00073']
# None
# None
# None
# ['lneldccrn' 'lnlccrn']
# None
# None
# None
# None
# None
# None
# ['CE2577']
# None
# ['C05519' 'C00188']
# None
# None
# None
# ['C06178']
# None
# ['C02642' 'C00152' 'C00300']
# None
# None
# None
# None
# None
# ['C05462' 'C05466']
# None
# ['C03239' 'C02946' 'C04076']
# ['C04148' 'C05642']
# ['C01252']
# ['C01035']
# None
# None
# None
# None
# ['C01026']
# None
# ['elaidcrn' 'vacccrn' 'odecrn']
# None
# ['C00439']
# None
# None
# None
# None
# None
# None
# ['C00327']
# None
# ['C16595' 'C16587' 'C00954']
# None
# None
# None
# ['C01035']
# ['tetpent6crn' 'tetpent3crn']
# None
# ['C00135']
# ['C05462' 'C05466']
# None
# None
# ['C00300' 'C06804']
# None
# None
# None
# ['C05660' 'C00078']
# None
# None
# None
# ['C00327']
# ['C02356' 'C01026' 'C00334' 'C05145' 'C01205' 'C03284']
# ['C00077' 'C00515' 'C01602']
# None
# ['tetpent6crn' 'tetpent3crn']
# None
# ['C00078' 'C00525' 'C00078' 'C00078']
# None
# None
# ['C00327']
# None
# None
# ['C00078' 'C00525']
# ['C00073']
# None
# None
# ['C00791' 'C00147' 'C03758']
# None
# None
# None
# None
# ['C00719' 'C00431' 'C00183']
# ['C08261']
# None
# None
# None
# None
# None
# None
# None
# ['C00065' 'C00740' 'C00065']
# None
# None
# ['pcrn']
# None
# ['C00785' 'C00262']
# None
# ['C02727']
# None
# None
# ['C02356' 'C01026' 'C00334' 'C05145' 'C01205' 'C03284' 'C01026']
# ['C00906']
# None
# None
# None

# %%
df = pd.DataFrame([cid_list, kegg_list]).transpose()

# %%
df.to_csv(osp+'/pals_analysis/annotation.csv', index=False)

# %%
pos = pd.read_csv(osp+'positive_mode/samples_filtered.csv')
neg = pd.read_csv(osp+'negative_mode/samples_filtered.csv')

# %%
neg
# Out:
#     row ID   KM_10.mzXML    KM_9.mzXML    KM_3.mzXML    KM_4.mzXML  \
# 0      n10  3.793162e+06  2.440189e+06  2.241037e+06  4.047472e+06
# 1      n18  7.231802e+06  6.161310e+06  6.910764e+06  7.193243e+06
# 2      n36  1.189739e+07  1.373429e+07  1.633100e+07  1.042577e+07
# 3      n41  1.783018e+07  1.475968e+07  4.700804e+07  2.365467e+07
# 4      n52  1.746852e+07  1.148218e+07  1.968069e+07  2.031807e+07
# ..     ...           ...           ...           ...           ...
# 454  n1869  4.233974e+06  3.374942e+06  0.000000e+00  3.800920e+06
# 455  n1872  1.662663e+07  1.658124e+07  3.038727e+07  1.674518e+07
# 456  n1873  8.451615e+06  8.522133e+06  1.601654e+07  8.469571e+06
# 457  n1874  3.493918e+06  3.999624e+06  6.803168e+06  3.317501e+06
# 458  n2033  7.506291e+05  8.199804e+05  1.633270e+06  8.715843e+05
#
#        KM_1.mzXML   KM_16.mzXML   KM_13.mzXML   KM_12.mzXML   KM_19.mzXML  \
# 0    3.526951e+06  2.550157e+06  3.119919e+06  4.064685e+06  3.267440e+06
# 1    7.394610e+06  7.019451e+06  7.681140e+06  7.375094e+06  0.000000e+00
# 2    1.391011e+07  9.226508e+06  2.610691e+07  1.653472e+07  1.314168e+07
# 3    4.366029e+07  1.803621e+07  2.112069e+07  2.297125e+07  3.723285e+07
# 4    3.337386e+07  1.682956e+07  2.457656e+07  2.060901e+07  2.116111e+07
# ..            ...           ...           ...           ...           ...
# 454  5.410286e+06  6.665323e+06  0.000000e+00  6.043435e+06  6.027341e+06
# 455  2.643999e+07  3.557300e+07  2.378481e+07  2.851966e+07  2.460818e+07
# 456  1.320666e+07  1.696763e+07  1.172378e+07  1.466731e+07  1.154253e+07
# 457  5.021402e+06  8.068348e+06  6.227106e+06  5.718128e+06  4.168176e+06
# 458  1.018683e+06  6.259411e+05  1.110314e+06  1.126141e+06  1.610813e+06
#
#      ...      C9.mzXML    ZIK4.mzXML    ZIK5.mzXML      C5.mzXML  \
# 0    ...  2.598344e+06  2.119470e+06  3.402185e+06  3.627914e+06
# 1    ...  0.000000e+00  6.039728e+06  6.093355e+06  6.231000e+06
# 2    ...  0.000000e+00  4.397926e+06  4.576895e+06  3.922250e+06
# 3    ...  1.812452e+07  2.413164e+07  2.311507e+07  1.856339e+07
# 4    ...  2.728661e+07  2.151957e+07  2.771342e+07  3.315330e+07
# ..   ...           ...           ...           ...           ...
# 454  ...  3.277193e+06  4.100196e+06  3.695617e+06  2.829000e+06
# 455  ...  6.215613e+06  6.929595e+06  6.089135e+06  5.087720e+06
# 456  ...  3.393751e+06  3.449068e+06  3.300749e+06  2.713515e+06
# 457  ...  2.040289e+06  1.529825e+06  2.569249e+06  1.427605e+06
# 458  ...  0.000000e+00  0.000000e+00  6.413473e+05  3.386858e+05
#
#          C4.mzXML    ZIK9.mzXML    ZIK8.mzXML    ZIK3.mzXML    ZIK2.mzXML  \
# 0    2.127515e+06  1.688153e+06  1.860977e+06  2.321284e+06  2.875451e+06
# 1    5.767440e+06  6.546788e+06  0.000000e+00  5.791719e+06  6.296008e+06
# 2    3.964978e+06  4.363380e+06  4.204267e+06  4.711809e+06  4.340989e+06
# 3    1.666186e+07  1.814772e+07  1.855383e+07  8.878743e+06  1.104423e+07
# 4    2.005624e+07  1.931843e+07  1.751603e+07  1.683767e+07  2.607889e+07
# ..            ...           ...           ...           ...           ...
# 454  2.792297e+06  3.619203e+06  3.404754e+06  3.450726e+06  2.842622e+06
# 455  7.506244e+06  6.452346e+06  5.806975e+06  6.696138e+06  1.185069e+07
# 456  4.180712e+06  2.962589e+06  2.979717e+06  3.290788e+06  5.810406e+06
# 457  2.848741e+06  1.803867e+06  2.136015e+06  2.235690e+06  3.235399e+06
# 458  2.785624e+05  3.651410e+05  5.050804e+05  4.060793e+05  0.000000e+00
#
#         C10.mzXML
# 0    2.774675e+06
# 1    5.467453e+06
# 2    3.950292e+06
# 3    1.188982e+07
# 4    2.605510e+07
# ..            ...
# 454  1.790214e+06
# 455  1.095455e+07
# 456  5.555594e+06
# 457  3.219688e+06
# 458  0.000000e+00
#
# [459 rows x 70 columns]

# %%
new_df = pd.concat([pos, neg])
new_df.to_csv(osp+'pals_analysis/samples_filtered.csv', index=False)

# %%
for peak in peakinfolist_positive:
    peak.change_cid('p')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-16a50cbefe5c> in <module>
#       1 for peak in peakinfolist_positive:
# ----> 2     peak.change_cid('p')
#
# ~/git/mma/mma/peakinfo.py in change_cid(self, mode)
#     215         self.mm_kegg_id = kegg_id
#     216     def change_cid(self, mode):
# --> 217         new_cid = int(self.cid.split(mode)[1].split('.')[0])
#     218         self.cid = new_cid
#     219
#
# AttributeError: 'int' object has no attribute 'split'

# %%
print(peakinfolist_positive[0])
# Out:
# Peak 633: m/z = 148.07345756155544, rt = 11.915376878181446
#
#                 p-val: 2.36533127803315e-07, logFC = -11.182687216628802
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:

# %%
for peak in peakinfolist_positive:
    print(peak.cid)
    get_peak(peakinfolist_positive, peak.cid).plot_boxplots(samples_values_filled_positive, osp+'positive_mode/peak_boxplots_png_large/')
# Out:
# 633
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 613
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3109
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3028
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2989
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2936
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 324
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2938
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 425
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2992
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2939
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 926
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 951
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3026
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 101
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1236
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 397
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 168
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 626
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 365
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 940
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3027
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 893
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 659
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2720
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2958
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3025
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2695
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1031
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1993
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2549
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1034
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2944
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2942
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2876
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1517
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2548
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1449
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2913
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2963
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 952
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2982
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2987
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2912
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2898
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2921
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 4343
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2725
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2724
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2666
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2897
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1839
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1238
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2895
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 459
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1299
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2230
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2960
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3022
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 970
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 366
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2664
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2763
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 835
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 410
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2678
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2600
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2696
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3577
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2701
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2997
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2698
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2711
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2918
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1526
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3108
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2894
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2969
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2151
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 785
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2743
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1463
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 667
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2949
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2881
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2966
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 634
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 109
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2980
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1580
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2745
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2837
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 614
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1100
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 690
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 121
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2961
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 38
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2995
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2235
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2875
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2832
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2923
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2998
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 264
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2800
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2320
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1450
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2925
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2934
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2693
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 906
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 535
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2985
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 423
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1441
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 253
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1078
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2384
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3317
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2315
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 677
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 676
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2842
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 4735
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 885
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1002
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2990
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1401
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3867
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 298
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2877
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2192
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1229
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3083
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2234
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1591
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2937
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2999
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 330
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1724
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 678
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 862
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1089
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2703
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2620
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 878
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1122
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2158
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1829
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2915
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2943
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 726
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2114
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 259
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 6915
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1754
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 967
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 152
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2744
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 424
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2371
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2716
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2830
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2332
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2804
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2646
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1312
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 599
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 4109
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1221
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 602
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2932
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2878
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 679
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3750
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 137
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1405
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2629
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1784
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 615
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2767
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 507
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2051
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2749
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1533
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2351
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 798
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1796
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1033
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2718
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 6582
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2096
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 162
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2726
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2728
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 756
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2647
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2445
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2746
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 714
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2799
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2757
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2175
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1189
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 4907
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2372
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2303
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1037
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 134
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 198
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2058
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2727
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1631
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1439
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2480
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2161
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1053
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2717
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2901
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1448
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 668
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 588
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1669
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 460
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1963
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1752
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1420
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2973
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 510
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3256
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2868
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2844
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1516
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 443
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2722
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 662
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2780
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 144
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2392
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 544
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1592
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1844
# ...
#   warnings.warn(msg, UserWarning)
# 569
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2038
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1005
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2242
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2863
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 922
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2699
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1372
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1110
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2857
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1068
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1155
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1870
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 166
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1205
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1909
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3390
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2843
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 637
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1850
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2378
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1887
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2855
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1233
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1821
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2469
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1322
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 172
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 444
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 58
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 411
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1364
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1819
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1599
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2478
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 704
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1468
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 658
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1798
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3945
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 824
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2871
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1824
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 716
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 309
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1016
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2940
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1751
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1908
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 877
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2425
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 789
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 859
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 187
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1196
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 855
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2834
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2803
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2043
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2439
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 488
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 4855
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2906
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1174
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2779
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2848
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1419
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3642
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1544
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1911
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 597
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2798
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 437
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 372
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 3000
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1713
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1149
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 2237
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 417
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 827
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
get_peak(peakinfolist_negative, 678).plot_boxplots(samples_values_filled_negative, osp+'negative_mode/')
# Out:
# /Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/seaborn/categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
get_peak(peakinfolist_negative, 1189).best_ms2_match_adduct.ms2spec.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-5be3ee55766f> in <module>
# ----> 1 get_peak(peakinfolist_positive, 1189).best_ms2_match_adduct.ms2spec.plot()
#
# AttributeError: 'str' object has no attribute 'ms2spec'

# %%
print(get_peak(peakinfolist_negative, 1157))
# Out:
# Peak 1157: m/z = 233.18369580553727, rt = 3.3046956013301227
#
#                 p-val: 0.00520086381425561, logFC = -0.5113524474483211
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation: Melatonin
#
#
#                 {'frag_zik': <mnet.Spectrum object at 0x11efc1a60>}

# %%
print(get_peak(peakinfolist_negative, 1453).spectra['frag_vl'])
# Out:
# Spectrum from scan 1852 in /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/negative_mode/fragmentation/vl/FRAG_NEG_vl.mgf with 104 peaks, max_ms2_intensity 25000.0

# %%
print(get_peak(peakinfolist_negative, 1453).best_ms2_match_adduct.ms2spec)
# Out:
# Spectrum from scan None in HMDB0000673 with 138 peaks, max_ms2_intensity 100.0

# %%
plot_mirror(list(get_peak(peakinfolist_negative, 1355).spectra.values())[0].normalised_peaks,
           get_peak(peakinfolist_negative, 1355).best_ms2_match_adduct.ms2spec.normalised_peaks)

# %%
get_peak(peakinfolist_negative, 1355).best_ms2_match_adduct.ms2spec.file_name
# Out:
# 'HMDB0001830'

# %%
for peak in peakinfolist_negative:
    if peak.spectra:
        if type(peak.best_ms2_match_adduct) != str:
            if peak.best_ms2_match_adduct.ms2spec.precursor_mz > 350 and peak.best_ms2_match_adduct.ms2spec.precursor_mz < 355:
                print(peak)
                #print(peak.spectra[spectrum], peak.spectra[spectrum].parent_mz)

# %%
f peak.best_ms2_match_adduct.ms2spec.precursor_mz > 349 and peak.best_ms2_match_adduct.ms2spec.precursor_mz < 356:
            print(peak)
            print(peak.spectra[spectrum], peak.spectra[spectrum].parent_mz)
# Out:
# [(95.086197, 2.895054),
#  (97.066154, 49.819059),
#  (98.067413, 2.92186),
#  (105.070061, 7.425278),
#  (107.048409, 2.104276),
#  (107.084991, 6.942769),
#  (109.06604, 100.0),
#  (109.103188, 2.734218),
#  (110.067566, 3.149712),
#  (117.070801, 4.262163),
#  (119.085945, 6.46026),
#  (121.101654, 4.985927),
#  (123.080971, 16.324889),
#  (129.069168, 3.122906),
#  (131.084824, 5.508645),
#  (133.101547, 4.664254),
#  (143.086182, 3.176518),
#  (145.101044, 12.062726),
#  (147.11676, 6.004557),
#  (149.095596, 2.238306),
#  (149.130783, 2.975472),
#  (157.102646, 6.15199),
#  (159.115295, 5.3076),
#  (161.132248, 4.503418),
#  (163.10907, 3.752848),
#  (171.117386, 2.278515),
#  (173.132416, 5.414824),
#  (175.148605, 2.171291),
#  (177.129486, 2.251709),
#  (185.132492, 2.47956),
#  (187.146393, 4.355984),
#  (189.127075, 3.511594),
#  (189.164261, 2.506366),
#  (197.13533, 2.559979),
#  (199.150558, 3.551803),
#  (201.162689, 3.055891),
#  (215.179291, 2.881651),
#  (239.178802, 2.895054),
#  (255.206238, 2.332127),
#  (279.21283, 2.198097),
#  (297.220306, 3.659027),
#  (315.234955, 3.015682)]

# %%
spec.plot()

# %%
plot_mirror(list(get_peak(peakinfolist_positive, 1463).spectra.values())[0].normalised_peaks, 
             get_peak(peakinfolist_positive, 1463).best_ms2_match_adduct.ms2spec.normalised_peaks)

# %%
plot_mirror(list(get_peak(peakinfolist_positive, 298).spectra.values())[0].normalised_peaks,
           list(get_peak(peakinfolist_positive, 298).spectra.values())[0].normalised_peaks)

# %%
list(get_peak(peakinfolist_positive, 1189).spectra.values())[0].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-a28af92b79b7> in <module>
# ----> 1 list(get_peak(peakinfolist_positive, 1189).spectra.values())[0].plot()
#
# AttributeError: 'str' object has no attribute 'values'

# %%
for peak in peakinfolist_positive:
    
    if peak.pval!=0:
        print(peak.cid, peak.std_annotation, peak.std_kegg_id, peak.mz, peak.pval, peak.logfc)
        print(peak.mm_annotation, peak.mm_kegg_id)
        normalised_peaks_top_list = []
        normalised_peaks_bottom_list = []

        if peak.best_ms2_match_adduct: 
            print(peak.best_ms2_match_adduct.name, ":",
                  metabolites[peak.best_ms2_match_adduct.hmdb][2],
                  metabolites[peak.best_ms2_match_adduct.hmdb][0],
                  metabolites[peak.best_ms2_match_adduct.hmdb][1],
                  metabolites[peak.best_ms2_match_adduct.hmdb][5], peak.best_ms2_match_adduct.score)
            if peak.best_ms2_match_adduct.ms2spec:
                    normalised_peaks_bottom = peak.best_ms2_match_adduct.ms2spec.normalised_peaks
                    normalised_peaks_bottom_list.append(normalised_peaks_bottom)


        if peak.spectra:

            spectra = peak.spectra

            for spectrum in spectra:

                normalised_peaks_top = spectra[spectrum].normalised_peaks
                normalised_peaks_top_list.append(normalised_peaks_top)



        for top in normalised_peaks_top_list:
            for bottom in normalised_peaks_bottom_list:
                plot_mirror(top, bottom)

        #metab_utils.plot_boxplots(samples_values_filled, str(peak.cid), 'ConditionDataset', (15,30), y = False )

        print('----')

# %%
print(list(get_peak(peakinfolist_positive, 298).spectra.values())[0])
print(list(get_peak(peakinfolist_positive, 298).spectra.values())[1])
# Out:
# Spectrum from scan 669 in /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pymz/mzmine/210120/mzmine_frag/mal/frag_pos_mal.mgf with 36 peaks, max_ms2_intensity 130000.0
# Spectrum from scan 195 in /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pymz/mzmine/210120/mzmine_frag/zik/gnps2.mgf with 36 peaks, max_ms2_intensity 130000.0

# %%
print(list(get_peak(peakinfolist_positive, 1463).spectra.values())[0])
# Out:
# Spectrum from scan 3613 in /Volumes/Transcend2/17_20_PhD/19_20_PhD_Metabolomics/pymz/mzmine/210120/mzmine_frag/vl/frag_pos_vl.mgf with 248 peaks, max_ms2_intensity 160000.0

# %%
import matplotlib.pyplot as plt
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
#           'axes.grid.axis': 'both',
#           'axes.grid.which': 'major',
#           'axes.labelcolor': 'black',
#           'axes.labelpad': 4.0,
#           'axes.labelsize': 'medium',
#           'axes.labelweight': 'normal',
#           'axes.linewidth': 0.8,
#           'axes.prop_cycle': cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']),
#           'axes.spines.bottom': True,
#           'axes.spines.left': True,
#           'axes.spines.right': True,
#           'axes.spines.top': True,
#           'axes.titlecolor': 'auto',
#           'axes.titlelocation': 'center',
#           'axes.titlepad': 6.0,
#           'axes.titlesize': 'large',
#           'axes.titleweight': 'normal',
#           'axes.unicode_minus': True,
#           'axes.xmargin': 0.05,
#           'axes.ymargin': 0.05,
#           'axes3d.grid': True,
#           'backend': 'module://ipykernel.pylab.backend_inline',
#           'backend_fallback': True,
#           'boxplot.bootstrap': None,
#           'boxplot.boxprops.color': 'black',
#           'boxplot.boxprops.linestyle': '-',
#           'boxplot.boxprops.linewidth': 1.0,
#           'boxplot.capprops.color': 'black',
#           'boxplot.capprops.linestyle': '-',
#           'boxplot.capprops.linewidth': 1.0,
#           'boxplot.flierprops.color': 'black',
#           'boxplot.flierprops.linestyle': 'none',
#           'boxplot.flierprops.linewidth': 1.0,
#           'boxplot.flierprops.marker': 'o',
#           'boxplot.flierprops.markeredgecolor': 'black',
#           'boxplot.flierprops.markeredgewidth': 1.0,
#           'boxplot.flierprops.markerfacecolor': 'none',
#           'boxplot.flierprops.markersize': 6.0,
#           'boxplot.meanline': False,
#           'boxplot.meanprops.color': 'C2',
#           'boxplot.meanprops.linestyle': '--',
#           'boxplot.meanprops.linewidth': 1.0,
#           'boxplot.meanprops.marker': '^',
#           'boxplot.meanprops.markeredgecolor': 'C2',
#           'boxplot.meanprops.markerfacecolor': 'C2',
#           'boxplot.meanprops.markersize': 6.0,
#           'boxplot.medianprops.color': 'C1',
#           'boxplot.medianprops.linestyle': '-',
#           'boxplot.medianprops.linewidth': 1.0,
#           'boxplot.notch': False,
#           'boxplot.patchartist': False,
#           'boxplot.showbox': True,
#           'boxplot.showcaps': True,
#           'boxplot.showfliers': True,
#           'boxplot.showmeans': False,
#           'boxplot.vertical': True,
#           'boxplot.whiskerprops.color': 'black',
#           'boxplot.whiskerprops.linestyle': '-',
#           'boxplot.whiskerprops.linewidth': 1.0,
#           'boxplot.whiskers': 1.5,
#           'contour.corner_mask': True,
#           'contour.negative_linestyle': 'dashed',
#           'datapath': '/Users/anamaria/.pyenv/versions/3.8.1/lib/python3.8/site-packages/matplotlib/mpl-data',
#           'date.autoformatter.day': '%Y-%m-%d',
#           'date.autoformatter.hour': '%m-%d %H',
#           'date.autoformatter.microsecond': '%M:%S.%f',
#           'date.autoformatter.minute': '%d %H:%M',
#           'date.autoformatter.month': '%Y-%m',
#           'date.autoformatter.second': '%H:%M:%S',
#           'date.autoformatter.year': '%Y',
#           'docstring.hardcopy': False,
#           'errorbar.capsize': 0.0,
#           'figure.autolayout': False,
#           'figure.constrained_layout.h_pad': 0.04167,
#           'figure.constrained_layout.hspace': 0.02,
#           'figure.constrained_layout.use': False,
#           'figure.constrained_layout.w_pad': 0.04167,
#           'figure.constrained_layout.wspace': 0.02,
#           'figure.dpi': 72.0,
#           'figure.edgecolor': (1, 1, 1, 0),
#           'figure.facecolor': (1, 1, 1, 0),
#           'figure.figsize': [6.0, 4.0],
#           'figure.frameon': True,
#           'figure.max_open_warning': 20,
#           'figure.subplot.bottom': 0.125,
#           'figure.subplot.hspace': 0.2,
#           'figure.subplot.left': 0.125,
#           'figure.subplot.right': 0.9,
#           'figure.subplot.top': 0.88,
#           'figure.subplot.wspace': 0.2,
#           'figure.titlesize': 'large',
#           'figure.titleweight': 'normal',
#           'font.cursive': ['Apple Chancery',
#                            'Textile',
#                            'Zapf Chancery',
#                            'Sand',
#                            'Script MT',
#                            'Felipa',
#                            'cursive'],
#           'font.family': ['serif'],
#           'font.fantasy': ['Comic Neue',
#                            'Comic Sans MS',
#                            'Chicago',
#                            'Charcoal',
#                            'Impact',
#                            'Western',
#                            'Humor Sans',
#                            'xkcd',
#                            'fantasy'],
#           'font.monospace': ['DejaVu Sans Mono',
#                              'Bitstream Vera Sans Mono',
#                              'Computer Modern Typewriter',
#                              'Andale Mono',
#                              'Nimbus Mono L',
#                              'Courier New',
#                              'Courier',
#                              'Fixed',
#                              'Terminal',
#                              'monospace'],
#           'font.sans-serif': ['DejaVu Sans',
#                               'Bitstream Vera Sans',
#                               'Computer Modern Sans Serif',
#                               'Lucida Grande',
#                               'Verdana',
#                               'Geneva',
#                               'Lucid',
#                               'Arial',
#                               'Helvetica',
#                               'Avant Garde',
#                               'sans-serif'],
#           'font.serif': ['Times New Roman'],
#           'font.size': 10.0,
#           'font.stretch': 'normal',
#           'font.style': 'normal',
#           'font.variant': 'normal',
#           'font.weight': 'normal',
#           'grid.alpha': 1.0,
#           'grid.color': '#b0b0b0',
#           'grid.linestyle': '-',
#           'grid.linewidth': 0.8,
#           'hatch.color': 'black',
#           'hatch.linewidth': 1.0,
#           'hist.bins': 10,
#           'image.aspect': 'equal',
#           'image.cmap': 'viridis',
#           'image.composite_image': True,
#           'image.interpolation': 'antialiased',
#           'image.lut': 256,
#           'image.origin': 'upper',
#           'image.resample': True,
#           'interactive': True,
#           'keymap.all_axes': ['a'],
#           'keymap.back': ['left', 'c', 'backspace', 'MouseButton.BACK'],
#           'keymap.copy': ['ctrl+c', 'cmd+c'],
#           'keymap.forward': ['right', 'v', 'MouseButton.FORWARD'],
#           'keymap.fullscreen': ['f', 'ctrl+f'],
#           'keymap.grid': ['g'],
#           'keymap.grid_minor': ['G'],
#           'keymap.help': ['f1'],
#           'keymap.home': ['h', 'r', 'home'],
#           'keymap.pan': ['p'],
#           'keymap.quit': ['ctrl+w', 'cmd+w', 'q'],
#           'keymap.quit_all': ['W', 'cmd+W', 'Q'],
#           'keymap.save': ['s', 'ctrl+s'],
#           'keymap.xscale': ['k', 'L'],
#           'keymap.yscale': ['l'],
#           'keymap.zoom': ['o'],
#           'legend.borderaxespad': 0.5,
#           'legend.borderpad': 0.4,
#           'legend.columnspacing': 2.0,
#           'legend.edgecolor': '0.8',
#           'legend.facecolor': 'inherit',
#           'legend.fancybox': True,
#           'legend.fontsize': 'medium',
#           'legend.framealpha': 0.8,
#           'legend.frameon': True,
#           'legend.handleheight': 0.7,
#           'legend.handlelength': 2.0,
#           'legend.handletextpad': 0.8,
#           'legend.labelspacing': 0.5,
#           'legend.loc': 'best',
#           'legend.markerscale': 1.0,
#           'legend.numpoints': 1,
#           'legend.scatterpoints': 1,
#           'legend.shadow': False,
#           'legend.title_fontsize': None,
#           'lines.antialiased': True,
#           'lines.color': 'C0',
#           'lines.dash_capstyle': 'butt',
#           'lines.dash_joinstyle': 'round',
#           'lines.dashdot_pattern': [6.4, 1.6, 1.0, 1.6],
#           'lines.dashed_pattern': [3.7, 1.6],
#           'lines.dotted_pattern': [1.0, 1.65],
#           'lines.linestyle': '-',
#           'lines.linewidth': 1.5,
#           'lines.marker': 'None',
#           'lines.markeredgecolor': 'auto',
#           'lines.markeredgewidth': 1.0,
#           'lines.markerfacecolor': 'auto',
#           'lines.markersize': 6.0,
#           'lines.scale_dashes': True,
#           'lines.solid_capstyle': 'projecting',
#           'lines.solid_joinstyle': 'round',
#           'markers.fillstyle': 'full',
#           'mathtext.bf': 'sans:bold',
#           'mathtext.cal': 'cursive',
#           'mathtext.default': 'it',
#           'mathtext.fallback_to_cm': True,
#           'mathtext.fontset': 'dejavusans',
#           'mathtext.it': 'sans:italic',
#           'mathtext.rm': 'sans',
#           'mathtext.sf': 'sans',
#           'mathtext.tt': 'monospace',
#           'mpl_toolkits.legacy_colorbar': True,
#           'patch.antialiased': True,
#           'patch.edgecolor': 'black',
#           'patch.facecolor': 'C0',
#           'patch.force_edgecolor': False,
#           'patch.linewidth': 1.0,
#           'path.effects': [],
#           'path.simplify': True,
#           'path.simplify_threshold': 0.1111111111111111,
#           'path.sketch': None,
#           'path.snap': True,
#           'pdf.compression': 6,
#           'pdf.fonttype': 3,
#           'pdf.inheritcolor': False,
#           'pdf.use14corefonts': False,
#           'pgf.preamble': '',
#           'pgf.rcfonts': True,
#           'pgf.texsystem': 'xelatex',
#           'polaraxes.grid': True,
#           'ps.distiller.res': 6000,
#           'ps.fonttype': 3,
#           'ps.papersize': 'letter',
#           'ps.useafm': False,
#           'ps.usedistiller': None,
#           'savefig.bbox': None,
#           'savefig.directory': '~',
#           'savefig.dpi': 'figure',
#           'savefig.edgecolor': 'white',
#           'savefig.facecolor': 'white',
#           'savefig.format': 'png',
#           'savefig.frameon': True,
#           'savefig.jpeg_quality': 95,
#           'savefig.orientation': 'portrait',
#           'savefig.pad_inches': 0.1,
#           'savefig.transparent': False,
#           'scatter.edgecolors': 'face',
#           'scatter.marker': 'o',
#           'svg.fonttype': 'path',
#           'svg.hashsalt': None,
#           'svg.image_inline': True,
#           'text.antialiased': True,
#           'text.color': 'black',
#           'text.hinting': 'auto',
#           'text.hinting_factor': 8,
#           'text.kerning_factor': 0,
#           'text.latex.preamble': '',
#           'text.latex.preview': False,
#           'text.latex.unicode': True,
#           'text.usetex': True,
#           'timezone': 'UTC',
#           'tk.window_focus': False,
#           'toolbar': 'toolbar2',
#           'verbose.fileo': 'sys.stdout',
#           'verbose.level': 'silent',
#           'webagg.address': '127.0.0.1',
#           'webagg.open_in_browser': True,
#           'webagg.port': 8988,
#           'webagg.port_retries': 50,
#           'xtick.alignment': 'center',
#           'xtick.bottom': True,
#           'xtick.color': 'black',
#           'xtick.direction': 'out',
#           'xtick.labelbottom': True,
#           'xtick.labelsize': 'large',
#           'xtick.labeltop': False,
#           'xtick.major.bottom': True,
#           'xtick.major.pad': 3.5,
#           'xtick.major.size': 3.5,
#           'xtick.major.top': True,
#           'xtick.major.width': 0.8,
#           'xtick.minor.bottom': True,
#           'xtick.minor.pad': 3.4,
#           'xtick.minor.size': 2.0,
#           'xtick.minor.top': True,
#           'xtick.minor.visible': False,
#           'xtick.minor.width': 0.6,
#           'xtick.top': False,
#           'ytick.alignment': 'center_baseline',
#           'ytick.color': 'black',
#           'ytick.direction': 'out',
#           'ytick.labelleft': True,
#           'ytick.labelright': False,
#           'ytick.labelsize': 'large',
#           'ytick.left': True,
#           'ytick.major.left': True,
#           'ytick.major.pad': 3.5,
#           'ytick.major.right': True,
#           'ytick.major.size': 3.5,
#           'ytick.major.width': 0.8,
#           'ytick.minor.left': True,
#           'ytick.minor.pad': 3.4,
#           'ytick.minor.right': True,
#           'ytick.minor.size': 2.0,
#           'ytick.minor.visible': False,
#           'ytick.minor.width': 0.6,
#           'ytick.right': False}))

# %%
print(get_peak(peakinfolist_positive, 712))
# Out:
# Peak 712: m/z = 154.04986931937086, rt = 6.717301560916661
#
#                 p-val: 0.863414446913331, logFC = 0.269189245778421
#
#                 mm annotation:
#
#                 std annotation:
#
#                 hmdb annotation:

# %%
for peak in peakinfolist_positive:
    print(peak.cid)
# Out:
# p633.0
# p613.0
# p3109.0
# p3028.0
# p2989.0
# p2936.0
# p324.0
# p2938.0
# p425.0
# p2992.0
# p2939.0
# p926.0
# p951.0
# p3026.0
# p101.0
# p1236.0
# p397.0
# p168.0
# p626.0
# p365.0
# p940.0
# p3027.0
# p893.0
# p659.0
# p2720.0
# p2958.0
# p3025.0
# p2695.0
# p1031.0
# p1993.0
# p2549.0
# p1034.0
# p2944.0
# p2942.0
# p2876.0
# p1517.0
# p2548.0
# p1449.0
# p2913.0
# p2963.0
# p952.0
# p2982.0
# p2987.0
# p2912.0
# p2898.0
# p2921.0
# p4343.0
# p2725.0
# p2724.0
# p2666.0
# p2897.0
# p1839.0
# p1238.0
# p2895.0
# p459.0
# p1299.0
# p2230.0
# p2960.0
# p3022.0
# p970.0
# p366.0
# p2664.0
# p2763.0
# p835.0
# p410.0
# p2678.0
# p2600.0
# p2696.0
# p3577.0
# p2701.0
# p2997.0
# p2698.0
# p2711.0
# p2918.0
# p1526.0
# p3108.0
# p2894.0
# p2969.0
# p2151.0
# p785.0
# p2743.0
# p1463.0
# p667.0
# p2949.0
# p2881.0
# p2966.0
# p634.0
# p109.0
# p2980.0
# p1580.0
# p2745.0
# p2837.0
# p614.0
# p1100.0
# p690.0
# p121.0
# p2961.0
# p38.0
# p2995.0
# p2235.0
# p2875.0
# p2832.0
# p2923.0
# p2998.0
# p264.0
# p2800.0
# p2320.0
# p1450.0
# p2925.0
# p2934.0
# p2693.0
# p906.0
# p535.0
# p2985.0
# p423.0
# p1441.0
# p253.0
# p1078.0
# p2384.0
# p3317.0
# p2315.0
# p677.0
# p676.0
# p2842.0
# p4735.0
# p885.0
# p1002.0
# p2990.0
# p1401.0
# p3867.0
# p298.0
# p2877.0
# p2192.0
# p1229.0
# p3083.0
# p2234.0
# p1591.0
# p2937.0
# p2999.0
# p330.0
# p1724.0
# p678.0
# p862.0
# p1089.0
# p2703.0
# p2620.0
# p878.0
# p1122.0
# p2158.0
# p1829.0
# p2915.0
# p2943.0
# p726.0
# p2114.0
# p259.0
# p6915.0
# p1754.0
# p967.0
# p152.0
# p2744.0
# p424.0
# p2371.0
# p2716.0
# p2830.0
# p2332.0
# p2804.0
# p2646.0
# p1312.0
# p599.0
# p4109.0
# p1221.0
# p602.0
# p2932.0
# p2878.0
# p679.0
# p3750.0
# p137.0
# p1405.0
# p2629.0
# p1784.0
# p615.0
# p2767.0
# p507.0
# p2051.0
# p2749.0
# p1533.0
# p2351.0
# p798.0
# p1796.0
# p1033.0
# p2718.0
# p6582.0
# p2096.0
# p162.0
# p2726.0
# p2728.0
# p756.0
# p2647.0
# p2445.0
# p2746.0
# p714.0
# p2799.0
# p2757.0
# p2175.0
# p1189.0
# p4907.0
# p2372.0
# p2303.0
# p1037.0
# p134.0
# p198.0
# p2058.0
# p2727.0
# p1631.0
# p1439.0
# p2480.0
# p2161.0
# p1053.0
# p2717.0
# p2901.0
# p1448.0
# p668.0
# p588.0
# p1669.0
# p460.0
# p1963.0
# p1752.0
# p1420.0
# p2973.0
# p510.0
# p3256.0
# p2868.0
# p2844.0
# p1516.0
# p443.0
# p2722.0
# p662.0
# p2780.0
# p144.0
# p2392.0
# p544.0
# p1592.0
# p1844.0
# p487.0
# p4370.0
# p1213.0
# p2896.0
# p2057.0
# p122.0
# p3305.0
# p2902.0
# p2322.0
# p1359.0
# p1808.0
# p399.0
# p3779.0
# p181.0
# p2385.0
# p229.0
# p5793.0
# p3990.0
# p1101.0
# p73.0
# p2289.0
# p2225.0
# p2824.0
# p630.0
# p2845.0
# p436.0
# p1195.0
# p67.0
# p2883.0
# p1889.0
# p778.0
# p569.0
# p2038.0
# p1005.0
# p2242.0
# p2863.0
# p922.0
# p2699.0
# p1372.0
# p1110.0
# p2857.0
# p1068.0
# p1155.0
# p1870.0
# p166.0
# p1205.0
# p1909.0
# p3390.0
# p2843.0
# p637.0
# p1850.0
# p2378.0
# p1887.0
# p2855.0
# p1233.0
# p1821.0
# p2469.0
# p1322.0
# p172.0
# p444.0
# p58.0
# p411.0
# p1364.0
# p1819.0
# p1599.0
# p2478.0
# p704.0
# p1468.0
# p658.0
# p1798.0
# p3945.0
# p824.0
# p2871.0
# p1824.0
# p716.0
# p309.0
# p1016.0
# p2940.0
# p1751.0
# p1908.0
# p877.0
# p2425.0
# p789.0
# p859.0
# p187.0
# p1196.0
# p855.0
# p2834.0
# p2803.0
# p2043.0
# p2439.0
# p488.0
# p4855.0
# p2906.0
# p1174.0
# p2779.0
# p2848.0
# p1419.0
# p3642.0
# p1544.0
# p1911.0
# p597.0
# p2798.0
# p437.0
# p372.0
# p3000.0
# p1713.0
# p1149.0
# p2237.0
# p417.0
# p827.0
# p1976.0
# p876.0
# p1295.0
# p810.0
# p2793.0
# p4854.0
# p1582.0
# p1341.0
# p907.0
# p1833.0
# p2781.0
# p498.0
# p1019.0
# p566.0
# p2825.0
# p4923.0
# p500.0
# p413.0
# p301.0
# p318.0
# p1907.0
# p1105.0
# p467.0
# p996.0
# p490.0
# p2476.0
# p18.0
# p2094.0
# p3643.0
# p1960.0
# p1499.0
# p176.0
# p737.0
# p1116.0
# p5128.0
# p1393.0
# p1022.0
# p2226.0
# p1432.0
# p427.0
# p943.0
# p883.0
# p670.0
# p2116.0
# p63.0
# p2185.0
# p1659.0
# p428.0
# p2006.0
# p429.0
# p1520.0
# p2820.0
# p1338.0
# p2927.0
# p2012.0
# p755.0
# p49.0
# p2019.0
# p2418.0
# p842.0
# p761.0
# p338.0
# p357.0
# p45.0
# p1712.0
# p2416.0
# p2451.0
# p502.0
# p145.0
# p955.0
# p4977.0
# p2207.0
# p826.0
# p4837.0
# p847.0
# p2441.0
# p2286.0
# p641.0
# p834.0
# p754.0
# p3502.0
# p1895.0
# p815.0
# p1156.0
# p1740.0
# p1363.0
# p1383.0
# p1458.0
# p897.0
# p5.0
# p776.0
# p184.0
# p2680.0
# p2093.0
# p1642.0
# p1041.0
# p238.0
# p125.0
# p344.0
# p1787.0
# p638.0
# p915.0
# p2904.0
# p1388.0
# p954.0
# p353.0
# p608.0
# p1686.0
# p497.0
# p401.0
# p450.0
# p2412.0
# p777.0
# p1112.0
# p1970.0
# p692.0
# p371.0
# p1623.0
# p491.0
# p254.0
# p135.0
# p3452.0
# p1685.0
# p418.0
# p1442.0
# p1901.0
# p177.0
# p224.0
# p825.0
# p412.0
# p848.0
# p1008.0
# p268.0
# p10779.0
# p516.0
# p895.0
# p2677.0
# p568.0
# p369.0
# p2861.0
# p256.0
# p1564.0
# p944.0
# p248.0
# p1391.0
# p1638.0
# p1.0
# p4755.0
# p953.0
# p2202.0
# p266.0
# p10.0
# p1251.0
# p635.0
# p239.0
# p183.0
# p3365.0
# p1032.0
# p708.0
# p817.0
# p2836.0
# p760.0
# p116.0
# p223.0
# p273.0
# p989.0
# p1731.0
# p1684.0
# p604.0
# p2667.0
# p1644.0
# p1389.0
# p1931.0
# p255.0
# p420.0
# p367.0
# p2870.0
# p258.0
# p742.0
# p20.0
# p2056.0
# p3879.0
# p606.0
# p1382.0
# p2293.0
# p111.0
# p2956.0
# p1173.0
# p1337.0
# p1125.0
# p1507.0
# p499.0
# p1328.0
# p1118.0
# p1366.0
# p1800.0
# p214.0
# p1610.0
# p257.0
# p232.0
# p2835.0
# p531.0
# p743.0
# p1004.0
# p2419.0
# p600.0
# p1340.0
# p2729.0
# p1583.0
# p2953.0
# p233.0
# p1010.0
# p416.0
# p2042.0
# p869.0
# p631.0
# p712.0
# p1572.0
# p4102.0
# p1192.0
# p1593.0
# p1150.0
# p2796.0
# p448.0
# p1191.0
# p402.0
# p2654.0
# p352.0
# p1832.0
# p107.0
# p480.0
# p1898.0
# p267.0
# p1394.0
# p241.0
# p6.0
# p2697.0
# p748.0
# p1982.0
# p35.0
# p929.0
# p192.0
# p1360.0
# p2951.0
# p2472.0
# p374.0
# p1822.0
# p3438.0
# p3349.0
# p327.0
# p759.0
# p2864.0
# p236.0
# p805.0
# p2319.0
# p725.0
# p2706.0
# p1095.0
# p3975.0
# p583.0
# p565.0
# p683.0
# p2037.0
# p636.0
# p269.0
# p325.0
# p541.0
# p240.0
# p191.0
# p1154.0
# p175.0

# %%
def get_peak(peakinfolist, cid):
    for peak in peakinfolist:
        if peak.cid == cid:
            return peak

# %%
from rdkit import Chem,DataStructs
mol1 = Chem.MolFromSmiles("CC(C)C=CCCCCC(=O)NCc1ccc(c(c1)OC)O")
mol2 = Chem.MolFromSmiles("COC1=C(C=CC(=C1)C=O)O")
fp1 = Chem.RDKFingerprint(mol1)
fp2 = Chem.RDKFingerprint(mol2)
print("RDK fingerprint: ",DataStructs.TanimotoSimilarity(fp1,fp2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-4011dce88f41> in <module>
# ----> 1 from rdkit import Chem,DataStructs
#       2 mol1 = Chem.MolFromSmiles("CC(C)C=CCCCCC(=O)NCc1ccc(c(c1)OC)O")
#       3 mol2 = Chem.MolFromSmiles("COC1=C(C=CC(=C1)C=O)O")
#       4 fp1 = Chem.RDKFingerprint(mol1)
#       5 fp2 = Chem.RDKFingerprint(mol2)
#
# ModuleNotFoundError: No module named 'rdkit'

# %%
get_peak_info(1463)
# Out:
# peak 1463: 209.09213899311263, 9.323316198803509
#
#                 p-val: 0.000125347662993327, 4.07637391147651
#
#                 ['porphobilinogen', 'l-kynurenine$formyl-5-hydroxykynurenamine']
#
#                 ['Tryptophan metabolism', 'Porphyrin metabolism']
#
#                 C00328;C05647
#
#                 {'frag_pos_vl': <mnet.Spectrum object at 0x12c9cf910>}
#
#                 <peakinfo.AdductList object at 0x1225ab8e0>
#
#                 <peakinfo.Adduct object at 0x12f4e0d60> 0.588843857846385

# %%
with open(osp+'pymz/mzmine/peak_picked_files/peakinfolist.dict', 'wb') as handle:
    pickle.dump(peakinfolist, handle)

# %%
# plot heatmap
g = sns.clustermap(group_intensities, center=0, cmap='vlag', col_colors=group_colours,
                       col_cluster=False, linewidths=0.75, cbar_pos=(0.1, 0.05, 0.05, 0.18))

plt.suptitle('Formula Hits in Pathways', y=0.85)

# draw group legend
for group in used_groups:
    g.ax_col_dendrogram.bar(0, 0, color=group_lut[group], label=group, linewidth=0)
g.ax_col_dendrogram.legend(loc="right")

    plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)

    # render plot
    st.pyplot()

    data = []
    for idx in members:
        formula = ','.join(dataset_row_id_to_unique_ids[idx])
        row = [idx, formula]
        data.append(row)
    data_df = pd.DataFrame(data, columns=['Row Index', 'Formula Annotations'])

# %% [markdown]
# ## Prepare data for PALS and reactome

# %%
sample_values_negative

# %%
cids = []
keggs = []
for peak in peakinfolist_positive:
    if peak.pval != 0:
        cids.append(peak.cid)
        #save it like this for pals
        keggs.append(str(peak.get_possible_kegg_ids()).translate({ord('['): '', ord(']'): '', ord('\''): ''}))
        print(peak.get_possible_kegg_ids())
# Out:
# ['C00418']
# ['C00906' 'C00064' 'C00047']
# NaN
# NaN
# NaN
# NaN
# ['C00245' 'C00245']
# NaN
# ['C02642' 'C00152']
# NaN
# NaN
# ['C00064' 'C05100' 'C00819']
# NaN
# NaN
# ['C00906']
# NaN
# ['C01879' 'C04281' 'C04282']
# ['C05522' 'C00380' 'C00380']
# NaN
# ['C02238']
# NaN
# NaN
# NaN
# ['C00418']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C06124']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C06124']
# NaN
# NaN
# NaN
# ['C02727']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00491' 'C00491']
# NaN
# NaN
# ['C00155' None]
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00217' 'C00025' 'C05938' 'C00408']
# ['tmndnccrn']
# NaN
# NaN
# NaN
# NaN
# ['C02990']
# ['dcsptn1crn' 'clpndcrn']
# ['C05587' 'C07453' 'C00250']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00410']
# NaN
# NaN
# ['C00328' 'C05647' 'C00328' 'C00328']
# ['C00073' 'C00073' 'C00073']
# NaN
# NaN
# NaN
# ['C00064' 'C05100' 'C00819']
# ['C05519' 'C00188']
# NaN
# NaN
# NaN
# NaN
# ['C00064' 'C05100' 'C00819']
# ['C13747' 'C07480' 'C01586']
# ['C00073' None]
# ['C00073']
# NaN
# ['C05519' 'C00188' 'C00408']
# NaN
# ['C02838']
# NaN
# NaN
# NaN
# NaN
# ['C00483' 'C01183' 'C02735' 'C00079']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['c226crn']
# ['C00079' 'CE2172']
# NaN
# NaN
# ['C00073']
# NaN
# NaN
# NaN
# [None]
# ['C00079' 'CE2172']
# NaN
# NaN
# ['C00906']
# NaN
# NaN
# NaN
# ['C00135']
# NaN
# ['C00031' 'C00221' 'C00247' 'C02336' 'C00267' 'C00738' 'C00936' 'C00095'
#  'C00962' 'C01582' 'C00795' 'C00137' 'C00293' 'C00124' 'C00984' 'C00159']
# ['pcrn']
# ['C05828' 'C00153']
# NaN
# NaN
# ['CE2122']
# NaN
# ['C02838']
# ['pcrn']
# NaN
# NaN
# ['C00178']
# NaN
# ['C00073']
# NaN
# NaN
# NaN
# ['lneldccrn' 'lnlccrn']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['CE2577']
# NaN
# ['C05519' 'C00188']
# NaN
# NaN
# NaN
# ['C06178']
# NaN
# ['C02642' 'C00152' 'C00300']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C05462' 'C05466']
# NaN
# ['C03239' 'C02946' 'C04076']
# ['C04148' 'C05642']
# ['C01252']
# ['C01035']
# NaN
# NaN
# NaN
# NaN
# ['C01026']
# NaN
# ['elaidcrn' 'vacccrn' 'odecrn']
# NaN
# ['C00439']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00327']
# NaN
# ['C16595' 'C16587' 'C00954']
# NaN
# NaN
# NaN
# ['C01035']
# ['tetpent6crn' 'tetpent3crn']
# NaN
# ['C00135']
# ['C05462' 'C05466']
# NaN
# NaN
# ['C00300' 'C06804']
# NaN
# NaN
# NaN
# ['C05660' 'C00078']
# NaN
# NaN
# NaN
# ['C00327']
# ['C02356' 'C01026' 'C00334' 'C05145' 'C01205' 'C03284']
# ['C00077' 'C00515' 'C01602']
# NaN
# ['tetpent6crn' 'tetpent3crn']
# NaN
# ['C00078' 'C00525' 'C00078' 'C00078']
# NaN
# NaN
# ['C00327']
# NaN
# NaN
# ['C00078' 'C00525']
# ['C00073']
# NaN
# NaN
# ['C00791' 'C00147' 'C03758']
# NaN
# NaN
# NaN
# NaN
# ['C00719' 'C00431' 'C00183']
# ['C08261']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00065' 'C00740' 'C00065']
# NaN
# NaN
# ['pcrn']
# NaN
# ['C00785' 'C00262']
# NaN
# ['C02727']
# NaN
# NaN
# ['C02356' 'C01026' 'C00334' 'C05145' 'C01205' 'C03284' 'C01026']
# ['C00906']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C03564']
# NaN
# ['C03214' 'C00441' 'C03508' 'C00719']
# ['C04092' 'C00450']
# NaN
# NaN
# ['C00213' 'C00041' 'C00099' 'C00133']
# ['C01595' 'C01595']
# NaN
# NaN
# ['C00302']
# NaN
# NaN
# NaN
# ['C00213' 'C00041' 'C00099' 'C00133' 'C00041']
# NaN
# NaN
# NaN
# NaN
# ['C04148' 'C05642']
# ['C00864']
# NaN
# NaN
# ['C00250' 'C05587']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C05587' 'C07453']
# NaN
# NaN
# NaN
# NaN
# ['C08261']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C04221']
# NaN
# NaN
# ['C00123']
# NaN
# NaN
# NaN
# NaN
# ['C05842' 'C05843']
# NaN
# ['C00217' 'C00025' 'C05938']
# NaN
# NaN
# ['C03087']
# NaN
# NaN
# ['C05842' 'C05843']
# ['C01152']
# ['C00262']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00262']
# NaN
# ['C00791' 'C00791']
# NaN
# ['C00318']
# NaN
# NaN
# ['C04148' 'C05642']
# ['dmnoncrn']
# ['C00262']
# ['C05589' 'C00788']
# NaN
# ['C06459']
# NaN
# NaN
# ['C00643']
# ['C00355' 'C01586']
# NaN
# NaN
# NaN
# NaN
# ['C00123' 'C00407']
# ['C05936' 'C00408' 'C00408']
# NaN
# NaN
# NaN
# NaN
# ['C00123' 'C00407' 'C00123']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C05589' 'C00788']
# NaN
# ['C05588']
# NaN
# NaN
# NaN
# ['C03680' 'C00785']
# ['C03680']
# NaN
# NaN
# NaN
# ['C03680']
# ['C03341']
# NaN
# NaN
# NaN
# ['C00082' 'CE2174' 'C00082' 'C00082']
# ['C02505' 'C02558' None]
# NaN
# ['C00108']
# NaN
# ['C00037' 'C00037']
# NaN
# ['C00355']
# NaN
# NaN
# ['C03912' 'C03564' 'C00791']
# ['C00135' 'C00135']
# ['C00082' 'CE2174']
# ['C04148' 'C05642']
# NaN
# ['C00437']
# NaN
# NaN
# ['C01165' 'C01157' 'C00430' 'C03440' 'C01110']
# ['C05588']
# ['C05583' 'C05582']
# NaN
# NaN
# ['C00246']
# ['C01595']
# NaN
# NaN
# NaN
# ['C00300']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C00123' 'C00407']
# NaN
# NaN
# ['C00318' 'C00318']
# ['C00437']
# ['C04092' 'C00450']
# NaN
# ['C03564']
# NaN
# NaN
# NaN
# ['C03680']
# NaN
# ['C08261']
# ['C05588']
# NaN
# NaN
# NaN
# ['C00329']
# NaN
# ['C14762' 'C14826' 'C14825']
# NaN
# NaN
# ['C03680']
# NaN
# ['C00318']
# NaN
# NaN
# NaN
# NaN
# ['pcrn']
# NaN
# ['C05589' 'C00788']
# NaN
# NaN
# ['C00791']
# NaN
# NaN
# NaN
# NaN
# ['C00719']
# ['C00123' 'C00407' 'C01026']
# ['C01035']
# NaN
# ['C05936' 'C00408']
# ['C00250' 'C00250']
# NaN
# NaN
# ['C01152']
# ['C00437']
# ['C05543']
# NaN
# NaN
# ['C05936' 'C00408']
# NaN
# NaN
# NaN
# NaN
# NaN
# ['CE5665']
# ['C00047' 'C00408']
# ['C00864' 'C00864']
# ['C00108']
# ['C00719']
# NaN
# NaN
# NaN
# ['C00123' 'C00407']
# NaN
# NaN
# ['C03912' 'C03564' 'C00791']
# ['C00122']
# NaN
# ['C03341' 'C00300']
# ['C00318' 'C00318' 'C00318']
# ['C00864']
# NaN
# ['C01152']
# ['C05828']
# ['C05589' 'C00788' 'C00079' 'C00079']
# NaN
# ['C05548']
# ['C00906']
# NaN
# ['C00719' 'C00431' 'C00183']
# NaN
# ['C05588' 'C00314']
# ['C00719']
# ['C05589' 'C00788']
# NaN
# ['CE1944' 'C00148']
# NaN
# NaN
# NaN
# NaN
# ['C01888' 'C02229' 'C05665']
# NaN
# ['C05936' 'C00408']
# ['C00719']
# ['C00791' 'C00791' 'C00791']
# ['C00108']
# NaN
# ['C08261']
# ['C03087']
# NaN
# ['C00437' 'C00062']
# NaN
# ['C00122' 'C00148']
# ['C05519' 'C00188']
# ['CE2577']
# NaN
# NaN
# ['C05543']
# NaN
# NaN
# ['C05589' 'C00788']
# NaN
# NaN
# ['C00123']
# ['C02238']
# NaN
# ['C05519' 'C00188' 'C00263' 'C00188']
# ['C05589' 'C00788']
# ['C05519' 'C00188']
# NaN
# NaN
# ['C05543']
# ['pcrn']
# NaN
# NaN
# NaN
# NaN
# ['C00327']
# NaN
# NaN
# ['C03680' 'C00785']
# NaN
# ['C12448' 'egme']
# ['C12448' 'egme']
# NaN
# ['CE4788' 'C00763' 'C00148']
# NaN
# ['C00719' 'C00431' 'C00183']
# ['C00719']
# NaN
# ['C03087']
# ['C05589' 'C00788']
# NaN
# NaN
# ['C03239' 'C02946' 'C04076']
# ['C05588']
# NaN
# NaN
# NaN
# ['C00581' 'gudac']
# NaN
# ['C00791']
# ['C04148' 'C05642']
# NaN
# ['C00302']
# ['C00632']
# ['C00355']
# NaN
# ['C05548']
# ['C12448' 'egme']
# NaN
# NaN
# NaN
# ['C00547' 'C00314']
# ['C05936' 'C00408' 'C00408']
# NaN
# ['C00047']
# NaN
# ['C05519' 'C00188']
# ['C00262' 'C00262' 'C00262']
# NaN
# NaN
# NaN
# ['C00719' 'C00431' 'C00183' 'C00719']
# ['C00719' 'C00431' 'C00183']
# ['dcsptn1crn' 'clpndcrn']
# NaN
# NaN
# NaN
# ['C06459']
# ['C00791']
# NaN
# NaN
# ['C00762' 'C01780']
# ['C05936' 'C00408']
# NaN
# ['C05543']
# NaN
# NaN
# NaN
# NaN
# ['C02505' 'C00719']
# NaN
# NaN
# NaN
# ['C04230']
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ['C05936' 'C00408']
# NaN
# ['C00178' 'C02835']
# NaN
# ['C00956' 'C00719' 'C00719']
# ['CE4788' 'C00763' 'C00148']
# NaN
# ['C00791' 'C00791']

# %%
annotation_df = pd.DataFrame((cids, keggs), ('peak_id', 'entity_id' )).transpose()

# %%
annotation_df
# Out:
#     peak_id             entity_id
# 0       633                C00418
# 1       613  C00906 C00064 C00047
# 2      3109                   NaN
# 3      3028                   NaN
# 4      2989                   NaN
# ..      ...                   ...
# 620     541                   NaN
# 621     240  C00956 C00719 C00719
# 622     191  CE4788 C00763 C00148
# 623    1154                   NaN
# 624     175         C00791 C00791
#
# [625 rows x 2 columns]

# %%
annotation_df.to_csv(osp+'pals_analysis/annotation.csv',index=False)

# %%
pd.read_csv(osp+'pals_analysis/annotation.csv')
# Out:
#      peak_id                     entity_id
# 0        633                    ['C00418']
# 1        613  ['C00906' 'C00064' 'C00047']
# 2       3109                            []
# 3       3028                            []
# 4       2989                            []
# ..       ...                           ...
# 620      541                            []
# 621      240  ['C00956' 'C00719' 'C00719']
# 622      191  ['CE4788' 'C00763' 'C00148']
# 623     1154                            []
# 624      175           ['C00791' 'C00791']
#
# [625 rows x 2 columns]

# %%
samples_values.columns = kid

# %%
kid =[]
for i in samples_values.columns:
    if int(i):
        peak = get_peak(peakinfolist_positive, int(i))
        kid.append(peak.get_possible_kegg_ids()[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-58e0d8ed0438> in <module>
#       1 kid =[]
#       2 for i in samples_values.columns:
# ----> 3     if int(i):
#       4         peak = get_peak(peakinfolist_positive, int(i))
#       5         kid.append(peak.get_possible_kegg_ids()[0])
#
# ValueError: invalid literal for int() with base 10: 'Condition'

# %%
kid.append('Condition')
kid.append('Dataset')
kid.append('Condition')

# %%
samples_values = samples_values.transpose()

# %%
samples_values = samples_values[~samples_values.index.duplicated(keep='first')]

# %%
samples_values.to_csv(osp+'ss.csv')

# %% [markdown]
# ## RT grouping

# %%
import numpy as np

# %%
def create_bins_mz_range(lista, n_bins):
    lista.sort()
    lowest_value = np.min(lista)-0.001
    highest_value = np.max(lista)+0.001
    width = (highest_value - lowest_value)/n_bins
    bins = []
    for i in range(n_bins):
        bins.append((lowest_value+width*i, lowest_value+width*(i+1)))
    nb = [i[0] for i in bins]
    nb.append(bins[-1][1])
    return bins

# %%
peakinfolist = peakinfolist_positive

# %%
rt = []
for peak in peakinfolist:
    rt.append(peak.rt)
bins = create_bins_mz_range(rt, 10)

# %%
bins
# Out:
# [(2.9269174575490164, 4.304436214450107),
#  (4.304436214450107, 5.681954971351198),
#  (5.681954971351198, 7.059473728252289),
#  (7.059473728252289, 8.43699248515338),
#  (8.43699248515338, 9.814511242054472),
#  (9.814511242054472, 11.192029998955562),
#  (11.192029998955562, 12.569548755856653),
#  (12.569548755856653, 13.947067512757744),
#  (13.947067512757744, 15.324586269658836),
#  (15.324586269658836, 16.702105026559927)]

# %%
peakbins = []
for peak in peakinfolist:
    if bins[6][0]<=peak.rt<=bins[6][1]:
        peakbins.append(peak)

# %%
print(peakbins)
# Out:
# [<peakinfo.PeakInfo object at 0x121409550>, <peakinfo.PeakInfo object at 0x121411310>, <peakinfo.PeakInfo object at 0x12132b130>, <peakinfo.PeakInfo object at 0x121323eb0>, <peakinfo.PeakInfo object at 0x1213120d0>, <peakinfo.PeakInfo object at 0x1212f12e0>, <peakinfo.PeakInfo object at 0x1212cc790>, <peakinfo.PeakInfo object at 0x12130eca0>, <peakinfo.PeakInfo object at 0x1212edee0>, <peakinfo.PeakInfo object at 0x1212c0250>, <peakinfo.PeakInfo object at 0x12132fbe0>, <peakinfo.PeakInfo object at 0x121228910>, <peakinfo.PeakInfo object at 0x12121c3a0>, <peakinfo.PeakInfo object at 0x121096190>, <peakinfo.PeakInfo object at 0x121065cd0>, <peakinfo.PeakInfo object at 0x1215e26d0>, <peakinfo.PeakInfo object at 0x1217892e0>, <peakinfo.PeakInfo object at 0x1217fcee0>, <peakinfo.PeakInfo object at 0x121878ee0>, <peakinfo.PeakInfo object at 0x1217eb2e0>, <peakinfo.PeakInfo object at 0x121832130>, <peakinfo.PeakInfo object at 0x121873820>, <peakinfo.PeakInfo object at 0x12186fac0>, <peakinfo.PeakInfo object at 0x12181dac0>, <peakinfo.PeakInfo object at 0x1218f7ac0>, <peakinfo.PeakInfo object at 0x121918af0>, <peakinfo.PeakInfo object at 0x1219385e0>, <peakinfo.PeakInfo object at 0x121949b50>, <peakinfo.PeakInfo object at 0x121987fd0>, <peakinfo.PeakInfo object at 0x12199b400>, <peakinfo.PeakInfo object at 0x121966550>, <peakinfo.PeakInfo object at 0x12198ba30>, <peakinfo.PeakInfo object at 0x1210e4760>, <peakinfo.PeakInfo object at 0x1217b2c70>, <peakinfo.PeakInfo object at 0x1218887f0>, <peakinfo.PeakInfo object at 0x121115c40>, <peakinfo.PeakInfo object at 0x1218d67f0>, <peakinfo.PeakInfo object at 0x1219cc670>, <peakinfo.PeakInfo object at 0x1219dda30>, <peakinfo.PeakInfo object at 0x121a54b50>, <peakinfo.PeakInfo object at 0x1217f42e0>, <peakinfo.PeakInfo object at 0x121747670>, <peakinfo.PeakInfo object at 0x1212fe490>, <peakinfo.PeakInfo object at 0x12126d760>, <peakinfo.PeakInfo object at 0x1211f24c0>, <peakinfo.PeakInfo object at 0x121259b50>, <peakinfo.PeakInfo object at 0x121143bb0>, <peakinfo.PeakInfo object at 0x12112eb20>, <peakinfo.PeakInfo object at 0x121109580>, <peakinfo.PeakInfo object at 0x12105ef40>, <peakinfo.PeakInfo object at 0x1215ac430>, <peakinfo.PeakInfo object at 0x1215b0640>, <peakinfo.PeakInfo object at 0x1215830a0>, <peakinfo.PeakInfo object at 0x121857d30>, <peakinfo.PeakInfo object at 0x1210c4b20>, <peakinfo.PeakInfo object at 0x1212d5ca0>, <peakinfo.PeakInfo object at 0x1219721f0>, <peakinfo.PeakInfo object at 0x121463880>, <peakinfo.PeakInfo object at 0x1214db1c0>, <peakinfo.PeakInfo object at 0x1214f7250>, <peakinfo.PeakInfo object at 0x12151ceb0>, <peakinfo.PeakInfo object at 0x121510160>, <peakinfo.PeakInfo object at 0x121535fd0>, <peakinfo.PeakInfo object at 0x121a96c10>, <peakinfo.PeakInfo object at 0x121ab3af0>, <peakinfo.PeakInfo object at 0x121b53e50>]

# %%
for peak in peakbins:
    peak.add_adduct_list()
    #print(peak.adducts)

# %%
def calculate_tolerance(x, ppm):
    tolerance = x*ppm/1000000
    return tolerance

# %%
#assuming mz is h+ 
def calculate_adducts(mz):
    PROTON = 1.00727646677
        
    addList = [
         (mz + 1.0034, 'M(C13)+H[1+]'),
         ((mz + 0.5017)/2, 'M(C13)+2H[2+]'),
         ((mz + 0.3344)/3, 'M(C13)+3H[3+]'),
         (mz + 1.9958 , 'M(S34)+H[1+]'),
         (mz + 1.9972 , 'M(Cl37)+H[1+]'),
         (mz + 21.9820 , 'M+Na[1+]'),
         ((mz + 10.991 )/2, 'M+H+Na[2+]'),
         (mz + 37.9555 , 'M+K[1+]'),
         (mz + 18.0106 , 'M+H2O+H[1+]'),
         (mz - 18.0106 , 'M-H2O+H[1+]'),
         (mz - 36.0212 , 'M-H4O2+H[1+]'),
         (mz - 17.0265 , 'M-NH3+H[1+]'),
         (mz - 27.9950 , 'M-CO+H[1+]'),
         (mz - 43.9898 , 'M-CO2+H[1+]'),
         (mz - 46.0054 , 'M-HCOOH+H[1+]'),
         (mz + 67.9874 , 'M+HCOONa[1+]'),
         (mz - 67.9874 , 'M-HCOONa+H[1+]'),
         (mz + 57.9586 , 'M+NaCl[1+]'),
         (mz - 72.0211 , 'M-C3H4O2+H[1+]'),
         (mz + 83.9613 , 'M+HCOOK[1+]'),
         (mz - 83.9613 , 'M-HCOOK+H[1+]')]
    return addList

# %%
def is_adduct(mz, mzh, ppm):
    adducts = calculate_adducts(mzh)
    for adduct in adducts:
        if adduct[0]-calculate_tolerance(adduct[0], ppm) <= mz <= adduct[0]+calculate_tolerance(adduct[0], ppm):
            return True, adduct
    else:
        return False, mz

# %%
clusters = []
for n in range(len(peakbins)):

    cluster = []
    cluster.append((peakbins[n], peakbins[n].adducts[0]))
    
    for i in range(len(peakbins)):
        if i !=n :
            isadduct, adduct = is_adduct(peakbins[i].mz, peakbins[n].mz, 10)
            if isadduct:
                
                cluster.append((peakbins[i], adduct))
    if len(cluster) > 1:
        clusters.append(cluster)

# %%
len(clusters)
# Out:
# 31

# %%
import matplotlib.pyplot as plt

# %%
clusters.sort(key=len, reverse=True)

# %%
for p, a in clusters[0]:
    print(a,p)
# Out:
# (146.06913101597954, 'M+H[1+]', '') Peak p613.0: m/z = 147.07640748274954, rt = 11.905213776127336
#
#                 p-val: 2.36533127803315e-07, logFC = -2.63034608332642
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation: l-glutamine
#
#                 hmdb annotation: L-Lysine
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x12140d880>, 'gnps2': <mnet.Spectrum object at 0x12140d490>}
#
# (169.05840748274954, 'M+Na[1+]') Peak p926.0: m/z = 169.05836848208781, rt = 11.897038272605002
#
#                 p-val: 4.7551680724052403e-07, logFC = -2.1962780494017102
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# (101.07100748274954, 'M-HCOOH+H[1+]') Peak p101.0: m/z = 101.07095439850336, rt = 11.929978879334824
#
#                 p-val: 6.53074216211131e-07, logFC = -10.0563554026259
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# (130.04990748274955, 'M-NH3+H[1+]') Peak p365.0: m/z = 130.04992655703896, rt = 11.890277826892214
#
#                 p-val: 1.05024419938963e-06, logFC = -1.06619681316973
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5-oxoproline$l-1-pyrroline-3-hydroxy-5-carboxylate$1-pyrroline-4-hydroxy-2-carboxylate', 'd-glutamate; d-glutamic acid; d-glutaminic acid; d-2-aminoglutaric acid$l-glutamate$l-4-hydroxyglutamate semialdehyde', '5-oxo-l-proline']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'gnps2': <mnet.Spectrum object at 0x1212edc70>}
#
# (148.07980748274954, 'M(C13)+H[1+]') Peak p634.0: m/z = 148.07970658393756, rt = 11.903578089878053
#
#                 p-val: 0.00110447355700778, logFC = -4.68884618786971
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {}
#
# (129.06580748274953, 'M-H2O+H[1+]') Peak p344.0: m/z = 129.06585633127312, rt = 11.739301054140347
#
#                 p-val: 0.618262900518145, logFC = 0.149806584389648
#
#                 mm annotation: ['l-glutamine$3-ureidoisobutyrate$d-glutamine; d-2-aminoglutaramic acid', '5,6-dihydrothymine', '4-guanidinobutanoate']
#
#                 std annotation:
#
#                 hmdb annotation:
#
#
#                 {'frag_pos_mal': <mnet.Spectrum object at 0x121583160>, 'frag_pos_vl': <mnet.Spectrum object at 0x121583ca0>}

# %%
peakinfo
# Out:
# Object `.sort()` not found.

# %%
for c in clusters:
    print(len(c))
    mz = []
    rt = []
    for p,a in c:
        mz.append(p.mz)
        rt.append(p.rt)
    plt.plot(rt, mz, '.')
    plt.show()
# Out:
# 2
# 4
# 4
# 3
# 4
# 3
# 3
# 2
# 3
# 3
# 5
# 3
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 3
# 3
# 3
# 3
# 2
# 2
# 2
# 5
